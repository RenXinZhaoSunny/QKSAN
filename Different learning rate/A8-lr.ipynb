# %%
import pennylane as qml
from pennylane import numpy as np
from sklearn.decomposition import PCA
import random
from collections import Counter
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve

# %%
wire = 2

wires = wire * 2
dim = 2 ** wire
dim1 = 2 * dim
dev = qml.device("default.qubit", wires=wires)
#dev = qml.device("lightning.qubit", wires=wires, shots=None)
#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
dev1 = qml.device("lightning.qubit", wires=wire, shots=None)
wires = dev.wires.tolist()

@qml.qnode(dev1)
def StateVector(x):
    qml.AmplitudeEmbedding(features=x, wires=range(wire), 
                           pad_with=0.0, normalize=True)
    return qml.state()

def accuracy(labels, predictions):

    loss = 0
    for l, p in zip(labels, predictions):
        if abs(l - p) < 1e-5:
            loss = loss + 1
    loss = loss / len(labels)

    return loss

def square_loss(labels, predictions):
    loss = 0
    for l, p in zip(labels, predictions):
        loss = loss + (l - p) ** 2

    loss = loss / len(labels)
    return loss

def noramlization(data):
    minVals = data.min(0)
    maxVals = data.max(0)
    ranges = maxVals - minVals
    normData = np.zeros(np.shape(data))
    m = data.shape[0]
    normData = data - np.tile(minVals, (m, 1))
    normData = normData/np.tile(ranges, (m, 1))
    return normData

def random_params(num_wires):
    """Generate random variational parameters in the shape for the ansatz."""
    return np.random.uniform(0, 2 * np.pi, num_wires, requires_grad=True)

num_para = 5
params_init = random_params(3 * num_para + wire)
print(params_init)
# Out:
# [5.44888792 2.34189072 2.122162   1.384159   0.31832764 1.3589645
#  4.16042781 0.61400631 0.9872702  4.44041852 3.86141898 5.56382368
#  5.46683666 2.45441345 4.41022225 2.63257968 6.19577356]

# %%
def ProcessingData(datapoints, train_size, test_size):
    train_data = np.loadtxt("./mnist_train.csv", delimiter=",")
    print(train_data.shape)
    #Extracting features and labels from the dataset 
    train_data_features = train_data[:datapoints, 1:]
    train_data_labels = train_data[:datapoints, :1].reshape(datapoints,)

    # Use PCA technique to reduce dimensions to 4
    DimReduce = PCA(n_components= dim1)
    train_data_features_reduced = DimReduce.fit_transform(train_data_features)
    # normalize dataset
    train_data_features_reduced = noramlization(train_data_features_reduced)
    s1 = np.array([StateVector(x) for x in train_data_features_reduced[:,:dim]])
    s2 = np.array([StateVector(x) for x in train_data_features_reduced[:,dim:]])
    train_data_features_reduced = np.hstack((s1, s2)).tolist()

    zero_one_datapoint_array = []
    label_0_1 = []
    zero_datapoints_array = [] #an array of the data points containing value 0
    one_datapoints_array = []# an array of the data points containing value 1
    label_0 = []
    label_1 = []
        
    for i in range(datapoints):
        if train_data_labels[i] == 0:                   # extracting zeros
            label_0.append(-1)
            zero_datapoints_array.append(train_data_features_reduced[i])
        elif train_data_labels[i] == 1:                   # extracting ones
            label_1.append(1)
            one_datapoints_array.append(train_data_features_reduced[i]) 
    print(len(zero_datapoints_array), len(one_datapoints_array))
    if (len(label_0) + len(label_1)) < 2 * (train_size + test_size):
        print("datapoints is too small!")
    else:
        print((len(label_0),len(label_1)))
        zero_datapoints_array_train = zero_datapoints_array[:train_size]
        one_datapoints_array_train = one_datapoints_array[:train_size]
        label_0_train = label_0[:train_size]
        label_1_train = label_1[:train_size]
        zero_datapoints_array_test = zero_datapoints_array[train_size + 1:train_size + test_size + 1]
        one_datapoints_array_test = one_datapoints_array[train_size + 1:train_size + test_size + 1]
        label_0_test = label_0[train_size + 1:train_size + test_size + 1]
        label_1_test = label_1[train_size + 1:train_size + test_size + 1]
        #print(len(zero_datapoints_array_train), len(label_1_train))
        #print(len(one_datapoints_array_test), len(label_0_test))

        zero_one_datapoint_array_train = zero_datapoints_array_train + one_datapoints_array_train
        label_0_1_train = label_0_train + label_1_train
        zero_one_datapoint_array_test = zero_datapoints_array_test + one_datapoints_array_test
        label_0_1_test = label_0_test + label_1_test
        #print(len(zero_one_datapoint_array_train), label_0_1_train)
        #print(len(zero_one_datapoint_array_test), label_0_1_test)

        np.random.seed(10)
        index_train = np.random.permutation(range(2 * train_size))
        index_test = np.random.permutation(range(2 * test_size))

        feats_train = []
        Y_train = []
        feats_val = []
        Y_val = []
        for i in range(2 * train_size):
            feats_train.append(zero_one_datapoint_array_train[index_train[i]])
            Y_train.append(label_0_1_train[index_train[i]])


        for i in range(2 * test_size):
            feats_val.append(zero_one_datapoint_array_test[index_test[i]])
            Y_val.append(label_0_1_test[index_test[i]])

        #print(feats_val, Y_val)

        features = feats_train + feats_val
        features = np.array(features, requires_grad=False)
        Y = Y_train + Y_val
        Y = np.array(Y, requires_grad=False)
        feats_train = np.array(feats_train, requires_grad=False)
        Y_train = np.array(Y_train, requires_grad=False)
        feats_val = np.array(feats_val, requires_grad=False)
        Y_val = np.array(Y_val, requires_grad=False)
    return feats_train, Y_train, feats_val, Y_val, features, Y

datapoints = 6000
train_size = 500
test_size = 50
feats_train, Y_train, feats_val, Y_val, features, Y = ProcessingData(datapoints, train_size, test_size)
# Out:
# (60000, 785)
# 592 671
# (592, 671)

# %%
#Block-encoding + Hardware-efficient Ansatz
def DataEncoding(x, wires_start, wires_end):
    wires = np.arange(wires_start, wires_end).tolist()
    qml.MottonenStatePreparation(state_vector=x, wires=wires)
    #qml.AmplitudeEmbedding(features=x, wires=wires, pad_with=0., normalize=True)

def Ansatz(params, wires_start, wires_end):
    for i in np.arange(wires_start, wires_end):
        qml.Hadamard(wires=wires[i])
        qml.RY(params[i - wires_start], wires=wires[i])
    qml.CNOT(wires=[wires[wires_start], wires[wires_end - 1]])
    qml.RZ(params[wires_end - wires_start], wires=wires[wires_end - 1])
    qml.CNOT(wires=[wires_start, wires_end - 1])
    for i in np.arange(wires_start, wires_end):
        qml.RY(params[i + wires_end - 2 * wires_start], wires=wires[i])
        qml.Hadamard(wires=wires[i])

#@qml.qnode(dev, interface="torch", diff_method="parameter-shift")
@qml.qnode(dev)
def QKSAN(feat, params):
    x1 = feat[0:4]
    x2 = feat[4:8]
    DataEncoding(x1, 0, wire)
    Ansatz(params[0: num_para], 0, wire)
    qml.adjoint(Ansatz)(params[num_para: 2 * num_para], 0, wire)
    qml.adjoint(DataEncoding)(x2, 0, wire)


    DataEncoding(x2, wire, (2 * wire))
    Ansatz(params[2 * num_para: 3 * num_para], wire, (2 * wire))
    for i in range(wire):
        qml.cond(qml.measure(i), qml.RY)(params[3 * num_para + i], wires=wires[i + wire])
    return qml.expval(qml.PauliZ(2 * wire - 1))

qml.drawer.use_style('black_white')
fig, ax = qml.draw_mpl(QKSAN, show_all_wires=True)(feats_train[0], params_init)
fig.set_size_inches((7, 5))

def variational_classifier(params, feat):
    return QKSAN(feat, params)


def cost(params, features, labels):
    predictions = [variational_classifier(params, feat) for feat in features]
    return square_loss(labels, predictions)

lr = 0.06
def TrainQKSAN(params_init):
    opt = qml.NesterovMomentumOptimizer(lr)
    batch_size = 30
    weights = params_init
    #bias = np.array(0.0, requires_grad=True)
    his_acc_val = []
    his_acc_train = []
    his_cost = []
    f1_train = []
    f1_test = []
    roc_auc_train = []
    roc_auc_test = []
    for it in range(120):

        # Update the weights by one optimizer step
        batch_index = np.random.randint(0, 2 * train_size, (batch_size,))
        feats_train_batch = feats_train[batch_index]
        Y_train_batch = Y_train[batch_index]
        
        weights, _, _ = opt.step(cost, weights, feats_train_batch, Y_train_batch)

        # Compute predictions on train and validation set
        predictions_train = [np.sign(variational_classifier(weights, feat)) for feat in feats_train]
        predictions_val = [np.sign(variational_classifier(weights, feat)) for feat in feats_val]
        #print(probs(Y_train, predictions_val))
        c = cost(weights, features, Y).numpy()
        #print(c)
        # Compute accuracy on train and validation set
        acc_train = accuracy_score(Y_train, predictions_train)
        acc_val = accuracy_score(Y_val, predictions_val)
        a = f1_score(Y_train, predictions_train)
        b = f1_score(Y_val, predictions_val)
        
        print("f1_score is", a, b)
        d = roc_auc_score(Y_train, predictions_train)
        e = roc_auc_score(Y_val, predictions_val)
        print("roc_auc_score is", d, e)


        f1_train.append(a)
        f1_test.append(b)
        roc_auc_train.append(d)
        roc_auc_test.append(e)
        his_acc_val.append(acc_val)
        his_acc_train.append(acc_train)
        his_cost.append(c)
        print("Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
            "".format(it + 1, c, acc_train, acc_val))
        
    return his_acc_val, his_acc_train, his_cost, f1_train, f1_test, roc_auc_train, roc_auc_test

# %%
lear_rate = [0.07, 0.08, 0.09]
a = []
b = []
c = []
for lr in lear_rate:
    a1, a2, a3, _, _, _, _, = TrainQKSAN(params_init)
    a.append(a1)
    b.append(a2)
    c.append(a3)
print(a)
print(b)
print(c)
# Out:
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     1 | Cost: 1.4480591 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     2 | Cost: 1.3414638 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6684491978609626 0.6666666666666666
# roc_auc_score is 0.504 0.5
# Iter:     3 | Cost: 1.2020770 | Acc train: 0.5040000 | Acc validation: 0.5000000
# f1_score is 0.6906077348066298 0.684931506849315
# roc_auc_score is 0.552 0.54
# Iter:     4 | Cost: 1.0837699 | Acc train: 0.5520000 | Acc validation: 0.5400000
# f1_score is 0.746969696969697 0.7462686567164178
# roc_auc_score is 0.6659999999999999 0.6599999999999999
# Iter:     5 | Cost: 1.0210445 | Acc train: 0.6660000 | Acc validation: 0.6600000
# f1_score is 0.0846262341325811 0.13513513513513514
# roc_auc_score is 0.351 0.36000000000000004
# Iter:     6 | Cost: 1.0269809 | Acc train: 0.3510000 | Acc validation: 0.3600000
# f1_score is 0.0 0.0
# roc_auc_score is 0.437 0.46
# Iter:     7 | Cost: 1.0661567 | Acc train: 0.4370000 | Acc validation: 0.4600000
# f1_score is 0.0 0.0
# roc_auc_score is 0.484 0.5
# Iter:     8 | Cost: 1.0861897 | Acc train: 0.4840000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.498 0.5
# Iter:     9 | Cost: 1.0881739 | Acc train: 0.4980000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.499 0.5
# Iter:    10 | Cost: 1.0768598 | Acc train: 0.4990000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.499 0.5
# Iter:    11 | Cost: 1.0465996 | Acc train: 0.4990000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.494 0.5
# Iter:    12 | Cost: 1.0105991 | Acc train: 0.4940000 | Acc validation: 0.5000000
# f1_score is 0.64349376114082 0.6942148760330579
# roc_auc_score is 0.6 0.63
# Iter:    13 | Cost: 0.9943527 | Acc train: 0.6000000 | Acc validation: 0.6300000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    14 | Cost: 1.0028377 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    15 | Cost: 1.0262709 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    16 | Cost: 1.0631766 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    17 | Cost: 1.0876043 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    18 | Cost: 1.0959770 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    19 | Cost: 1.0920459 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    20 | Cost: 1.0696037 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.66711140760507 0.6666666666666666
# roc_auc_score is 0.501 0.5
# Iter:    21 | Cost: 1.0456268 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.6839945280437757 0.6802721088435374
# roc_auc_score is 0.538 0.53
# Iter:    22 | Cost: 1.0058053 | Acc train: 0.5380000 | Acc validation: 0.5300000
# f1_score is 0.7699604743083003 0.7874015748031497
# roc_auc_score is 0.709 0.73
# Iter:    23 | Cost: 0.9840727 | Acc train: 0.7090000 | Acc validation: 0.7300000
# f1_score is 0.03139717425431711 0.03225806451612903
# roc_auc_score is 0.383 0.4
# Iter:    24 | Cost: 0.9771252 | Acc train: 0.3830000 | Acc validation: 0.4000000
# f1_score is 0.007194244604316545 0.03636363636363636
# roc_auc_score is 0.448 0.47000000000000003
# Iter:    25 | Cost: 0.9658139 | Acc train: 0.4480000 | Acc validation: 0.4700000
# f1_score is 0.007920792079207921 0.07692307692307693
# roc_auc_score is 0.499 0.52
# Iter:    26 | Cost: 0.9531347 | Acc train: 0.4990000 | Acc validation: 0.5200000
# f1_score is 0.16819012797074956 0.36065573770491804
# roc_auc_score is 0.545 0.61
# Iter:    27 | Cost: 0.9337546 | Acc train: 0.5450000 | Acc validation: 0.6100000
# f1_score is 0.3216080402010051 0.5915492957746479
# roc_auc_score is 0.595 0.71
# Iter:    28 | Cost: 0.9171148 | Acc train: 0.5950000 | Acc validation: 0.7100000
# f1_score is 0.6076294277929155 0.8095238095238095
# roc_auc_score is 0.712 0.8400000000000001
# Iter:    29 | Cost: 0.8894895 | Acc train: 0.7120000 | Acc validation: 0.8400000
# f1_score is 0.7488584474885844 0.9
# roc_auc_score is 0.78 0.9
# Iter:    30 | Cost: 0.8562763 | Acc train: 0.7800000 | Acc validation: 0.9000000
# f1_score is 0.7819095477386935 0.8807339449541285
# roc_auc_score is 0.783 0.87
# Iter:    31 | Cost: 0.8332371 | Acc train: 0.7830000 | Acc validation: 0.8700000
# f1_score is 0.7887323943661971 0.8596491228070174
# roc_auc_score is 0.7749999999999999 0.84
# Iter:    32 | Cost: 0.8166149 | Acc train: 0.7750000 | Acc validation: 0.8400000
# f1_score is 0.7796917497733453 0.8376068376068375
# roc_auc_score is 0.757 0.81
# Iter:    33 | Cost: 0.8029069 | Acc train: 0.7570000 | Acc validation: 0.8100000
# f1_score is 0.7716390423572743 0.8347826086956522
# roc_auc_score is 0.752 0.8099999999999999
# Iter:    34 | Cost: 0.7878689 | Acc train: 0.7520000 | Acc validation: 0.8100000
# f1_score is 0.7659176029962548 0.8495575221238937
# roc_auc_score is 0.75 0.83
# Iter:    35 | Cost: 0.7735378 | Acc train: 0.7500000 | Acc validation: 0.8300000
# f1_score is 0.7600767754318617 0.8648648648648649
# roc_auc_score is 0.7499999999999999 0.85
# Iter:    36 | Cost: 0.7578660 | Acc train: 0.7500000 | Acc validation: 0.8500000
# f1_score is 0.7524752475247525 0.8623853211009174
# roc_auc_score is 0.75 0.85
# Iter:    37 | Cost: 0.7419046 | Acc train: 0.7500000 | Acc validation: 0.8500000
# f1_score is 0.7497446373850868 0.8867924528301886
# roc_auc_score is 0.7550000000000001 0.88
# Iter:    38 | Cost: 0.7246672 | Acc train: 0.7550000 | Acc validation: 0.8800000
# f1_score is 0.7436974789915967 0.8867924528301886
# roc_auc_score is 0.756 0.88
# Iter:    39 | Cost: 0.7097955 | Acc train: 0.7560000 | Acc validation: 0.8800000
# f1_score is 0.7544041450777201 0.8867924528301886
# roc_auc_score is 0.763 0.88
# Iter:    40 | Cost: 0.6977044 | Acc train: 0.7630000 | Acc validation: 0.8800000
# f1_score is 0.7647058823529411 0.8867924528301886
# roc_auc_score is 0.768 0.88
# Iter:    41 | Cost: 0.6867956 | Acc train: 0.7680000 | Acc validation: 0.8800000
# f1_score is 0.7801980198019802 0.8867924528301886
# roc_auc_score is 0.778 0.88
# Iter:    42 | Cost: 0.6771847 | Acc train: 0.7780000 | Acc validation: 0.8800000
# f1_score is 0.7765419615773508 0.8867924528301886
# roc_auc_score is 0.7790000000000001 0.88
# Iter:    43 | Cost: 0.6638149 | Acc train: 0.7790000 | Acc validation: 0.8800000
# f1_score is 0.7775510204081633 0.8867924528301886
# roc_auc_score is 0.782 0.88
# Iter:    44 | Cost: 0.6522852 | Acc train: 0.7820000 | Acc validation: 0.8800000
# f1_score is 0.7648305084745762 0.9038461538461539
# roc_auc_score is 0.778 0.8999999999999999
# Iter:    45 | Cost: 0.6414142 | Acc train: 0.7780000 | Acc validation: 0.9000000
# f1_score is 0.7675906183368869 0.9038461538461539
# roc_auc_score is 0.7819999999999999 0.8999999999999999
# Iter:    46 | Cost: 0.6332361 | Acc train: 0.7820000 | Acc validation: 0.9000000
# f1_score is 0.7609649122807017 0.8910891089108911
# roc_auc_score is 0.7819999999999999 0.89
# Iter:    47 | Cost: 0.6277592 | Acc train: 0.7820000 | Acc validation: 0.8900000
# f1_score is 0.7725788900979327 0.8910891089108911
# roc_auc_score is 0.791 0.89
# Iter:    48 | Cost: 0.6191238 | Acc train: 0.7910000 | Acc validation: 0.8900000
# f1_score is 0.7898627243928193 0.912621359223301
# roc_auc_score is 0.8009999999999999 0.91
# Iter:    49 | Cost: 0.6096233 | Acc train: 0.8010000 | Acc validation: 0.9100000
# f1_score is 0.8078512396694215 0.9038461538461539
# roc_auc_score is 0.814 0.8999999999999999
# Iter:    50 | Cost: 0.6016760 | Acc train: 0.8140000 | Acc validation: 0.9000000
# f1_score is 0.8444003964321111 0.9056603773584904
# roc_auc_score is 0.8429999999999999 0.8999999999999999
# Iter:    51 | Cost: 0.5958843 | Acc train: 0.8430000 | Acc validation: 0.9000000
# f1_score is 0.8549019607843137 0.8971962616822429
# roc_auc_score is 0.8519999999999999 0.8900000000000001
# Iter:    52 | Cost: 0.5895445 | Acc train: 0.8520000 | Acc validation: 0.8900000
# f1_score is 0.8675623800383877 0.888888888888889
# roc_auc_score is 0.862 0.88
# Iter:    53 | Cost: 0.5851368 | Acc train: 0.8620000 | Acc validation: 0.8800000
# f1_score is 0.8718446601941748 0.9056603773584904
# roc_auc_score is 0.868 0.8999999999999999
# Iter:    54 | Cost: 0.5757881 | Acc train: 0.8680000 | Acc validation: 0.9000000
# f1_score is 0.8791208791208791 0.9142857142857144
# roc_auc_score is 0.8789999999999999 0.91
# Iter:    55 | Cost: 0.5688045 | Acc train: 0.8790000 | Acc validation: 0.9100000
# f1_score is 0.8610240334378266 0.9142857142857144
# roc_auc_score is 0.867 0.91
# Iter:    56 | Cost: 0.5695730 | Acc train: 0.8670000 | Acc validation: 0.9100000
# f1_score is 0.8761706555671176 0.9320388349514563
# roc_auc_score is 0.8810000000000001 0.93
# Iter:    57 | Cost: 0.5656975 | Acc train: 0.8810000 | Acc validation: 0.9300000
# f1_score is 0.9009009009009009 0.9142857142857144
# roc_auc_score is 0.901 0.91
# Iter:    58 | Cost: 0.5558435 | Acc train: 0.9010000 | Acc validation: 0.9100000
# f1_score is 0.9208494208494209 0.9142857142857144
# roc_auc_score is 0.9179999999999999 0.91
# Iter:    59 | Cost: 0.5489006 | Acc train: 0.9180000 | Acc validation: 0.9100000
# f1_score is 0.9242424242424243 0.9158878504672898
# roc_auc_score is 0.9199999999999999 0.91
# Iter:    60 | Cost: 0.5473140 | Acc train: 0.9200000 | Acc validation: 0.9100000
# f1_score is 0.9275634995296331 0.9259259259259259
# roc_auc_score is 0.9229999999999999 0.9199999999999999
# Iter:    61 | Cost: 0.5451633 | Acc train: 0.9230000 | Acc validation: 0.9200000
# f1_score is 0.9233644859813085 0.9259259259259259
# roc_auc_score is 0.918 0.9199999999999999
# Iter:    62 | Cost: 0.5442882 | Acc train: 0.9180000 | Acc validation: 0.9200000
# f1_score is 0.9168207024029574 0.9174311926605504
# roc_auc_score is 0.9100000000000001 0.91
# Iter:    63 | Cost: 0.5461475 | Acc train: 0.9100000 | Acc validation: 0.9100000
# f1_score is 0.9330819981149859 0.9345794392523363
# roc_auc_score is 0.929 0.9299999999999999
# Iter:    64 | Cost: 0.5405651 | Acc train: 0.9290000 | Acc validation: 0.9300000
# f1_score is 0.930188679245283 0.9345794392523363
# roc_auc_score is 0.9259999999999999 0.9299999999999999
# Iter:    65 | Cost: 0.5407327 | Acc train: 0.9260000 | Acc validation: 0.9300000
# f1_score is 0.9328287606433302 0.9345794392523363
# roc_auc_score is 0.929 0.9299999999999999
# Iter:    66 | Cost: 0.5397983 | Acc train: 0.9290000 | Acc validation: 0.9300000
# f1_score is 0.9216417910447761 0.9174311926605504
# roc_auc_score is 0.916 0.91
# Iter:    67 | Cost: 0.5432459 | Acc train: 0.9160000 | Acc validation: 0.9100000
# f1_score is 0.9324452901998096 0.9433962264150945
# roc_auc_score is 0.929 0.94
# Iter:    68 | Cost: 0.5379658 | Acc train: 0.9290000 | Acc validation: 0.9400000
# f1_score is 0.943798449612403 0.9320388349514563
# roc_auc_score is 0.9420000000000001 0.93
# Iter:    69 | Cost: 0.5358023 | Acc train: 0.9420000 | Acc validation: 0.9300000
# f1_score is 0.946236559139785 0.9108910891089109
# roc_auc_score is 0.9450000000000001 0.91
# Iter:    70 | Cost: 0.5357628 | Acc train: 0.9450000 | Acc validation: 0.9100000
# f1_score is 0.9491525423728813 0.9
# roc_auc_score is 0.9489999999999998 0.9
# Iter:    71 | Cost: 0.5395269 | Acc train: 0.9490000 | Acc validation: 0.9000000
# f1_score is 0.9512437810945273 0.9
# roc_auc_score is 0.9509999999999998 0.9
# Iter:    72 | Cost: 0.5373375 | Acc train: 0.9510000 | Acc validation: 0.9000000
# f1_score is 0.9383429672447012 0.9108910891089109
# roc_auc_score is 0.936 0.91
# Iter:    73 | Cost: 0.5337748 | Acc train: 0.9360000 | Acc validation: 0.9100000
# f1_score is 0.9280303030303031 0.9142857142857144
# roc_auc_score is 0.9239999999999999 0.91
# Iter:    74 | Cost: 0.5380565 | Acc train: 0.9240000 | Acc validation: 0.9100000
# f1_score is 0.8943533697632058 0.8849557522123894
# roc_auc_score is 0.884 0.87
# Iter:    75 | Cost: 0.5568787 | Acc train: 0.8840000 | Acc validation: 0.8700000
# f1_score is 0.8894927536231885 0.8849557522123894
# roc_auc_score is 0.878 0.87
# Iter:    76 | Cost: 0.5592649 | Acc train: 0.8780000 | Acc validation: 0.8700000
# f1_score is 0.9194756554307116 0.9074074074074074
# roc_auc_score is 0.9139999999999999 0.9000000000000001
# Iter:    77 | Cost: 0.5416131 | Acc train: 0.9140000 | Acc validation: 0.9000000
# f1_score is 0.9348659003831418 0.9333333333333333
# roc_auc_score is 0.932 0.9299999999999999
# Iter:    78 | Cost: 0.5324686 | Acc train: 0.9320000 | Acc validation: 0.9300000
# f1_score is 0.958498023715415 0.9108910891089109
# roc_auc_score is 0.958 0.91
# Iter:    79 | Cost: 0.5330139 | Acc train: 0.9580000 | Acc validation: 0.9100000
# f1_score is 0.9535353535353536 0.9
# roc_auc_score is 0.954 0.9
# Iter:    80 | Cost: 0.5400469 | Acc train: 0.9540000 | Acc validation: 0.9000000
# f1_score is 0.9564356435643564 0.9108910891089109
# roc_auc_score is 0.956 0.91
# Iter:    81 | Cost: 0.5338735 | Acc train: 0.9560000 | Acc validation: 0.9100000
# f1_score is 0.9473684210526315 0.9108910891089109
# roc_auc_score is 0.9460000000000001 0.91
# Iter:    82 | Cost: 0.5319488 | Acc train: 0.9460000 | Acc validation: 0.9100000
# f1_score is 0.9458128078817734 0.9108910891089109
# roc_auc_score is 0.9449999999999998 0.91
# Iter:    83 | Cost: 0.5326420 | Acc train: 0.9450000 | Acc validation: 0.9100000
# f1_score is 0.9446640316205533 0.9108910891089109
# roc_auc_score is 0.944 0.91
# Iter:    84 | Cost: 0.5330018 | Acc train: 0.9440000 | Acc validation: 0.9100000
# f1_score is 0.9404761904761905 0.9
# roc_auc_score is 0.94 0.9
# Iter:    85 | Cost: 0.5337923 | Acc train: 0.9400000 | Acc validation: 0.9000000
# f1_score is 0.9411764705882353 0.8571428571428572
# roc_auc_score is 0.9409999999999998 0.86
# Iter:    86 | Cost: 0.5351807 | Acc train: 0.9410000 | Acc validation: 0.8600000
# f1_score is 0.9350912778904665 0.8541666666666666
# roc_auc_score is 0.936 0.86
# Iter:    87 | Cost: 0.5375230 | Acc train: 0.9360000 | Acc validation: 0.8600000
# f1_score is 0.9267782426778243 0.8387096774193548
# roc_auc_score is 0.93 0.8500000000000001
# Iter:    88 | Cost: 0.5425506 | Acc train: 0.9300000 | Acc validation: 0.8500000
# f1_score is 0.9326530612244898 0.8541666666666666
# roc_auc_score is 0.934 0.86
# Iter:    89 | Cost: 0.5379031 | Acc train: 0.9340000 | Acc validation: 0.8600000
# f1_score is 0.9362549800796813 0.8541666666666666
# roc_auc_score is 0.9359999999999999 0.86
# Iter:    90 | Cost: 0.5353087 | Acc train: 0.9360000 | Acc validation: 0.8600000
# f1_score is 0.9381237524950099 0.8541666666666666
# roc_auc_score is 0.938 0.86
# Iter:    91 | Cost: 0.5348785 | Acc train: 0.9380000 | Acc validation: 0.8600000
# f1_score is 0.9349112426035503 0.88
# roc_auc_score is 0.9339999999999999 0.8799999999999999
# Iter:    92 | Cost: 0.5342931 | Acc train: 0.9340000 | Acc validation: 0.8800000
# f1_score is 0.934761441090555 0.9019607843137256
# roc_auc_score is 0.933 0.9
# Iter:    93 | Cost: 0.5349299 | Acc train: 0.9330000 | Acc validation: 0.9000000
# f1_score is 0.9441723800195887 0.9108910891089109
# roc_auc_score is 0.943 0.91
# Iter:    94 | Cost: 0.5323526 | Acc train: 0.9430000 | Acc validation: 0.9100000
# f1_score is 0.9516288252714709 0.9108910891089109
# roc_auc_score is 0.951 0.91
# Iter:    95 | Cost: 0.5312730 | Acc train: 0.9510000 | Acc validation: 0.9100000
# f1_score is 0.9519136408243375 0.9108910891089109
# roc_auc_score is 0.951 0.91
# Iter:    96 | Cost: 0.5307220 | Acc train: 0.9510000 | Acc validation: 0.9100000
# f1_score is 0.949317738791423 0.9108910891089109
# roc_auc_score is 0.948 0.91
# Iter:    97 | Cost: 0.5307240 | Acc train: 0.9480000 | Acc validation: 0.9100000
# f1_score is 0.9392478302796528 0.9333333333333333
# roc_auc_score is 0.9369999999999999 0.9299999999999999
# Iter:    98 | Cost: 0.5314784 | Acc train: 0.9370000 | Acc validation: 0.9300000
# f1_score is 0.9308056872037914 0.9345794392523363
# roc_auc_score is 0.927 0.9299999999999999
# Iter:    99 | Cost: 0.5362319 | Acc train: 0.9270000 | Acc validation: 0.9300000
# f1_score is 0.9370229007633588 0.9345794392523363
# roc_auc_score is 0.9339999999999999 0.9299999999999999
# Iter:   100 | Cost: 0.5341846 | Acc train: 0.9340000 | Acc validation: 0.9300000
# f1_score is 0.9484936831875609 0.9433962264150945
# roc_auc_score is 0.9470000000000001 0.94
# Iter:   101 | Cost: 0.5287082 | Acc train: 0.9470000 | Acc validation: 0.9400000
# f1_score is 0.9616519174041298 0.9523809523809523
# roc_auc_score is 0.9609999999999999 0.9500000000000001
# Iter:   102 | Cost: 0.5290368 | Acc train: 0.9610000 | Acc validation: 0.9500000
# f1_score is 0.9681274900398406 0.9320388349514563
# roc_auc_score is 0.9679999999999999 0.93
# Iter:   103 | Cost: 0.5334155 | Acc train: 0.9680000 | Acc validation: 0.9300000
# f1_score is 0.9690927218344965 0.9423076923076924
# roc_auc_score is 0.969 0.9400000000000001
# Iter:   104 | Cost: 0.5334009 | Acc train: 0.9690000 | Acc validation: 0.9400000
# f1_score is 0.972 0.9514563106796116
# roc_auc_score is 0.9719999999999999 0.9500000000000001
# Iter:   105 | Cost: 0.5346119 | Acc train: 0.9720000 | Acc validation: 0.9500000
# f1_score is 0.9749247743229689 0.94
# roc_auc_score is 0.975 0.94
# Iter:   106 | Cost: 0.5365689 | Acc train: 0.9750000 | Acc validation: 0.9400000
# f1_score is 0.9719438877755512 0.9411764705882353
# roc_auc_score is 0.972 0.9400000000000001
# Iter:   107 | Cost: 0.5357924 | Acc train: 0.9720000 | Acc validation: 0.9400000
# f1_score is 0.9568627450980391 0.9433962264150945
# roc_auc_score is 0.956 0.94
# Iter:   108 | Cost: 0.5311788 | Acc train: 0.9560000 | Acc validation: 0.9400000
# f1_score is 0.9486931268151017 0.9433962264150945
# roc_auc_score is 0.947 0.94
# Iter:   109 | Cost: 0.5316337 | Acc train: 0.9470000 | Acc validation: 0.9400000
# f1_score is 0.9568627450980391 0.9433962264150945
# roc_auc_score is 0.956 0.94
# Iter:   110 | Cost: 0.5304643 | Acc train: 0.9560000 | Acc validation: 0.9400000
# f1_score is 0.9566929133858268 0.9433962264150945
# roc_auc_score is 0.9559999999999998 0.94
# Iter:   111 | Cost: 0.5304698 | Acc train: 0.9560000 | Acc validation: 0.9400000
# f1_score is 0.9690927218344965 0.9306930693069307
# roc_auc_score is 0.969 0.9299999999999999
# Iter:   112 | Cost: 0.5326365 | Acc train: 0.9690000 | Acc validation: 0.9300000
# f1_score is 0.9698795180722891 0.9292929292929293
# roc_auc_score is 0.97 0.9299999999999998
# Iter:   113 | Cost: 0.5352461 | Acc train: 0.9700000 | Acc validation: 0.9300000
# f1_score is 0.971028971028971 0.9292929292929293
# roc_auc_score is 0.971 0.9299999999999998
# Iter:   114 | Cost: 0.5326382 | Acc train: 0.9710000 | Acc validation: 0.9300000
# f1_score is 0.9662698412698413 0.9215686274509804
# roc_auc_score is 0.966 0.92
# Iter:   115 | Cost: 0.5299502 | Acc train: 0.9660000 | Acc validation: 0.9200000
# f1_score is 0.9615004935834156 0.9523809523809523
# roc_auc_score is 0.961 0.9500000000000001
# Iter:   116 | Cost: 0.5284706 | Acc train: 0.9610000 | Acc validation: 0.9500000
# f1_score is 0.9674234945705823 0.9523809523809523
# roc_auc_score is 0.967 0.9500000000000001
# Iter:   117 | Cost: 0.5286501 | Acc train: 0.9670000 | Acc validation: 0.9500000
# f1_score is 0.9673590504451038 0.9523809523809523
# roc_auc_score is 0.967 0.9500000000000001
# Iter:   118 | Cost: 0.5294232 | Acc train: 0.9670000 | Acc validation: 0.9500000
# f1_score is 0.9626719056974459 0.9523809523809523
# roc_auc_score is 0.962 0.9500000000000001
# Iter:   119 | Cost: 0.5277784 | Acc train: 0.9620000 | Acc validation: 0.9500000
# f1_score is 0.958984375 0.9523809523809523
# roc_auc_score is 0.958 0.9500000000000001
# Iter:   120 | Cost: 0.5271036 | Acc train: 0.9580000 | Acc validation: 0.9500000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     1 | Cost: 1.4499669 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     2 | Cost: 1.3488611 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6684491978609626 0.6666666666666666
# roc_auc_score is 0.504 0.5
# Iter:     3 | Cost: 1.2152444 | Acc train: 0.5040000 | Acc validation: 0.5000000
# f1_score is 0.687757909215956 0.6756756756756758
# roc_auc_score is 0.546 0.52
# Iter:     4 | Cost: 1.1079407 | Acc train: 0.5460000 | Acc validation: 0.5200000
# f1_score is 0.7385524372230429 0.7352941176470588
# roc_auc_score is 0.646 0.64
# Iter:     5 | Cost: 1.0313962 | Acc train: 0.6460000 | Acc validation: 0.6400000
# f1_score is 0.5774907749077491 0.5964912280701754
# roc_auc_score is 0.542 0.54
# Iter:     6 | Cost: 1.0123924 | Acc train: 0.5420000 | Acc validation: 0.5400000
# f1_score is 0.22584692597239647 0.4565217391304348
# roc_auc_score is 0.38300000000000006 0.5
# Iter:     7 | Cost: 1.0138613 | Acc train: 0.3830000 | Acc validation: 0.5000000
# f1_score is 0.02523659305993691 0.0
# roc_auc_score is 0.382 0.38
# Iter:     8 | Cost: 1.0265823 | Acc train: 0.3820000 | Acc validation: 0.3800000
# f1_score is 0.01 0.0
# roc_auc_score is 0.406 0.41000000000000003
# Iter:     9 | Cost: 1.0271374 | Acc train: 0.4060000 | Acc validation: 0.4100000
# f1_score is 0.010416666666666668 0.0
# roc_auc_score is 0.43 0.44
# Iter:    10 | Cost: 1.0270243 | Acc train: 0.4300000 | Acc validation: 0.4400000
# f1_score is 0.020134228187919465 0.0
# roc_auc_score is 0.41600000000000004 0.42
# Iter:    11 | Cost: 1.0093913 | Acc train: 0.4160000 | Acc validation: 0.4200000
# f1_score is 0.1828410689170183 0.4
# roc_auc_score is 0.41899999999999993 0.52
# Iter:    12 | Cost: 0.9922630 | Acc train: 0.4190000 | Acc validation: 0.5200000
# f1_score is 0.5065856129685916 0.6111111111111112
# roc_auc_score is 0.513 0.5800000000000001
# Iter:    13 | Cost: 0.9856239 | Acc train: 0.5130000 | Acc validation: 0.5800000
# f1_score is 0.7473841554559043 0.7462686567164178
# roc_auc_score is 0.6619999999999999 0.6599999999999999
# Iter:    14 | Cost: 0.9868012 | Acc train: 0.6620000 | Acc validation: 0.6600000
# f1_score is 0.6887052341597797 0.6802721088435374
# roc_auc_score is 0.548 0.53
# Iter:    15 | Cost: 0.9945006 | Acc train: 0.5480000 | Acc validation: 0.5300000
# f1_score is 0.6775067750677507 0.6711409395973155
# roc_auc_score is 0.524 0.51
# Iter:    16 | Cost: 0.9955110 | Acc train: 0.5240000 | Acc validation: 0.5100000
# f1_score is 0.678886625933469 0.6711409395973155
# roc_auc_score is 0.527 0.51
# Iter:    17 | Cost: 0.9902347 | Acc train: 0.5270000 | Acc validation: 0.5100000
# f1_score is 0.6688963210702341 0.6711409395973155
# roc_auc_score is 0.505 0.51
# Iter:    18 | Cost: 0.9890064 | Acc train: 0.5050000 | Acc validation: 0.5100000
# f1_score is 0.6697923643670461 0.6711409395973155
# roc_auc_score is 0.507 0.51
# Iter:    19 | Cost: 0.9822210 | Acc train: 0.5070000 | Acc validation: 0.5100000
# f1_score is 0.6896551724137931 0.684931506849315
# roc_auc_score is 0.55 0.54
# Iter:    20 | Cost: 0.9687833 | Acc train: 0.5500000 | Acc validation: 0.5400000
# f1_score is 0.7672756155679109 0.7633587786259541
# roc_auc_score is 0.707 0.69
# Iter:    21 | Cost: 0.9553403 | Acc train: 0.7070000 | Acc validation: 0.6900000
# f1_score is 0.5442359249329758 0.7317073170731707
# roc_auc_score is 0.66 0.78
# Iter:    22 | Cost: 0.9473203 | Acc train: 0.6600000 | Acc validation: 0.7800000
# f1_score is 0.05394990366088632 0.21428571428571425
# roc_auc_score is 0.509 0.56
# Iter:    23 | Cost: 0.9493744 | Acc train: 0.5090000 | Acc validation: 0.5600000
# f1_score is 0.12686567164179105 0.3050847457627119
# roc_auc_score is 0.532 0.59
# Iter:    24 | Cost: 0.9340783 | Acc train: 0.5320000 | Acc validation: 0.5900000
# f1_score is 0.7169344870210137 0.9010989010989011
# roc_auc_score is 0.771 0.9099999999999999
# Iter:    25 | Cost: 0.8951075 | Acc train: 0.7710000 | Acc validation: 0.9100000
# f1_score is 0.8483720930232559 0.8596491228070174
# roc_auc_score is 0.837 0.84
# Iter:    26 | Cost: 0.8666338 | Acc train: 0.8370000 | Acc validation: 0.8400000
# f1_score is 0.723935389133627 0.7424242424242423
# roc_auc_score is 0.624 0.6599999999999999
# Iter:    27 | Cost: 0.8529372 | Acc train: 0.6240000 | Acc validation: 0.6600000
# f1_score is 0.66711140760507 0.6666666666666666
# roc_auc_score is 0.501 0.5
# Iter:    28 | Cost: 0.8657245 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    29 | Cost: 0.8710101 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6729602157788266 0.6666666666666666
# roc_auc_score is 0.515 0.5
# Iter:    30 | Cost: 0.8486115 | Acc train: 0.5150000 | Acc validation: 0.5000000
# f1_score is 0.7374810318664644 0.7368421052631579
# roc_auc_score is 0.6539999999999999 0.6499999999999999
# Iter:    31 | Cost: 0.8055255 | Acc train: 0.6540000 | Acc validation: 0.6500000
# f1_score is 0.7989371124889282 0.8305084745762712
# roc_auc_score is 0.7730000000000001 0.8
# Iter:    32 | Cost: 0.7708671 | Acc train: 0.7730000 | Acc validation: 0.8000000
# f1_score is 0.8090107737512242 0.8672566371681417
# roc_auc_score is 0.805 0.85
# Iter:    33 | Cost: 0.7480626 | Acc train: 0.8050000 | Acc validation: 0.8500000
# f1_score is 0.7730337078651686 0.9215686274509804
# roc_auc_score is 0.798 0.92
# Iter:    34 | Cost: 0.7299432 | Acc train: 0.7980000 | Acc validation: 0.9200000
# f1_score is 0.729891956782713 0.8913043478260869
# roc_auc_score is 0.775 0.8999999999999999
# Iter:    35 | Cost: 0.7294498 | Acc train: 0.7750000 | Acc validation: 0.9000000
# f1_score is 0.7004950495049505 0.9010989010989011
# roc_auc_score is 0.7579999999999999 0.9099999999999999
# Iter:    36 | Cost: 0.7259898 | Acc train: 0.7580000 | Acc validation: 0.9100000
# f1_score is 0.7303102625298328 0.8913043478260869
# roc_auc_score is 0.774 0.8999999999999999
# Iter:    37 | Cost: 0.7051652 | Acc train: 0.7740000 | Acc validation: 0.9000000
# f1_score is 0.7444574095682615 0.8979591836734694
# roc_auc_score is 0.781 0.9
# Iter:    38 | Cost: 0.6873533 | Acc train: 0.7810000 | Acc validation: 0.9000000
# f1_score is 0.7635135135135136 0.9108910891089109
# roc_auc_score is 0.7899999999999999 0.91
# Iter:    39 | Cost: 0.6706445 | Acc train: 0.7900000 | Acc validation: 0.9100000
# f1_score is 0.7812840043525571 0.9038461538461539
# roc_auc_score is 0.799 0.8999999999999999
# Iter:    40 | Cost: 0.6596722 | Acc train: 0.7990000 | Acc validation: 0.9000000
# f1_score is 0.7903055848261327 0.9142857142857144
# roc_auc_score is 0.8009999999999999 0.91
# Iter:    41 | Cost: 0.6518396 | Acc train: 0.8010000 | Acc validation: 0.9100000
# f1_score is 0.8113017154389505 0.8807339449541285
# roc_auc_score is 0.8130000000000001 0.87
# Iter:    42 | Cost: 0.6479307 | Acc train: 0.8130000 | Acc validation: 0.8700000
# f1_score is 0.8208208208208209 0.8807339449541285
# roc_auc_score is 0.821 0.87
# Iter:    43 | Cost: 0.6395635 | Acc train: 0.8210000 | Acc validation: 0.8700000
# f1_score is 0.8260427263479145 0.8971962616822429
# roc_auc_score is 0.8290000000000001 0.8900000000000001
# Iter:    44 | Cost: 0.6286203 | Acc train: 0.8290000 | Acc validation: 0.8900000
# f1_score is 0.8278008298755187 0.8971962616822429
# roc_auc_score is 0.834 0.8900000000000001
# Iter:    45 | Cost: 0.6189162 | Acc train: 0.8340000 | Acc validation: 0.8900000
# f1_score is 0.8283898305084747 0.8971962616822429
# roc_auc_score is 0.838 0.8900000000000001
# Iter:    46 | Cost: 0.6113687 | Acc train: 0.8380000 | Acc validation: 0.8900000
# f1_score is 0.8213507625272332 0.9215686274509804
# roc_auc_score is 0.8360000000000001 0.92
# Iter:    47 | Cost: 0.6063515 | Acc train: 0.8360000 | Acc validation: 0.9200000
# f1_score is 0.8142380422691881 0.9591836734693877
# roc_auc_score is 0.8329999999999999 0.96
# Iter:    48 | Cost: 0.6037389 | Acc train: 0.8330000 | Acc validation: 0.9600000
# f1_score is 0.8161434977578476 0.9591836734693877
# roc_auc_score is 0.8359999999999999 0.96
# Iter:    49 | Cost: 0.6011352 | Acc train: 0.8360000 | Acc validation: 0.9600000
# f1_score is 0.8313120176405733 0.9494949494949495
# roc_auc_score is 0.847 0.95
# Iter:    50 | Cost: 0.5956151 | Acc train: 0.8470000 | Acc validation: 0.9500000
# f1_score is 0.8506493506493507 0.9504950495049505
# roc_auc_score is 0.862 0.95
# Iter:    51 | Cost: 0.5904421 | Acc train: 0.8620000 | Acc validation: 0.9500000
# f1_score is 0.8623655913978495 0.9504950495049505
# roc_auc_score is 0.872 0.95
# Iter:    52 | Cost: 0.5854924 | Acc train: 0.8720000 | Acc validation: 0.9500000
# f1_score is 0.8549450549450549 0.96
# roc_auc_score is 0.868 0.96
# Iter:    53 | Cost: 0.5829712 | Acc train: 0.8680000 | Acc validation: 0.9600000
# f1_score is 0.8327645051194539 0.9690721649484536
# roc_auc_score is 0.853 0.97
# Iter:    54 | Cost: 0.5848147 | Acc train: 0.8530000 | Acc validation: 0.9700000
# f1_score is 0.8320000000000001 0.9690721649484536
# roc_auc_score is 0.853 0.97
# Iter:    55 | Cost: 0.5844530 | Acc train: 0.8530000 | Acc validation: 0.9700000
# f1_score is 0.869086908690869 0.9696969696969697
# roc_auc_score is 0.881 0.97
# Iter:    56 | Cost: 0.5736816 | Acc train: 0.8810000 | Acc validation: 0.9700000
# f1_score is 0.9117341640706127 0.9504950495049505
# roc_auc_score is 0.915 0.95
# Iter:    57 | Cost: 0.5613977 | Acc train: 0.9150000 | Acc validation: 0.9500000
# f1_score is 0.9301397205588822 0.9333333333333333
# roc_auc_score is 0.93 0.9299999999999999
# Iter:    58 | Cost: 0.5575229 | Acc train: 0.9300000 | Acc validation: 0.9300000
# f1_score is 0.9299610894941633 0.9245283018867924
# roc_auc_score is 0.9279999999999999 0.9199999999999999
# Iter:    59 | Cost: 0.5573653 | Acc train: 0.9280000 | Acc validation: 0.9200000
# f1_score is 0.933206106870229 0.9245283018867924
# roc_auc_score is 0.93 0.9199999999999999
# Iter:    60 | Cost: 0.5573232 | Acc train: 0.9300000 | Acc validation: 0.9200000
# f1_score is 0.9428571428571428 0.9245283018867924
# roc_auc_score is 0.9400000000000001 0.9199999999999999
# Iter:    61 | Cost: 0.5550703 | Acc train: 0.9400000 | Acc validation: 0.9200000
# f1_score is 0.9401709401709402 0.9345794392523363
# roc_auc_score is 0.937 0.9299999999999999
# Iter:    62 | Cost: 0.5549905 | Acc train: 0.9370000 | Acc validation: 0.9300000
# f1_score is 0.9334582942830366 0.9090909090909091
# roc_auc_score is 0.929 0.9
# Iter:    63 | Cost: 0.5591673 | Acc train: 0.9290000 | Acc validation: 0.9000000
# f1_score is 0.9246511627906977 0.9009009009009009
# roc_auc_score is 0.919 0.89
# Iter:    64 | Cost: 0.5654657 | Acc train: 0.9190000 | Acc validation: 0.8900000
# f1_score is 0.9212233549582948 0.9009009009009009
# roc_auc_score is 0.915 0.89
# Iter:    65 | Cost: 0.5669158 | Acc train: 0.9150000 | Acc validation: 0.8900000
# f1_score is 0.9313264346190029 0.9009009009009009
# roc_auc_score is 0.927 0.89
# Iter:    66 | Cost: 0.5558605 | Acc train: 0.9270000 | Acc validation: 0.8900000
# f1_score is 0.9399428026692088 0.9259259259259259
# roc_auc_score is 0.937 0.9199999999999999
# Iter:    67 | Cost: 0.5484225 | Acc train: 0.9370000 | Acc validation: 0.9200000
# f1_score is 0.9426386233269598 0.9259259259259259
# roc_auc_score is 0.9400000000000001 0.9199999999999999
# Iter:    68 | Cost: 0.5450548 | Acc train: 0.9400000 | Acc validation: 0.9200000
# f1_score is 0.9435406698564593 0.9259259259259259
# roc_auc_score is 0.941 0.9199999999999999
# Iter:    69 | Cost: 0.5421115 | Acc train: 0.9410000 | Acc validation: 0.9200000
# f1_score is 0.9435406698564593 0.9259259259259259
# roc_auc_score is 0.941 0.9199999999999999
# Iter:    70 | Cost: 0.5415586 | Acc train: 0.9410000 | Acc validation: 0.9200000
# f1_score is 0.9488910318225651 0.9345794392523363
# roc_auc_score is 0.9470000000000001 0.9299999999999999
# Iter:    71 | Cost: 0.5388383 | Acc train: 0.9470000 | Acc validation: 0.9300000
# f1_score is 0.9608610567514677 0.9433962264150945
# roc_auc_score is 0.9599999999999999 0.94
# Iter:    72 | Cost: 0.5370060 | Acc train: 0.9600000 | Acc validation: 0.9400000
# f1_score is 0.9740518962075848 0.9615384615384615
# roc_auc_score is 0.974 0.9600000000000001
# Iter:    73 | Cost: 0.5402987 | Acc train: 0.9740000 | Acc validation: 0.9600000
# f1_score is 0.9788519637462235 0.9615384615384615
# roc_auc_score is 0.979 0.9600000000000001
# Iter:    74 | Cost: 0.5440282 | Acc train: 0.9790000 | Acc validation: 0.9600000
# f1_score is 0.9799599198396793 0.9615384615384615
# roc_auc_score is 0.98 0.9600000000000001
# Iter:    75 | Cost: 0.5368315 | Acc train: 0.9800000 | Acc validation: 0.9600000
# f1_score is 0.967551622418879 0.9523809523809523
# roc_auc_score is 0.9669999999999999 0.9500000000000001
# Iter:    76 | Cost: 0.5298325 | Acc train: 0.9670000 | Acc validation: 0.9500000
# f1_score is 0.9456625357483317 0.9345794392523363
# roc_auc_score is 0.943 0.9299999999999999
# Iter:    77 | Cost: 0.5327217 | Acc train: 0.9430000 | Acc validation: 0.9300000
# f1_score is 0.9237918215613383 0.9090909090909091
# roc_auc_score is 0.9179999999999999 0.9
# Iter:    78 | Cost: 0.5435164 | Acc train: 0.9180000 | Acc validation: 0.9000000
# f1_score is 0.9203703703703703 0.8849557522123894
# roc_auc_score is 0.9139999999999999 0.87
# Iter:    79 | Cost: 0.5461170 | Acc train: 0.9140000 | Acc validation: 0.8700000
# f1_score is 0.9245107176141658 0.8928571428571428
# roc_auc_score is 0.9189999999999999 0.88
# Iter:    80 | Cost: 0.5430149 | Acc train: 0.9190000 | Acc validation: 0.8800000
# f1_score is 0.9364928909952607 0.9245283018867924
# roc_auc_score is 0.9329999999999999 0.9199999999999999
# Iter:    81 | Cost: 0.5298696 | Acc train: 0.9330000 | Acc validation: 0.9200000
# f1_score is 0.9592039800995025 0.9504950495049505
# roc_auc_score is 0.959 0.95
# Iter:    82 | Cost: 0.5280332 | Acc train: 0.9590000 | Acc validation: 0.9500000
# f1_score is 0.9538152610441766 0.9504950495049505
# roc_auc_score is 0.954 0.95
# Iter:    83 | Cost: 0.5291514 | Acc train: 0.9540000 | Acc validation: 0.9500000
# f1_score is 0.9525731584258325 0.9504950495049505
# roc_auc_score is 0.9529999999999998 0.95
# Iter:    84 | Cost: 0.5310820 | Acc train: 0.9530000 | Acc validation: 0.9500000
# f1_score is 0.946840521564694 0.9504950495049505
# roc_auc_score is 0.9469999999999998 0.95
# Iter:    85 | Cost: 0.5297975 | Acc train: 0.9470000 | Acc validation: 0.9500000
# f1_score is 0.944 0.9411764705882353
# roc_auc_score is 0.944 0.9400000000000001
# Iter:    86 | Cost: 0.5286541 | Acc train: 0.9440000 | Acc validation: 0.9400000
# f1_score is 0.9393034825870648 0.9411764705882353
# roc_auc_score is 0.9389999999999998 0.9400000000000001
# Iter:    87 | Cost: 0.5280562 | Acc train: 0.9390000 | Acc validation: 0.9400000
# f1_score is 0.9402390438247011 0.9411764705882353
# roc_auc_score is 0.94 0.9400000000000001
# Iter:    88 | Cost: 0.5277911 | Acc train: 0.9400000 | Acc validation: 0.9400000
# f1_score is 0.9432485322896281 0.9320388349514563
# roc_auc_score is 0.9420000000000001 0.93
# Iter:    89 | Cost: 0.5264350 | Acc train: 0.9420000 | Acc validation: 0.9300000
# f1_score is 0.9319470699432892 0.8990825688073395
# roc_auc_score is 0.9279999999999999 0.89
# Iter:    90 | Cost: 0.5304963 | Acc train: 0.9280000 | Acc validation: 0.8900000
# f1_score is 0.9260991580916745 0.9009009009009009
# roc_auc_score is 0.9209999999999999 0.89
# Iter:    91 | Cost: 0.5348192 | Acc train: 0.9210000 | Acc validation: 0.8900000
# f1_score is 0.941738299904489 0.9158878504672898
# roc_auc_score is 0.939 0.91
# Iter:    92 | Cost: 0.5277249 | Acc train: 0.9390000 | Acc validation: 0.9100000
# f1_score is 0.9596853490658801 0.9411764705882353
# roc_auc_score is 0.959 0.9400000000000001
# Iter:    93 | Cost: 0.5253465 | Acc train: 0.9590000 | Acc validation: 0.9400000
# f1_score is 0.96579476861167 0.9504950495049505
# roc_auc_score is 0.966 0.95
# Iter:    94 | Cost: 0.5307486 | Acc train: 0.9660000 | Acc validation: 0.9500000
# f1_score is 0.9678714859437753 0.9504950495049505
# roc_auc_score is 0.9679999999999999 0.95
# Iter:    95 | Cost: 0.5306735 | Acc train: 0.9680000 | Acc validation: 0.9500000
# f1_score is 0.9663366336633663 0.9504950495049505
# roc_auc_score is 0.966 0.95
# Iter:    96 | Cost: 0.5269094 | Acc train: 0.9660000 | Acc validation: 0.9500000
# f1_score is 0.9536679536679538 0.9345794392523363
# roc_auc_score is 0.952 0.9299999999999999
# Iter:    97 | Cost: 0.5249039 | Acc train: 0.9520000 | Acc validation: 0.9300000
# f1_score is 0.94106463878327 0.9345794392523363
# roc_auc_score is 0.938 0.9299999999999999
# Iter:    98 | Cost: 0.5293809 | Acc train: 0.9380000 | Acc validation: 0.9300000
# f1_score is 0.9500959692898272 0.9345794392523363
# roc_auc_score is 0.948 0.9299999999999999
# Iter:    99 | Cost: 0.5264690 | Acc train: 0.9480000 | Acc validation: 0.9300000
# f1_score is 0.9620253164556962 0.9345794392523363
# roc_auc_score is 0.9609999999999999 0.9299999999999999
# Iter:   100 | Cost: 0.5255390 | Acc train: 0.9610000 | Acc validation: 0.9300000
# f1_score is 0.974308300395257 0.970873786407767
# roc_auc_score is 0.974 0.97
# Iter:   101 | Cost: 0.5272650 | Acc train: 0.9740000 | Acc validation: 0.9700000
# f1_score is 0.978131212723658 0.9803921568627451
# roc_auc_score is 0.978 0.98
# Iter:   102 | Cost: 0.5297122 | Acc train: 0.9780000 | Acc validation: 0.9800000
# f1_score is 0.974308300395257 0.9615384615384615
# roc_auc_score is 0.974 0.9600000000000001
# Iter:   103 | Cost: 0.5266493 | Acc train: 0.9740000 | Acc validation: 0.9600000
# f1_score is 0.9733990147783251 0.9523809523809523
# roc_auc_score is 0.973 0.9500000000000001
# Iter:   104 | Cost: 0.5253407 | Acc train: 0.9730000 | Acc validation: 0.9500000
# f1_score is 0.9657869012707723 0.9523809523809523
# roc_auc_score is 0.965 0.9500000000000001
# Iter:   105 | Cost: 0.5244761 | Acc train: 0.9650000 | Acc validation: 0.9500000
# f1_score is 0.9656526005888125 0.9411764705882353
# roc_auc_score is 0.965 0.9400000000000001
# Iter:   106 | Cost: 0.5252600 | Acc train: 0.9650000 | Acc validation: 0.9400000
# f1_score is 0.9571150097465886 0.9411764705882353
# roc_auc_score is 0.956 0.9400000000000001
# Iter:   107 | Cost: 0.5247002 | Acc train: 0.9560000 | Acc validation: 0.9400000
# f1_score is 0.9523809523809523 0.9411764705882353
# roc_auc_score is 0.9510000000000001 0.9400000000000001
# Iter:   108 | Cost: 0.5247177 | Acc train: 0.9510000 | Acc validation: 0.9400000
# f1_score is 0.944015444015444 0.9320388349514563
# roc_auc_score is 0.942 0.93
# Iter:   109 | Cost: 0.5257938 | Acc train: 0.9420000 | Acc validation: 0.9300000
# f1_score is 0.9371428571428572 0.8990825688073395
# roc_auc_score is 0.934 0.89
# Iter:   110 | Cost: 0.5303054 | Acc train: 0.9340000 | Acc validation: 0.8900000
# f1_score is 0.9138090824837812 0.890909090909091
# roc_auc_score is 0.907 0.88
# Iter:   111 | Cost: 0.5397941 | Acc train: 0.9070000 | Acc validation: 0.8800000
# f1_score is 0.9240986717267552 0.8971962616822429
# roc_auc_score is 0.92 0.8900000000000001
# Iter:   112 | Cost: 0.5325105 | Acc train: 0.9200000 | Acc validation: 0.8900000
# f1_score is 0.9214758751182592 0.8971962616822429
# roc_auc_score is 0.917 0.8900000000000001
# Iter:   113 | Cost: 0.5338520 | Acc train: 0.9170000 | Acc validation: 0.8900000
# f1_score is 0.9054178145087236 0.890909090909091
# roc_auc_score is 0.897 0.88
# Iter:   114 | Cost: 0.5440820 | Acc train: 0.8970000 | Acc validation: 0.8800000
# f1_score is 0.9111111111111111 0.890909090909091
# roc_auc_score is 0.904 0.88
# Iter:   115 | Cost: 0.5392860 | Acc train: 0.9040000 | Acc validation: 0.8800000
# f1_score is 0.9307692307692307 0.9056603773584904
# roc_auc_score is 0.928 0.8999999999999999
# Iter:   116 | Cost: 0.5285257 | Acc train: 0.9280000 | Acc validation: 0.9000000
# f1_score is 0.932562620423892 0.9056603773584904
# roc_auc_score is 0.9299999999999999 0.8999999999999999
# Iter:   117 | Cost: 0.5274185 | Acc train: 0.9300000 | Acc validation: 0.9000000
# f1_score is 0.937864077669903 0.9142857142857144
# roc_auc_score is 0.9359999999999999 0.91
# Iter:   118 | Cost: 0.5262934 | Acc train: 0.9360000 | Acc validation: 0.9100000
# f1_score is 0.9335863377609108 0.9174311926605504
# roc_auc_score is 0.9299999999999999 0.91
# Iter:   119 | Cost: 0.5291654 | Acc train: 0.9300000 | Acc validation: 0.9100000
# f1_score is 0.9109274563820018 0.9009009009009009
# roc_auc_score is 0.903 0.89
# Iter:   120 | Cost: 0.5379508 | Acc train: 0.9030000 | Acc validation: 0.8900000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     1 | Cost: 1.4564513 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     2 | Cost: 1.3770568 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.66711140760507 0.6666666666666666
# roc_auc_score is 0.501 0.5
# Iter:     3 | Cost: 1.2440694 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.6863417982155113 0.6711409395973155
# roc_auc_score is 0.5429999999999999 0.51
# Iter:     4 | Cost: 1.1048078 | Acc train: 0.5430000 | Acc validation: 0.5100000
# f1_score is 0.727802037845706 0.7246376811594203
# roc_auc_score is 0.626 0.62
# Iter:     5 | Cost: 1.0360840 | Acc train: 0.6260000 | Acc validation: 0.6200000
# f1_score is 0.41465968586387436 0.574074074074074
# roc_auc_score is 0.44099999999999995 0.54
# Iter:     6 | Cost: 1.0157428 | Acc train: 0.4410000 | Acc validation: 0.5400000
# f1_score is 0.03343465045592705 0.0
# roc_auc_score is 0.364 0.36
# Iter:     7 | Cost: 1.0289050 | Acc train: 0.3640000 | Acc validation: 0.3600000
# f1_score is 0.0 0.0
# roc_auc_score is 0.446 0.47
# Iter:     8 | Cost: 1.0574492 | Acc train: 0.4460000 | Acc validation: 0.4700000
# f1_score is 0.0 0.0
# roc_auc_score is 0.481 0.5
# Iter:     9 | Cost: 1.0619234 | Acc train: 0.4810000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.494 0.5
# Iter:    10 | Cost: 1.0438721 | Acc train: 0.4940000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.498 0.5
# Iter:    11 | Cost: 1.0265540 | Acc train: 0.4980000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.498 0.5
# Iter:    12 | Cost: 1.0091159 | Acc train: 0.4980000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.499 0.5
# Iter:    13 | Cost: 1.0070066 | Acc train: 0.4990000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.5 0.5
# Iter:    14 | Cost: 1.0032844 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.023064250411861616 0.03448275862068966
# roc_auc_score is 0.40700000000000003 0.44
# Iter:    15 | Cost: 1.0013589 | Acc train: 0.4070000 | Acc validation: 0.4400000
# f1_score is 0.08771929824561403 0.125
# roc_auc_score is 0.376 0.44000000000000006
# Iter:    16 | Cost: 1.0006563 | Acc train: 0.3760000 | Acc validation: 0.4400000
# f1_score is 0.014084507042253523 0.03773584905660377
# roc_auc_score is 0.44 0.49
# Iter:    17 | Cost: 1.0001543 | Acc train: 0.4400000 | Acc validation: 0.4900000
# f1_score is 0.007142857142857144 0.0
# roc_auc_score is 0.444 0.48
# Iter:    18 | Cost: 0.9987623 | Acc train: 0.4440000 | Acc validation: 0.4800000
# f1_score is 0.7469512195121951 0.7575757575757575
# roc_auc_score is 0.6679999999999999 0.6799999999999999
# Iter:    19 | Cost: 0.9938892 | Acc train: 0.6680000 | Acc validation: 0.6800000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    20 | Cost: 0.9927898 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    21 | Cost: 0.9875157 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    22 | Cost: 0.9759576 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    23 | Cost: 0.9616654 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    24 | Cost: 0.9474874 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.8064791133844842 0.8333333333333333
# roc_auc_score is 0.773 0.8
# Iter:    25 | Cost: 0.9280575 | Acc train: 0.7730000 | Acc validation: 0.8000000
# f1_score is 0.79445727482679 0.9690721649484536
# roc_auc_score is 0.822 0.97
# Iter:    26 | Cost: 0.9092660 | Acc train: 0.8220000 | Acc validation: 0.9700000
# f1_score is 0.571830985915493 0.7499999999999999
# roc_auc_score is 0.6960000000000001 0.8
# Iter:    27 | Cost: 0.8986637 | Acc train: 0.6960000 | Acc validation: 0.8000000
# f1_score is 0.6717948717948719 0.8636363636363636
# roc_auc_score is 0.744 0.88
# Iter:    28 | Cost: 0.8707130 | Acc train: 0.7440000 | Acc validation: 0.8800000
# f1_score is 0.7699214365881033 0.9108910891089109
# roc_auc_score is 0.7949999999999999 0.91
# Iter:    29 | Cost: 0.8393546 | Acc train: 0.7950000 | Acc validation: 0.9100000
# f1_score is 0.8048289738430584 0.8990825688073395
# roc_auc_score is 0.8060000000000002 0.89
# Iter:    30 | Cost: 0.8165687 | Acc train: 0.8060000 | Acc validation: 0.8900000
# f1_score is 0.7605633802816901 0.912621359223301
# roc_auc_score is 0.779 0.91
# Iter:    31 | Cost: 0.7988347 | Acc train: 0.7790000 | Acc validation: 0.9100000
# f1_score is 0.7521929824561403 0.912621359223301
# roc_auc_score is 0.7739999999999999 0.91
# Iter:    32 | Cost: 0.7829968 | Acc train: 0.7740000 | Acc validation: 0.9100000
# f1_score is 0.751863684771033 0.9038461538461539
# roc_auc_score is 0.767 0.8999999999999999
# Iter:    33 | Cost: 0.7673868 | Acc train: 0.7670000 | Acc validation: 0.9000000
# f1_score is 0.7676767676767676 0.8727272727272728
# roc_auc_score is 0.77 0.86
# Iter:    34 | Cost: 0.7562562 | Acc train: 0.7700000 | Acc validation: 0.8600000
# f1_score is 0.7567567567567567 0.8785046728971964
# roc_auc_score is 0.766 0.87
# Iter:    35 | Cost: 0.7400931 | Acc train: 0.7660000 | Acc validation: 0.8700000
# f1_score is 0.7363834422657952 0.8823529411764707
# roc_auc_score is 0.758 0.88
# Iter:    36 | Cost: 0.7240727 | Acc train: 0.7580000 | Acc validation: 0.8800000
# f1_score is 0.7329608938547486 0.9
# roc_auc_score is 0.761 0.9
# Iter:    37 | Cost: 0.7106585 | Acc train: 0.7610000 | Acc validation: 0.9000000
# f1_score is 0.7255813953488373 0.8775510204081632
# roc_auc_score is 0.764 0.88
# Iter:    38 | Cost: 0.7012253 | Acc train: 0.7640000 | Acc validation: 0.8800000
# f1_score is 0.7304147465437788 0.888888888888889
# roc_auc_score is 0.7659999999999999 0.89
# Iter:    39 | Cost: 0.6859138 | Acc train: 0.7660000 | Acc validation: 0.8900000
# f1_score is 0.7418655097613884 0.8932038834951457
# roc_auc_score is 0.762 0.89
# Iter:    40 | Cost: 0.6680937 | Acc train: 0.7620000 | Acc validation: 0.8900000
# f1_score is 0.7658688865764829 0.8952380952380952
# roc_auc_score is 0.775 0.89
# Iter:    41 | Cost: 0.6596803 | Acc train: 0.7750000 | Acc validation: 0.8900000
# f1_score is 0.7711598746081505 0.9038461538461539
# roc_auc_score is 0.781 0.8999999999999999
# Iter:    42 | Cost: 0.6483962 | Acc train: 0.7810000 | Acc validation: 0.9000000
# f1_score is 0.7752577319587629 0.8952380952380952
# roc_auc_score is 0.782 0.89
# Iter:    43 | Cost: 0.6415097 | Acc train: 0.7820000 | Acc validation: 0.8900000
# f1_score is 0.7955911823647294 0.888888888888889
# roc_auc_score is 0.796 0.88
# Iter:    44 | Cost: 0.6383162 | Acc train: 0.7960000 | Acc validation: 0.8800000
# f1_score is 0.7963709677419355 0.8971962616822429
# roc_auc_score is 0.798 0.8900000000000001
# Iter:    45 | Cost: 0.6301656 | Acc train: 0.7980000 | Acc validation: 0.8900000
# f1_score is 0.8024316109422491 0.9056603773584904
# roc_auc_score is 0.805 0.8999999999999999
# Iter:    46 | Cost: 0.6229407 | Acc train: 0.8050000 | Acc validation: 0.9000000
# f1_score is 0.7937172774869109 0.912621359223301
# roc_auc_score is 0.8029999999999999 0.91
# Iter:    47 | Cost: 0.6131532 | Acc train: 0.8030000 | Acc validation: 0.9100000
# f1_score is 0.800424628450106 0.912621359223301
# roc_auc_score is 0.8119999999999999 0.91
# Iter:    48 | Cost: 0.6068993 | Acc train: 0.8120000 | Acc validation: 0.9100000
# f1_score is 0.8063829787234043 0.9038461538461539
# roc_auc_score is 0.8180000000000001 0.8999999999999999
# Iter:    49 | Cost: 0.6016046 | Acc train: 0.8180000 | Acc validation: 0.9000000
# f1_score is 0.8180862250262881 0.8971962616822429
# roc_auc_score is 0.827 0.8900000000000001
# Iter:    50 | Cost: 0.5969761 | Acc train: 0.8270000 | Acc validation: 0.8900000
# f1_score is 0.8250265111346766 0.9056603773584904
# ...
# f1_score is 0.9179723502304147 0.8928571428571428
# roc_auc_score is 0.911 0.88
# Iter:    78 | Cost: 0.5499640 | Acc train: 0.9110000 | Acc validation: 0.8800000
# f1_score is 0.9152854511970534 0.8928571428571428
# roc_auc_score is 0.9080000000000001 0.88
# Iter:    79 | Cost: 0.5507565 | Acc train: 0.9080000 | Acc validation: 0.8800000
# f1_score is 0.9253731343283581 0.9009009009009009
# roc_auc_score is 0.92 0.89
# Iter:    80 | Cost: 0.5393688 | Acc train: 0.9200000 | Acc validation: 0.8900000
# f1_score is 0.9375 0.9259259259259259
# roc_auc_score is 0.9339999999999999 0.9199999999999999
# Iter:    81 | Cost: 0.5291096 | Acc train: 0.9340000 | Acc validation: 0.9200000
# f1_score is 0.952565343659245 0.9423076923076924
# roc_auc_score is 0.9510000000000001 0.9400000000000001
# Iter:    82 | Cost: 0.5253501 | Acc train: 0.9510000 | Acc validation: 0.9400000
# f1_score is 0.9485148514851485 0.9411764705882353
# roc_auc_score is 0.948 0.9400000000000001
# Iter:    83 | Cost: 0.5290400 | Acc train: 0.9480000 | Acc validation: 0.9400000
# f1_score is 0.9393034825870648 0.9411764705882353
# roc_auc_score is 0.9389999999999998 0.9400000000000001
# Iter:    84 | Cost: 0.5297497 | Acc train: 0.9390000 | Acc validation: 0.9400000
# f1_score is 0.9393034825870648 0.9411764705882353
# roc_auc_score is 0.9389999999999998 0.9400000000000001
# Iter:    85 | Cost: 0.5305509 | Acc train: 0.9390000 | Acc validation: 0.9400000
# f1_score is 0.9410628019323671 0.923076923076923
# roc_auc_score is 0.9390000000000001 0.9199999999999999
# Iter:    86 | Cost: 0.5258243 | Acc train: 0.9390000 | Acc validation: 0.9200000
# f1_score is 0.9354838709677419 0.9174311926605504
# roc_auc_score is 0.932 0.91
# Iter:    87 | Cost: 0.5290585 | Acc train: 0.9320000 | Acc validation: 0.9100000
# f1_score is 0.9313264346190029 0.9174311926605504
# roc_auc_score is 0.927 0.91
# Iter:    88 | Cost: 0.5311206 | Acc train: 0.9270000 | Acc validation: 0.9100000
# f1_score is 0.9489894128970164 0.9345794392523363
# roc_auc_score is 0.947 0.9299999999999999
# Iter:    89 | Cost: 0.5247045 | Acc train: 0.9470000 | Acc validation: 0.9300000
# f1_score is 0.9571984435797666 0.9514563106796116
# roc_auc_score is 0.9560000000000001 0.9500000000000001
# Iter:    90 | Cost: 0.5251516 | Acc train: 0.9560000 | Acc validation: 0.9500000
# f1_score is 0.9671641791044775 0.92
# roc_auc_score is 0.967 0.9199999999999999
# Iter:    91 | Cost: 0.5313219 | Acc train: 0.9670000 | Acc validation: 0.9200000
# f1_score is 0.9359916054564533 0.8817204301075269
# roc_auc_score is 0.939 0.8899999999999999
# Iter:    92 | Cost: 0.5548230 | Acc train: 0.9390000 | Acc validation: 0.8900000
# f1_score is 0.9019607843137254 0.8444444444444444
# roc_auc_score is 0.9099999999999999 0.86
# Iter:    93 | Cost: 0.5655636 | Acc train: 0.9100000 | Acc validation: 0.8600000
# f1_score is 0.9220917822838847 0.8314606741573033
# roc_auc_score is 0.9269999999999999 0.85
# Iter:    94 | Cost: 0.5533606 | Acc train: 0.9270000 | Acc validation: 0.8500000
# f1_score is 0.945529290853032 0.8842105263157894
# roc_auc_score is 0.947 0.8899999999999999
# Iter:    95 | Cost: 0.5362954 | Acc train: 0.9470000 | Acc validation: 0.8900000
# f1_score is 0.940603700097371 0.9019607843137256
# roc_auc_score is 0.9390000000000001 0.9
# Iter:    96 | Cost: 0.5316772 | Acc train: 0.9390000 | Acc validation: 0.9000000
# f1_score is 0.9254013220018886 0.8761904761904761
# roc_auc_score is 0.921 0.87
# Iter:    97 | Cost: 0.5447545 | Acc train: 0.9210000 | Acc validation: 0.8700000
# f1_score is 0.9281663516068053 0.8761904761904761
# roc_auc_score is 0.924 0.87
# Iter:    98 | Cost: 0.5459922 | Acc train: 0.9240000 | Acc validation: 0.8700000
# f1_score is 0.9397129186602869 0.8932038834951457
# roc_auc_score is 0.9369999999999999 0.89
# Iter:    99 | Cost: 0.5380709 | Acc train: 0.9370000 | Acc validation: 0.8900000
# f1_score is 0.9441233140655105 0.9019607843137256
# roc_auc_score is 0.942 0.9
# Iter:   100 | Cost: 0.5310653 | Acc train: 0.9420000 | Acc validation: 0.9000000
# f1_score is 0.9558390578999019 0.923076923076923
# roc_auc_score is 0.955 0.9199999999999999
# Iter:   101 | Cost: 0.5268468 | Acc train: 0.9550000 | Acc validation: 0.9200000
# f1_score is 0.9545014520813165 0.9433962264150945
# roc_auc_score is 0.9530000000000001 0.94
# Iter:   102 | Cost: 0.5266835 | Acc train: 0.9530000 | Acc validation: 0.9400000
# f1_score is 0.9482758620689654 0.9259259259259259
# roc_auc_score is 0.9460000000000001 0.9199999999999999
# Iter:   103 | Cost: 0.5290770 | Acc train: 0.9460000 | Acc validation: 0.9200000
# f1_score is 0.9509143407122232 0.9259259259259259
# roc_auc_score is 0.9490000000000001 0.9199999999999999
# Iter:   104 | Cost: 0.5273521 | Acc train: 0.9490000 | Acc validation: 0.9200000
# f1_score is 0.95 0.9345794392523363
# roc_auc_score is 0.9480000000000001 0.9299999999999999
# Iter:   105 | Cost: 0.5266832 | Acc train: 0.9480000 | Acc validation: 0.9300000
# f1_score is 0.96 0.9514563106796116
# roc_auc_score is 0.9589999999999999 0.9500000000000001
# Iter:   106 | Cost: 0.5253314 | Acc train: 0.9590000 | Acc validation: 0.9500000
# f1_score is 0.9652432969215491 0.9504950495049505
# roc_auc_score is 0.965 0.95
# Iter:   107 | Cost: 0.5283895 | Acc train: 0.9650000 | Acc validation: 0.9500000
# f1_score is 0.958710976837865 0.9504950495049505
# roc_auc_score is 0.959 0.95
# Iter:   108 | Cost: 0.5341566 | Acc train: 0.9590000 | Acc validation: 0.9500000
# f1_score is 0.9355509355509355 0.9696969696969697
# roc_auc_score is 0.938 0.97
# Iter:   109 | Cost: 0.5469410 | Acc train: 0.9380000 | Acc validation: 0.9700000
# f1_score is 0.9651046859421735 0.9504950495049505
# roc_auc_score is 0.965 0.95
# Iter:   110 | Cost: 0.5304665 | Acc train: 0.9650000 | Acc validation: 0.9500000
# f1_score is 0.9590643274853801 0.9514563106796116
# roc_auc_score is 0.958 0.9500000000000001
# Iter:   111 | Cost: 0.5242525 | Acc train: 0.9580000 | Acc validation: 0.9500000
# f1_score is 0.9573643410852714 0.9433962264150945
# roc_auc_score is 0.9560000000000001 0.94
# Iter:   112 | Cost: 0.5237348 | Acc train: 0.9560000 | Acc validation: 0.9400000
# f1_score is 0.95 0.9345794392523363
# roc_auc_score is 0.9480000000000001 0.9299999999999999
# Iter:   113 | Cost: 0.5244517 | Acc train: 0.9480000 | Acc validation: 0.9300000
# f1_score is 0.9509143407122232 0.9345794392523363
# roc_auc_score is 0.9490000000000001 0.9299999999999999
# Iter:   114 | Cost: 0.5242390 | Acc train: 0.9490000 | Acc validation: 0.9300000
# f1_score is 0.9385052034058656 0.9345794392523363
# roc_auc_score is 0.935 0.9299999999999999
# Iter:   115 | Cost: 0.5292266 | Acc train: 0.9350000 | Acc validation: 0.9300000
# f1_score is 0.9333333333333333 0.9174311926605504
# roc_auc_score is 0.9289999999999999 0.91
# Iter:   116 | Cost: 0.5321945 | Acc train: 0.9290000 | Acc validation: 0.9100000
# f1_score is 0.9333333333333333 0.9174311926605504
# roc_auc_score is 0.9289999999999999 0.91
# Iter:   117 | Cost: 0.5325816 | Acc train: 0.9290000 | Acc validation: 0.9100000
# f1_score is 0.9367327667610954 0.9345794392523363
# roc_auc_score is 0.9329999999999999 0.9299999999999999
# Iter:   118 | Cost: 0.5296855 | Acc train: 0.9330000 | Acc validation: 0.9300000
# f1_score is 0.9446564885496184 0.9345794392523363
# roc_auc_score is 0.9420000000000001 0.9299999999999999
# Iter:   119 | Cost: 0.5251650 | Acc train: 0.9420000 | Acc validation: 0.9300000
# f1_score is 0.9573643410852714 0.9433962264150945
# roc_auc_score is 0.9560000000000001 0.94
# Iter:   120 | Cost: 0.5232986 | Acc train: 0.9560000 | Acc validation: 0.9400000
# [[0.5, 0.5, 0.5, 0.54, 0.66, 0.36, 0.46, 0.5, 0.5, 0.5, 0.5, 0.5, 0.63, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.53, 0.73, 0.4, 0.47, 0.52, 0.61, 0.71, 0.84, 0.9, 0.87, 0.84, 0.81, 0.81, 0.83, 0.85, 0.85, 0.88, 0.88, 0.88, 0.88, 0.88, 0.88, 0.88, 0.9, 0.9, 0.89, 0.89, 0.91, 0.9, 0.9, 0.89, 0.88, 0.9, 0.91, 0.91, 0.93, 0.91, 0.91, 0.91, 0.92, 0.92, 0.91, 0.93, 0.93, 0.93, 0.91, 0.94, 0.93, 0.91, 0.9, 0.9, 0.91, 0.91, 0.87, 0.87, 0.9, 0.93, 0.91, 0.9, 0.91, 0.91, 0.91, 0.91, 0.9, 0.86, 0.86, 0.85, 0.86, 0.86, 0.86, 0.88, 0.9, 0.91, 0.91, 0.91, 0.91, 0.93, 0.93, 0.93, 0.94, 0.95, 0.93, 0.94, 0.95, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.93, 0.93, 0.93, 0.92, 0.95, 0.95, 0.95, 0.95, 0.95], [0.5, 0.5, 0.5, 0.52, 0.64, 0.54, 0.5, 0.38, 0.41, 0.44, 0.42, 0.52, 0.58, 0.66, 0.53, 0.51, 0.51, 0.51, 0.51, 0.54, 0.69, 0.78, 0.56, 0.59, 0.91, 0.84, 0.66, 0.5, 0.5, 0.5, 0.65, 0.8, 0.85, 0.92, 0.9, 0.91, 0.9, 0.9, 0.91, 0.9, 0.91, 0.87, 0.87, 0.89, 0.89, 0.89, 0.92, 0.96, 0.96, 0.95, 0.95, 0.95, 0.96, 0.97, 0.97, 0.97, 0.95, 0.93, 0.92, 0.92, 0.92, 0.93, 0.9, 0.89, 0.89, 0.89, 0.92, 0.92, 0.92, 0.92, 0.93, 0.94, 0.96, 0.96, 0.96, 0.95, 0.93, 0.9, 0.87, 0.88, 0.92, 0.95, 0.95, 0.95, 0.95, 0.94, 0.94, 0.94, 0.93, 0.89, 0.89, 0.91, 0.94, 0.95, 0.95, 0.95, 0.93, 0.93, 0.93, 0.93, 0.97, 0.98, 0.96, 0.95, 0.95, 0.94, 0.94, 0.94, 0.93, 0.89, 0.88, 0.89, 0.89, 0.88, 0.88, 0.9, 0.9, 0.91, 0.91, 0.89], [0.5, 0.5, 0.5, 0.51, 0.62, 0.54, 0.36, 0.47, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.44, 0.44, 0.49, 0.48, 0.68, 0.5, 0.5, 0.5, 0.5, 0.5, 0.8, 0.97, 0.8, 0.88, 0.91, 0.89, 0.91, 0.91, 0.9, 0.86, 0.87, 0.88, 0.9, 0.88, 0.89, 0.89, 0.89, 0.9, 0.89, 0.88, 0.89, 0.9, 0.91, 0.91, 0.9, 0.89, 0.9, 0.9, 0.9, 0.93, 0.94, 0.94, 0.96, 0.96, 0.94, 0.94, 0.92, 0.92, 0.92, 0.94, 0.94, 0.93, 0.94, 0.95, 0.95, 0.92, 0.93, 0.93, 0.93, 0.97, 0.97, 0.93, 0.9, 0.88, 0.88, 0.89, 0.92, 0.94, 0.94, 0.94, 0.94, 0.92, 0.91, 0.91, 0.93, 0.95, 0.92, 0.89, 0.86, 0.85, 0.89, 0.9, 0.87, 0.87, 0.89, 0.9, 0.92, 0.94, 0.92, 0.92, 0.93, 0.95, 0.95, 0.95, 0.97, 0.95, 0.95, 0.94, 0.93, 0.93, 0.93, 0.91, 0.91, 0.93, 0.93, 0.94]]
# [[0.5, 0.5, 0.504, 0.552, 0.666, 0.351, 0.437, 0.484, 0.498, 0.499, 0.499, 0.494, 0.6, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.501, 0.538, 0.709, 0.383, 0.448, 0.499, 0.545, 0.595, 0.712, 0.78, 0.783, 0.775, 0.757, 0.752, 0.75, 0.75, 0.75, 0.755, 0.756, 0.763, 0.768, 0.778, 0.779, 0.782, 0.778, 0.782, 0.782, 0.791, 0.801, 0.814, 0.843, 0.852, 0.862, 0.868, 0.879, 0.867, 0.881, 0.901, 0.918, 0.92, 0.923, 0.918, 0.91, 0.929, 0.926, 0.929, 0.916, 0.929, 0.942, 0.945, 0.949, 0.951, 0.936, 0.924, 0.884, 0.878, 0.914, 0.932, 0.958, 0.954, 0.956, 0.946, 0.945, 0.944, 0.94, 0.941, 0.936, 0.93, 0.934, 0.936, 0.938, 0.934, 0.933, 0.943, 0.951, 0.951, 0.948, 0.937, 0.927, 0.934, 0.947, 0.961, 0.968, 0.969, 0.972, 0.975, 0.972, 0.956, 0.947, 0.956, 0.956, 0.969, 0.97, 0.971, 0.966, 0.961, 0.967, 0.967, 0.962, 0.958], [0.5, 0.5, 0.504, 0.546, 0.646, 0.542, 0.383, 0.382, 0.406, 0.43, 0.416, 0.419, 0.513, 0.662, 0.548, 0.524, 0.527, 0.505, 0.507, 0.55, 0.707, 0.66, 0.509, 0.532, 0.771, 0.837, 0.624, 0.501, 0.5, 0.515, 0.654, 0.773, 0.805, 0.798, 0.775, 0.758, 0.774, 0.781, 0.79, 0.799, 0.801, 0.813, 0.821, 0.829, 0.834, 0.838, 0.836, 0.833, 0.836, 0.847, 0.862, 0.872, 0.868, 0.853, 0.853, 0.881, 0.915, 0.93, 0.928, 0.93, 0.94, 0.937, 0.929, 0.919, 0.915, 0.927, 0.937, 0.94, 0.941, 0.941, 0.947, 0.96, 0.974, 0.979, 0.98, 0.967, 0.943, 0.918, 0.914, 0.919, 0.933, 0.959, 0.954, 0.953, 0.947, 0.944, 0.939, 0.94, 0.942, 0.928, 0.921, 0.939, 0.959, 0.966, 0.968, 0.966, 0.952, 0.938, 0.948, 0.961, 0.974, 0.978, 0.974, 0.973, 0.965, 0.965, 0.956, 0.951, 0.942, 0.934, 0.907, 0.92, 0.917, 0.897, 0.904, 0.928, 0.93, 0.936, 0.93, 0.903], [0.5, 0.5, 0.501, 0.543, 0.626, 0.441, 0.364, 0.446, 0.481, 0.494, 0.498, 0.498, 0.499, 0.5, 0.407, 0.376, 0.44, 0.444, 0.668, 0.5, 0.5, 0.5, 0.5, 0.5, 0.773, 0.822, 0.696, 0.744, 0.795, 0.806, 0.779, 0.774, 0.767, 0.77, 0.766, 0.758, 0.761, 0.764, 0.766, 0.762, 0.775, 0.781, 0.782, 0.796, 0.798, 0.805, 0.803, 0.812, 0.818, 0.827, 0.835, 0.848, 0.854, 0.858, 0.87, 0.877, 0.875, 0.897, 0.909, 0.921, 0.933, 0.928, 0.937, 0.941, 0.943, 0.945, 0.953, 0.953, 0.964, 0.958, 0.945, 0.939, 0.959, 0.978, 0.978, 0.957, 0.926, 0.911, 0.908, 0.92, 0.934, 0.951, 0.948, 0.939, 0.939, 0.939, 0.932, 0.927, 0.947, 0.956, 0.967, 0.939, 0.91, 0.927, 0.947, 0.939, 0.921, 0.924, 0.937, 0.942, 0.955, 0.953, 0.946, 0.949, 0.948, 0.959, 0.965, 0.959, 0.938, 0.965, 0.958, 0.956, 0.948, 0.949, 0.935, 0.929, 0.929, 0.933, 0.942, 0.956]]
# [[1.448059148027405, 1.3414637578904758, 1.2020770042665632, 1.083769879997763, 1.0210444644569563, 1.0269809042714007, 1.0661566674627156, 1.086189703779173, 1.0881739080546444, 1.076859830016095, 1.0465995506848924, 1.0105991005160808, 0.9943527439969044, 1.0028376501031444, 1.026270920204466, 1.0631766353723182, 1.087604327873941, 1.0959770181862463, 1.0920458818937213, 1.0696037186305012, 1.045626834803339, 1.0058052764206182, 0.9840727383561216, 0.9771251906114474, 0.9658139015145047, 0.9531347377077596, 0.9337545576198882, 0.9171147561027228, 0.889489541670958, 0.8562762625259331, 0.8332370951844182, 0.8166149402324238, 0.8029069042515476, 0.7878688659356359, 0.7735377650133047, 0.7578659748660886, 0.7419046104444911, 0.7246671776384616, 0.7097954967528747, 0.6977043878733733, 0.6867956048057547, 0.6771846544009145, 0.6638148770242719, 0.6522852179545678, 0.6414141668827128, 0.6332360752860123, 0.6277592145207389, 0.6191237940935141, 0.6096232769235715, 0.6016760333585445, 0.5958843233392912, 0.5895444887289671, 0.5851368043603206, 0.5757881241533922, 0.5688045467100505, 0.5695729533432884, 0.5656975220933008, 0.5558434835757793, 0.5489006499406289, 0.5473140250918755, 0.5451632963268538, 0.5442881737631411, 0.5461475166185974, 0.5405650817790757, 0.5407327388012644, 0.5397983005711378, 0.5432459015940456, 0.5379658288200134, 0.5358022659189315, 0.5357628463059244, 0.5395269202089685, 0.5373374827796029, 0.533774793604247, 0.5380564997600369, 0.5568787475142476, 0.5592648751052931, 0.5416130608767774, 0.5324686069928108, 0.5330139080833184, 0.5400469168771638, 0.5338734923014068, 0.5319488316793562, 0.5326419610654004, 0.5330017891854385, 0.5337923418119219, 0.5351807158539887, 0.5375230253813182, 0.5425505840831538, 0.5379030554017297, 0.5353086536289229, 0.5348784849745869, 0.5342931495870967, 0.5349299188733577, 0.5323526047551443, 0.5312730299863901, 0.5307219527446884, 0.5307240210572179, 0.5314783731860364, 0.5362318778856744, 0.5341846233467226, 0.5287081993038687, 0.5290367608743417, 0.5334154500943461, 0.5334008729430557, 0.5346118954771233, 0.5365689087221279, 0.5357923865234758, 0.531178796751563, 0.5316336660109783, 0.5304643470487357, 0.530469794230872, 0.5326364551273767, 0.5352461165464348, 0.5326381796994292, 0.5299501724414148, 0.5284705579743613, 0.5286501034212538, 0.5294232117407363, 0.5277784033506847, 0.5271036014638834], [1.4499669485480273, 1.348861074472535, 1.2152443702253413, 1.1079407476124965, 1.0313961646298149, 1.0123923828692214, 1.013861315664145, 1.0265822507338922, 1.027137447230411, 1.02702425372475, 1.0093912829341811, 0.9922630182131469, 0.9856239143045032, 0.9868012438886075, 0.9945005557100428, 0.9955109951805521, 0.9902346831673634, 0.9890063835403818, 0.9822209775037622, 0.9687832679315042, 0.955340283034836, 0.9473203436733293, 0.9493743798019945, 0.9340783206629852, 0.895107516863096, 0.8666338246815707, 0.8529371848864997, 0.8657244906439877, 0.8710100522315677, 0.8486115345397897, 0.8055255033042998, 0.7708671420277577, 0.7480625840938706, 0.7299432007953388, 0.7294497553693092, 0.7259898344853574, 0.7051651917810194, 0.6873532589855399, 0.6706445316741384, 0.6596722495161428, 0.6518395768923742, 0.647930712673711, 0.6395635101576688, 0.628620251733192, 0.6189161837204368, 0.6113687039500412, 0.6063515220794088, 0.6037388579455113, 0.6011352087241785, 0.5956151301138082, 0.5904421358306697, 0.5854924486029237, 0.5829712368223006, 0.5848147049891278, 0.5844530179024231, 0.5736816040161062, 0.5613976514798474, 0.5575228883659978, 0.5573652778646332, 0.5573231709055473, 0.5550703079877063, 0.5549905414494529, 0.5591672702876719, 0.5654657264544773, 0.5669158291752233, 0.5558604792265996, 0.548422472792098, 0.5450547680836578, 0.5421114959256346, 0.5415586241794026, 0.5388382560665151, 0.5370060010010057, 0.5402986765292007, 0.5440281778855447, 0.5368315340151784, 0.5298324822195458, 0.5327217209865962, 0.5435164323976364, 0.5461169769433746, 0.5430148920734701, 0.529869551654191 ...
