# %%
import pennylane as qml
from pennylane import numpy as np
from sklearn.decomposition import PCA
import random
from collections import Counter
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve

# %%
wire = 2

wires = wire * 2
dim = 2 ** wire
dim1 = 2 * dim
dev = qml.device("default.qubit", wires=wires)
#dev = qml.device("lightning.qubit", wires=wires, shots=None)
#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
dev1 = qml.device("lightning.qubit", wires=wire, shots=None)
wires = dev.wires.tolist()

@qml.qnode(dev1)
def StateVector(x):
    qml.AmplitudeEmbedding(features=x, wires=range(wire), 
                           pad_with=0.0, normalize=True)
    return qml.state()

def accuracy(labels, predictions):

    loss = 0
    for l, p in zip(labels, predictions):
        if abs(l - p) < 1e-5:
            loss = loss + 1
    loss = loss / len(labels)

    return loss

def square_loss(labels, predictions):
    loss = 0
    for l, p in zip(labels, predictions):
        loss = loss + (l - p) ** 2

    loss = loss / len(labels)
    return loss

def noramlization(data):
    minVals = data.min(0)
    maxVals = data.max(0)
    ranges = maxVals - minVals
    normData = np.zeros(np.shape(data))
    m = data.shape[0]
    normData = data - np.tile(minVals, (m, 1))
    normData = normData/np.tile(ranges, (m, 1))
    return normData

def random_params(num_wires):
    """Generate random variational parameters in the shape for the ansatz."""
    return np.random.uniform(0, 2 * np.pi, num_wires, requires_grad=True)

num_para = int(wire + (wire - 1) * wire / 2)
params_init = random_params(3 * num_para + wire)
print(params_init)
# Out:
# [2.60989935 3.7181927  3.21475175 2.68082978 1.79928937 5.63893755
#  1.55887924 1.05052705 0.95137693 5.09212143 3.41797624]

# %%
def ProcessingData(datapoints, train_size, test_size):
    train_data = np.loadtxt("./mnist_train.csv", delimiter=",")
    #Extracting features and labels from the dataset 
    train_data_features = train_data[:datapoints, 1:]
    train_data_labels = train_data[:datapoints, :1].reshape(datapoints,)

    # Use PCA technique to reduce dimensions to 4
    DimReduce = PCA(n_components= dim1)
    train_data_features_reduced = DimReduce.fit_transform(train_data_features)
    # normalize dataset
    train_data_features_reduced = noramlization(train_data_features_reduced)
    s1 = np.array([StateVector(x) for x in train_data_features_reduced[:,:dim]])
    s2 = np.array([StateVector(x) for x in train_data_features_reduced[:,dim:dim1]])
    train_data_features_reduced = np.hstack((s1, s2)).tolist()

    zero_one_datapoint_array = []
    label_0_1 = []
    zero_datapoints_array = [] #an array of the data points containing value 0
    one_datapoints_array = []# an array of the data points containing value 1
    label_0 = []
    label_1 = []

    for i in range(datapoints):
        if train_data_labels[i] == 0:                   # extracting zeros
            label_0.append(-1)
            zero_datapoints_array.append(train_data_features_reduced[i])
        elif train_data_labels[i] == 1:                   # extracting ones
            label_1.append(1)
            one_datapoints_array.append(train_data_features_reduced[i]) 

    if (len(label_0) + len(label_1)) < 2 * (train_size + test_size):
        print("datapoints is too small!")
    else:
        print((len(label_0),len(label_1)))
        zero_datapoints_array_train = zero_datapoints_array[:train_size]
        one_datapoints_array_train = one_datapoints_array[:train_size]
        label_0_train = label_0[:train_size]
        label_1_train = label_1[:train_size]
        zero_datapoints_array_test = zero_datapoints_array[train_size + 1:train_size + test_size + 1]
        one_datapoints_array_test = one_datapoints_array[train_size + 1:train_size + test_size + 1]
        label_0_test = label_0[train_size + 1:train_size + test_size + 1]
        label_1_test = label_1[train_size + 1:train_size + test_size + 1]
        #print(len(zero_datapoints_array_train), len(label_1_train))
        #print(len(one_datapoints_array_test), len(label_0_test))

        zero_one_datapoint_array_train = zero_datapoints_array_train + one_datapoints_array_train
        label_0_1_train = label_0_train + label_1_train
        zero_one_datapoint_array_test = zero_datapoints_array_test + one_datapoints_array_test
        label_0_1_test = label_0_test + label_1_test
        #print(len(zero_one_datapoint_array_train), label_0_1_train)
        #print(len(zero_one_datapoint_array_test), label_0_1_test)

        np.random.seed(10)
        index_train = np.random.permutation(range(2 * train_size))
        index_test = np.random.permutation(range(2 * test_size))

        feats_train = []
        Y_train = []
        feats_val = []
        Y_val = []
        for i in range(2 * train_size):
            feats_train.append(zero_one_datapoint_array_train[index_train[i]])
            Y_train.append(label_0_1_train[index_train[i]])


        for i in range(2 * test_size):
            feats_val.append(zero_one_datapoint_array_test[index_test[i]])
            Y_val.append(label_0_1_test[index_test[i]])

        #print(feats_val, Y_val)

        features = feats_train + feats_val
        features = np.array(features, requires_grad=False)
        Y = Y_train + Y_val
        Y = np.array(Y, requires_grad=False)
        feats_train = np.array(feats_train, requires_grad=False)
        Y_train = np.array(Y_train, requires_grad=False)
        feats_val = np.array(feats_val, requires_grad=False)
        Y_val = np.array(Y_val, requires_grad=False)
    return feats_train, Y_train, feats_val, Y_val, features, Y

datapoints = 6000
train_size = 500
test_size = 50
feats_train, Y_train, feats_val, Y_val, features, Y = ProcessingData(datapoints, train_size, test_size)
# Out:
# (592, 671)

# %%
#Block-encoding + Hardware-efficient Ansatz
def DataEncoding(x, wires_start, wires_end):
    wires = np.arange(wires_start, wires_end).tolist()
    qml.RX(x[0], wires=wires_start)
    qml.RX(x[1], wires=wires_start + 1)
    qml.RY(x[2], wires=wires_start)
    qml.RY(x[3], wires=wires_start + 1)
    #qml.AmplitudeEmbedding(features=x, wires=wires, pad_with=0., normalize=True)

def Ansatz(params, wires_start, wires_end):
    for i in np.arange(wires_start, wires_end):
        qml.Hadamard(wires=wires[i])
        qml.RY(params[i - wires_start], wires=wires[i])
        #print(i)
    for i in np.arange(wires_start, wires_end):
        for j in np.arange(i + 1, wires_end):
            qml.CRZ(params[i - wires_start + wires_end - wires_start], wires=[wires[i], wires[j]])

#@qml.qnode(dev, interface="torch", diff_method="parameter-shift")
@qml.qnode(dev)
def QKSAN(feat, params):
    x1 = feat[0:4]
    x2 = feat[4:8]
    DataEncoding(x1, 0, wire)
    Ansatz(params[0: num_para], 0, wire)
    qml.adjoint(Ansatz)(params[num_para: 2 * num_para], 0, wire)
    qml.adjoint(DataEncoding)(x2, 0, wire)


    DataEncoding(x2, wire, (2 * wire))
    Ansatz(params[2 * num_para: 3 * num_para], wire, (2 * wire))
    for i in range(wire):
        qml.cond(qml.measure(i), qml.RY)(params[3 * num_para + i], wires=wires[i + wire])
    return qml.expval(qml.PauliZ(2 * wire - 1))

qml.drawer.use_style('black_white')
fig, ax = qml.draw_mpl(QKSAN, show_all_wires=True)(feats_train[0], params_init)
fig.set_size_inches((7, 5))

def variational_classifier(params, feat):
    return QKSAN(feat, params)


def cost(params, features, labels):
    predictions = [variational_classifier(params, feat) for feat in features]
    return square_loss(labels, predictions)

lr = 0.06
def TrainQKSAN(params_init):
    opt = qml.NesterovMomentumOptimizer(lr)
    batch_size = 30
    weights = params_init
    #bias = np.array(0.0, requires_grad=True)
    his_acc_val = []
    his_acc_train = []
    his_cost = []
    f1_train = []
    f1_test = []
    roc_auc_train = []
    roc_auc_test = []
    for it in range(120):

        # Update the weights by one optimizer step
        batch_index = np.random.randint(0, 2 * train_size, (batch_size,))
        feats_train_batch = feats_train[batch_index]
        Y_train_batch = Y_train[batch_index]
        
        weights, _, _ = opt.step(cost, weights, feats_train_batch, Y_train_batch)

        # Compute predictions on train and validation set
        predictions_train = [np.sign(variational_classifier(weights, feat)) for feat in feats_train]
        predictions_val = [np.sign(variational_classifier(weights, feat)) for feat in feats_val]
        #print(probs(Y_train, predictions_val))
        c = cost(weights, features, Y).numpy()
        #print(c)
        # Compute accuracy on train and validation set
        acc_train = accuracy_score(Y_train, predictions_train)
        acc_val = accuracy_score(Y_val, predictions_val)
        a = f1_score(Y_train, predictions_train)
        b = f1_score(Y_val, predictions_val)
        
        print("f1_score is", a, b)
        d = roc_auc_score(Y_train, predictions_train)
        e = roc_auc_score(Y_val, predictions_val)
        print("roc_auc_score is", d, e)


        f1_train.append(a)
        f1_test.append(b)
        roc_auc_train.append(d)
        roc_auc_test.append(e)
        his_acc_val.append(acc_val)
        his_acc_train.append(acc_train)
        his_cost.append(c)
        print("Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
            "".format(it + 1, c, acc_train, acc_val))
        
    return his_acc_val, his_acc_train, his_cost, f1_train, f1_test, roc_auc_train, roc_auc_test

# %%
lear_rate = [0.07, 0.08, 0.09]
a = []
b = []
c = []
for lr in lear_rate:
    a1, a2, a3, _, _, _, _, = TrainQKSAN(params_init)
    a.append(a1)
    b.append(a2)
    c.append(a3)
print(a)
print(b)
print(c)
# Out:
# f1_score is 0.01443001443001443 0.0
# roc_auc_score is 0.317 0.3
# Iter:     1 | Cost: 1.0641515 | Acc train: 0.3170000 | Acc validation: 0.3000000
# f1_score is 0.006015037593984964 0.0
# roc_auc_score is 0.33899999999999997 0.32
# Iter:     2 | Cost: 1.0623299 | Acc train: 0.3390000 | Acc validation: 0.3200000
# f1_score is 0.006259780907668232 0.0
# roc_auc_score is 0.365 0.36
# Iter:     3 | Cost: 1.0591998 | Acc train: 0.3650000 | Acc validation: 0.3600000
# f1_score is 0.006379585326953748 0.0
# roc_auc_score is 0.377 0.4
# Iter:     4 | Cost: 1.0544790 | Acc train: 0.3770000 | Acc validation: 0.4000000
# f1_score is 0.0065252854812398045 0.0
# roc_auc_score is 0.391 0.41000000000000003
# Iter:     5 | Cost: 1.0495345 | Acc train: 0.3910000 | Acc validation: 0.4100000
# f1_score is 0.0067453625632377745 0.0
# roc_auc_score is 0.41100000000000003 0.44
# Iter:     6 | Cost: 1.0438065 | Acc train: 0.4110000 | Acc validation: 0.4400000
# f1_score is 0.0034482758620689655 0.0
# roc_auc_score is 0.422 0.44
# Iter:     7 | Cost: 1.0375038 | Acc train: 0.4220000 | Acc validation: 0.4400000
# f1_score is 0.006825938566552901 0.0
# roc_auc_score is 0.418 0.44
# Iter:     8 | Cost: 1.0298617 | Acc train: 0.4180000 | Acc validation: 0.4400000
# f1_score is 0.006756756756756757 0.0
# roc_auc_score is 0.41200000000000003 0.44
# Iter:     9 | Cost: 1.0224853 | Acc train: 0.4120000 | Acc validation: 0.4400000
# f1_score is 0.01346801346801347 0.0
# roc_auc_score is 0.41400000000000003 0.45
# Iter:    10 | Cost: 1.0161537 | Acc train: 0.4140000 | Acc validation: 0.4500000
# f1_score is 0.03618421052631579 0.0
# roc_auc_score is 0.41400000000000003 0.44
# Iter:    11 | Cost: 1.0102147 | Acc train: 0.4140000 | Acc validation: 0.4400000
# f1_score is 0.09846153846153848 0.0625
# roc_auc_score is 0.41400000000000003 0.4
# Iter:    12 | Cost: 1.0048151 | Acc train: 0.4140000 | Acc validation: 0.4000000
# f1_score is 0.4 0.4137931034482759
# roc_auc_score is 0.49 0.49
# Iter:    13 | Cost: 1.0007808 | Acc train: 0.4900000 | Acc validation: 0.4900000
# f1_score is 0.6577301161751563 0.6371681415929202
# roc_auc_score is 0.617 0.59
# Iter:    14 | Cost: 0.9978045 | Acc train: 0.6170000 | Acc validation: 0.5900000
# f1_score is 0.7126258714175059 0.7131782945736436
# roc_auc_score is 0.629 0.63
# Iter:    15 | Cost: 0.9961431 | Acc train: 0.6290000 | Acc validation: 0.6300000
# f1_score is 0.702355460385439 0.7050359712230216
# roc_auc_score is 0.583 0.59
# Iter:    16 | Cost: 0.9959709 | Acc train: 0.5830000 | Acc validation: 0.5900000
# f1_score is 0.6842105263157895 0.6896551724137931
# roc_auc_score is 0.5439999999999999 0.55
# Iter:    17 | Cost: 0.9962010 | Acc train: 0.5440000 | Acc validation: 0.5500000
# f1_score is 0.6752542372881356 0.684931506849315
# roc_auc_score is 0.521 0.54
# Iter:    18 | Cost: 0.9965499 | Acc train: 0.5210000 | Acc validation: 0.5400000
# f1_score is 0.6680080482897384 0.6802721088435374
# roc_auc_score is 0.505 0.53
# Iter:    19 | Cost: 0.9967828 | Acc train: 0.5050000 | Acc validation: 0.5300000
# f1_score is 0.6671122994652408 0.6711409395973155
# roc_auc_score is 0.502 0.51
# Iter:    20 | Cost: 0.9969984 | Acc train: 0.5020000 | Acc validation: 0.5100000
# f1_score is 0.6666666666666666 0.6711409395973155
# roc_auc_score is 0.5 0.51
# Iter:    21 | Cost: 0.9973136 | Acc train: 0.5000000 | Acc validation: 0.5100000
# f1_score is 0.6666666666666666 0.6711409395973155
# roc_auc_score is 0.5 0.51
# Iter:    22 | Cost: 0.9960919 | Acc train: 0.5000000 | Acc validation: 0.5100000
# f1_score is 0.6666666666666666 0.6711409395973155
# roc_auc_score is 0.5 0.51
# Iter:    23 | Cost: 0.9942563 | Acc train: 0.5000000 | Acc validation: 0.5100000
# f1_score is 0.6666666666666666 0.6756756756756758
# roc_auc_score is 0.5 0.52
# Iter:    24 | Cost: 0.9923613 | Acc train: 0.5000000 | Acc validation: 0.5200000
# f1_score is 0.6675585284280937 0.6756756756756758
# roc_auc_score is 0.503 0.52
# Iter:    25 | Cost: 0.9904434 | Acc train: 0.5030000 | Acc validation: 0.5200000
# f1_score is 0.6689008042895442 0.6802721088435374
# roc_auc_score is 0.506 0.53
# Iter:    26 | Cost: 0.9873570 | Acc train: 0.5060000 | Acc validation: 0.5300000
# f1_score is 0.6729857819905213 0.684931506849315
# roc_auc_score is 0.517 0.54
# Iter:    27 | Cost: 0.9838961 | Acc train: 0.5170000 | Acc validation: 0.5400000
# f1_score is 0.6875000000000001 0.6993006993006993
# roc_auc_score is 0.55 0.5700000000000001
# Iter:    28 | Cost: 0.9796580 | Acc train: 0.5500000 | Acc validation: 0.5700000
# f1_score is 0.7212874908558888 0.7299270072992701
# roc_auc_score is 0.619 0.63
# Iter:    29 | Cost: 0.9758419 | Acc train: 0.6190000 | Acc validation: 0.6300000
# f1_score is 0.7450076804915514 0.717557251908397
# roc_auc_score is 0.6679999999999999 0.6299999999999999
# Iter:    30 | Cost: 0.9726510 | Acc train: 0.6680000 | Acc validation: 0.6300000
# f1_score is 0.7727645611156686 0.7479674796747968
# roc_auc_score is 0.723 0.69
# Iter:    31 | Cost: 0.9695455 | Acc train: 0.7230000 | Acc validation: 0.6900000
# f1_score is 0.788389513108614 0.7307692307692308
# roc_auc_score is 0.774 0.72
# Iter:    32 | Cost: 0.9657105 | Acc train: 0.7740000 | Acc validation: 0.7200000
# f1_score is 0.6931818181818182 0.6823529411764706
# roc_auc_score is 0.7299999999999999 0.73
# Iter:    33 | Cost: 0.9622307 | Acc train: 0.7300000 | Acc validation: 0.7300000
# f1_score is 0.3630769230769231 0.3492063492063492
# roc_auc_score is 0.586 0.59
# Iter:    34 | Cost: 0.9592930 | Acc train: 0.5860000 | Acc validation: 0.5900000
# f1_score is 0.1070110701107011 0.0392156862745098
# roc_auc_score is 0.516 0.51
# Iter:    35 | Cost: 0.9569166 | Acc train: 0.5160000 | Acc validation: 0.5100000
# f1_score is 0.03875968992248062 0.0
# roc_auc_score is 0.504 0.5
# Iter:    36 | Cost: 0.9550116 | Acc train: 0.5040000 | Acc validation: 0.5000000
# f1_score is 0.023575638506876228 0.0
# roc_auc_score is 0.503 0.5
# Iter:    37 | Cost: 0.9533113 | Acc train: 0.5030000 | Acc validation: 0.5000000
# f1_score is 0.00398406374501992 0.0
# roc_auc_score is 0.5 0.5
# Iter:    38 | Cost: 0.9516879 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.003992015968063872 0.0
# roc_auc_score is 0.501 0.5
# Iter:    39 | Cost: 0.9502172 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.003992015968063872 0.0
# roc_auc_score is 0.501 0.5
# Iter:    40 | Cost: 0.9480423 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.03522504892367906 0.0
# roc_auc_score is 0.507 0.5
# Iter:    41 | Cost: 0.9453922 | Acc train: 0.5070000 | Acc validation: 0.5000000
# f1_score is 0.09792843691148775 0.0
# roc_auc_score is 0.521 0.5
# Iter:    42 | Cost: 0.9428026 | Acc train: 0.5210000 | Acc validation: 0.5000000
# f1_score is 0.16363636363636364 0.21428571428571425
# roc_auc_score is 0.54 0.56
# Iter:    43 | Cost: 0.9404465 | Acc train: 0.5400000 | Acc validation: 0.5600000
# f1_score is 0.30564784053156147 0.33333333333333337
# roc_auc_score is 0.582 0.6
# Iter:    44 | Cost: 0.9379010 | Acc train: 0.5820000 | Acc validation: 0.6000000
# f1_score is 0.31125827814569534 0.3870967741935484
# roc_auc_score is 0.584 0.62
# Iter:    45 | Cost: 0.9352396 | Acc train: 0.5840000 | Acc validation: 0.6200000
# f1_score is 0.3706070287539936 0.5714285714285715
# roc_auc_score is 0.606 0.7
# Iter:    46 | Cost: 0.9324526 | Acc train: 0.6060000 | Acc validation: 0.7000000
# f1_score is 0.3038397328881469 0.41269841269841273
# roc_auc_score is 0.583 0.63
# Iter:    47 | Cost: 0.9294618 | Acc train: 0.5830000 | Acc validation: 0.6300000
# f1_score is 0.3866877971473851 0.6111111111111112
# roc_auc_score is 0.613 0.72
# Iter:    48 | Cost: 0.9260503 | Acc train: 0.6130000 | Acc validation: 0.7200000
# f1_score is 0.5166908563134978 0.7654320987654321
# roc_auc_score is 0.6669999999999999 0.81
# Iter:    49 | Cost: 0.9223671 | Acc train: 0.6670000 | Acc validation: 0.8100000
# f1_score is 0.527536231884058 0.7654320987654321
# roc_auc_score is 0.6739999999999999 0.81
# Iter:    50 | Cost: 0.9186216 | Acc train: 0.6740000 | Acc validation: 0.8100000
# f1_score is 0.6035665294924555 0.8235294117647058
# roc_auc_score is 0.711 0.85
# Iter:    51 | Cost: 0.9145732 | Acc train: 0.7110000 | Acc validation: 0.8500000
# f1_score is 0.6408544726301735 0.8235294117647058
# roc_auc_score is 0.731 0.85
# Iter:    52 | Cost: 0.9103936 | Acc train: 0.7310000 | Acc validation: 0.8500000
# f1_score is 0.7265917602996255 0.8764044943820225
# roc_auc_score is 0.7809999999999999 0.89
# Iter:    53 | Cost: 0.9058835 | Acc train: 0.7810000 | Acc validation: 0.8900000
# f1_score is 0.7297633872976338 0.8764044943820225
# roc_auc_score is 0.7829999999999999 0.89
# Iter:    54 | Cost: 0.9015316 | Acc train: 0.7830000 | Acc validation: 0.8900000
# f1_score is 0.7227101631116687 0.8636363636363636
# roc_auc_score is 0.779 0.88
# Iter:    55 | Cost: 0.8970986 | Acc train: 0.7790000 | Acc validation: 0.8800000
# f1_score is 0.6238030095759234 0.8505747126436781
# roc_auc_score is 0.725 0.87
# Iter:    56 | Cost: 0.8935313 | Acc train: 0.7250000 | Acc validation: 0.8700000
# f1_score is 0.6151724137931034 0.8505747126436781
# roc_auc_score is 0.721 0.87
# Iter:    57 | Cost: 0.8893800 | Acc train: 0.7210000 | Acc validation: 0.8700000
# f1_score is 0.7161125319693095 0.8764044943820225
# roc_auc_score is 0.778 0.89
# Iter:    58 | Cost: 0.8837688 | Acc train: 0.7780000 | Acc validation: 0.8900000
# f1_score is 0.7667887667887667 0.9473684210526316
# roc_auc_score is 0.809 0.95
# Iter:    59 | Cost: 0.8784978 | Acc train: 0.8090000 | Acc validation: 0.9500000
# f1_score is 0.8170310701956272 0.9690721649484536
# roc_auc_score is 0.8409999999999999 0.97
# Iter:    60 | Cost: 0.8732152 | Acc train: 0.8410000 | Acc validation: 0.9700000
# f1_score is 0.8475336322869955 0.9795918367346939
# roc_auc_score is 0.864 0.98
# Iter:    61 | Cost: 0.8686092 | Acc train: 0.8640000 | Acc validation: 0.9800000
# f1_score is 0.8990435706695005 0.9795918367346939
# roc_auc_score is 0.905 0.98
# Iter:    62 | Cost: 0.8637579 | Acc train: 0.9050000 | Acc validation: 0.9800000
# f1_score is 0.9247311827956989 0.9333333333333333
# roc_auc_score is 0.923 0.9299999999999999
# Iter:    63 | Cost: 0.8589640 | Acc train: 0.9230000 | Acc validation: 0.9300000
# f1_score is 0.9139579349904398 0.9245283018867924
# roc_auc_score is 0.9099999999999999 0.9199999999999999
# Iter:    64 | Cost: 0.8545760 | Acc train: 0.9100000 | Acc validation: 0.9200000
# f1_score is 0.889087656529517 0.9074074074074074
# roc_auc_score is 0.876 0.9000000000000001
# Iter:    65 | Cost: 0.8512628 | Acc train: 0.8760000 | Acc validation: 0.9000000
# f1_score is 0.8708551483420593 0.8672566371681417
# roc_auc_score is 0.852 0.85
# Iter:    66 | Cost: 0.8483175 | Acc train: 0.8520000 | Acc validation: 0.8500000
# f1_score is 0.8237232289950577 0.8474576271186441
# roc_auc_score is 0.786 0.8200000000000001
# Iter:    67 | Cost: 0.8492042 | Acc train: 0.7860000 | Acc validation: 0.8200000
# f1_score is 0.7961783439490446 0.819672131147541
# roc_auc_score is 0.744 0.78
# Iter:    68 | Cost: 0.8481347 | Acc train: 0.7440000 | Acc validation: 0.7800000
# f1_score is 0.7917656373713382 0.819672131147541
# roc_auc_score is 0.737 0.78
# Iter:    69 | Cost: 0.8455089 | Acc train: 0.7370000 | Acc validation: 0.7800000
# f1_score is 0.7843137254901961 0.8130081300813007
# roc_auc_score is 0.725 0.77
# Iter:    70 | Cost: 0.8436034 | Acc train: 0.7250000 | Acc validation: 0.7700000
# f1_score is 0.8633217993079585 0.8695652173913044
# roc_auc_score is 0.842 0.85
# Iter:    71 | Cost: 0.8323865 | Acc train: 0.8420000 | Acc validation: 0.8500000
# f1_score is 0.9087591240875913 0.8990825688073395
# roc_auc_score is 0.9 0.89
# Iter:    72 | Cost: 0.8278255 | Acc train: 0.9000000 | Acc validation: 0.8900000
# f1_score is 0.9089253187613843 0.890909090909091
# roc_auc_score is 0.9000000000000001 0.88
# Iter:    73 | Cost: 0.8259264 | Acc train: 0.9000000 | Acc validation: 0.8800000
# f1_score is 0.909423604757548 0.890909090909091
# roc_auc_score is 0.901 0.88
# Iter:    74 | Cost: 0.8239806 | Acc train: 0.9010000 | Acc validation: 0.8800000
# f1_score is 0.8539709649871905 0.8474576271186441
# roc_auc_score is 0.829 0.8200000000000001
# Iter:    75 | Cost: 0.8250713 | Acc train: 0.8290000 | Acc validation: 0.8200000
# f1_score is 0.8340283569641367 0.8333333333333333
# roc_auc_score is 0.8009999999999999 0.8
# Iter:    76 | Cost: 0.8255816 | Acc train: 0.8010000 | Acc validation: 0.8000000
# f1_score is 0.8503401360544218 0.8474576271186441
# roc_auc_score is 0.8240000000000001 0.8200000000000001
# Iter:    77 | Cost: 0.8222893 | Acc train: 0.8240000 | Acc validation: 0.8200000
# f1_score is 0.8532423208191127 0.8474576271186441
# roc_auc_score is 0.8280000000000001 0.8200000000000001
# Iter:    78 | Cost: 0.8208300 | Acc train: 0.8280000 | Acc validation: 0.8200000
# f1_score is 0.892665474060823 0.8771929824561403
# roc_auc_score is 0.88 0.86
# Iter:    79 | Cost: 0.8174813 | Acc train: 0.8800000 | Acc validation: 0.8600000
# f1_score is 0.9263746505125815 0.9074074074074074
# roc_auc_score is 0.921 0.9000000000000001
# Iter:    80 | Cost: 0.8160420 | Acc train: 0.9210000 | Acc validation: 0.9000000
# f1_score is 0.909423604757548 0.9009009009009009
# roc_auc_score is 0.901 0.89
# Iter:    81 | Cost: 0.8147057 | Acc train: 0.9010000 | Acc validation: 0.8900000
# f1_score is 0.9005424954792044 0.8771929824561403
# roc_auc_score is 0.89 0.86
# Iter:    82 | Cost: 0.8135689 | Acc train: 0.8900000 | Acc validation: 0.8600000
# f1_score is 0.9455587392550144 0.9245283018867924
# roc_auc_score is 0.943 0.9199999999999999
# Iter:    83 | Cost: 0.8134964 | Acc train: 0.9430000 | Acc validation: 0.9200000
# f1_score is 0.9547244094488189 0.9607843137254902
# roc_auc_score is 0.954 0.96
# Iter:    84 | Cost: 0.8153683 | Acc train: 0.9540000 | Acc validation: 0.9600000
# f1_score is 0.9037837837837838 0.8409090909090909
# roc_auc_score is 0.9109999999999999 0.86
# Iter:    85 | Cost: 0.8208796 | Acc train: 0.9110000 | Acc validation: 0.8600000
# f1_score is 0.7530864197530864 0.6027397260273973
# roc_auc_score is 0.7999999999999999 0.71
# Iter:    86 | Cost: 0.8228710 | Acc train: 0.8000000 | Acc validation: 0.7100000
# f1_score is 0.5096870342771982 0.36065573770491804
# roc_auc_score is 0.671 0.61
# Iter:    87 | Cost: 0.8272724 | Acc train: 0.6710000 | Acc validation: 0.6100000
# f1_score is 0.08061420345489444 0.07692307692307693
# roc_auc_score is 0.521 0.52
# Iter:    88 | Cost: 0.8323932 | Acc train: 0.5210000 | Acc validation: 0.5200000
# f1_score is 0.7801932367149759 0.5833333333333334
# roc_auc_score is 0.818 0.7
# Iter:    89 | Cost: 0.8183540 | Acc train: 0.8180000 | Acc validation: 0.7000000
# f1_score is 0.9486166007905138 0.970873786407767
# roc_auc_score is 0.9479999999999998 0.97
# Iter:    90 | Cost: 0.8091627 | Acc train: 0.9480000 | Acc validation: 0.9700000
# f1_score is 0.9528392685274302 0.9523809523809523
# roc_auc_score is 0.9510000000000001 0.9500000000000001
# Iter:    91 | Cost: 0.8052578 | Acc train: 0.9510000 | Acc validation: 0.9500000
# f1_score is 0.8950672645739911 0.9009009009009009
# roc_auc_score is 0.883 0.89
# Iter:    92 | Cost: 0.8017838 | Acc train: 0.8830000 | Acc validation: 0.8900000
# f1_score is 0.8354218880534671 0.8474576271186441
# roc_auc_score is 0.8029999999999999 0.8200000000000001
# Iter:    93 | Cost: 0.8051752 | Acc train: 0.8030000 | Acc validation: 0.8200000
# f1_score is 0.8103727714748784 0.8264462809917354
# roc_auc_score is 0.766 0.79
# Iter:    94 | Cost: 0.8077973 | Acc train: 0.7660000 | Acc validation: 0.7900000
# f1_score is 0.8156606851549755 0.8264462809917354
# roc_auc_score is 0.774 0.79
# Iter:    95 | Cost: 0.8060555 | Acc train: 0.7740000 | Acc validation: 0.7900000
# f1_score is 0.8090614886731392 0.8264462809917354
# roc_auc_score is 0.764 0.79
# Iter:    96 | Cost: 0.8059456 | Acc train: 0.7640000 | Acc validation: 0.7900000
# f1_score is 0.8216926869350863 0.8264462809917354
# roc_auc_score is 0.783 0.79
# Iter:    97 | Cost: 0.8033094 | Acc train: 0.7830000 | Acc validation: 0.7900000
# f1_score is 0.8237232289950577 0.8264462809917354
# roc_auc_score is 0.786 0.79
# Iter:    98 | Cost: 0.8021912 | Acc train: 0.7860000 | Acc validation: 0.7900000
# f1_score is 0.8025682182985554 0.819672131147541
# roc_auc_score is 0.754 0.78
# Iter:    99 | Cost: 0.8053947 | Acc train: 0.7540000 | Acc validation: 0.7800000
# f1_score is 0.8176614881439084 0.8264462809917354
# roc_auc_score is 0.777 0.79
# Iter:   100 | Cost: 0.8009560 | Acc train: 0.7770000 | Acc validation: 0.7900000
# f1_score is 0.8670721112076456 0.8849557522123894
# roc_auc_score is 0.847 0.87
# Iter:   101 | Cost: 0.7936175 | Acc train: 0.8470000 | Acc validation: 0.8700000
# f1_score is 0.9162833486660533 0.9259259259259259
# roc_auc_score is 0.909 0.9199999999999999
# Iter:   102 | Cost: 0.7909207 | Acc train: 0.9090000 | Acc validation: 0.9200000
# f1_score is 0.8751311647429171 0.7294117647058823
# roc_auc_score is 0.881 0.7700000000000001
# Iter:   103 | Cost: 0.7951700 | Acc train: 0.8810000 | Acc validation: 0.7700000
# f1_score is 0.8484848484848485 0.65
# roc_auc_score is 0.86 0.7200000000000001
# Iter:   104 | Cost: 0.7954664 | Acc train: 0.8600000 | Acc validation: 0.7200000
# f1_score is 0.7972508591065293 0.5945945945945945
# roc_auc_score is 0.823 0.7
# Iter:   105 | Cost: 0.7970962 | Acc train: 0.8230000 | Acc validation: 0.7000000
# f1_score is 0.7420924574209246 0.5555555555555556
# roc_auc_score is 0.7879999999999999 0.6799999999999999
# Iter:   106 | Cost: 0.8007641 | Acc train: 0.7880000 | Acc validation: 0.6800000
# f1_score is 0.7119496855345911 0.5142857142857143
# roc_auc_score is 0.7709999999999999 0.6599999999999999
# Iter:   107 | Cost: 0.8029377 | Acc train: 0.7710000 | Acc validation: 0.6600000
# f1_score is 0.8755186721991701 0.7415730337078651
# roc_auc_score is 0.88 0.77
# Iter:   108 | Cost: 0.7895650 | Acc train: 0.8800000 | Acc validation: 0.7700000
# f1_score is 0.911955514365153 0.9259259259259259
# roc_auc_score is 0.905 0.9199999999999999
# Iter:   109 | Cost: 0.7850722 | Acc train: 0.9050000 | Acc validation: 0.9200000
# f1_score is 0.9134157944814463 0.8952380952380952
# roc_auc_score is 0.9089999999999999 0.89
# Iter:   110 | Cost: 0.7848379 | Acc train: 0.9090000 | Acc validation: 0.8900000
# f1_score is 0.904854368932039 0.8399999999999999
# roc_auc_score is 0.902 0.84
# Iter:   111 | Cost: 0.7844574 | Acc train: 0.9020000 | Acc validation: 0.8400000
# f1_score is 0.8138238573021181 0.5789473684210525
# roc_auc_score is 0.833 0.6799999999999999
# Iter:   112 | Cost: 0.7883713 | Acc train: 0.8330000 | Acc validation: 0.6800000
# f1_score is 0.7218788627935724 0.5352112676056339
# roc_auc_score is 0.775 0.6699999999999999
# Iter:   113 | Cost: 0.7951056 | Acc train: 0.7750000 | Acc validation: 0.6700000
# f1_score is 0.7294981640146879 0.5352112676056339
# roc_auc_score is 0.779 0.6699999999999999
# Iter:   114 | Cost: 0.7936493 | Acc train: 0.7790000 | Acc validation: 0.6700000
# f1_score is 0.8072153325817363 0.5866666666666667
# roc_auc_score is 0.829 0.69
# Iter:   115 | Cost: 0.7858363 | Acc train: 0.8290000 | Acc validation: 0.6900000
# f1_score is 0.896484375 0.816326530612245
# roc_auc_score is 0.894 0.8200000000000001
# Iter:   116 | Cost: 0.7799817 | Acc train: 0.8940000 | Acc validation: 0.8200000
# f1_score is 0.9002904162633107 0.8514851485148515
# roc_auc_score is 0.897 0.8499999999999999
# Iter:   117 | Cost: 0.7790317 | Acc train: 0.8970000 | Acc validation: 0.8500000
# f1_score is 0.8938656280428432 0.816326530612245
# roc_auc_score is 0.8910000000000001 0.8200000000000001
# Iter:   118 | Cost: 0.7784279 | Acc train: 0.8910000 | Acc validation: 0.8200000
# f1_score is 0.9066918001885014 0.8846153846153846
# roc_auc_score is 0.901 0.8799999999999999
# Iter:   119 | Cost: 0.7770219 | Acc train: 0.9010000 | Acc validation: 0.8800000
# f1_score is 0.9045871559633027 0.9174311926605504
# roc_auc_score is 0.896 0.91
# Iter:   120 | Cost: 0.7762223 | Acc train: 0.8960000 | Acc validation: 0.9100000
# f1_score is 0.035278154681139755 0.0
# roc_auc_score is 0.28900000000000003 0.25
# Iter:     1 | Cost: 1.0622769 | Acc train: 0.2890000 | Acc validation: 0.2500000
# f1_score is 0.05721716514954486 0.05
# roc_auc_score is 0.275 0.24
# Iter:     2 | Cost: 1.0583647 | Acc train: 0.2750000 | Acc validation: 0.2400000
# f1_score is 0.16350710900473933 0.13793103448275862
# roc_auc_score is 0.29399999999999993 0.25
# Iter:     3 | Cost: 1.0528890 | Acc train: 0.2940000 | Acc validation: 0.2500000
# f1_score is 0.46112115732368897 0.5378151260504201
# roc_auc_score is 0.404 0.45000000000000007
# Iter:     4 | Cost: 1.0475151 | Acc train: 0.4040000 | Acc validation: 0.4500000
# f1_score is 0.627027027027027 0.6466165413533834
# roc_auc_score is 0.517 0.53
# Iter:     5 | Cost: 1.0426095 | Acc train: 0.5170000 | Acc validation: 0.5300000
# f1_score is 0.6760563380281689 0.6762589928057553
# roc_auc_score is 0.54 0.55
# Iter:     6 | Cost: 1.0385116 | Acc train: 0.5400000 | Acc validation: 0.5500000
# f1_score is 0.679089026915114 0.6944444444444444
# roc_auc_score is 0.535 0.56
# Iter:     7 | Cost: 1.0346676 | Acc train: 0.5350000 | Acc validation: 0.5600000
# f1_score is 0.6767330130404942 0.6896551724137931
# roc_auc_score is 0.5289999999999999 0.55
# Iter:     8 | Cost: 1.0298614 | Acc train: 0.5290000 | Acc validation: 0.5500000
# f1_score is 0.677618069815195 0.6802721088435374
# roc_auc_score is 0.5289999999999999 0.53
# Iter:     9 | Cost: 1.0254327 | Acc train: 0.5290000 | Acc validation: 0.5300000
# f1_score is 0.6776406035665296 0.6944444444444444
# roc_auc_score is 0.5299999999999999 0.56
# Iter:    10 | Cost: 1.0199746 | Acc train: 0.5300000 | Acc validation: 0.5600000
# f1_score is 0.6781056966369251 0.6944444444444444
# roc_auc_score is 0.5309999999999999 0.56
# Iter:    11 | Cost: 1.0151697 | Acc train: 0.5310000 | Acc validation: 0.5600000
# f1_score is 0.6795048143053645 0.6944444444444444
# roc_auc_score is 0.5339999999999999 0.56
# Iter:    12 | Cost: 1.0106356 | Acc train: 0.5340000 | Acc validation: 0.5600000
# f1_score is 0.6847222222222222 0.6944444444444444
# roc_auc_score is 0.546 0.56
# Iter:    13 | Cost: 1.0065747 | Acc train: 0.5460000 | Acc validation: 0.5600000
# f1_score is 0.6856745479833102 0.6944444444444444
# roc_auc_score is 0.5479999999999999 0.56
# Iter:    14 | Cost: 1.0031486 | Acc train: 0.5480000 | Acc validation: 0.5600000
# f1_score is 0.6810584958217271 0.6713286713286712
# roc_auc_score is 0.542 0.53
# Iter:    15 | Cost: 1.0004117 | Acc train: 0.5420000 | Acc validation: 0.5300000
# f1_score is 0.6774647887323944 0.6666666666666667
# roc_auc_score is 0.5419999999999999 0.5299999999999999
# Iter:    16 | Cost: 0.9976620 | Acc train: 0.5420000 | Acc validation: 0.5300000
# f1_score is 0.6790564689063616 0.6762589928057553
# roc_auc_score is 0.551 0.55
# Iter:    17 | Cost: 0.9950681 | Acc train: 0.5510000 | Acc validation: 0.5500000
# f1_score is 0.6714801444043322 0.6764705882352942
# roc_auc_score is 0.545 0.56
# Iter:    18 | Cost: 0.9931415 | Acc train: 0.5450000 | Acc validation: 0.5600000
# f1_score is 0.6666666666666667 0.6412213740458015
# roc_auc_score is 0.547 0.53
# Iter:    19 | Cost: 0.9911950 | Acc train: 0.5470000 | Acc validation: 0.5300000
# f1_score is 0.6631339894019682 0.6356589147286822
# roc_auc_score is 0.5549999999999999 0.53
# Iter:    20 | Cost: 0.9891843 | Acc train: 0.5550000 | Acc validation: 0.5300000
# f1_score is 0.665086887835703 0.5666666666666667
# roc_auc_score is 0.5760000000000001 0.4800000000000001
# Iter:    21 | Cost: 0.9869916 | Acc train: 0.5760000 | Acc validation: 0.4800000
# f1_score is 0.6586620926243567 0.5137614678899083
# roc_auc_score is 0.6020000000000001 0.47
# Iter:    22 | Cost: 0.9847512 | Acc train: 0.6020000 | Acc validation: 0.4700000
# f1_score is 0.6440349175557711 0.4418604651162791
# roc_auc_score is 0.633 0.5199999999999999
# Iter:    23 | Cost: 0.9817906 | Acc train: 0.6330000 | Acc validation: 0.5200000
# f1_score is 0.6223628691983122 0.4
# roc_auc_score is 0.6419999999999999 0.52
# Iter:    24 | Cost: 0.9796501 | Acc train: 0.6420000 | Acc validation: 0.5200000
# f1_score is 0.6229860365198711 0.4
# roc_auc_score is 0.649 0.52
# Iter:    25 | Cost: 0.9783864 | Acc train: 0.6490000 | Acc validation: 0.5200000
# f1_score is 0.620021528525296 0.379746835443038
# roc_auc_score is 0.6469999999999999 0.51
# Iter:    26 | Cost: 0.9771245 | Acc train: 0.6470000 | Acc validation: 0.5100000
# f1_score is 0.6125137211855104 0.379746835443038
# roc_auc_score is 0.647 0.51
# Iter:    27 | Cost: 0.9756909 | Acc train: 0.6470000 | Acc validation: 0.5100000
# f1_score is 0.6424870466321244 0.42857142857142855
# roc_auc_score is 0.6549999999999999 0.5199999999999999
# Iter:    28 | Cost: 0.9754347 | Acc train: 0.6550000 | Acc validation: 0.5200000
# f1_score is 0.6510681586978637 0.4367816091954023
# roc_auc_score is 0.6569999999999999 0.51
# Iter:    29 | Cost: 0.9743888 | Acc train: 0.6570000 | Acc validation: 0.5100000
# f1_score is 0.6556016597510373 0.44705882352941173
# roc_auc_score is 0.6679999999999999 0.5299999999999999
# Iter:    30 | Cost: 0.9726161 | Acc train: 0.6680000 | Acc validation: 0.5300000
# f1_score is 0.6279329608938548 0.379746835443038
# roc_auc_score is 0.667 0.51
# Iter:    31 | Cost: 0.9698146 | Acc train: 0.6670000 | Acc validation: 0.5100000
# f1_score is 0.602905569007264 0.36619718309859156
# roc_auc_score is 0.6719999999999999 0.55
# Iter:    32 | Cost: 0.9670669 | Acc train: 0.6720000 | Acc validation: 0.5500000
# f1_score is 0.5710691823899371 0.28124999999999994
# roc_auc_score is 0.659 0.54
# Iter:    33 | Cost: 0.9649566 | Acc train: 0.6590000 | Acc validation: 0.5400000
# f1_score is 0.3898809523809524 0.1090909090909091
# roc_auc_score is 0.5900000000000001 0.51
# Iter:    34 | Cost: 0.9617564 | Acc train: 0.5900000 | Acc validation: 0.5100000
# f1_score is 0.08807339449541285 0.0392156862745098
# roc_auc_score is 0.503 0.51
# Iter:    35 | Cost: 0.9590749 | Acc train: 0.5030000 | Acc validation: 0.5100000
# f1_score is 0.007889546351084811 0.0
# roc_auc_score is 0.497 0.5
# Iter:    36 | Cost: 0.9575817 | Acc train: 0.4970000 | Acc validation: 0.5000000
# f1_score is 0.00398406374501992 0.0
# roc_auc_score is 0.5 0.5
# Iter:    37 | Cost: 0.9562394 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.00398406374501992 0.0
# roc_auc_score is 0.5 0.5
# Iter:    38 | Cost: 0.9549518 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.00398406374501992 0.0
# roc_auc_score is 0.5 0.5
# Iter:    39 | Cost: 0.9533487 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.00398406374501992 0.0
# roc_auc_score is 0.5 0.5
# Iter:    40 | Cost: 0.9512764 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.003976143141153082 0.0
# roc_auc_score is 0.499 0.5
# Iter:    41 | Cost: 0.9491341 | Acc train: 0.4990000 | Acc validation: 0.5000000
# f1_score is 0.019230769230769232 0.0392156862745098
# roc_auc_score is 0.49 0.51
# Iter:    42 | Cost: 0.9468368 | Acc train: 0.4900000 | Acc validation: 0.5100000
# f1_score is 0.08088235294117646 0.0392156862745098
# roc_auc_score is 0.5 0.51
# Iter:    43 | Cost: 0.9449429 | Acc train: 0.5000000 | Acc validation: 0.5100000
# f1_score is 0.12164579606440071 0.0392156862745098
# roc_auc_score is 0.509 0.51
# Iter:    44 | Cost: 0.9430023 | Acc train: 0.5090000 | Acc validation: 0.5100000
# f1_score is 0.28341384863124 0.11320754716981131
# roc_auc_score is 0.5549999999999999 0.53
# Iter:    45 | Cost: 0.9412329 | Acc train: 0.5550000 | Acc validation: 0.5300000
# f1_score is 0.43795620437956206 0.16949152542372883
# roc_auc_score is 0.6149999999999999 0.5100000000000001
# Iter:    46 | Cost: 0.9393374 | Acc train: 0.6150000 | Acc validation: 0.5100000
# f1_score is 0.5247252747252747 0.3384615384615385
# roc_auc_score is 0.654 0.5700000000000001
# Iter:    47 | Cost: 0.9371079 | Acc train: 0.6540000 | Acc validation: 0.5700000
# f1_score is 0.5347885402455662 0.36363636363636365
# roc_auc_score is 0.6589999999999999 0.5800000000000001
# Iter:    48 | Cost: 0.9345675 | Acc train: 0.6590000 | Acc validation: 0.5800000
# f1_score is 0.5842105263157895 0.4347826086956521
# roc_auc_score is 0.684 0.6100000000000001
# Iter:    49 | Cost: 0.9319949 | Acc train: 0.6840000 | Acc validation: 0.6100000
# f1_score is 0.8190476190476191 0.8510638297872342
# roc_auc_score is 0.8290000000000001 0.8600000000000001
# Iter:    50 | Cost: 0.9301589 | Acc train: 0.8290000 | Acc validation: 0.8600000
# f1_score is 0.8893241919686581 0.9
# roc_auc_score is 0.887 0.9
# Iter:    51 | Cost: 0.9276462 | Acc train: 0.8870000 | Acc validation: 0.9000000
# f1_score is 0.9058823529411765 0.9215686274509804
# roc_auc_score is 0.9039999999999999 0.92
# Iter:    52 | Cost: 0.9241244 | Acc train: 0.9040000 | Acc validation: 0.9200000
# f1_score is 0.607095926412615 0.7317073170731707
# roc_auc_score is 0.701 0.78
# Iter:    53 | Cost: 0.9191455 | Acc train: 0.7010000 | Acc validation: 0.7800000
# f1_score is 0.1367837338262477 0.11320754716981131
# roc_auc_score is 0.533 0.53
# Iter:    54 | Cost: 0.9157113 | Acc train: 0.5330000 | Acc validation: 0.5300000
# f1_score is 0.015810276679841896 0.0
# roc_auc_score is 0.502 0.5
# Iter:    55 | Cost: 0.9131907 | Acc train: 0.5020000 | Acc validation: 0.5000000
# f1_score is 0.011904761904761906 0.0
# roc_auc_score is 0.502 0.5
# Iter:    56 | Cost: 0.9101738 | Acc train: 0.5020000 | Acc validation: 0.5000000
# f1_score is 0.06551059730250482 0.11320754716981131
# roc_auc_score is 0.515 0.53
# Iter:    57 | Cost: 0.9061111 | Acc train: 0.5150000 | Acc validation: 0.5300000
# f1_score is 0.35772357723577236 0.5294117647058824
# roc_auc_score is 0.605 0.6799999999999999
# Iter:    58 | Cost: 0.9016683 | Acc train: 0.6050000 | Acc validation: 0.6800000
# f1_score is 0.6288798920377868 0.7654320987654321
# roc_auc_score is 0.725 0.81
# Iter:    59 | Cost: 0.8975135 | Acc train: 0.7250000 | Acc validation: 0.8100000
# f1_score is 0.7515299877600979 0.888888888888889
# roc_auc_score is 0.7969999999999999 0.9
# Iter:    60 | Cost: 0.8935966 | Acc train: 0.7970000 | Acc validation: 0.9000000
# f1_score is 0.8009367681498829 0.9148936170212766
# roc_auc_score is 0.8300000000000001 0.9199999999999999
# Iter:    61 | Cost: 0.8896619 | Acc train: 0.8300000 | Acc validation: 0.9200000
# f1_score is 0.8759278897136797 0.9591836734693877
# roc_auc_score is 0.883 0.96
# Iter:    62 | Cost: 0.8860185 | Acc train: 0.8830000 | Acc validation: 0.9600000
# f1_score is 0.9196940726577437 0.9333333333333333
# roc_auc_score is 0.9159999999999999 0.9299999999999999
# Iter:    63 | Cost: 0.8838149 | Acc train: 0.9160000 | Acc validation: 0.9300000
# f1_score is 0.8733624454148472 0.8928571428571428
# roc_auc_score is 0.855 0.88
# Iter:    64 | Cost: 0.8841288 | Acc train: 0.8550000 | Acc validation: 0.8800000
# f1_score is 0.7955449482895783 0.8264462809917354
# roc_auc_score is 0.743 0.79
# Iter:    65 | Cost: 0.8861794 | Acc train: 0.7430000 | Acc validation: 0.7900000
# f1_score is 0.774593338497289 0.8130081300813007
# roc_auc_score is 0.7090000000000001 0.77
# Iter:    66 | Cost: 0.8844539 | Acc train: 0.7090000 | Acc validation: 0.7700000
# f1_score is 0.7604562737642586 0.7692307692307693
# roc_auc_score is 0.685 0.7
# Iter:    67 | Cost: 0.8826059 | Acc train: 0.6850000 | Acc validation: 0.7000000
# f1_score is 0.7304601899196494 0.7194244604316548
# roc_auc_score is 0.631 0.61
# Iter:    68 | Cost: 0.8825982 | Acc train: 0.6310000 | Acc validation: 0.6100000
# f1_score is 0.7189072609633357 0.7092198581560284
# roc_auc_score is 0.609 0.5900000000000001
# Iter:    69 | Cost: 0.8822508 | Acc train: 0.6090000 | Acc validation: 0.5900000
# f1_score is 0.7032348804500703 0.704225352112676
# roc_auc_score is 0.5780000000000001 0.5800000000000001
# Iter:    70 | Cost: 0.8819974 | Acc train: 0.5780000 | Acc validation: 0.5800000
# f1_score is 0.7137758743754461 0.7092198581560284
# roc_auc_score is 0.599 0.5900000000000001
# Iter:    71 | Cost: 0.8778426 | Acc train: 0.5990000 | Acc validation: 0.5900000
# f1_score is 0.7530120481927711 0.7633587786259541
# roc_auc_score is 0.6719999999999999 0.69
# Iter:    72 | Cost: 0.8679133 | Acc train: 0.6720000 | Acc validation: 0.6900000
# f1_score is 0.8517241379310345 0.8749999999999999
# roc_auc_score is 0.828 0.8600000000000001
# Iter:    73 | Cost: 0.8550366 | Acc train: 0.8280000 | Acc validation: 0.8600000
# f1_score is 0.8795056642636457 0.9320388349514563
# roc_auc_score is 0.883 0.93
# Iter:    74 | Cost: 0.8488859 | Acc train: 0.8830000 | Acc validation: 0.9300000
# f1_score is 0.8132118451025058 0.9292929292929293
# roc_auc_score is 0.8359999999999999 0.9299999999999998
# Iter:    75 | Cost: 0.8481627 | Acc train: 0.8360000 | Acc validation: 0.9300000
# f1_score is 0.8032220943613348 0.9292929292929293
# roc_auc_score is 0.829 0.9299999999999998
# Iter:    76 | Cost: 0.8467006 | Acc train: 0.8290000 | Acc validation: 0.9300000
# f1_score is 0.8351409978308025 0.92
# roc_auc_score is 0.8480000000000001 0.9199999999999999
# Iter:    77 | Cost: 0.8440300 | Acc train: 0.8480000 | Acc validation: 0.9200000
# f1_score is 0.8612997090203685 0.8971962616822429
# roc_auc_score is 0.857 0.8900000000000001
# Iter:    78 | Cost: 0.8425669 | Acc train: 0.8570000 | Acc validation: 0.8900000
# f1_score is 0.841823056300268 0.8749999999999999
# roc_auc_score is 0.823 0.8600000000000001
# Iter:    79 | Cost: 0.8437667 | Acc train: 0.8230000 | Acc validation: 0.8600000
# f1_score is 0.8120805369127518 0.8376068376068375
# roc_auc_score is 0.776 0.81
# Iter:    80 | Cost: 0.8459439 | Acc train: 0.7760000 | Acc validation: 0.8100000
# f1_score is 0.8267370272647317 0.8672566371681417
# roc_auc_score is 0.8029999999999999 0.85
# Iter:    81 | Cost: 0.8423216 | Acc train: 0.8030000 | Acc validation: 0.8500000
# f1_score is 0.8389057750759878 0.8867924528301886
# roc_auc_score is 0.8409999999999999 0.88
# Iter:    82 | Cost: 0.8382309 | Acc train: 0.8410000 | Acc validation: 0.8800000
# f1_score is 0.8112798264642084 0.8932038834951457
# roc_auc_score is 0.8260000000000001 0.89
# Iter:    83 | Cost: 0.8378193 | Acc train: 0.8260000 | Acc validation: 0.8900000
# f1_score is 0.7491082045184304 0.8842105263157894
# roc_auc_score is 0.7889999999999998 0.8899999999999999
# Iter:    84 | Cost: 0.8401404 | Acc train: 0.7890000 | Acc validation: 0.8900000
# f1_score is 0.7199017199017198 0.8817204301075269
# roc_auc_score is 0.7719999999999999 0.8899999999999999
# Iter:    85 | Cost: 0.8415031 | Acc train: 0.7720000 | Acc validation: 0.8900000
# f1_score is 0.7137546468401487 0.8571428571428571
# roc_auc_score is 0.7689999999999999 0.8699999999999999
# Iter:    86 | Cost: 0.8420327 | Acc train: 0.7690000 | Acc validation: 0.8700000
# f1_score is 0.7141104294478526 0.8723404255319149
# roc_auc_score is 0.7669999999999999 0.8799999999999998
# Iter:    87 | Cost: 0.8405930 | Acc train: 0.7670000 | Acc validation: 0.8800000
# f1_score is 0.7087980173482031 0.8571428571428571
# roc_auc_score is 0.765 0.8699999999999999
# Iter:    88 | Cost: 0.8415891 | Acc train: 0.7650000 | Acc validation: 0.8700000
# f1_score is 0.7215496368038741 0.8723404255319149
# roc_auc_score is 0.77 0.8799999999999998
# Iter:    89 | Cost: 0.8388514 | Acc train: 0.7700000 | Acc validation: 0.8800000
# f1_score is 0.7866379310344828 0.8761904761904761
# roc_auc_score is 0.8019999999999999 0.87
# Iter:    90 | Cost: 0.8346467 | Acc train: 0.8020000 | Acc validation: 0.8700000
# f1_score is 0.7965779467680608 0.8727272727272728
# roc_auc_score is 0.786 0.86
# Iter:    91 | Cost: 0.8350808 | Acc train: 0.7860000 | Acc validation: 0.8600000
# f1_score is 0.7901960784313726 0.8703703703703703
# roc_auc_score is 0.786 0.8600000000000001
# Iter:    92 | Cost: 0.8346326 | Acc train: 0.7860000 | Acc validation: 0.8600000
# f1_score is 0.7766179540709811 0.8761904761904761
# roc_auc_score is 0.7860000000000001 0.87
# Iter:    93 | Cost: 0.8341303 | Acc train: 0.7860000 | Acc validation: 0.8700000
# f1_score is 0.7611607142857144 0.8823529411764707
# roc_auc_score is 0.786 0.88
# Iter:    94 | Cost: 0.8348466 | Acc train: 0.7860000 | Acc validation: 0.8800000
# f1_score is 0.7480045610034208 0.88
# roc_auc_score is 0.7790000000000001 0.8799999999999999
# Iter:    95 | Cost: 0.8355905 | Acc train: 0.7790000 | Acc validation: 0.8800000
# f1_score is 0.7451428571428571 0.88
# roc_auc_score is 0.777 0.8799999999999999
# Iter:    96 | Cost: 0.8355674 | Acc train: 0.7770000 | Acc validation: 0.8800000
# f1_score is 0.7616926503340756 0.8737864077669903
# roc_auc_score is 0.786 0.8699999999999999
# Iter:    97 | Cost: 0.8344914 | Acc train: 0.7860000 | Acc validation: 0.8700000
# f1_score is 0.768421052631579 0.8761904761904761
# roc_auc_score is 0.78 0.87
# Iter:    98 | Cost: 0.8336804 | Acc train: 0.7800000 | Acc validation: 0.8700000
# f1_score is 0.7695605573419079 0.8761904761904761
# roc_auc_score is 0.7849999999999999 0.87
# Iter:    99 | Cost: 0.8336721 | Acc train: 0.7850000 | Acc validation: 0.8700000
# f1_score is 0.767741935483871 0.8761904761904761
# roc_auc_score is 0.7839999999999999 0.87
# Iter:   100 | Cost: 0.8335728 | Acc train: 0.7840000 | Acc validation: 0.8700000
# f1_score is 0.7545045045045046 0.8823529411764707
# roc_auc_score is 0.782 0.88
# Iter:   101 | Cost: 0.8342712 | Acc train: 0.7820000 | Acc validation: 0.8800000
# f1_score is 0.7433831990794016 0.8775510204081632
# roc_auc_score is 0.7769999999999999 0.88
# Iter:   102 | Cost: 0.8351830 | Acc train: 0.7770000 | Acc validation: 0.8800000
# f1_score is 0.7465753424657534 0.88
# roc_auc_score is 0.778 0.8799999999999999
# Iter:   103 | Cost: 0.8346768 | Acc train: 0.7780000 | Acc validation: 0.8800000
# f1_score is 0.7310826542491268 0.8659793814432989
# roc_auc_score is 0.769 0.87
# Iter:   104 | Cost: 0.8354636 | Acc train: 0.7690000 | Acc validation: 0.8700000
# f1_score is 0.7208480565371024 0.8541666666666666
# roc_auc_score is 0.7630000000000001 0.86
# Iter:   105 | Cost: 0.8358623 | Acc train: 0.7630000 | Acc validation: 0.8600000
# f1_score is 0.707878787878788 0.8631578947368421
# roc_auc_score is 0.7589999999999999 0.8699999999999999
# Iter:   106 | Cost: 0.8376636 | Acc train: 0.7590000 | Acc validation: 0.8700000
# f1_score is 0.7117008443908323 0.8631578947368421
# roc_auc_score is 0.7609999999999999 0.8699999999999999
# Iter:   107 | Cost: 0.8371401 | Acc train: 0.7610000 | Acc validation: 0.8700000
# f1_score is 0.7115384615384613 0.8631578947368421
# roc_auc_score is 0.7600000000000001 0.8699999999999999
# Iter:   108 | Cost: 0.8367261 | Acc train: 0.7600000 | Acc validation: 0.8700000
# f1_score is 0.7240977881257276 0.8775510204081632
# roc_auc_score is 0.763 0.88
# Iter:   109 | Cost: 0.8350809 | Acc train: 0.7630000 | Acc validation: 0.8800000
# f1_score is 0.7536842105263158 0.8761904761904761
# roc_auc_score is 0.7660000000000001 0.87
# Iter:   110 | Cost: 0.8331303 | Acc train: 0.7660000 | Acc validation: 0.8700000
# f1_score is 0.7630375114364135 0.8347826086956522
# roc_auc_score is 0.7410000000000001 0.8099999999999999
# Iter:   111 | Cost: 0.8358872 | Acc train: 0.7410000 | Acc validation: 0.8100000
# f1_score is 0.7639257294429708 0.8205128205128206
# roc_auc_score is 0.7329999999999999 0.79
# Iter:   112 | Cost: 0.8381686 | Acc train: 0.7330000 | Acc validation: 0.7900000
# f1_score is 0.7442244224422441 0.7999999999999999
# roc_auc_score is 0.6900000000000001 0.76
# Iter:   113 | Cost: 0.8435110 | Acc train: 0.6900000 | Acc validation: 0.7600000
# f1_score is 0.7321981424148607 0.7596899224806202
# roc_auc_score is 0.6539999999999999 0.69
# Iter:   114 | Cost: 0.8532731 | Acc train: 0.6540000 | Acc validation: 0.6900000
# f1_score is 0.7323506594259116 0.765625
# roc_auc_score is 0.655 0.7
# Iter:   115 | Cost: 0.8529793 | Acc train: 0.6550000 | Acc validation: 0.7000000
# f1_score is 0.7431340872374798 0.7868852459016393
# roc_auc_score is 0.6819999999999999 0.74
# Iter:   116 | Cost: 0.8464503 | Acc train: 0.6820000 | Acc validation: 0.7400000
# f1_score is 0.751918158567775 0.8135593220338982
# roc_auc_score is 0.7090000000000001 0.78
# Iter:   117 | Cost: 0.8408560 | Acc train: 0.7090000 | Acc validation: 0.7800000
# f1_score is 0.7579329102447868 0.8495575221238937
# roc_auc_score is 0.733 0.83
# Iter:   118 | Cost: 0.8371748 | Acc train: 0.7330000 | Acc validation: 0.8300000
# f1_score is 0.7579329102447868 0.8495575221238937
# roc_auc_score is 0.733 0.83
# Iter:   119 | Cost: 0.8372396 | Acc train: 0.7330000 | Acc validation: 0.8300000
# f1_score is 0.7562724014336917 0.8421052631578947
# roc_auc_score is 0.728 0.8199999999999998
# Iter:   120 | Cost: 0.8380797 | Acc train: 0.7280000 | Acc validation: 0.8200000
# f1_score is 0.05490196078431373 0.02531645569620253
# roc_auc_score is 0.27699999999999997 0.22999999999999998
# Iter:     1 | Cost: 1.0620273 | Acc train: 0.2770000 | Acc validation: 0.2300000
# f1_score is 0.26068376068376065 0.3061224489795918
# roc_auc_score is 0.308 0.31999999999999995
# Iter:     2 | Cost: 1.0574469 | Acc train: 0.3080000 | Acc validation: 0.3200000
# f1_score is 0.451319381255687 0.5378151260504201
# roc_auc_score is 0.397 0.45000000000000007
# Iter:     3 | Cost: 1.0525638 | Acc train: 0.3970000 | Acc validation: 0.4500000
# f1_score is 0.5637692932575142 0.6616541353383459
# roc_auc_score is 0.46299999999999997 0.5499999999999999
# Iter:     4 | Cost: 1.0472906 | Acc train: 0.4630000 | Acc validation: 0.5500000
# f1_score is 0.6733238231098431 0.6762589928057553
# roc_auc_score is 0.5419999999999999 0.55
# Iter:     5 | Cost: 1.0428928 | Acc train: 0.5420000 | Acc validation: 0.5500000
# f1_score is 0.6820083682008367 0.6993006993006993
# roc_auc_score is 0.5439999999999999 0.5700000000000001
# Iter:     6 | Cost: 1.0376904 | Acc train: 0.5440000 | Acc validation: 0.5700000
# f1_score is 0.6795313576843556 0.6944444444444444
# roc_auc_score is 0.5349999999999999 0.56
# Iter:     7 | Cost: 1.0327493 | Acc train: 0.5350000 | Acc validation: 0.5600000
# f1_score is 0.681409813407049 0.6944444444444444
# roc_auc_score is 0.5389999999999999 0.56
# Iter:     8 | Cost: 1.0268602 | Acc train: 0.5390000 | Acc validation: 0.5600000
# f1_score is 0.6823855755894591 0.6993006993006993
# roc_auc_score is 0.542 0.5700000000000001
# Iter:     9 | Cost: 1.0212150 | Acc train: 0.5420000 | Acc validation: 0.5700000
# f1_score is 0.6857142857142857 0.6993006993006993
# roc_auc_score is 0.549 0.5700000000000001
# Iter:    10 | Cost: 1.0160815 | Acc train: 0.5490000 | Acc validation: 0.5700000
# f1_score is 0.6921985815602838 0.681159420289855
# roc_auc_score is 0.566 0.56
# Iter:    11 | Cost: 1.0099778 | Acc train: 0.5660000 | Acc validation: 0.5600000
# f1_score is 0.6973977695167286 0.6814814814814815
# roc_auc_score is 0.593 0.57
# Iter:    12 | Cost: 1.0041782 | Acc train: 0.5930000 | Acc validation: 0.5700000
# f1_score is 0.6870355078447564 0.6440677966101696
# roc_auc_score is 0.621 0.5800000000000001
# Iter:    13 | Cost: 0.9987386 | Acc train: 0.6210000 | Acc validation: 0.5800000
# f1_score is 0.6380133715377269 0.5106382978723404
# roc_auc_score is 0.6210000000000001 0.54
# Iter:    14 | Cost: 0.9939697 | Acc train: 0.6210000 | Acc validation: 0.5400000
# f1_score is 0.5462753950338601 0.38461538461538464
# roc_auc_score is 0.598 0.52
# Iter:    15 | Cost: 0.9898980 | Acc train: 0.5980000 | Acc validation: 0.5200000
# f1_score is 0.3318903318903319 0.1724137931034483
# roc_auc_score is 0.5369999999999999 0.52
# Iter:    16 | Cost: 0.9858846 | Acc train: 0.5370000 | Acc validation: 0.5200000
# f1_score is 0.09946714031971579 0.07407407407407407
# roc_auc_score is 0.493 0.5
# Iter:    17 | Cost: 0.9824374 | Acc train: 0.4930000 | Acc validation: 0.5000000
# f1_score is 0.04182509505703422 0.07547169811320754
# roc_auc_score is 0.496 0.51
# Iter:    18 | Cost: 0.9796014 | Acc train: 0.4960000 | Acc validation: 0.5100000
# f1_score is 0.045889101338432124 0.0392156862745098
# roc_auc_score is 0.501 0.51
# Iter:    19 | Cost: 0.9769669 | Acc train: 0.5010000 | Acc validation: 0.5100000
# f1_score is 0.09276437847866419 0.07692307692307693
# roc_auc_score is 0.511 0.52
# Iter:    20 | Cost: 0.9745905 | Acc train: 0.5110000 | Acc validation: 0.5200000
# f1_score is 0.1366906474820144 0.07692307692307693
# roc_auc_score is 0.52 0.52
# Iter:    21 | Cost: 0.9724564 | Acc train: 0.5200000 | Acc validation: 0.5200000
# f1_score is 0.19310344827586207 0.07692307692307693
# roc_auc_score is 0.532 0.52
# Iter:    22 | Cost: 0.9704891 | Acc train: 0.5320000 | Acc validation: 0.5200000
# f1_score is 0.19621342512908777 0.07692307692307693
# roc_auc_score is 0.533 0.52
# Iter:    23 | Cost: 0.9685081 | Acc train: 0.5330000 | Acc validation: 0.5200000
# f1_score is 0.29773462783171517 0.07692307692307693
# roc_auc_score is 0.566 0.52
# Iter:    24 | Cost: 0.9668263 | Acc train: 0.5660000 | Acc validation: 0.5200000
# f1_score is 0.2582781456953642 0.07692307692307693
# roc_auc_score is 0.5519999999999999 0.52
# Iter:    25 | Cost: 0.9648588 | Acc train: 0.5520000 | Acc validation: 0.5200000
# f1_score is 0.1808695652173913 0.07692307692307693
# roc_auc_score is 0.529 0.52
# Iter:    26 | Cost: 0.9625422 | Acc train: 0.5290000 | Acc validation: 0.5200000
# f1_score is 0.046065259117082535 0.0392156862745098
# roc_auc_score is 0.503 0.51
# Iter:    27 | Cost: 0.9603275 | Acc train: 0.5030000 | Acc validation: 0.5100000
# f1_score is 0.04597701149425287 0.0392156862745098
# roc_auc_score is 0.502 0.51
# Iter:    28 | Cost: 0.9583981 | Acc train: 0.5020000 | Acc validation: 0.5100000
# f1_score is 0.08239700374531835 0.0392156862745098
# roc_auc_score is 0.51 0.51
# Iter:    29 | Cost: 0.9563480 | Acc train: 0.5100000 | Acc validation: 0.5100000
# f1_score is 0.12274368231046934 0.07692307692307693
# roc_auc_score is 0.514 0.52
# Iter:    30 | Cost: 0.9544148 | Acc train: 0.5140000 | Acc validation: 0.5200000
# f1_score is 0.031007751937984496 0.0392156862745098
# roc_auc_score is 0.5 0.51
# Iter:    31 | Cost: 0.9520343 | Acc train: 0.5000000 | Acc validation: 0.5100000
# f1_score is 0.007936507936507936 0.0
# roc_auc_score is 0.5 0.5
# Iter:    32 | Cost: 0.9498605 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.007952286282306164 0.0
# roc_auc_score is 0.501 0.5
# Iter:    33 | Cost: 0.9471608 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.007936507936507936 0.0
# roc_auc_score is 0.5 0.5
# Iter:    34 | Cost: 0.9440068 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.00398406374501992 0.0
# roc_auc_score is 0.5 0.5
# Iter:    35 | Cost: 0.9409683 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.499 0.5
# Iter:    36 | Cost: 0.9387839 | Acc train: 0.4990000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.499 0.5
# Iter:    37 | Cost: 0.9359877 | Acc train: 0.4990000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.5 0.5
# Iter:    38 | Cost: 0.9333959 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.5 0.5
# Iter:    39 | Cost: 0.9286576 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.499 0.5
# Iter:    40 | Cost: 0.9217835 | Acc train: 0.4990000 | Acc validation: 0.5000000
# f1_score is 0.007952286282306164 0.0
# roc_auc_score is 0.501 0.5
# Iter:    41 | Cost: 0.9161151 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.04678362573099415 0.0
# roc_auc_score is 0.511 0.5
# Iter:    42 | Cost: 0.9118193 | Acc train: 0.5110000 | Acc validation: 0.5000000
# f1_score is 0.5986013986013985 0.8095238095238095
# roc_auc_score is 0.713 0.8400000000000001
# Iter:    43 | Cost: 0.9071950 | Acc train: 0.7130000 | Acc validation: 0.8400000
# f1_score is 0.9251844046364593 0.98989898989899
# roc_auc_score is 0.929 0.99
# Iter:    44 | Cost: 0.9035202 | Acc train: 0.9290000 | Acc validation: 0.9900000
# f1_score is 0.9593657086223986 0.9803921568627451
# roc_auc_score is 0.959 0.98
# Iter:    45 | Cost: 0.9001961 | Acc train: 0.9590000 | Acc validation: 0.9800000
# f1_score is 0.9342105263157895 0.9259259259259259
# roc_auc_score is 0.93 0.9199999999999999
# Iter:    46 | Cost: 0.8966223 | Acc train: 0.9300000 | Acc validation: 0.9200000
# f1_score is 0.9237918215613383 0.9158878504672898
# roc_auc_score is 0.9179999999999999 0.91
# Iter:    47 | Cost: 0.8912454 | Acc train: 0.9180000 | Acc validation: 0.9100000
# f1_score is 0.8680555555555556 0.8928571428571428
# roc_auc_score is 0.848 0.88
# Iter:    48 | Cost: 0.8879168 | Acc train: 0.8480000 | Acc validation: 0.8800000
# f1_score is 0.8116883116883116 0.8064516129032258
# roc_auc_score is 0.768 0.76
# Iter:    49 | Cost: 0.8855570 | Acc train: 0.7680000 | Acc validation: 0.7600000
# f1_score is 0.7656967840735069 0.7812500000000001
# roc_auc_score is 0.694 0.72
# Iter:    50 | Cost: 0.8841599 | Acc train: 0.6940000 | Acc validation: 0.7200000
# f1_score is 0.778816199376947 0.7874015748031497
# roc_auc_score is 0.716 0.73
# ...
# roc_auc_score is 0.8270000000000001 0.8900000000000001
# Iter:    76 | Cost: 0.8280956 | Acc train: 0.8270000 | Acc validation: 0.8900000
# f1_score is 0.7567152724481965 0.765625
# roc_auc_score is 0.683 0.7
# Iter:    77 | Cost: 0.8407754 | Acc train: 0.6830000 | Acc validation: 0.7000000
# f1_score is 0.7057991513437057 0.7259259259259259
# roc_auc_score is 0.5840000000000001 0.63
# Iter:    78 | Cost: 0.8580791 | Acc train: 0.5840000 | Acc validation: 0.6300000
# f1_score is 0.693000693000693 0.7142857142857143
# roc_auc_score is 0.5569999999999999 0.6
# Iter:    79 | Cost: 0.8715265 | Acc train: 0.5570000 | Acc validation: 0.6000000
# f1_score is 0.6915629322268326 0.7142857142857143
# roc_auc_score is 0.554 0.6
# Iter:    80 | Cost: 0.8732717 | Acc train: 0.5540000 | Acc validation: 0.6000000
# f1_score is 0.7013352073085033 0.7205882352941176
# roc_auc_score is 0.575 0.62
# Iter:    81 | Cost: 0.8619147 | Acc train: 0.5750000 | Acc validation: 0.6200000
# f1_score is 0.7310243183492998 0.7424242424242423
# roc_auc_score is 0.635 0.6599999999999999
# Iter:    82 | Cost: 0.8461339 | Acc train: 0.6350000 | Acc validation: 0.6600000
# f1_score is 0.8 0.8448275862068965
# roc_auc_score is 0.77 0.8199999999999998
# Iter:    83 | Cost: 0.8301487 | Acc train: 0.7700000 | Acc validation: 0.8200000
# f1_score is 0.8203530633437175 0.9056603773584904
# roc_auc_score is 0.827 0.8999999999999999
# Iter:    84 | Cost: 0.8277668 | Acc train: 0.8270000 | Acc validation: 0.9000000
# f1_score is 0.779976717112922 0.9183673469387755
# roc_auc_score is 0.8109999999999999 0.9199999999999999
# Iter:    85 | Cost: 0.8308839 | Acc train: 0.8110000 | Acc validation: 0.9200000
# f1_score is 0.7743467933491687 0.8958333333333334
# roc_auc_score is 0.81 0.8999999999999999
# Iter:    86 | Cost: 0.8316019 | Acc train: 0.8100000 | Acc validation: 0.9000000
# f1_score is 0.7830188679245284 0.9183673469387755
# roc_auc_score is 0.8160000000000001 0.9199999999999999
# Iter:    87 | Cost: 0.8307139 | Acc train: 0.8160000 | Acc validation: 0.9200000
# f1_score is 0.7849588719153936 0.9183673469387755
# roc_auc_score is 0.8170000000000001 0.9199999999999999
# Iter:    88 | Cost: 0.8300319 | Acc train: 0.8170000 | Acc validation: 0.9200000
# f1_score is 0.7668269230769231 0.8958333333333334
# roc_auc_score is 0.8059999999999999 0.8999999999999999
# Iter:    89 | Cost: 0.8306839 | Acc train: 0.8060000 | Acc validation: 0.9000000
# f1_score is 0.7934655775962661 0.9183673469387755
# roc_auc_score is 0.8230000000000001 0.9199999999999999
# Iter:    90 | Cost: 0.8278636 | Acc train: 0.8230000 | Acc validation: 0.9200000
# f1_score is 0.7814726840855107 0.9183673469387755
# roc_auc_score is 0.8159999999999998 0.9199999999999999
# Iter:    91 | Cost: 0.8279224 | Acc train: 0.8160000 | Acc validation: 0.9200000
# f1_score is 0.6357435197817191 0.8636363636363636
# roc_auc_score is 0.733 0.88
# Iter:    92 | Cost: 0.8401079 | Acc train: 0.7330000 | Acc validation: 0.8800000
# f1_score is 0.5029940119760479 0.7341772151898733
# roc_auc_score is 0.668 0.79
# Iter:    93 | Cost: 0.8493746 | Acc train: 0.6680000 | Acc validation: 0.7900000
# f1_score is 0.44236760124610586 0.7012987012987013
# roc_auc_score is 0.642 0.77
# Iter:    94 | Cost: 0.8496033 | Acc train: 0.6420000 | Acc validation: 0.7700000
# f1_score is 0.5974754558204769 0.7951807228915663
# roc_auc_score is 0.713 0.8300000000000001
# Iter:    95 | Cost: 0.8402757 | Acc train: 0.7130000 | Acc validation: 0.8300000
# f1_score is 0.8350398179749716 0.9278350515463918
# roc_auc_score is 0.855 0.9299999999999999
# Iter:    96 | Cost: 0.8214724 | Acc train: 0.8550000 | Acc validation: 0.9300000
# f1_score is 0.8724954462659381 0.890909090909091
# roc_auc_score is 0.8600000000000001 0.88
# Iter:    97 | Cost: 0.8164144 | Acc train: 0.8600000 | Acc validation: 0.8800000
# f1_score is 0.790513833992095 0.784
# roc_auc_score is 0.735 0.73
# Iter:    98 | Cost: 0.8239509 | Acc train: 0.7350000 | Acc validation: 0.7300000
# f1_score is 0.7407407407407407 0.7633587786259541
# roc_auc_score is 0.65 0.69
# Iter:    99 | Cost: 0.8345972 | Acc train: 0.6500000 | Acc validation: 0.6900000
# f1_score is 0.7251631617113851 0.7407407407407407
# roc_auc_score is 0.621 0.65
# Iter:   100 | Cost: 0.8391506 | Acc train: 0.6210000 | Acc validation: 0.6500000
# f1_score is 0.7473841554559043 0.7692307692307693
# roc_auc_score is 0.6619999999999999 0.7
# Iter:   101 | Cost: 0.8300683 | Acc train: 0.6620000 | Acc validation: 0.7000000
# f1_score is 0.7479431563201197 0.7692307692307693
# roc_auc_score is 0.663 0.7
# Iter:   102 | Cost: 0.8300081 | Acc train: 0.6630000 | Acc validation: 0.7000000
# f1_score is 0.7587253414264037 0.7812500000000001
# roc_auc_score is 0.6819999999999999 0.72
# Iter:   103 | Cost: 0.8258834 | Acc train: 0.6820000 | Acc validation: 0.7200000
# f1_score is 0.8058017727639001 0.8264462809917354
# roc_auc_score is 0.759 0.79
# Iter:   104 | Cost: 0.8161059 | Acc train: 0.7590000 | Acc validation: 0.7900000
# f1_score is 0.8658008658008659 0.8547008547008548
# roc_auc_score is 0.845 0.83
# Iter:   105 | Cost: 0.8094308 | Acc train: 0.8450000 | Acc validation: 0.8300000
# f1_score is 0.9510763209393347 0.9607843137254902
# roc_auc_score is 0.9500000000000001 0.96
# Iter:   106 | Cost: 0.8096894 | Acc train: 0.9500000 | Acc validation: 0.9600000
# f1_score is 0.7144686299615877 0.7710843373493975
# roc_auc_score is 0.777 0.81
# Iter:   107 | Cost: 0.8224843 | Acc train: 0.7770000 | Acc validation: 0.8100000
# f1_score is 0.0 0.0
# roc_auc_score is 0.5 0.5
# Iter:   108 | Cost: 0.8487606 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.5 0.5
# Iter:   109 | Cost: 0.8726589 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.5 0.5
# Iter:   110 | Cost: 0.8447752 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.845360824742268 0.7407407407407407
# roc_auc_score is 0.865 0.79
# Iter:   111 | Cost: 0.8149253 | Acc train: 0.8650000 | Acc validation: 0.7900000
# f1_score is 0.9572815533980582 0.970873786407767
# roc_auc_score is 0.9560000000000001 0.97
# Iter:   112 | Cost: 0.8024391 | Acc train: 0.9560000 | Acc validation: 0.9700000
# f1_score is 0.8886910062333038 0.8695652173913044
# roc_auc_score is 0.875 0.85
# Iter:   113 | Cost: 0.7987724 | Acc train: 0.8750000 | Acc validation: 0.8500000
# f1_score is 0.8396305625524769 0.8474576271186441
# roc_auc_score is 0.8089999999999999 0.8200000000000001
# Iter:   114 | Cost: 0.8014147 | Acc train: 0.8090000 | Acc validation: 0.8200000
# f1_score is 0.7581501137225171 0.7633587786259541
# roc_auc_score is 0.681 0.69
# Iter:   115 | Cost: 0.8163754 | Acc train: 0.6810000 | Acc validation: 0.6900000
# f1_score is 0.7220216606498194 0.7246376811594203
# roc_auc_score is 0.615 0.62
# Iter:   116 | Cost: 0.8267264 | Acc train: 0.6150000 | Acc validation: 0.6200000
# f1_score is 0.7057163020465772 0.7246376811594203
# roc_auc_score is 0.583 0.62
# Iter:   117 | Cost: 0.8309220 | Acc train: 0.5830000 | Acc validation: 0.6200000
# f1_score is 0.7215007215007215 0.7299270072992701
# roc_auc_score is 0.614 0.63
# Iter:   118 | Cost: 0.8221488 | Acc train: 0.6140000 | Acc validation: 0.6300000
# f1_score is 0.7763975155279503 0.7812500000000001
# roc_auc_score is 0.712 0.72
# Iter:   119 | Cost: 0.8078290 | Acc train: 0.7120000 | Acc validation: 0.7200000
# f1_score is 0.8670721112076456 0.8849557522123894
# roc_auc_score is 0.847 0.87
# Iter:   120 | Cost: 0.7917262 | Acc train: 0.8470000 | Acc validation: 0.8700000
# [[0.3, 0.32, 0.36, 0.4, 0.41, 0.44, 0.44, 0.44, 0.44, 0.45, 0.44, 0.4, 0.49, 0.59, 0.63, 0.59, 0.55, 0.54, 0.53, 0.51, 0.51, 0.51, 0.51, 0.52, 0.52, 0.53, 0.54, 0.57, 0.63, 0.63, 0.69, 0.72, 0.73, 0.59, 0.51, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.56, 0.6, 0.62, 0.7, 0.63, 0.72, 0.81, 0.81, 0.85, 0.85, 0.89, 0.89, 0.88, 0.87, 0.87, 0.89, 0.95, 0.97, 0.98, 0.98, 0.93, 0.92, 0.9, 0.85, 0.82, 0.78, 0.78, 0.77, 0.85, 0.89, 0.88, 0.88, 0.82, 0.8, 0.82, 0.82, 0.86, 0.9, 0.89, 0.86, 0.92, 0.96, 0.86, 0.71, 0.61, 0.52, 0.7, 0.97, 0.95, 0.89, 0.82, 0.79, 0.79, 0.79, 0.79, 0.79, 0.78, 0.79, 0.87, 0.92, 0.77, 0.72, 0.7, 0.68, 0.66, 0.77, 0.92, 0.89, 0.84, 0.68, 0.67, 0.67, 0.69, 0.82, 0.85, 0.82, 0.88, 0.91], [0.25, 0.24, 0.25, 0.45, 0.53, 0.55, 0.56, 0.55, 0.53, 0.56, 0.56, 0.56, 0.56, 0.56, 0.53, 0.53, 0.55, 0.56, 0.53, 0.53, 0.48, 0.47, 0.52, 0.52, 0.52, 0.51, 0.51, 0.52, 0.51, 0.53, 0.51, 0.55, 0.54, 0.51, 0.51, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.51, 0.51, 0.51, 0.53, 0.51, 0.57, 0.58, 0.61, 0.86, 0.9, 0.92, 0.78, 0.53, 0.5, 0.5, 0.53, 0.68, 0.81, 0.9, 0.92, 0.96, 0.93, 0.88, 0.79, 0.77, 0.7, 0.61, 0.59, 0.58, 0.59, 0.69, 0.86, 0.93, 0.93, 0.93, 0.92, 0.89, 0.86, 0.81, 0.85, 0.88, 0.89, 0.89, 0.89, 0.87, 0.88, 0.87, 0.88, 0.87, 0.86, 0.86, 0.87, 0.88, 0.88, 0.88, 0.87, 0.87, 0.87, 0.87, 0.88, 0.88, 0.88, 0.87, 0.86, 0.87, 0.87, 0.87, 0.88, 0.87, 0.81, 0.79, 0.76, 0.69, 0.7, 0.74, 0.78, 0.83, 0.83, 0.82], [0.23, 0.32, 0.45, 0.55, 0.55, 0.57, 0.56, 0.56, 0.57, 0.57, 0.56, 0.57, 0.58, 0.54, 0.52, 0.52, 0.5, 0.51, 0.51, 0.52, 0.52, 0.52, 0.52, 0.52, 0.52, 0.52, 0.51, 0.51, 0.51, 0.52, 0.51, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.84, 0.99, 0.98, 0.92, 0.91, 0.88, 0.76, 0.72, 0.73, 0.75, 0.86, 0.94, 0.94, 0.93, 0.83, 0.83, 0.88, 0.88, 0.92, 0.92, 0.92, 0.92, 0.89, 0.87, 0.87, 0.89, 0.91, 0.88, 0.87, 0.87, 0.9, 0.89, 0.9, 0.89, 0.7, 0.63, 0.6, 0.6, 0.62, 0.66, 0.82, 0.9, 0.92, 0.9, 0.92, 0.92, 0.9, 0.92, 0.92, 0.88, 0.79, 0.77, 0.83, 0.93, 0.88, 0.73, 0.69, 0.65, 0.7, 0.7, 0.72, 0.79, 0.83, 0.96, 0.81, 0.5, 0.5, 0.5, 0.79, 0.97, 0.85, 0.82, 0.69, 0.62, 0.62, 0.63, 0.72, 0.87]]
# [[0.317, 0.339, 0.365, 0.377, 0.391, 0.411, 0.422, 0.418, 0.412, 0.414, 0.414, 0.414, 0.49, 0.617, 0.629, 0.583, 0.544, 0.521, 0.505, 0.502, 0.5, 0.5, 0.5, 0.5, 0.503, 0.506, 0.517, 0.55, 0.619, 0.668, 0.723, 0.774, 0.73, 0.586, 0.516, 0.504, 0.503, 0.5, 0.501, 0.501, 0.507, 0.521, 0.54, 0.582, 0.584, 0.606, 0.583, 0.613, 0.667, 0.674, 0.711, 0.731, 0.781, 0.783, 0.779, 0.725, 0.721, 0.778, 0.809, 0.841, 0.864, 0.905, 0.923, 0.91, 0.876, 0.852, 0.786, 0.744, 0.737, 0.725, 0.842, 0.9, 0.9, 0.901, 0.829, 0.801, 0.824, 0.828, 0.88, 0.921, 0.901, 0.89, 0.943, 0.954, 0.911, 0.8, 0.671, 0.521, 0.818, 0.948, 0.951, 0.883, 0.803, 0.766, 0.774, 0.764, 0.783, 0.786, 0.754, 0.777, 0.847, 0.909, 0.881, 0.86, 0.823, 0.788, 0.771, 0.88, 0.905, 0.909, 0.902, 0.833, 0.775, 0.779, 0.829, 0.894, 0.897, 0.891, 0.901, 0.896], [0.289, 0.275, 0.294, 0.404, 0.517, 0.54, 0.535, 0.529, 0.529, 0.53, 0.531, 0.534, 0.546, 0.548, 0.542, 0.542, 0.551, 0.545, 0.547, 0.555, 0.576, 0.602, 0.633, 0.642, 0.649, 0.647, 0.647, 0.655, 0.657, 0.668, 0.667, 0.672, 0.659, 0.59, 0.503, 0.497, 0.5, 0.5, 0.5, 0.5, 0.499, 0.49, 0.5, 0.509, 0.555, 0.615, 0.654, 0.659, 0.684, 0.829, 0.887, 0.904, 0.701, 0.533, 0.502, 0.502, 0.515, 0.605, 0.725, 0.797, 0.83, 0.883, 0.916, 0.855, 0.743, 0.709, 0.685, 0.631, 0.609, 0.578, 0.599, 0.672, 0.828, 0.883, 0.836, 0.829, 0.848, 0.857, 0.823, 0.776, 0.803, 0.841, 0.826, 0.789, 0.772, 0.769, 0.767, 0.765, 0.77, 0.802, 0.786, 0.786, 0.786, 0.786, 0.779, 0.777, 0.786, 0.78, 0.785, 0.784, 0.782, 0.777, 0.778, 0.769, 0.763, 0.759, 0.761, 0.76, 0.763, 0.766, 0.741, 0.733, 0.69, 0.654, 0.655, 0.682, 0.709, 0.733, 0.733, 0.728], [0.277, 0.308, 0.397, 0.463, 0.542, 0.544, 0.535, 0.539, 0.542, 0.549, 0.566, 0.593, 0.621, 0.621, 0.598, 0.537, 0.493, 0.496, 0.501, 0.511, 0.52, 0.532, 0.533, 0.566, 0.552, 0.529, 0.503, 0.502, 0.51, 0.514, 0.5, 0.5, 0.501, 0.5, 0.5, 0.499, 0.499, 0.5, 0.5, 0.499, 0.501, 0.511, 0.713, 0.929, 0.959, 0.93, 0.918, 0.848, 0.768, 0.694, 0.716, 0.738, 0.848, 0.906, 0.859, 0.818, 0.718, 0.717, 0.744, 0.755, 0.816, 0.841, 0.861, 0.851, 0.848, 0.825, 0.833, 0.847, 0.848, 0.84, 0.834, 0.832, 0.84, 0.814, 0.815, 0.827, 0.683, 0.584, 0.557, 0.554, 0.575, 0.635, 0.77, 0.827, 0.811, 0.81, 0.816, 0.817, 0.806, 0.823, 0.816, 0.733, 0.668, 0.642, 0.713, 0.855, 0.86, 0.735, 0.65, 0.621, 0.662, 0.663, 0.682, 0.759, 0.845, 0.95, 0.777, 0.5, 0.5, 0.5, 0.865, 0.956, 0.875, 0.809, 0.681, 0.615, 0.583, 0.614, 0.712, 0.847]]
# [[1.0641515095526048, 1.0623298643151886, 1.0591998337666437, 1.0544789517433089, 1.0495345376708671, 1.0438064539369385, 1.0375038331803226, 1.0298616645278593, 1.02248525526943, 1.0161537322703424, 1.0102146811471056, 1.004815103799887, 1.00078082113022, 0.9978045269971028, 0.9961431228538759, 0.9959708516062217, 0.9962010116577876, 0.9965498893558398, 0.9967828111414763, 0.9969983719506571, 0.9973136209715465, 0.9960919297557933, 0.9942562775531875, 0.9923613468059264, 0.9904434327137851, 0.9873570097088137, 0.9838961226284852, 0.9796579881254494, 0.9758419118787848, 0.9726509878430404, 0.9695454807858113, 0.965710524888266, 0.9622307203840713, 0.959292982819718, 0.9569165864477224, 0.9550115920952265, 0.9533113040789815, 0.9516878587291959, 0.9502172441818147, 0.9480423148601157, 0.9453922012150824, 0.9428025979352018, 0.9404465201950779, 0.9379010045831857, 0.9352395749479759, 0.9324525532482343, 0.9294617933723098, 0.9260502641932624, 0.9223671213747046, 0.9186216275017628, 0.9145731763925578, 0.9103935743691233, 0.9058834602088996, 0.9015316295992564, 0.8970985570136006, 0.8935313142269844, 0.8893799539111399, 0.8837688219191041, 0.878497769429521, 0.873215242887432, 0.8686092139104121, 0.8637579405117033, 0.8589639908656893, 0.8545759869355176, 0.851262770547097, 0.8483175392539445, 0.8492042125012443, 0.8481347307431204, 0.8455089261786625, 0.8436033833396755, 0.8323864936202748, 0.8278254899091058, 0.8259264127073971, 0.8239806305638501, 0.8250713044133472, 0.8255815875576513, 0.8222892768157499, 0.8208300412301274, 0.817481334696278, 0.8160419945388379, 0.8147056640577799, 0.8135688982507205, 0.813496368462034, 0.8153683496376345, 0.8208796039314471, 0.822870950238373, 0.8272723563564273, 0.8323932247773792, 0.8183540207216881, 0.8091627033452975, 0.8052577593897504, 0.8017838182791407, 0.8051751782783471, 0.8077972643866792, 0.8060555278334318, 0.805945581514275, 0.8033093704600336, 0.8021912076142064, 0.8053946570840058, 0.8009560311472009, 0.7936175421652129, 0.7909207191958674, 0.7951699998373654, 0.7954664412331877, 0.7970961561918009, 0.800764066515946, 0.8029376926048187, 0.7895650369283729, 0.7850721695337975, 0.784837907973999, 0.7844573801114161, 0.7883712758845053, 0.7951056313864585, 0.7936492978242031, 0.785836298492078, 0.7799817261155386, 0.7790316794212072, 0.7784278997131732, 0.7770219413547111, 0.7762223076274863], [1.06227694657437, 1.0583646547563619, 1.0528890183268897, 1.0475150700490619, 1.0426095374133826, 1.0385115959630857, 1.0346675620783197, 1.029861383408167, 1.0254326557944209, 1.0199745738492911, 1.015169725757346, 1.010635634492403, 1.006574734520911, 1.0031485502675912, 1.0004117260817906, 0.997661973494017, 0.9950681278306499, 0.9931415492566475, 0.9911949637584875, 0.9891842890954576, 0.9869916131888045, 0.9847512198466277, 0.981790568785635, 0.9796501163685462, 0.9783863974508074, 0.9771244973669652, 0.9756909435261055, 0.9754347191167265, 0.9743888334905602, 0.9726160633049228, 0.9698146035115214, 0.9670669066379155, 0.9649566185058178, 0.9617563985170996, 0.959074874493228, 0.9575817469825091, 0.9562394174225003, 0.9549517832616368, 0.9533487289751206, 0.9512764216641536, 0.9491340560095949, 0.9468367760997911, 0.9449429110729625, 0.9430023480529894, 0.9412329417523514, 0.9393374088061077, 0.9371079212424814, 0.9345675289101283, 0.9319949334001955, 0.9301588843023881, 0.9276461887533856, 0.9241244472889208, 0.9191455032963398, 0.915711321119676, 0.9131907158843922, 0.9101738388255616, 0.9061111109088555, 0.9016683461546144, 0.897513542251613, 0.8935965697409087, 0.8896619146255391, 0.8860184973301585, 0.883814862501642, 0.8841288097976419, 0.8861794076161262, 0.8844539110639756, 0.8826059396130418, 0.8825981630721679, 0.8822507732652406, 0.881997431353651, 0.8778425997149926, 0.8679133007101398, 0.8550365648670342, 0.8488859068501385, 0.8481626680742433, 0.8467005751505126, 0.844030020990494, 0.8425668870644862, 0.843766733637384, 0.8459438635230876, 0.8423215929398744, 0.838230 ...
