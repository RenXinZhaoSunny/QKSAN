# %%
import pennylane as qml
from pennylane import numpy as np
from sklearn.decomposition import PCA
import random
from collections import Counter
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
wire = 1

wires = wire * 2
dim = 2 ** wire
dim1 = 2 * dim
dev = qml.device('default.mixed', wires=wires)
#dev = qml.device("lightning.qubit", wires=wires, shots=None)
#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
dev1 = qml.device("lightning.qubit", wires=wire, shots=None)
wires = dev.wires.tolist()

@qml.qnode(dev1)
def StateVector(x):
    qml.AmplitudeEmbedding(features=x, wires=range(wire), 
                           pad_with=0.0, normalize=True)
    return qml.state()

def accuracy(labels, predictions):

    loss = 0
    for l, p in zip(labels, predictions):
        if abs(l - p) < 1e-5:
            loss = loss + 1
    loss = loss / len(labels)

    return loss

def square_loss(labels, predictions):
    loss = 0
    for l, p in zip(labels, predictions):
        loss = loss + (l - p) ** 2

    loss = loss / len(labels)
    return loss

def noramlization(data):
    minVals = data.min(0)
    maxVals = data.max(0)
    ranges = maxVals - minVals
    normData = np.zeros(np.shape(data))
    m = data.shape[0]
    normData = data - np.tile(minVals, (m, 1))
    normData = normData/np.tile(ranges, (m, 1))
    return normData

def random_params(num_wires):
    """Generate random variational parameters in the shape for the ansatz."""
    return np.random.uniform(0, 2 * np.pi, num_wires, requires_grad=True)

num_para = int(wire + (wire - 1) * wire / 2)
params_init = random_params(3 * num_para + wire)
print(params_init)
# Out:
# [3.38440085 3.12276127 0.15060644 3.09852142]

# %%
def ProcessingData(datapoints, train_size, test_size):
    train_data = np.loadtxt("./mnist_train.csv", delimiter=",")
    print(train_data.shape)
    #Extracting features and labels from the dataset 
    train_data_features = train_data[:datapoints, 1:]
    train_data_labels = train_data[:datapoints, :1].reshape(datapoints,)

    # Use PCA technique to reduce dimensions to 4
    DimReduce = PCA(n_components= dim1)
    train_data_features_reduced = DimReduce.fit_transform(train_data_features)
    # normalize dataset
    train_data_features_reduced = noramlization(train_data_features_reduced)
    s1 = np.array([StateVector(x) for x in train_data_features_reduced[:,:dim]])
    s2 = np.array([StateVector(x) for x in train_data_features_reduced[:,dim:]])
    train_data_features_reduced = np.hstack((s1, s2)).tolist()

    zero_one_datapoint_array = []
    label_0_1 = []
    zero_datapoints_array = [] #an array of the data points containing value 0
    one_datapoints_array = []# an array of the data points containing value 1
    label_0 = []
    label_1 = []
        
    for i in range(datapoints):
        if train_data_labels[i] == 0:                   # extracting zeros
            label_0.append(-1)
            zero_datapoints_array.append(train_data_features_reduced[i])
        elif train_data_labels[i] == 1:                   # extracting ones
            label_1.append(1)
            one_datapoints_array.append(train_data_features_reduced[i]) 
    print(len(zero_datapoints_array), len(one_datapoints_array))
    if (len(label_0) + len(label_1)) < 2 * (train_size + test_size):
        print("datapoints is too small!")
    else:
        print((len(label_0),len(label_1)))
        zero_datapoints_array_train = zero_datapoints_array[:train_size]
        one_datapoints_array_train = one_datapoints_array[:train_size]
        label_0_train = label_0[:train_size]
        label_1_train = label_1[:train_size]
        zero_datapoints_array_test = zero_datapoints_array[train_size + 1:train_size + test_size + 1]
        one_datapoints_array_test = one_datapoints_array[train_size + 1:train_size + test_size + 1]
        label_0_test = label_0[train_size + 1:train_size + test_size + 1]
        label_1_test = label_1[train_size + 1:train_size + test_size + 1]
        #print(len(zero_datapoints_array_train), len(label_1_train))
        #print(len(one_datapoints_array_test), len(label_0_test))

        zero_one_datapoint_array_train = zero_datapoints_array_train + one_datapoints_array_train
        label_0_1_train = label_0_train + label_1_train
        zero_one_datapoint_array_test = zero_datapoints_array_test + one_datapoints_array_test
        label_0_1_test = label_0_test + label_1_test
        #print(len(zero_one_datapoint_array_train), label_0_1_train)
        #print(len(zero_one_datapoint_array_test), label_0_1_test)

        np.random.seed(10)
        index_train = np.random.permutation(range(2 * train_size))
        index_test = np.random.permutation(range(2 * test_size))

        feats_train = []
        Y_train = []
        feats_val = []
        Y_val = []
        for i in range(2 * train_size):
            feats_train.append(zero_one_datapoint_array_train[index_train[i]])
            Y_train.append(label_0_1_train[index_train[i]])


        for i in range(2 * test_size):
            feats_val.append(zero_one_datapoint_array_test[index_test[i]])
            Y_val.append(label_0_1_test[index_test[i]])

        #print(feats_val, Y_val)

        features = feats_train + feats_val
        features = np.array(features, requires_grad=False)
        Y = Y_train + Y_val
        Y = np.array(Y, requires_grad=False)
        feats_train = np.array(feats_train, requires_grad=False)
        Y_train = np.array(Y_train, requires_grad=False)
        feats_val = np.array(feats_val, requires_grad=False)
        Y_val = np.array(Y_val, requires_grad=False)
    return feats_train, Y_train, feats_val, Y_val, features, Y

datapoints = 6000
train_size = 500
test_size = 50
feats_train, Y_train, feats_val, Y_val, features, Y = ProcessingData(datapoints, train_size, test_size)
# Out:
# (60000, 785)
# 592 671
# (592, 671)

# %%
#AmplitudeEncoding + Hardware-effient Ansatz
def DataEncoding(x, wires_start, wires_end):
    wires = np.arange(wires_start, wires_end).tolist()
    qml.MottonenStatePreparation(state_vector=x, wires=wires)
    #qml.AmplitudeEmbedding(features=x, wires=wires, pad_with=0., normalize=True)

def Ansatz(params, wires_start, wires_end):
    for i in np.arange(wires_start, wires_end):
        qml.Hadamard(wires=wires[i])
        qml.RY(params[i - wires_start], wires=wires[i])
        #print(i)
    for i in np.arange(wires_start, wires_end):
        for j in np.arange(i + 1, wires_end):
            qml.CRZ(params[i - wires_start + wires_end - wires_start], wires=[wires[i], wires[j]])

p = 0.01
mode = 0
#@qml.qnode(dev, interface="torch", diff_method="parameter-shift")
@qml.qnode(dev)
def QKSAN(feat, params):
    x1 = feat[:dim]
    x2 = feat[dim:]
    DataEncoding(x1, 0, wire)
    Ansatz(params[0: num_para], 0, wire)
    qml.adjoint(Ansatz)(params[num_para: 2 * num_para], 0, wire)
    qml.adjoint(DataEncoding)(x2, 0, wire)

    DataEncoding(x2, wire, (2 * wire))
    Ansatz(params[2 * num_para + wire: 3 * num_para + wire], wire, (2 * wire))
    if p != 0:
        if mode == 0:
            for i in range(2 * wire):
                qml.AmplitudeDamping(p, wires=i)
        elif mode == 1:
            for i in range(2 * wire):
                qml.BitFlip(p, wires=i)
        else:
            print("error!")
            return 0
    for i in range(wire):
        qml.cond(qml.measure(i), qml.RY)(params[2 * num_para + i], wires=wires[i + wire])
    #qml.Snapshot()
    return qml.expval(qml.PauliZ(2 * wire - 1))

qml.drawer.use_style('black_white')
fig, ax = qml.draw_mpl(QKSAN, show_all_wires=True)(feats_train[0], params_init)
fig.set_size_inches((7, 5))
print(qml.specs(QKSAN)(feats_train[0], params_init))

def variational_classifier(params, feat):
    return QKSAN(feat, params)


def cost(params, features, labels):
    predictions = [variational_classifier(params, feat) for feat in features]
    return square_loss(labels, predictions)

def TrainQKSAN(params_init):
    opt = qml.NesterovMomentumOptimizer(0.09)
    batch_size = 30
    weights = params_init
    #bias = np.array(0.0, requires_grad=True)
    his_acc_val = []
    his_acc_train = []
    his_cost = []
    f1_train = []
    f1_test = []
    roc_auc_train = []
    roc_auc_test = []
    for it in range(120):

        # Update the weights by one optimizer step
        batch_index = np.random.randint(0, 2 * train_size, (batch_size,))
        feats_train_batch = feats_train[batch_index]
        Y_train_batch = Y_train[batch_index]
        
        weights, _, _ = opt.step(cost, weights, feats_train_batch, Y_train_batch)

        # Compute predictions on train and validation set
        predictions_train = [np.sign(variational_classifier(weights, feat)) for feat in feats_train]
        predictions_val = [np.sign(variational_classifier(weights, feat)) for feat in feats_val]
        #print(probs(Y_train, predictions_val))
        c = cost(weights, features, Y).numpy()
        #print(c)
        # Compute accuracy on train and validation set
        acc_train = accuracy_score(Y_train, predictions_train)
        acc_val = accuracy_score(Y_val, predictions_val)
        a = f1_score(Y_train, predictions_train)
        b = f1_score(Y_val, predictions_val)
        
        #print("f1_score is", a, b)
        d = roc_auc_score(Y_train, predictions_train)
        e = roc_auc_score(Y_val, predictions_val)
        #print("roc_auc_score is", d, e)


        f1_train.append(a)
        f1_test.append(b)
        roc_auc_train.append(d)
        roc_auc_test.append(e)
        his_acc_val.append(acc_val)
        his_acc_train.append(acc_train)
        his_cost.append(c)
        print("Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
            "".format(it + 1, c, acc_train, acc_val))
    print(p)    
    return his_acc_val, his_acc_train, his_cost, f1_train, f1_test, roc_auc_train, roc_auc_test
# Out:
# {'gate_sizes': defaultdict(<class 'int'>, {1: 11, 2: 1}), 'gate_types': defaultdict(<class 'int'>, {'MottonenStatePreparation': 2, 'Hadamard': 2, 'RY': 2, 'Adjoint(RY)': 1, 'Adjoint(Hadamard)': 1, 'Adjoint(MottonenStatePreparation)': 1, 'AmplitudeDamping': 2, 'C(RY)': 1}), 'num_operations': 12, 'num_observables': 1, 'num_diagonalizing_gates': 0, 'num_used_wires': 2, 'depth': 8, 'num_trainable_params': 9, 'num_device_wires': 2, 'device_name': 'default.mixed', 'expansion_strategy': 'gradient', 'gradient_options': {}, 'interface': 'auto', 'diff_method': 'best', 'gradient_fn': 'backprop'}

# %%
modes = [0, 1]
ps = [0.1, 0.2, 0.3]
his1 = []
his2 = []
his3 = []
p = 0
his_acc_val, his_acc_train, his_cost, _, _, _, _ = TrainQKSAN(params_init)
his1.append(his_acc_val)
his2.append(his_acc_train)
his3.append(his_cost)
for mode in modes:
    for p in ps:
        his_acc_val, his_acc_train, his_cost, _, _, _, _ = TrainQKSAN(params_init)
        his1.append(his_acc_val)
        his2.append(his_acc_train)
        his3.append(his_cost)
print(his1)
print(his2)
print(his3)
# Out:
# Iter:     1 | Cost: 1.9837975 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     2 | Cost: 1.9823175 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     3 | Cost: 1.9793200 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     4 | Cost: 1.9758166 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     5 | Cost: 1.9712595 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     6 | Cost: 1.9646468 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     7 | Cost: 1.9549541 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     8 | Cost: 1.9424495 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     9 | Cost: 1.9247321 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    10 | Cost: 1.9020804 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    11 | Cost: 1.8708218 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    12 | Cost: 1.8264986 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    13 | Cost: 1.7628072 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    14 | Cost: 1.6717407 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    15 | Cost: 1.5258472 | Acc train: 0.5010000 | Acc validation: 0.4900000
# Iter:    16 | Cost: 1.2768135 | Acc train: 0.4860000 | Acc validation: 0.4800000
# Iter:    17 | Cost: 0.9656285 | Acc train: 0.5030000 | Acc validation: 0.4900000
# Iter:    18 | Cost: 0.6723970 | Acc train: 0.8420000 | Acc validation: 0.8100000
# Iter:    19 | Cost: 0.4815368 | Acc train: 0.9380000 | Acc validation: 0.9400000
# Iter:    20 | Cost: 0.3589458 | Acc train: 0.9720000 | Acc validation: 0.9600000
# Iter:    21 | Cost: 0.2979534 | Acc train: 0.9860000 | Acc validation: 0.9800000
# Iter:    22 | Cost: 0.2896919 | Acc train: 0.9830000 | Acc validation: 0.9800000
# Iter:    23 | Cost: 0.3384334 | Acc train: 0.9730000 | Acc validation: 0.9600000
# Iter:    24 | Cost: 0.3648606 | Acc train: 0.9660000 | Acc validation: 0.9500000
# Iter:    25 | Cost: 0.3362801 | Acc train: 0.9700000 | Acc validation: 0.9600000
# Iter:    26 | Cost: 0.3059180 | Acc train: 0.9780000 | Acc validation: 0.9600000
# Iter:    27 | Cost: 0.2965792 | Acc train: 0.9700000 | Acc validation: 0.9400000
# Iter:    28 | Cost: 0.2984749 | Acc train: 0.9570000 | Acc validation: 0.9300000
# Iter:    29 | Cost: 0.3019738 | Acc train: 0.9440000 | Acc validation: 0.9300000
# Iter:    30 | Cost: 0.3066253 | Acc train: 0.9330000 | Acc validation: 0.9100000
# Iter:    31 | Cost: 0.3072639 | Acc train: 0.9320000 | Acc validation: 0.9100000
# Iter:    32 | Cost: 0.3091778 | Acc train: 0.9260000 | Acc validation: 0.9100000
# Iter:    33 | Cost: 0.3139106 | Acc train: 0.9180000 | Acc validation: 0.8900000
# Iter:    34 | Cost: 0.3178924 | Acc train: 0.9070000 | Acc validation: 0.8800000
# Iter:    35 | Cost: 0.3224376 | Acc train: 0.9010000 | Acc validation: 0.8800000
# Iter:    36 | Cost: 0.3231552 | Acc train: 0.9000000 | Acc validation: 0.8800000
# Iter:    37 | Cost: 0.3212783 | Acc train: 0.9130000 | Acc validation: 0.8800000
# Iter:    38 | Cost: 0.3189369 | Acc train: 0.9270000 | Acc validation: 0.9100000
# Iter:    39 | Cost: 0.3174297 | Acc train: 0.9330000 | Acc validation: 0.9100000
# Iter:    40 | Cost: 0.3137360 | Acc train: 0.9250000 | Acc validation: 0.9000000
# Iter:    41 | Cost: 0.3115758 | Acc train: 0.9170000 | Acc validation: 0.8900000
# Iter:    42 | Cost: 0.3088189 | Acc train: 0.9150000 | Acc validation: 0.8900000
# Iter:    43 | Cost: 0.3041097 | Acc train: 0.9210000 | Acc validation: 0.9000000
# Iter:    44 | Cost: 0.3017447 | Acc train: 0.9190000 | Acc validation: 0.9000000
# Iter:    45 | Cost: 0.2940951 | Acc train: 0.9360000 | Acc validation: 0.9100000
# Iter:    46 | Cost: 0.2892860 | Acc train: 0.9440000 | Acc validation: 0.9300000
# Iter:    47 | Cost: 0.2845260 | Acc train: 0.9610000 | Acc validation: 0.9400000
# Iter:    48 | Cost: 0.2811597 | Acc train: 0.9600000 | Acc validation: 0.9400000
# Iter:    49 | Cost: 0.2777901 | Acc train: 0.9610000 | Acc validation: 0.9400000
# Iter:    50 | Cost: 0.2745949 | Acc train: 0.9690000 | Acc validation: 0.9500000
# Iter:    51 | Cost: 0.2720620 | Acc train: 0.9700000 | Acc validation: 0.9500000
# Iter:    52 | Cost: 0.2693103 | Acc train: 0.9730000 | Acc validation: 0.9700000
# Iter:    53 | Cost: 0.2672432 | Acc train: 0.9750000 | Acc validation: 0.9700000
# Iter:    54 | Cost: 0.2658095 | Acc train: 0.9800000 | Acc validation: 0.9700000
# Iter:    55 | Cost: 0.2651219 | Acc train: 0.9830000 | Acc validation: 0.9700000
# Iter:    56 | Cost: 0.2667838 | Acc train: 0.9880000 | Acc validation: 0.9800000
# Iter:    57 | Cost: 0.2666332 | Acc train: 0.9870000 | Acc validation: 0.9800000
# Iter:    58 | Cost: 0.2633486 | Acc train: 0.9870000 | Acc validation: 0.9800000
# Iter:    59 | Cost: 0.2615095 | Acc train: 0.9850000 | Acc validation: 0.9800000
# Iter:    60 | Cost: 0.2612968 | Acc train: 0.9840000 | Acc validation: 0.9700000
# Iter:    61 | Cost: 0.2624389 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:     8 | Cost: 1.5196086 | Acc train: 0.4960000 | Acc validation: 0.4800000
# Iter:     9 | Cost: 1.4211139 | Acc train: 0.4760000 | Acc validation: 0.4600000
# Iter:    10 | Cost: 1.2989081 | Acc train: 0.4360000 | Acc validation: 0.4400000
# Iter:    11 | Cost: 1.1453473 | Acc train: 0.4000000 | Acc validation: 0.3900000
# Iter:    12 | Cost: 1.0244400 | Acc train: 0.4720000 | Acc validation: 0.4600000
# Iter:    13 | Cost: 0.9755601 | Acc train: 0.7000000 | Acc validation: 0.6900000
# Iter:    14 | Cost: 0.9914780 | Acc train: 0.6980000 | Acc validation: 0.7300000
# Iter:    15 | Cost: 1.0287966 | Acc train: 0.6740000 | Acc validation: 0.6900000
# Iter:    16 | Cost: 1.0404438 | Acc train: 0.6550000 | Acc validation: 0.7000000
# Iter:    17 | Cost: 1.0017686 | Acc train: 0.6630000 | Acc validation: 0.7000000
# Iter:    18 | Cost: 0.9381792 | Acc train: 0.6910000 | Acc validation: 0.7100000
# Iter:    19 | Cost: 0.8345772 | Acc train: 0.7290000 | Acc validation: 0.7500000
# Iter:    20 | Cost: 0.7160148 | Acc train: 0.8050000 | Acc validation: 0.7900000
# Iter:    21 | Cost: 0.6280453 | Acc train: 0.8640000 | Acc validation: 0.8600000
# Iter:    22 | Cost: 0.5924682 | Acc train: 0.8970000 | Acc validation: 0.9300000
# Iter:    23 | Cost: 0.5903883 | Acc train: 0.8920000 | Acc validation: 0.8700000
# Iter:    24 | Cost: 0.5607781 | Acc train: 0.9180000 | Acc validation: 0.8900000
# Iter:    25 | Cost: 0.4869420 | Acc train: 0.9710000 | Acc validation: 0.9700000
# Iter:    26 | Cost: 0.4202968 | Acc train: 0.9840000 | Acc validation: 0.9800000
# Iter:    27 | Cost: 0.3803088 | Acc train: 0.9850000 | Acc validation: 0.9700000
# Iter:    28 | Cost: 0.3719019 | Acc train: 0.9660000 | Acc validation: 0.9700000
# Iter:    29 | Cost: 0.3634349 | Acc train: 0.9660000 | Acc validation: 0.9600000
# Iter:    30 | Cost: 0.3406918 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:    31 | Cost: 0.3174533 | Acc train: 0.9870000 | Acc validation: 0.9900000
# Iter:    32 | Cost: 0.3081016 | Acc train: 0.9880000 | Acc validation: 1.0000000
# Iter:    33 | Cost: 0.3085015 | Acc train: 0.9880000 | Acc validation: 0.9900000
# Iter:    34 | Cost: 0.3150739 | Acc train: 0.9880000 | Acc validation: 0.9900000
# Iter:    35 | Cost: 0.3182543 | Acc train: 0.9880000 | Acc validation: 0.9900000
# Iter:    36 | Cost: 0.3153128 | Acc train: 0.9880000 | Acc validation: 0.9700000
# Iter:    37 | Cost: 0.3125480 | Acc train: 0.9750000 | Acc validation: 0.9700000
# Iter:    38 | Cost: 0.3155629 | Acc train: 0.9600000 | Acc validation: 0.9500000
# Iter:    39 | Cost: 0.3192987 | Acc train: 0.9440000 | Acc validation: 0.9400000
# Iter:    40 | Cost: 0.3248921 | Acc train: 0.9260000 | Acc validation: 0.9400000
# Iter:    41 | Cost: 0.3311708 | Acc train: 0.9100000 | Acc validation: 0.9100000
# Iter:    42 | Cost: 0.3391180 | Acc train: 0.8980000 | Acc validation: 0.9000000
# Iter:    43 | Cost: 0.3372891 | Acc train: 0.9000000 | Acc validation: 0.9000000
# Iter:    44 | Cost: 0.3327259 | Acc train: 0.9100000 | Acc validation: 0.8900000
# Iter:    45 | Cost: 0.3249037 | Acc train: 0.9340000 | Acc validation: 0.9200000
# Iter:    46 | Cost: 0.3229605 | Acc train: 0.9560000 | Acc validation: 0.9400000
# Iter:    47 | Cost: 0.3240888 | Acc train: 0.9660000 | Acc validation: 0.9400000
# Iter:    48 | Cost: 0.3243361 | Acc train: 0.9700000 | Acc validation: 0.9500000
# Iter:    49 | Cost: 0.3218551 | Acc train: 0.9700000 | Acc validation: 0.9500000
# Iter:    50 | Cost: 0.3176891 | Acc train: 0.9610000 | Acc validation: 0.9400000
# Iter:    51 | Cost: 0.3170848 | Acc train: 0.9500000 | Acc validation: 0.9400000
# Iter:    52 | Cost: 0.3163787 | Acc train: 0.9500000 | Acc validation: 0.9400000
# Iter:    53 | Cost: 0.3139240 | Acc train: 0.9690000 | Acc validation: 0.9500000
# Iter:    54 | Cost: 0.3152213 | Acc train: 0.9750000 | Acc validation: 0.9700000
# Iter:    55 | Cost: 0.3155947 | Acc train: 0.9780000 | Acc validation: 0.9700000
# Iter:    56 | Cost: 0.3128798 | Acc train: 0.9760000 | Acc validation: 0.9700000
# Iter:    57 | Cost: 0.3093540 | Acc train: 0.9730000 | Acc validation: 0.9700000
# Iter:    58 | Cost: 0.3091748 | Acc train: 0.9710000 | Acc validation: 0.9500000
# Iter:    59 | Cost: 0.3105769 | Acc train: 0.9620000 | Acc validation: 0.9600000
# Iter:    60 | Cost: 0.3100857 | Acc train: 0.9630000 | Acc validation: 0.9600000
# Iter:    61 | Cost: 0.3072002 | Acc train: 0.9740000 | Acc validation: 0.9800000
# Iter:    62 | Cost: 0.3063622 | Acc train: 0.9750000 | Acc validation: 0.9800000
# Iter:    63 | Cost: 0.3062362 | Acc train: 0.9740000 | Acc validation: 0.9800000
# Iter:    64 | Cost: 0.3085143 | Acc train: 0.9680000 | Acc validation: 0.9700000
# Iter:    65 | Cost: 0.3103689 | Acc train: 0.9650000 | Acc validation: 0.9700000
# Iter:    66 | Cost: 0.3060078 | Acc train: 0.9760000 | Acc validation: 0.9800000
# Iter:    67 | Cost: 0.3036909 | Acc train: 0.9790000 | Acc validation: 0.9800000
# Iter:    68 | Cost: 0.3041716 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    69 | Cost: 0.3052019 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    70 | Cost: 0.3055939 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    71 | Cost: 0.3048835 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:    72 | Cost: 0.3031529 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    73 | Cost: 0.3056373 | Acc train: 0.9870000 | Acc validation: 0.9900000
# Iter:   107 | Cost: 0.3025974 | Acc train: 0.9860000 | Acc validation: 0.9900000
# Iter:   108 | Cost: 0.3030962 | Acc train: 0.9860000 | Acc validation: 1.0000000
# Iter:   109 | Cost: 0.3027547 | Acc train: 0.9860000 | Acc validation: 1.0000000
# Iter:   110 | Cost: 0.3032882 | Acc train: 0.9840000 | Acc validation: 0.9800000
# Iter:   111 | Cost: 0.3068602 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:   112 | Cost: 0.3064765 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:   113 | Cost: 0.3089762 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:   114 | Cost: 0.3103797 | Acc train: 0.9770000 | Acc validation: 0.9800000
# Iter:   115 | Cost: 0.3088332 | Acc train: 0.9790000 | Acc validation: 0.9800000
# Iter:   116 | Cost: 0.3051967 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:   117 | Cost: 0.3046363 | Acc train: 0.9820000 | Acc validation: 0.9800000
# Iter:   118 | Cost: 0.3049013 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:   119 | Cost: 0.3050846 | Acc train: 0.9820000 | Acc validation: 0.9800000
# Iter:   120 | Cost: 0.3070378 | Acc train: 0.9790000 | Acc validation: 0.9800000
# 0.1
# Iter:     1 | Cost: 1.4025856 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     2 | Cost: 1.4015195 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     3 | Cost: 1.4008143 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     4 | Cost: 1.3998147 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     5 | Cost: 1.3981728 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     6 | Cost: 1.3969754 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     7 | Cost: 1.3951395 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     8 | Cost: 1.3923544 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     9 | Cost: 1.3886485 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    10 | Cost: 1.3836071 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    11 | Cost: 1.3771089 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    12 | Cost: 1.3676449 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    13 | Cost: 1.3557027 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    14 | Cost: 1.3396800 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    15 | Cost: 1.3147973 | Acc train: 0.4980000 | Acc validation: 0.4900000
# Iter:    16 | Cost: 1.2824277 | Acc train: 0.4970000 | Acc validation: 0.4800000
# Iter:    17 | Cost: 1.2357901 | Acc train: 0.4890000 | Acc validation: 0.4800000
# Iter:    18 | Cost: 1.1639354 | Acc train: 0.4750000 | Acc validation: 0.4500000
# Iter:    19 | Cost: 1.0588983 | Acc train: 0.4380000 | Acc validation: 0.4600000
# Iter:    20 | Cost: 0.9385005 | Acc train: 0.4780000 | Acc validation: 0.4600000
# Iter:    21 | Cost: 0.8394925 | Acc train: 0.7150000 | Acc validation: 0.6600000
# Iter:    22 | Cost: 0.7589262 | Acc train: 0.8110000 | Acc validation: 0.8200000
# Iter:    23 | Cost: 0.6878079 | Acc train: 0.8370000 | Acc validation: 0.8200000
# Iter:    24 | Cost: 0.6253270 | Acc train: 0.8570000 | Acc validation: 0.8300000
# Iter:    25 | Cost: 0.5639498 | Acc train: 0.8850000 | Acc validation: 0.8700000
# Iter:    26 | Cost: 0.5192851 | Acc train: 0.9140000 | Acc validation: 0.9200000
# Iter:    27 | Cost: 0.4963039 | Acc train: 0.9460000 | Acc validation: 0.9500000
# Iter:    28 | Cost: 0.4776193 | Acc train: 0.9560000 | Acc validation: 0.9600000
# Iter:    29 | Cost: 0.4491931 | Acc train: 0.9670000 | Acc validation: 0.9600000
# Iter:    30 | Cost: 0.4181069 | Acc train: 0.9730000 | Acc validation: 0.9800000
# Iter:    31 | Cost: 0.4000782 | Acc train: 0.9840000 | Acc validation: 0.9800000
# Iter:    32 | Cost: 0.3804215 | Acc train: 0.9870000 | Acc validation: 0.9900000
# Iter:    33 | Cost: 0.3653174 | Acc train: 0.9870000 | Acc validation: 1.0000000
# Iter:    34 | Cost: 0.3622567 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    35 | Cost: 0.3636681 | Acc train: 0.9660000 | Acc validation: 0.9700000
# Iter:    36 | Cost: 0.3648981 | Acc train: 0.9570000 | Acc validation: 0.9600000
# Iter:    37 | Cost: 0.3667066 | Acc train: 0.9540000 | Acc validation: 0.9600000
# Iter:    38 | Cost: 0.3689251 | Acc train: 0.9540000 | Acc validation: 0.9500000
# Iter:    39 | Cost: 0.3728295 | Acc train: 0.9440000 | Acc validation: 0.9400000
# Iter:    40 | Cost: 0.3783540 | Acc train: 0.9200000 | Acc validation: 0.9400000
# Iter:    41 | Cost: 0.3823733 | Acc train: 0.9030000 | Acc validation: 0.9100000
# Iter:    42 | Cost: 0.3798860 | Acc train: 0.9180000 | Acc validation: 0.9300000
# Iter:    43 | Cost: 0.3786643 | Acc train: 0.9210000 | Acc validation: 0.9300000
# Iter:    44 | Cost: 0.3765598 | Acc train: 0.9300000 | Acc validation: 0.9200000
# Iter:    45 | Cost: 0.3747292 | Acc train: 0.9330000 | Acc validation: 0.9200000
# Iter:    46 | Cost: 0.3726733 | Acc train: 0.9480000 | Acc validation: 0.9400000
# Iter:    47 | Cost: 0.3722813 | Acc train: 0.9630000 | Acc validation: 0.9400000
# Iter:    48 | Cost: 0.3700217 | Acc train: 0.9620000 | Acc validation: 0.9400000
# Iter:    49 | Cost: 0.3688833 | Acc train: 0.9610000 | Acc validation: 0.9400000
# Iter:    50 | Cost: 0.3696299 | Acc train: 0.9570000 | Acc validation: 0.9500000
# Iter:    51 | Cost: 0.3703295 | Acc train: 0.9570000 | Acc validation: 0.9500000
# Iter:    52 | Cost: 0.3707892 | Acc train: 0.9600000 | Acc validation: 0.9500000
# Iter:    53 | Cost: 0.3702506 | Acc train: 0.9690000 | Acc validation: 0.9600000
# Iter:    54 | Cost: 0.3691242 | Acc train: 0.9720000 | Acc validation: 0.9700000
# Iter:    55 | Cost: 0.3676532 | Acc train: 0.9720000 | Acc validation: 0.9600000
# Iter:    56 | Cost: 0.3651816 | Acc train: 0.9710000 | Acc validation: 0.9600000
# Iter:    57 | Cost: 0.3638472 | Acc train: 0.9720000 | Acc validation: 0.9800000
# Iter:    58 | Cost: 0.3625004 | Acc train: 0.9700000 | Acc validation: 0.9600000
# Iter:    59 | Cost: 0.3620701 | Acc train: 0.9650000 | Acc validation: 0.9600000
# Iter:    60 | Cost: 0.3618737 | Acc train: 0.9750000 | Acc validation: 0.9800000
# Iter:    61 | Cost: 0.3616155 | Acc train: 0.9740000 | Acc validation: 0.9800000
# Iter:    62 | Cost: 0.3614466 | Acc train: 0.9760000 | Acc validation: 0.9800000
# Iter:    63 | Cost: 0.3610076 | Acc train: 0.9780000 | Acc validation: 0.9800000
# Iter:    64 | Cost: 0.3609806 | Acc train: 0.9790000 | Acc validation: 0.9800000
# Iter:    65 | Cost: 0.3600860 | Acc train: 0.9790000 | Acc validation: 0.9800000
# Iter:    66 | Cost: 0.3597639 | Acc train: 0.9780000 | Acc validation: 0.9800000
# Iter:    67 | Cost: 0.3596467 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    68 | Cost: 0.3598395 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:    69 | Cost: 0.3598785 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    70 | Cost: 0.3596184 | Acc train: 0.9790000 | Acc validation: 0.9800000
# Iter:    71 | Cost: 0.3607686 | Acc train: 0.9760000 | Acc validation: 0.9800000
# Iter:    72 | Cost: 0.3614146 | Acc train: 0.9740000 | Acc validation: 0.9800000
# Iter:    73 | Cost: 0.3596446 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    74 | Cost: 0.3599048 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:    75 | Cost: 0.3601596 | Acc train: 0.9830000 | Acc validation: 0.9800000
# Iter:    76 | Cost: 0.3595846 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    77 | Cost: 0.3639330 | Acc train: 0.9710000 | Acc validation: 0.9800000
# Iter:    78 | Cost: 0.3694333 | Acc train: 0.9570000 | Acc validation: 0.9700000
# Iter:    79 | Cost: 0.3752761 | Acc train: 0.9470000 | Acc validation: 0.9500000
# Iter:    80 | Cost: 0.3752054 | Acc train: 0.9460000 | Acc validation: 0.9500000
# Iter:    81 | Cost: 0.3707403 | Acc train: 0.9500000 | Acc validation: 0.9600000
# Iter:    82 | Cost: 0.3662457 | Acc train: 0.9580000 | Acc validation: 0.9700000
# Iter:    83 | Cost: 0.3614637 | Acc train: 0.9720000 | Acc validation: 0.9800000
# Iter:    84 | Cost: 0.3608738 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    85 | Cost: 0.3625351 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    86 | Cost: 0.3628245 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    87 | Cost: 0.3625926 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    88 | Cost: 0.3622580 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    89 | Cost: 0.3623737 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    90 | Cost: 0.3624674 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    91 | Cost: 0.3622016 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    92 | Cost: 0.3647564 | Acc train: 0.9850000 | Acc validation: 0.9700000
# Iter:    93 | Cost: 0.3674482 | Acc train: 0.9870000 | Acc validation: 0.9800000
# Iter:    94 | Cost: 0.3671529 | Acc train: 0.9870000 | Acc validation: 0.9800000
# Iter:    95 | Cost: 0.3626330 | Acc train: 0.9860000 | Acc validation: 0.9800000
# Iter:    96 | Cost: 0.3593914 | Acc train: 0.9820000 | Acc validation: 0.9800000
# Iter:    97 | Cost: 0.3609192 | Acc train: 0.9740000 | Acc validation: 0.9800000
# Iter:    98 | Cost: 0.3628938 | Acc train: 0.9710000 | Acc validation: 0.9800000
# Iter:    99 | Cost: 0.3637302 | Acc train: 0.9690000 | Acc validation: 0.9700000
# Iter:   100 | Cost: 0.3629271 | Acc train: 0.9710000 | Acc validation: 0.9800000
# Iter:   101 | Cost: 0.3609092 | Acc train: 0.9780000 | Acc validation: 0.9800000
# Iter:   102 | Cost: 0.3611776 | Acc train: 0.9780000 | Acc validation: 0.9800000
# Iter:   103 | Cost: 0.3614372 | Acc train: 0.9780000 | Acc validation: 0.9800000
# Iter:   104 | Cost: 0.3611064 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:   105 | Cost: 0.3608256 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:   106 | Cost: 0.3615935 | Acc train: 0.9840000 | Acc validation: 0.9800000
# Iter:   107 | Cost: 0.3645084 | Acc train: 0.9860000 | Acc validation: 0.9900000
# Iter:   108 | Cost: 0.3674245 | Acc train: 0.9870000 | Acc validation: 0.9900000
# Iter:   109 | Cost: 0.3715485 | Acc train: 0.9870000 | Acc validation: 0.9900000
# Iter:   110 | Cost: 0.3676057 | Acc train: 0.9860000 | Acc validation: 0.9900000
# Iter:   111 | Cost: 0.3634440 | Acc train: 0.9860000 | Acc validation: 0.9900000
# Iter:   112 | Cost: 0.3618708 | Acc train: 0.9860000 | Acc validation: 0.9900000
# Iter:   113 | Cost: 0.3596424 | Acc train: 0.9820000 | Acc validation: 0.9800000
# Iter:   114 | Cost: 0.3596933 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:   115 | Cost: 0.3629958 | Acc train: 0.9720000 | Acc validation: 0.9800000
# Iter:   116 | Cost: 0.3672263 | Acc train: 0.9580000 | Acc validation: 0.9700000
# Iter:   117 | Cost: 0.3693586 | Acc train: 0.9540000 | Acc validation: 0.9600000
# Iter:   118 | Cost: 0.3669153 | Acc train: 0.9580000 | Acc validation: 0.9700000
# Iter:   119 | Cost: 0.3636781 | Acc train: 0.9640000 | Acc validation: 0.9700000
# Iter:   120 | Cost: 0.3605261 | Acc train: 0.9760000 | Acc validation: 0.9800000
# 0.2
# Iter:     1 | Cost: 1.2202765 | Acc train: 0.4970000 | Acc validation: 0.4800000
# Iter:     2 | Cost: 1.2189247 | Acc train: 0.4970000 | Acc validation: 0.4800000
# Iter:     3 | Cost: 1.2174192 | Acc train: 0.4970000 | Acc validation: 0.4800000
# Iter:     4 | Cost: 1.2145039 | Acc train: 0.4960000 | Acc validation: 0.4800000
# Iter:     5 | Cost: 1.2107963 | Acc train: 0.4960000 | Acc validation: 0.4800000
# Iter:     6 | Cost: 1.2058565 | Acc train: 0.4910000 | Acc validation: 0.4800000
# Iter:     7 | Cost: 1.1993066 | Acc train: 0.4830000 | Acc validation: 0.4800000
# Iter:     8 | Cost: 1.1881593 | Acc train: 0.4770000 | Acc validation: 0.4600000
# Iter:     9 | Cost: 1.1751323 | Acc train: 0.4620000 | Acc validation: 0.4600000
# Iter:    10 | Cost: 1.1569384 | Acc train: 0.4470000 | Acc validation: 0.4500000
# Iter:    11 | Cost: 1.1339487 | Acc train: 0.4300000 | Acc validation: 0.4300000
# Iter:    12 | Cost: 1.1089276 | Acc train: 0.4130000 | Acc validation: 0.4000000
# Iter:    13 | Cost: 1.0773457 | Acc train: 0.3970000 | Acc validation: 0.3800000
# Iter:    14 | Cost: 1.0515857 | Acc train: 0.3880000 | Acc validation: 0.4000000
# Iter:    15 | Cost: 1.0282103 | Acc train: 0.4270000 | Acc validation: 0.4200000
# Iter:    16 | Cost: 1.0089305 | Acc train: 0.5290000 | Acc validation: 0.4700000
# Iter:    17 | Cost: 0.9924715 | Acc train: 0.6360000 | Acc validation: 0.5600000
# Iter:    18 | Cost: 0.9776699 | Acc train: 0.6700000 | Acc validation: 0.6200000
# Iter:    19 | Cost: 0.9582900 | Acc train: 0.6940000 | Acc validation: 0.6500000
# Iter:    20 | Cost: 0.9327056 | Acc train: 0.7210000 | Acc validation: 0.7000000
# Iter:    21 | Cost: 0.8987546 | Acc train: 0.7440000 | Acc validation: 0.7400000
# Iter:    22 | Cost: 0.8572555 | Acc train: 0.7740000 | Acc validation: 0.7800000
# Iter:    23 | Cost: 0.8080159 | Acc train: 0.8040000 | Acc validation: 0.8200000
# Iter:    24 | Cost: 0.7546735 | Acc train: 0.8360000 | Acc validation: 0.8200000
# Iter:    25 | Cost: 0.6995271 | Acc train: 0.8600000 | Acc validation: 0.8400000
# Iter:    26 | Cost: 0.6488236 | Acc train: 0.8880000 | Acc validation: 0.8700000
# Iter:    27 | Cost: 0.6030963 | Acc train: 0.9080000 | Acc validation: 0.9000000
# Iter:    28 | Cost: 0.5626556 | Acc train: 0.9280000 | Acc validation: 0.9500000
# Iter:    29 | Cost: 0.5293748 | Acc train: 0.9440000 | Acc validation: 0.9500000
# Iter:    30 | Cost: 0.5031133 | Acc train: 0.9650000 | Acc validation: 0.9500000
# Iter:    31 | Cost: 0.4828681 | Acc train: 0.9730000 | Acc validation: 0.9800000
# Iter:    65 | Cost: 0.4377922 | Acc train: 0.9340000 | Acc validation: 0.9400000
# Iter:    66 | Cost: 0.4393263 | Acc train: 0.9200000 | Acc validation: 0.9400000
# Iter:    67 | Cost: 0.4390684 | Acc train: 0.9200000 | Acc validation: 0.9400000
# Iter:    68 | Cost: 0.4376198 | Acc train: 0.9250000 | Acc validation: 0.9400000
# Iter:    69 | Cost: 0.4367598 | Acc train: 0.9320000 | Acc validation: 0.9400000
# Iter:    70 | Cost: 0.4350517 | Acc train: 0.9460000 | Acc validation: 0.9500000
# Iter:    71 | Cost: 0.4341830 | Acc train: 0.9550000 | Acc validation: 0.9600000
# Iter:    72 | Cost: 0.4340287 | Acc train: 0.9550000 | Acc validation: 0.9600000
# Iter:    73 | Cost: 0.4342122 | Acc train: 0.9530000 | Acc validation: 0.9600000
# Iter:    74 | Cost: 0.4337000 | Acc train: 0.9570000 | Acc validation: 0.9600000
# Iter:    75 | Cost: 0.4335198 | Acc train: 0.9580000 | Acc validation: 0.9700000
# Iter:    76 | Cost: 0.4330507 | Acc train: 0.9710000 | Acc validation: 0.9800000
# Iter:    77 | Cost: 0.4350309 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:    78 | Cost: 0.4370192 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:    79 | Cost: 0.4351789 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:    80 | Cost: 0.4344667 | Acc train: 0.9790000 | Acc validation: 0.9700000
# Iter:    81 | Cost: 0.4340275 | Acc train: 0.9780000 | Acc validation: 0.9700000
# Iter:    82 | Cost: 0.4347293 | Acc train: 0.9780000 | Acc validation: 0.9700000
# Iter:    83 | Cost: 0.4361272 | Acc train: 0.9760000 | Acc validation: 0.9700000
# Iter:    84 | Cost: 0.4378265 | Acc train: 0.9730000 | Acc validation: 0.9700000
# Iter:    85 | Cost: 0.4389661 | Acc train: 0.9740000 | Acc validation: 0.9700000
# Iter:    86 | Cost: 0.4408620 | Acc train: 0.9770000 | Acc validation: 0.9700000
# Iter:    87 | Cost: 0.4407175 | Acc train: 0.9720000 | Acc validation: 0.9600000
# Iter:    88 | Cost: 0.4400551 | Acc train: 0.9730000 | Acc validation: 0.9600000
# Iter:    89 | Cost: 0.4392293 | Acc train: 0.9750000 | Acc validation: 0.9700000
# Iter:    90 | Cost: 0.4380087 | Acc train: 0.9750000 | Acc validation: 0.9700000
# Iter:    91 | Cost: 0.4377612 | Acc train: 0.9710000 | Acc validation: 0.9700000
# Iter:    92 | Cost: 0.4370522 | Acc train: 0.9660000 | Acc validation: 0.9700000
# Iter:    93 | Cost: 0.4369613 | Acc train: 0.9650000 | Acc validation: 0.9700000
# Iter:    94 | Cost: 0.4391912 | Acc train: 0.9500000 | Acc validation: 0.9700000
# Iter:    95 | Cost: 0.4382337 | Acc train: 0.9500000 | Acc validation: 0.9700000
# Iter:    96 | Cost: 0.4362530 | Acc train: 0.9530000 | Acc validation: 0.9700000
# Iter:    97 | Cost: 0.4347788 | Acc train: 0.9550000 | Acc validation: 0.9700000
# Iter:    98 | Cost: 0.4338800 | Acc train: 0.9610000 | Acc validation: 0.9700000
# Iter:    99 | Cost: 0.4331383 | Acc train: 0.9690000 | Acc validation: 0.9800000
# Iter:   100 | Cost: 0.4338463 | Acc train: 0.9770000 | Acc validation: 0.9800000
# Iter:   101 | Cost: 0.4347070 | Acc train: 0.9780000 | Acc validation: 0.9800000
# Iter:   102 | Cost: 0.4355612 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:   103 | Cost: 0.4360354 | Acc train: 0.9800000 | Acc validation: 0.9800000
# Iter:   104 | Cost: 0.4380122 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:   105 | Cost: 0.4393703 | Acc train: 0.9820000 | Acc validation: 0.9800000
# Iter:   106 | Cost: 0.4396187 | Acc train: 0.9820000 | Acc validation: 0.9800000
# Iter:   107 | Cost: 0.4356572 | Acc train: 0.9810000 | Acc validation: 0.9800000
# Iter:   108 | Cost: 0.4327541 | Acc train: 0.9760000 | Acc validation: 0.9800000
# Iter:   109 | Cost: 0.4322900 | Acc train: 0.9680000 | Acc validation: 0.9800000
# Iter:   110 | Cost: 0.4322201 | Acc train: 0.9680000 | Acc validation: 0.9800000
# Iter:   111 | Cost: 0.4319959 | Acc train: 0.9720000 | Acc validation: 0.9800000
# Iter:   112 | Cost: 0.4323307 | Acc train: 0.9780000 | Acc validation: 0.9800000
# Iter:   113 | Cost: 0.4333465 | Acc train: 0.9790000 | Acc validation: 0.9800000
# Iter:   114 | Cost: 0.4352172 | Acc train: 0.9790000 | Acc validation: 0.9700000
# Iter:   115 | Cost: 0.4377178 | Acc train: 0.9850000 | Acc validation: 0.9700000
# Iter:   116 | Cost: 0.4407868 | Acc train: 0.9860000 | Acc validation: 0.9800000
# Iter:   117 | Cost: 0.4399182 | Acc train: 0.9860000 | Acc validation: 0.9800000
# Iter:   118 | Cost: 0.4369289 | Acc train: 0.9850000 | Acc validation: 0.9700000
# Iter:   119 | Cost: 0.4336400 | Acc train: 0.9790000 | Acc validation: 0.9700000
# Iter:   120 | Cost: 0.4327854 | Acc train: 0.9760000 | Acc validation: 0.9800000
# 0.3
# Iter:     1 | Cost: 1.6538896 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     2 | Cost: 1.6526812 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     3 | Cost: 1.6514347 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     4 | Cost: 1.6498632 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     5 | Cost: 1.6474894 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     6 | Cost: 1.6445499 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     7 | Cost: 1.6411434 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     8 | Cost: 1.6371857 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:     9 | Cost: 1.6320071 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    10 | Cost: 1.6256140 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    11 | Cost: 1.6176486 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    12 | Cost: 1.6082074 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    13 | Cost: 1.5965334 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    14 | Cost: 1.5827315 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    15 | Cost: 1.5656686 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    16 | Cost: 1.5461433 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    17 | Cost: 1.5224782 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    18 | Cost: 1.4942244 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    19 | Cost: 1.4595317 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    20 | Cost: 1.4183659 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    21 | Cost: 1.3711423 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    22 | Cost: 1.3141683 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    23 | Cost: 1.2517228 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    24 | Cost: 1.1870657 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    25 | Cost: 1.1151644 | Acc train: 0.5000000 | Acc validation: 0.5000000
# Iter:    26 | Cost: 1.0485061 | Acc train: 0.5010000 | Acc validation: 0.4900000
# Iter:    27 | Cost: 0.9838953 | Acc train: 0.4960000 | Acc validation: 0.5000000
# Iter:    28 | Cost: 0.9277301 | Acc train: 0.4870000 | Acc validation: 0.5000000
# Iter:    29 | Cost: 0.8812041 | Acc train: 0.4960000 | Acc validation: 0.4900000
# Iter:    30 | Cost: 0.8473512 | Acc train: 0.6940000 | Acc validation: 0.6400000
# Iter:    31 | Cost: 0.8226410 | Acc train: 0.7660000 | Acc validation: 0.7800000
# Iter:    32 | Cost: 0.8079678 | Acc train: 0.7440000 | Acc validation: 0.7700000
# Iter:    33 | Cost: 0.7973978 | Acc train: 0.7190000 | Acc validation: 0.7400000
# Iter:    34 | Cost: 0.7863625 | Acc train: 0.6740000 | Acc validation: 0.7400000
# Iter:    35 | Cost: 0.7715103 | Acc train: 0.6360000 | Acc validation: 0.7100000
# Iter:    36 | Cost: 0.7440342 | Acc train: 0.6160000 | Acc validation: 0.6400000
# Iter:    37 | Cost: 0.7025037 | Acc train: 0.6360000 | Acc validation: 0.6700000
# Iter:    38 | Cost: 0.6455142 | Acc train: 0.6860000 | Acc validation: 0.6900000
# Iter:    39 | Cost: 0.5866200 | Acc train: 0.7370000 | Acc validation: 0.7400000
# Iter:    40 | Cost: 0.5336781 | Acc train: 0.7890000 | Acc validation: 0.8000000
# Iter:    41 | Cost: 0.5024865 | Acc train: 0.8650000 | Acc validation: 0.8100000
# Iter:    42 | Cost: 0.4920240 | Acc train: 0.9260000 | Acc validation: 0.9000000
# Iter:    43 | Cost: 0.4919276 | Acc train: 0.9610000 | Acc validation: 0.9300000
# Iter:    77 | Cost: 0.7562708 | Acc train: 0.8310000 | Acc validation: 0.8300000
# Iter:    78 | Cost: 0.7594479 | Acc train: 0.8370000 | Acc validation: 0.8200000
# Iter:    79 | Cost: 0.7601765 | Acc train: 0.8370000 | Acc validation: 0.8200000
# Iter:    80 | Cost: 0.7596580 | Acc train: 0.8370000 | Acc validation: 0.8200000
# Iter:    81 | Cost: 0.7566137 | Acc train: 0.8330000 | Acc validation: 0.8200000
# Iter:    82 | Cost: 0.7545664 | Acc train: 0.8280000 | Acc validation: 0.8200000
# Iter:    83 | Cost: 0.7525747 | Acc train: 0.8240000 | Acc validation: 0.8300000
# Iter:    84 | Cost: 0.7513953 | Acc train: 0.8170000 | Acc validation: 0.8000000
# Iter:    85 | Cost: 0.7506563 | Acc train: 0.8130000 | Acc validation: 0.8000000
# Iter:    86 | Cost: 0.7502140 | Acc train: 0.8110000 | Acc validation: 0.8000000
# Iter:    87 | Cost: 0.7497281 | Acc train: 0.8080000 | Acc validation: 0.8000000
# Iter:    88 | Cost: 0.7497323 | Acc train: 0.8080000 | Acc validation: 0.8000000
# Iter:    89 | Cost: 0.7513864 | Acc train: 0.8200000 | Acc validation: 0.7900000
# Iter:    90 | Cost: 0.7510997 | Acc train: 0.8180000 | Acc validation: 0.7900000
# Iter:    91 | Cost: 0.7500575 | Acc train: 0.8110000 | Acc validation: 0.7900000
# Iter:    92 | Cost: 0.7492362 | Acc train: 0.8080000 | Acc validation: 0.7900000
# Iter:    93 | Cost: 0.7492104 | Acc train: 0.8080000 | Acc validation: 0.7900000
# Iter:    94 | Cost: 0.7491520 | Acc train: 0.8070000 | Acc validation: 0.7900000
# Iter:    95 | Cost: 0.7500135 | Acc train: 0.8100000 | Acc validation: 0.7900000
# Iter:    96 | Cost: 0.7528001 | Acc train: 0.8190000 | Acc validation: 0.8100000
# Iter:    97 | Cost: 0.7557918 | Acc train: 0.8250000 | Acc validation: 0.8200000
# Iter:    98 | Cost: 0.7569366 | Acc train: 0.8260000 | Acc validation: 0.8200000
# Iter:    99 | Cost: 0.7561881 | Acc train: 0.8240000 | Acc validation: 0.8200000
# Iter:   100 | Cost: 0.7524002 | Acc train: 0.8170000 | Acc validation: 0.7900000
# Iter:   101 | Cost: 0.7498157 | Acc train: 0.8070000 | Acc validation: 0.7800000
# Iter:   102 | Cost: 0.7486494 | Acc train: 0.8010000 | Acc validation: 0.7900000
# Iter:   103 | Cost: 0.7480011 | Acc train: 0.7900000 | Acc validation: 0.7700000
# Iter:   104 | Cost: 0.7478990 | Acc train: 0.7810000 | Acc validation: 0.7700000
# Iter:   105 | Cost: 0.7487499 | Acc train: 0.7610000 | Acc validation: 0.7700000
# Iter:   106 | Cost: 0.7530600 | Acc train: 0.7300000 | Acc validation: 0.7500000
# Iter:   107 | Cost: 0.7554556 | Acc train: 0.7200000 | Acc validation: 0.7500000
# Iter:   108 | Cost: 0.7558404 | Acc train: 0.7200000 | Acc validation: 0.7500000
# Iter:   109 | Cost: 0.7546938 | Acc train: 0.7200000 | Acc validation: 0.7500000
594, 0.3243361329729211, 0.32185509009514673, 0.3176891382422451, 0.31708484176646357, 0.31637865064064147, 0.3139240420138143, 0.31522125731893785, 0.3155947304438808, 0.31287980633627904, 0.3093539849870771, 0.3091748310599633, 0.3105768837624356, 0.31008566643205776, 0.30720023174306266, 0.3063621702217162, 0.30623620780058036, 0.30851431282373215, 0.310368928751368, 0.30600783473426263, 0.3036909466435331, 0.30417159344893363, 0.3052019353177269, 0.3055938605420138, 0.30488350352101334, 0.30315288106549765, 0.3056372745936698, 0.3099413663475985, 0.3063135016895252, 0.3025902551649534, 0.3056301215290873, 0.31 ...

# %%
#plot 1:

plt.figure(figsize=(18, 4))
plt.subplot(1, 3, 1)

plt.plot([i for i in range(120)],his1[0], label = 'noiseless')
plt.plot([i for i in range(120)],his1[1], label = 'Amplitude damping p=0.1', linestyle="--")
plt.plot([i for i in range(120)],his1[2], label = 'Amplitude damping p=0.2', linestyle="--")
plt.plot([i for i in range(120)],his1[3], label = 'Amplitude damping p=0.3', linestyle="--")
plt.plot([i for i in range(120)],his1[4], label = 'Bit flip p=0.1', linestyle="-.")
plt.plot([i for i in range(120)],his1[5], label = 'Bit flip p=0.2', linestyle="-.")
plt.plot([i for i in range(120)],his1[6], label = 'Bit flip p=0.3', linestyle="-.")
#plt.ylim((0.7, 1.05))
plt.xlabel('Training steps')
plt.ylabel('Test accuracy')
plt.legend()
#plt.title("plot 1")

plt.subplot(1, 3, 2)

plt.plot([i for i in range(120)],his2[0], label = 'noiseless')
plt.plot([i for i in range(120)],his2[1], label = 'Amplitude damping p=0.1', linestyle="--")
plt.plot([i for i in range(120)],his2[2], label = 'Amplitude damping p=0.2', linestyle="--")
plt.plot([i for i in range(120)],his2[3], label = 'Amplitude damping p=0.3', linestyle="--")
plt.plot([i for i in range(120)],his2[4], label = 'Bit flip p=0.1', linestyle="-.")
plt.plot([i for i in range(120)],his2[5], label = 'Bit flip p=0.2', linestyle="-.")
plt.plot([i for i in range(120)],his2[6], label = 'Bit flip p=0.3', linestyle="-.")
#plt.ylim((0.6, 1.05))
plt.xlabel('Training steps')
plt.ylabel('Train accuracy')
plt.legend()
#plt.title("plot 2")

plt.subplot(1, 3, 3)

plt.plot([i for i in range(120)],his3[0], label = 'noiseless')
plt.plot([i for i in range(120)],his3[1], label = 'Amplitude damping p=0.1', linestyle="--")
plt.plot([i for i in range(120)],his3[2], label = 'Amplitude damping p=0.2', linestyle="--")
plt.plot([i for i in range(120)],his3[3], label = 'Amplitude damping p=0.3', linestyle="--")
plt.plot([i for i in range(120)],his3[4], label = 'Bit flip p=0.1', linestyle="-.")
plt.plot([i for i in range(120)],his3[5], label = 'Bit flip p=0.2', linestyle="-.")
plt.plot([i for i in range(120)],his3[6], label = 'Bit flip p=0.3', linestyle="-.")
#plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Cost function')
plt.legend()
#plt.title("plot 2")

#plt.suptitle("RUNOOB subplot Test")
plt.savefig('Amplitude_Encoding_Hardware_efficient_ansatz5',dpi=800,bbox_inches='tight')
plt.show()
