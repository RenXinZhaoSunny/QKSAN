# %%
import pennylane as qml
from pennylane import numpy as np
from sklearn.decomposition import PCA
import random
from collections import Counter
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
wire = 2

wires = wire * 2
dim = 2 ** wire
dim1 = 2 * dim
dev = qml.device('default.mixed', wires=wires)
#dev = qml.device("lightning.qubit", wires=wires, shots=None)
#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
dev1 = qml.device("lightning.qubit", wires=wire, shots=None)
wires = dev.wires.tolist()

@qml.qnode(dev1)
def StateVector(x):
    qml.AmplitudeEmbedding(features=x, wires=range(wire), 
                           pad_with=0.0, normalize=True)
    return qml.state()

def accuracy(labels, predictions):

    loss = 0
    for l, p in zip(labels, predictions):
        if abs(l - p) < 1e-5:
            loss = loss + 1
    loss = loss / len(labels)

    return loss

def square_loss(labels, predictions):
    loss = 0
    for l, p in zip(labels, predictions):
        loss = loss + (l - p) ** 2

    loss = loss / len(labels)
    return loss

def noramlization(data):
    minVals = data.min(0)
    maxVals = data.max(0)
    ranges = maxVals - minVals
    normData = np.zeros(np.shape(data))
    m = data.shape[0]
    normData = data - np.tile(minVals, (m, 1))
    normData = normData/np.tile(ranges, (m, 1))
    return normData

def random_params(num_wires):
    """Generate random variational parameters in the shape for the ansatz."""
    return np.random.uniform(0, 2 * np.pi, num_wires, requires_grad=True)

num_para = int(wire + (wire - 1) * wire / 2)
params_init = random_params(3 * num_para + wire)
print(params_init)
# Out:
# [1.27531311 1.28358038 4.60891208 5.50082197 3.21302315 2.09896899
#  4.23666859 1.02095352 0.27892477 1.34758691 4.35060956]

# %%
def ProcessingData(datapoints, train_size, test_size):
    train_data = np.loadtxt("./mnist_train.csv", delimiter=",")
    #Extracting features and labels from the dataset 
    train_data_features = train_data[:datapoints, 1:]
    train_data_labels = train_data[:datapoints, :1].reshape(datapoints,)

    # Use PCA technique to reduce dimensions to 4
    DimReduce = PCA(n_components= dim1)
    train_data_features_reduced = DimReduce.fit_transform(train_data_features)
    # normalize dataset
    train_data_features_reduced = noramlization(train_data_features_reduced)
    s1 = np.array([StateVector(x) for x in train_data_features_reduced[:,:dim]])
    s2 = np.array([StateVector(x) for x in train_data_features_reduced[:,dim:dim1]])
    train_data_features_reduced = np.hstack((s1, s2)).tolist()

    zero_one_datapoint_array = []
    label_0_1 = []
    zero_datapoints_array = [] #an array of the data points containing value 0
    one_datapoints_array = []# an array of the data points containing value 1
    label_0 = []
    label_1 = []

    for i in range(datapoints):
        if train_data_labels[i] == 0:                   # extracting zeros
            label_0.append(-1)
            zero_datapoints_array.append(train_data_features_reduced[i])
        elif train_data_labels[i] == 1:                   # extracting ones
            label_1.append(1)
            one_datapoints_array.append(train_data_features_reduced[i]) 

    if (len(label_0) + len(label_1)) < 2 * (train_size + test_size):
        print("datapoints is too small!")
    else:
        print((len(label_0),len(label_1)))
        zero_datapoints_array_train = zero_datapoints_array[:train_size]
        one_datapoints_array_train = one_datapoints_array[:train_size]
        label_0_train = label_0[:train_size]
        label_1_train = label_1[:train_size]
        zero_datapoints_array_test = zero_datapoints_array[train_size + 1:train_size + test_size + 1]
        one_datapoints_array_test = one_datapoints_array[train_size + 1:train_size + test_size + 1]
        label_0_test = label_0[train_size + 1:train_size + test_size + 1]
        label_1_test = label_1[train_size + 1:train_size + test_size + 1]
        #print(len(zero_datapoints_array_train), len(label_1_train))
        #print(len(one_datapoints_array_test), len(label_0_test))

        zero_one_datapoint_array_train = zero_datapoints_array_train + one_datapoints_array_train
        label_0_1_train = label_0_train + label_1_train
        zero_one_datapoint_array_test = zero_datapoints_array_test + one_datapoints_array_test
        label_0_1_test = label_0_test + label_1_test
        #print(len(zero_one_datapoint_array_train), label_0_1_train)
        #print(len(zero_one_datapoint_array_test), label_0_1_test)

        np.random.seed(10)
        index_train = np.random.permutation(range(2 * train_size))
        index_test = np.random.permutation(range(2 * test_size))

        feats_train = []
        Y_train = []
        feats_val = []
        Y_val = []
        for i in range(2 * train_size):
            feats_train.append(zero_one_datapoint_array_train[index_train[i]])
            Y_train.append(label_0_1_train[index_train[i]])


        for i in range(2 * test_size):
            feats_val.append(zero_one_datapoint_array_test[index_test[i]])
            Y_val.append(label_0_1_test[index_test[i]])

        #print(feats_val, Y_val)

        features = feats_train + feats_val
        features = np.array(features, requires_grad=False)
        Y = Y_train + Y_val
        Y = np.array(Y, requires_grad=False)
        feats_train = np.array(feats_train, requires_grad=False)
        Y_train = np.array(Y_train, requires_grad=False)
        feats_val = np.array(feats_val, requires_grad=False)
        Y_val = np.array(Y_val, requires_grad=False)
    return feats_train, Y_train, feats_val, Y_val, features, Y

datapoints = 6000
train_size = 500
test_size = 50
feats_train, Y_train, feats_val, Y_val, features, Y = ProcessingData(datapoints, train_size, test_size)
# Out:
# (592, 671)

# %%
#Block-encoding + Hardware-efficient Ansatz
def DataEncoding(x, wires_start, wires_end):
    wires = np.arange(wires_start, wires_end).tolist()
    qml.RX(x[0], wires=wires_start)
    qml.RX(x[1], wires=wires_start + 1)
    qml.RY(x[2], wires=wires_start)
    qml.RY(x[3], wires=wires_start + 1)
    #qml.AmplitudeEmbedding(features=x, wires=wires, pad_with=0., normalize=True)

def Ansatz(params, wires_start, wires_end):
    for i in np.arange(wires_start, wires_end):
        qml.Hadamard(wires=wires[i])
        qml.RY(params[i - wires_start], wires=wires[i])
        #print(i)
    for i in np.arange(wires_start, wires_end):
        for j in np.arange(i + 1, wires_end):
            qml.CRZ(params[i - wires_start + wires_end - wires_start], wires=[wires[i], wires[j]])

p = 0
#@qml.qnode(dev, interface="torch", diff_method="parameter-shift")
@qml.qnode(dev)
def QKSAN(feat, params):
    x1 = feat[0:4]
    x2 = feat[4:8]
    DataEncoding(x1, 0, wire)
    Ansatz(params[0: num_para], 0, wire)
    qml.adjoint(Ansatz)(params[num_para: 2 * num_para], 0, wire)
    qml.adjoint(DataEncoding)(x2, 0, wire)


    DataEncoding(x2, wire, (2 * wire))
    Ansatz(params[2 * num_para: 3 * num_para], wire, (2 * wire))
    if p != 0:
        for i in range(2 * wire):
            qml.AmplitudeDamping(p, wires=i)
    for i in range(wire):
        qml.cond(qml.measure(i), qml.RY)(params[3 * num_para + i], wires=wires[i + wire])
    return qml.expval(qml.PauliZ(2 * wire - 1))

qml.drawer.use_style('black_white')
fig, ax = qml.draw_mpl(QKSAN, show_all_wires=True)(feats_train[0], params_init)
fig.set_size_inches((7, 5))

def variational_classifier(params, feat):
    return QKSAN(feat, params)


def cost(params, features, labels):
    predictions = [variational_classifier(params, feat) for feat in features]
    return square_loss(labels, predictions)

def TrainQKSAN(params_init):
    opt = qml.NesterovMomentumOptimizer(0.09)
    batch_size = 30
    weights = params_init
    #bias = np.array(0.0, requires_grad=True)
    his_acc_val = []
    his_acc_train = []
    his_cost = []
    f1_train = []
    f1_test = []
    roc_auc_train = []
    roc_auc_test = []
    for it in range(120):

        # Update the weights by one optimizer step
        batch_index = np.random.randint(0, 2 * train_size, (batch_size,))
        feats_train_batch = feats_train[batch_index]
        Y_train_batch = Y_train[batch_index]
        
        weights, _, _ = opt.step(cost, weights, feats_train_batch, Y_train_batch)

        # Compute predictions on train and validation set
        predictions_train = [np.sign(variational_classifier(weights, feat)) for feat in feats_train]
        predictions_val = [np.sign(variational_classifier(weights, feat)) for feat in feats_val]
        #print(probs(Y_train, predictions_val))
        c = cost(weights, features, Y).numpy()
        #print(c)
        # Compute accuracy on train and validation set
        acc_train = accuracy_score(Y_train, predictions_train)
        acc_val = accuracy_score(Y_val, predictions_val)
        a = f1_score(Y_train, predictions_train)
        b = f1_score(Y_val, predictions_val)
        
        print("f1_score is", a, b)
        d = roc_auc_score(Y_train, predictions_train)
        e = roc_auc_score(Y_val, predictions_val)
        print("roc_auc_score is", d, e)


        f1_train.append(a)
        f1_test.append(b)
        roc_auc_train.append(d)
        roc_auc_test.append(e)
        his_acc_val.append(acc_val)
        his_acc_train.append(acc_train)
        his_cost.append(c)
        print("Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
            "".format(it + 1, c, acc_train, acc_val))
    print(p)
    return his_acc_val, his_acc_train, his_cost, f1_train, f1_test, roc_auc_train, roc_auc_test

# %%
ps = [0, 0.1, 0.2, 0.3]
his1 = []
his2 = []
his3 = []

for p in ps:
    his_acc_val, his_acc_train, his_cost, _, _, _, _ = TrainQKSAN(params_init)
    his1.append(his_acc_val)
    his2.append(his_acc_train)
    his3.append(his_cost)
# Out:
# f1_score is 0.0 0.0
# roc_auc_score is 0.5 0.5
# Iter:     1 | Cost: 1.0623065 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.499 0.5
# Iter:     2 | Cost: 1.0440390 | Acc train: 0.4990000 | Acc validation: 0.5000000
# f1_score is 0.0 0.0
# roc_auc_score is 0.498 0.5
# Iter:     3 | Cost: 1.0195407 | Acc train: 0.4980000 | Acc validation: 0.5000000
# f1_score is 0.0037593984962406013 0.0
# roc_auc_score is 0.47 0.48
# Iter:     4 | Cost: 0.9927581 | Acc train: 0.4700000 | Acc validation: 0.4800000
# f1_score is 0.030405405405405404 0.03508771929824562
# roc_auc_score is 0.426 0.45
# Iter:     5 | Cost: 0.9727537 | Acc train: 0.4260000 | Acc validation: 0.4500000
# f1_score is 0.31299734748010605 0.17142857142857143
# roc_auc_score is 0.482 0.42
# Iter:     6 | Cost: 0.9566355 | Acc train: 0.4820000 | Acc validation: 0.4200000
# f1_score is 0.765840220385675 0.7339449541284404
# roc_auc_score is 0.7450000000000001 0.7100000000000001
# Iter:     7 | Cost: 0.9443678 | Acc train: 0.7450000 | Acc validation: 0.7100000
# f1_score is 0.8051529790660226 0.8
# roc_auc_score is 0.758 0.75
# Iter:     8 | Cost: 0.9350682 | Acc train: 0.7580000 | Acc validation: 0.7500000
# f1_score is 0.7698229407236336 0.7633587786259541
# roc_auc_score is 0.7010000000000001 0.69
# Iter:     9 | Cost: 0.9286042 | Acc train: 0.7010000 | Acc validation: 0.6900000
# f1_score is 0.7680491551459293 0.7462686567164178
# roc_auc_score is 0.698 0.6599999999999999
# Iter:    10 | Cost: 0.9208846 | Acc train: 0.6980000 | Acc validation: 0.6600000
# f1_score is 0.7668711656441717 0.7407407407407407
# roc_auc_score is 0.696 0.65
# Iter:    11 | Cost: 0.9135723 | Acc train: 0.6960000 | Acc validation: 0.6500000
# f1_score is 0.7564296520423601 0.7352941176470588
# roc_auc_score is 0.6779999999999999 0.64
# Iter:    12 | Cost: 0.9087611 | Acc train: 0.6780000 | Acc validation: 0.6400000
# f1_score is 0.731528895391368 0.7246376811594203
# roc_auc_score is 0.633 0.62
# Iter:    13 | Cost: 0.9070444 | Acc train: 0.6330000 | Acc validation: 0.6200000
# f1_score is 0.7299270072992701 0.7194244604316548
# roc_auc_score is 0.63 0.61
# Iter:    14 | Cost: 0.9027176 | Acc train: 0.6300000 | Acc validation: 0.6100000
# f1_score is 0.724112961622013 0.7092198581560284
# roc_auc_score is 0.619 0.5900000000000001
# Iter:    15 | Cost: 0.9004421 | Acc train: 0.6190000 | Acc validation: 0.5900000
# f1_score is 0.7127583749109052 0.7092198581560284
# roc_auc_score is 0.597 0.5900000000000001
# Iter:    16 | Cost: 0.9030524 | Acc train: 0.5970000 | Acc validation: 0.5900000
# f1_score is 0.7092198581560284 0.7092198581560284
# roc_auc_score is 0.5900000000000001 0.5900000000000001
# Iter:    17 | Cost: 0.9015318 | Acc train: 0.5900000 | Acc validation: 0.5900000
# f1_score is 0.7142857142857143 0.7092198581560284
# roc_auc_score is 0.6 0.5900000000000001
# Iter:    18 | Cost: 0.8981885 | Acc train: 0.6000000 | Acc validation: 0.5900000
# f1_score is 0.7185025197984162 0.7092198581560284
# roc_auc_score is 0.609 0.5900000000000001
# Iter:    19 | Cost: 0.8936600 | Acc train: 0.6090000 | Acc validation: 0.5900000
# f1_score is 0.7300658376005852 0.7194244604316548
# roc_auc_score is 0.631 0.61
# Iter:    20 | Cost: 0.8860489 | Acc train: 0.6310000 | Acc validation: 0.6100000
# f1_score is 0.7458893871449925 0.7407407407407407
# roc_auc_score is 0.6599999999999999 0.65
# Iter:    21 | Cost: 0.8808607 | Acc train: 0.6600000 | Acc validation: 0.6500000
# f1_score is 0.8262676641729011 0.8403361344537814
# roc_auc_score is 0.791 0.81
# Iter:    22 | Cost: 0.8680003 | Acc train: 0.7910000 | Acc validation: 0.8100000
# f1_score is 0.8716094032549728 0.8990825688073395
# roc_auc_score is 0.858 0.89
# Iter:    23 | Cost: 0.8617871 | Acc train: 0.8580000 | Acc validation: 0.8900000
# f1_score is 0.8237704918032788 0.8571428571428572
# roc_auc_score is 0.828 0.86
# Iter:    24 | Cost: 0.8612272 | Acc train: 0.8280000 | Acc validation: 0.8600000
# f1_score is 0.7883369330453563 0.8210526315789474
# roc_auc_score is 0.8039999999999999 0.83
# Iter:    25 | Cost: 0.8598174 | Acc train: 0.8040000 | Acc validation: 0.8300000
# f1_score is 0.698450536352801 0.7586206896551725
# roc_auc_score is 0.7469999999999999 0.79
# Iter:    26 | Cost: 0.8591770 | Acc train: 0.7470000 | Acc validation: 0.7900000
# f1_score is 0.6779661016949153 0.7441860465116279
# roc_auc_score is 0.7340000000000001 0.78
# Iter:    27 | Cost: 0.8568008 | Acc train: 0.7340000 | Acc validation: 0.7800000
# f1_score is 0.5474254742547425 0.6233766233766234
# roc_auc_score is 0.666 0.71
# Iter:    28 | Cost: 0.8565045 | Acc train: 0.6660000 | Acc validation: 0.7100000
# f1_score is 0.619108280254777 0.6829268292682927
# roc_auc_score is 0.701 0.74
# Iter:    29 | Cost: 0.8520253 | Acc train: 0.7010000 | Acc validation: 0.7400000
# f1_score is 0.8178053830227744 0.8571428571428572
# roc_auc_score is 0.824 0.86
# Iter:    30 | Cost: 0.8438179 | Acc train: 0.8240000 | Acc validation: 0.8600000
# f1_score is 0.8595505617977528 0.888888888888889
# roc_auc_score is 0.8500000000000001 0.88
# Iter:    31 | Cost: 0.8376737 | Acc train: 0.8500000 | Acc validation: 0.8800000
# f1_score is 0.872398190045249 0.890909090909091
# roc_auc_score is 0.859 0.88
# Iter:    32 | Cost: 0.8332320 | Acc train: 0.8590000 | Acc validation: 0.8800000
# f1_score is 0.8726625111308993 0.882882882882883
# roc_auc_score is 0.857 0.87
# Iter:    33 | Cost: 0.8293419 | Acc train: 0.8570000 | Acc validation: 0.8700000
# f1_score is 0.8715677590788308 0.882882882882883
# roc_auc_score is 0.855 0.87
# Iter:    34 | Cost: 0.8255054 | Acc train: 0.8550000 | Acc validation: 0.8700000
# f1_score is 0.862882096069869 0.882882882882883
# roc_auc_score is 0.843 0.87
# Iter:    35 | Cost: 0.8216931 | Acc train: 0.8430000 | Acc validation: 0.8700000
# f1_score is 0.8648648648648648 0.8749999999999999
# roc_auc_score is 0.845 0.8600000000000001
# Iter:    36 | Cost: 0.8176862 | Acc train: 0.8450000 | Acc validation: 0.8600000
# f1_score is 0.8613518197573657 0.8672566371681417
# roc_auc_score is 0.84 0.85
# Iter:    37 | Cost: 0.8139272 | Acc train: 0.8400000 | Acc validation: 0.8500000
# f1_score is 0.8666085440278989 0.8749999999999999
# roc_auc_score is 0.847 0.8600000000000001
# Iter:    38 | Cost: 0.8094519 | Acc train: 0.8470000 | Acc validation: 0.8600000
# f1_score is 0.8696412948381452 0.8749999999999999
# roc_auc_score is 0.851 0.8600000000000001
# Iter:    39 | Cost: 0.8050181 | Acc train: 0.8510000 | Acc validation: 0.8600000
# f1_score is 0.860344827586207 0.8620689655172413
# roc_auc_score is 0.838 0.84
# Iter:    40 | Cost: 0.8019116 | Acc train: 0.8380000 | Acc validation: 0.8400000
# f1_score is 0.8365465213746857 0.8333333333333333
# roc_auc_score is 0.805 0.8
# Iter:    41 | Cost: 0.8009858 | Acc train: 0.8050000 | Acc validation: 0.8000000
# f1_score is 0.8146938775510204 0.8064516129032258
# roc_auc_score is 0.773 0.76
# Iter:    42 | Cost: 0.8004442 | Acc train: 0.7730000 | Acc validation: 0.7600000
# f1_score is 0.8429054054054054 0.8403361344537814
# roc_auc_score is 0.814 0.81
# Iter:    43 | Cost: 0.7919456 | Acc train: 0.8140000 | Acc validation: 0.8100000
# f1_score is 0.8508098891730606 0.8474576271186441
# roc_auc_score is 0.8250000000000001 0.8200000000000001
# Iter:    44 | Cost: 0.7867801 | Acc train: 0.8250000 | Acc validation: 0.8200000
# f1_score is 0.8783068783068784 0.9009009009009009
# roc_auc_score is 0.862 0.89
# Iter:    45 | Cost: 0.7799766 | Acc train: 0.8620000 | Acc validation: 0.8900000
# f1_score is 0.8865058087578194 0.9009009009009009
# roc_auc_score is 0.873 0.89
# Iter:    46 | Cost: 0.7760805 | Acc train: 0.8730000 | Acc validation: 0.8900000
# f1_score is 0.9073900841908324 0.8867924528301886
# roc_auc_score is 0.9009999999999999 0.88
# Iter:    47 | Cost: 0.7757117 | Acc train: 0.9010000 | Acc validation: 0.8800000
# f1_score is 0.9089219330855018 0.8867924528301886
# roc_auc_score is 0.902 0.88
# Iter:    48 | Cost: 0.7714504 | Acc train: 0.9020000 | Acc validation: 0.8800000
# f1_score is 0.8979963570127504 0.9009009009009009
# roc_auc_score is 0.888 0.89
# Iter:    49 | Cost: 0.7655733 | Acc train: 0.8880000 | Acc validation: 0.8900000
# f1_score is 0.8963636363636365 0.9009009009009009
# roc_auc_score is 0.886 0.89
# Iter:    50 | Cost: 0.7619355 | Acc train: 0.8860000 | Acc validation: 0.8900000
# f1_score is 0.8906810035842293 0.9009009009009009
# roc_auc_score is 0.878 0.89
# Iter:    51 | Cost: 0.7579191 | Acc train: 0.8780000 | Acc validation: 0.8900000
# f1_score is 0.8935018050541517 0.9009009009009009
# roc_auc_score is 0.882 0.89
# Iter:    52 | Cost: 0.7546899 | Acc train: 0.8820000 | Acc validation: 0.8900000
# f1_score is 0.8851291184327693 0.9009009009009009
# roc_auc_score is 0.871 0.89
# Iter:    53 | Cost: 0.7513577 | Acc train: 0.8710000 | Acc validation: 0.8900000
# f1_score is 0.8986301369863013 0.9009009009009009
# roc_auc_score is 0.889 0.89
# Iter:    54 | Cost: 0.7490337 | Acc train: 0.8890000 | Acc validation: 0.8900000
# f1_score is 0.9065420560747663 0.8598130841121495
# roc_auc_score is 0.9 0.85
# Iter:    55 | Cost: 0.7486337 | Acc train: 0.9000000 | Acc validation: 0.8500000
# f1_score is 0.8451282051282051 0.7999999999999999
# roc_auc_score is 0.8489999999999999 0.8200000000000001
# Iter:    56 | Cost: 0.7530894 | Acc train: 0.8490000 | Acc validation: 0.8200000
# f1_score is 0.8397104446742502 0.8131868131868132
# roc_auc_score is 0.8450000000000001 0.83
# Iter:    57 | Cost: 0.7511124 | Acc train: 0.8450000 | Acc validation: 0.8300000
# f1_score is 0.8897411313518697 0.8235294117647058
# roc_auc_score is 0.885 0.82
# Iter:    58 | Cost: 0.7441312 | Acc train: 0.8850000 | Acc validation: 0.8200000
# f1_score is 0.8992673992673992 0.8807339449541285
# roc_auc_score is 0.89 0.87
# Iter:    59 | Cost: 0.7397553 | Acc train: 0.8900000 | Acc validation: 0.8700000
# f1_score is 0.8839285714285715 0.9009009009009009
# roc_auc_score is 0.87 0.89
# Iter:    60 | Cost: 0.7386660 | Acc train: 0.8700000 | Acc validation: 0.8900000
# f1_score is 0.8798586572438163 0.9009009009009009
# roc_auc_score is 0.864 0.89
# Iter:    61 | Cost: 0.7384864 | Acc train: 0.8640000 | Acc validation: 0.8900000
# f1_score is 0.8706293706293705 0.9009009009009009
# roc_auc_score is 0.852 0.89
# Iter:    62 | Cost: 0.7390233 | Acc train: 0.8520000 | Acc validation: 0.8900000
# f1_score is 0.855917667238422 0.8620689655172413
# roc_auc_score is 0.8319999999999999 0.84
# Iter:    63 | Cost: 0.7418521 | Acc train: 0.8320000 | Acc validation: 0.8400000
# f1_score is 0.8660869565217392 0.8771929824561403
# roc_auc_score is 0.846 0.86
# Iter:    64 | Cost: 0.7398876 | Acc train: 0.8460000 | Acc validation: 0.8600000
# f1_score is 0.8556701030927835 0.8695652173913044
# roc_auc_score is 0.832 0.85
# Iter:    65 | Cost: 0.7415411 | Acc train: 0.8320000 | Acc validation: 0.8500000
# f1_score is 0.8532423208191127 0.8547008547008548
# roc_auc_score is 0.8280000000000001 0.83
# Iter:    66 | Cost: 0.7424327 | Acc train: 0.8280000 | Acc validation: 0.8300000
# f1_score is 0.8244023083264632 0.819672131147541
# roc_auc_score is 0.787 0.78
# Iter:    67 | Cost: 0.7498015 | Acc train: 0.7870000 | Acc validation: 0.7800000
# f1_score is 0.8271298593879239 0.819672131147541
# roc_auc_score is 0.791 0.78
# Iter:    68 | Cost: 0.7491465 | Acc train: 0.7910000 | Acc validation: 0.7800000
# f1_score is 0.8438818565400844 0.8333333333333333
# roc_auc_score is 0.815 0.8
# Iter:    69 | Cost: 0.7442884 | Acc train: 0.8150000 | Acc validation: 0.8000000
# f1_score is 0.859603789836348 0.8695652173913044
# roc_auc_score is 0.837 0.85
# Iter:    70 | Cost: 0.7403246 | Acc train: 0.8370000 | Acc validation: 0.8500000
# f1_score is 0.8968692449355433 0.8679245283018867
# roc_auc_score is 0.888 0.86
# Iter:    71 | Cost: 0.7361657 | Acc train: 0.8880000 | Acc validation: 0.8600000
# f1_score is 0.868605817452357 0.816326530612245
# roc_auc_score is 0.8690000000000001 0.8200000000000001
# Iter:    72 | Cost: 0.7386103 | Acc train: 0.8690000 | Acc validation: 0.8200000
# f1_score is 0.8968779564806055 0.8543689320388349
# roc_auc_score is 0.8909999999999999 0.8500000000000001
# Iter:    73 | Cost: 0.7363549 | Acc train: 0.8910000 | Acc validation: 0.8500000
# f1_score is 0.8997240110395583 0.8785046728971964
# roc_auc_score is 0.8910000000000001 0.87
# Iter:    74 | Cost: 0.7351537 | Acc train: 0.8910000 | Acc validation: 0.8700000
# f1_score is 0.8648180242634316 0.8695652173913044
# roc_auc_score is 0.844 0.85
# Iter:    75 | Cost: 0.7378444 | Acc train: 0.8440000 | Acc validation: 0.8500000
# f1_score is 0.8496176720475785 0.8474576271186441
# roc_auc_score is 0.823 0.8200000000000001
# Iter:    76 | Cost: 0.7412961 | Acc train: 0.8230000 | Acc validation: 0.8200000
# f1_score is 0.8588640275387264 0.8695652173913044
# roc_auc_score is 0.836 0.85
# Iter:    77 | Cost: 0.7383755 | Acc train: 0.8360000 | Acc validation: 0.8500000
# f1_score is 0.8648180242634316 0.8695652173913044
# roc_auc_score is 0.844 0.85
# Iter:    78 | Cost: 0.7368695 | Acc train: 0.8440000 | Acc validation: 0.8500000
# f1_score is 0.891674127126231 0.9009009009009009
# roc_auc_score is 0.879 0.89
# Iter:    79 | Cost: 0.7335170 | Acc train: 0.8790000 | Acc validation: 0.8900000
# f1_score is 0.9124767225325885 0.8867924528301886
# roc_auc_score is 0.9059999999999999 0.88
# Iter:    80 | Cost: 0.7338926 | Acc train: 0.9060000 | Acc validation: 0.8800000
# f1_score is 0.9124767225325885 0.8867924528301886
# roc_auc_score is 0.9059999999999999 0.88
# Iter:    81 | Cost: 0.7337578 | Acc train: 0.9060000 | Acc validation: 0.8800000
# f1_score is 0.9128014842300557 0.8971962616822429
# roc_auc_score is 0.9060000000000001 0.8900000000000001
# Iter:    82 | Cost: 0.7333717 | Acc train: 0.9060000 | Acc validation: 0.8900000
# f1_score is 0.8789420142421159 0.8421052631578948
# roc_auc_score is 0.881 0.8500000000000001
# Iter:    83 | Cost: 0.7377890 | Acc train: 0.8810000 | Acc validation: 0.8500000
# f1_score is 0.8272138228941686 0.7380952380952381
# roc_auc_score is 0.8400000000000001 0.7799999999999999
# Iter:    84 | Cost: 0.7420920 | Acc train: 0.8400000 | Acc validation: 0.7800000
# f1_score is 0.7473560517038779 0.5428571428571428
# roc_auc_score is 0.785 0.6799999999999999
# Iter:    85 | Cost: 0.7481764 | Acc train: 0.7850000 | Acc validation: 0.6800000
# f1_score is 0.7455621301775148 0.5352112676056339
# roc_auc_score is 0.7849999999999999 0.6699999999999999
# Iter:    86 | Cost: 0.7482642 | Acc train: 0.7850000 | Acc validation: 0.6700000
# f1_score is 0.7410926365795725 0.5352112676056339
# roc_auc_score is 0.7819999999999999 0.6699999999999999
# Iter:    87 | Cost: 0.7482500 | Acc train: 0.7820000 | Acc validation: 0.6700000
# f1_score is 0.7233009708737864 0.4927536231884058
# roc_auc_score is 0.7719999999999999 0.65
# Iter:    88 | Cost: 0.7502151 | Acc train: 0.7720000 | Acc validation: 0.6500000
# f1_score is 0.8426610348468849 0.8172043010752689
# roc_auc_score is 0.8510000000000001 0.8300000000000001
# Iter:    89 | Cost: 0.7385937 | Acc train: 0.8510000 | Acc validation: 0.8300000
# f1_score is 0.9089184060721062 0.8543689320388349
# roc_auc_score is 0.9039999999999999 0.8500000000000001
# Iter:    90 | Cost: 0.7338161 | Acc train: 0.9040000 | Acc validation: 0.8500000
# f1_score is 0.906567992599445 0.8867924528301886
# roc_auc_score is 0.8990000000000001 0.88
# Iter:    91 | Cost: 0.7330761 | Acc train: 0.8990000 | Acc validation: 0.8800000
# f1_score is 0.8859180035650623 0.8849557522123894
# roc_auc_score is 0.872 0.87
# Iter:    92 | Cost: 0.7336324 | Acc train: 0.8720000 | Acc validation: 0.8700000
# f1_score is 0.8610871440897325 0.8695652173913044
# roc_auc_score is 0.839 0.85
# Iter:    93 | Cost: 0.7375331 | Acc train: 0.8390000 | Acc validation: 0.8500000
# f1_score is 0.8551842330762639 0.8620689655172413
# roc_auc_score is 0.831 0.84
# Iter:    94 | Cost: 0.7386319 | Acc train: 0.8310000 | Acc validation: 0.8400000
# f1_score is 0.8618307426597582 0.8695652173913044
# roc_auc_score is 0.84 0.85
# Iter:    95 | Cost: 0.7372410 | Acc train: 0.8400000 | Acc validation: 0.8500000
# f1_score is 0.8648180242634316 0.8695652173913044
# roc_auc_score is 0.844 0.85
# Iter:    96 | Cost: 0.7370559 | Acc train: 0.8440000 | Acc validation: 0.8500000
# f1_score is 0.8723776223776224 0.8771929824561403
# roc_auc_score is 0.854 0.86
# Iter:    97 | Cost: 0.7360913 | Acc train: 0.8540000 | Acc validation: 0.8600000
# f1_score is 0.8716157205240174 0.8695652173913044
# roc_auc_score is 0.853 0.85
# Iter:    98 | Cost: 0.7366357 | Acc train: 0.8530000 | Acc validation: 0.8500000
# f1_score is 0.8525149190110827 0.8620689655172413
# roc_auc_score is 0.827 0.84
# Iter:    99 | Cost: 0.7408219 | Acc train: 0.8270000 | Acc validation: 0.8400000
# f1_score is 0.8598452278589854 0.8695652173913044
# roc_auc_score is 0.837 0.85
# Iter:   100 | Cost: 0.7385955 | Acc train: 0.8370000 | Acc validation: 0.8500000
# f1_score is 0.8875 0.8849557522123894
# roc_auc_score is 0.874 0.87
# Iter:   101 | Cost: 0.7345756 | Acc train: 0.8740000 | Acc validation: 0.8700000
# f1_score is 0.9019607843137255 0.8653846153846153
# roc_auc_score is 0.895 0.86
# Iter:   102 | Cost: 0.7339782 | Acc train: 0.8950000 | Acc validation: 0.8600000
# f1_score is 0.8351177730192719 0.7500000000000001
# roc_auc_score is 0.8460000000000001 0.7800000000000001
# Iter:   103 | Cost: 0.7389108 | Acc train: 0.8460000 | Acc validation: 0.7800000
# f1_score is 0.830636461704423 0.7209302325581396
# roc_auc_score is 0.8430000000000001 0.7600000000000001
# Iter:   104 | Cost: 0.7394912 | Acc train: 0.8430000 | Acc validation: 0.7600000
# f1_score is 0.7936865839909809 0.605263157894737
# roc_auc_score is 0.817 0.7
# Iter:   105 | Cost: 0.7421732 | Acc train: 0.8170000 | Acc validation: 0.7000000
# f1_score is 0.7455197132616487 0.5217391304347826
# roc_auc_score is 0.7869999999999999 0.6699999999999999
# Iter:   106 | Cost: 0.7466382 | Acc train: 0.7870000 | Acc validation: 0.6700000
# f1_score is 0.7369696969696969 0.5217391304347826
# roc_auc_score is 0.783 0.6699999999999999
# Iter:   107 | Cost: 0.7480840 | Acc train: 0.7830000 | Acc validation: 0.6700000
# f1_score is 0.8541882109617372 0.8172043010752689
# roc_auc_score is 0.859 0.8300000000000001
# Iter:   108 | Cost: 0.7372840 | Acc train: 0.8590000 | Acc validation: 0.8300000
# f1_score is 0.9037037037037038 0.8598130841121495
# roc_auc_score is 0.896 0.85
# Iter:   109 | Cost: 0.7340302 | Acc train: 0.8960000 | Acc validation: 0.8500000
# f1_score is 0.899904671115348 0.8599999999999999
# roc_auc_score is 0.8949999999999999 0.86
# Iter:   110 | Cost: 0.7345706 | Acc train: 0.8950000 | Acc validation: 0.8600000
# f1_score is 0.8908382066276803 0.8453608247422681
# roc_auc_score is 0.8880000000000001 0.85
# Iter:   111 | Cost: 0.7350876 | Acc train: 0.8880000 | Acc validation: 0.8500000
# f1_score is 0.8360128617363344 0.7356321839080459
# roc_auc_score is 0.8470000000000001 0.7700000000000001
# Iter:   112 | Cost: 0.7392023 | Acc train: 0.8470000 | Acc validation: 0.7700000
# f1_score is 0.7620164126611958 0.5633802816901408
# roc_auc_score is 0.7969999999999999 0.69
# Iter:   113 | Cost: 0.7456503 | Acc train: 0.7970000 | Acc validation: 0.6900000
# f1_score is 0.746730083234245 0.5217391304347826
# roc_auc_score is 0.787 0.6699999999999999
# Iter:   114 | Cost: 0.7465633 | Acc train: 0.7870000 | Acc validation: 0.6700000
# f1_score is 0.8079470198675497 0.675
# roc_auc_score is 0.826 0.74
# Iter:   115 | Cost: 0.7415024 | Acc train: 0.8260000 | Acc validation: 0.7400000
# f1_score is 0.8796764408493428 0.8421052631578948
# roc_auc_score is 0.8810000000000001 0.8500000000000001
# Iter:   116 | Cost: 0.7363824 | Acc train: 0.8810000 | Acc validation: 0.8500000
# f1_score is 0.8968253968253967 0.8421052631578948
# roc_auc_score is 0.896 0.8500000000000001
# Iter:   117 | Cost: 0.7355297 | Acc train: 0.8960000 | Acc validation: 0.8500000
# f1_score is 0.8968253968253967 0.8421052631578948
# roc_auc_score is 0.896 0.8500000000000001
# Iter:   118 | Cost: 0.7356577 | Acc train: 0.8960000 | Acc validation: 0.8500000
# f1_score is 0.9135802469135803 0.88
# roc_auc_score is 0.9089999999999999 0.8799999999999999
# Iter:   119 | Cost: 0.7337949 | Acc train: 0.9090000 | Acc validation: 0.8800000
# f1_score is 0.9055912007332722 0.8990825688073395
# roc_auc_score is 0.8970000000000001 0.89
# Iter:   120 | Cost: 0.7325422 | Acc train: 0.8970000 | Acc validation: 0.8900000
# 0
# f1_score is 0.0 0.0
# roc_auc_score is 0.479 0.5
# Iter:     1 | Cost: 1.0189451 | Acc train: 0.4790000 | Acc validation: 0.5000000
# f1_score is 0.003610108303249097 0.0
# roc_auc_score is 0.448 0.45
# Iter:     2 | Cost: 1.0052660 | Acc train: 0.4480000 | Acc validation: 0.4500000
# f1_score is 0.11094452773613193 0.02985074626865672
# roc_auc_score is 0.40700000000000003 0.35
# Iter:     3 | Cost: 0.9901846 | Acc train: 0.4070000 | Acc validation: 0.3500000
# f1_score is 0.7127211457455771 0.6779661016949153
# roc_auc_score is 0.659 0.62
# Iter:     4 | Cost: 0.9800993 | Acc train: 0.6590000 | Acc validation: 0.6200000
# f1_score is 0.7401924500370096 0.7462686567164178
# roc_auc_score is 0.649 0.6599999999999999
# Iter:     5 | Cost: 0.9778033 | Acc train: 0.6490000 | Acc validation: 0.6600000
# f1_score is 0.6963788300835655 0.6944444444444444
# roc_auc_score is 0.5640000000000001 0.56
# Iter:     6 | Cost: 0.9809804 | Acc train: 0.5640000 | Acc validation: 0.5600000
# f1_score is 0.6724949562878278 0.6711409395973155
# roc_auc_score is 0.513 0.51
# Iter:     7 | Cost: 0.9856623 | Acc train: 0.5130000 | Acc validation: 0.5100000
# f1_score is 0.6720430107526881 0.6711409395973155
# roc_auc_score is 0.512 0.51
# Iter:     8 | Cost: 0.9829171 | Acc train: 0.5120000 | Acc validation: 0.5100000
# f1_score is 0.6743088334457181 0.6711409395973155
# roc_auc_score is 0.517 0.51
# Iter:     9 | Cost: 0.9771666 | Acc train: 0.5170000 | Acc validation: 0.5100000
# f1_score is 0.6939625260235947 0.6896551724137931
# roc_auc_score is 0.5589999999999999 0.55
# Iter:    10 | Cost: 0.9643648 | Acc train: 0.5590000 | Acc validation: 0.5500000
# f1_score is 0.715307582260372 0.704225352112676
# roc_auc_score is 0.602 0.5800000000000001
# Iter:    11 | Cost: 0.9537624 | Acc train: 0.6020000 | Acc validation: 0.5800000
# f1_score is 0.7407407407407407 0.7407407407407407
# roc_auc_score is 0.65 0.65
# Iter:    12 | Cost: 0.9438116 | Acc train: 0.6500000 | Acc validation: 0.6500000
# f1_score is 0.7704160246533128 0.7518796992481204
# roc_auc_score is 0.702 0.6699999999999999
# Iter:    13 | Cost: 0.9343700 | Acc train: 0.7020000 | Acc validation: 0.6700000
# f1_score is 0.7908082408874801 0.7692307692307693
# roc_auc_score is 0.736 0.7
# Iter:    14 | Cost: 0.9263997 | Acc train: 0.7360000 | Acc validation: 0.7000000
# f1_score is 0.8035426731078905 0.7936507936507937
# roc_auc_score is 0.756 0.74
# Iter:    15 | Cost: 0.9200813 | Acc train: 0.7560000 | Acc validation: 0.7400000
# f1_score is 0.8268434134217066 0.8130081300813007
# roc_auc_score is 0.791 0.77
# Iter:    16 | Cost: 0.9135794 | Acc train: 0.7910000 | Acc validation: 0.7700000
# f1_score is 0.8524590163934426 0.8620689655172413
# roc_auc_score is 0.829 0.84
# Iter:    17 | Cost: 0.9080134 | Acc train: 0.8290000 | Acc validation: 0.8400000
# f1_score is 0.8537005163511188 0.8547008547008548
# roc_auc_score is 0.83 0.83
# Iter:    18 | Cost: 0.9033768 | Acc train: 0.8300000 | Acc validation: 0.8300000
# f1_score is 0.8507718696397941 0.8474576271186441
# roc_auc_score is 0.826 0.8200000000000001
# Iter:    19 | Cost: 0.8994237 | Acc train: 0.8260000 | Acc validation: 0.8200000
# f1_score is 0.859375 0.8695652173913044
# roc_auc_score is 0.8379999999999999 0.85
# Iter:    20 | Cost: 0.8958568 | Acc train: 0.8380000 | Acc validation: 0.8500000
# f1_score is 0.8635147190008922 0.8648648648648649
# roc_auc_score is 0.847 0.85
# Iter:    21 | Cost: 0.8928989 | Acc train: 0.8470000 | Acc validation: 0.8500000
# f1_score is 0.8091451292246521 0.7659574468085107
# roc_auc_score is 0.8080000000000002 0.7799999999999999
# Iter:    22 | Cost: 0.8914051 | Acc train: 0.8080000 | Acc validation: 0.7800000
# f1_score is 0.4712328767123287 0.36923076923076925
# roc_auc_score is 0.6139999999999999 0.59
# Iter:    23 | Cost: 0.8930221 | Acc train: 0.6140000 | Acc validation: 0.5900000
# f1_score is 0.4324324324324324 0.31746031746031744
# roc_auc_score is 0.601 0.57
# Iter:    24 | Cost: 0.8917047 | Acc train: 0.6010000 | Acc validation: 0.5700000
# f1_score is 0.744136460554371 0.6888888888888889
# roc_auc_score is 0.76 0.7200000000000001
# Iter:    25 | Cost: 0.8858914 | Acc train: 0.7600000 | Acc validation: 0.7200000
# f1_score is 0.8627103631532329 0.8749999999999999
# roc_auc_score is 0.845 0.8600000000000001
# Iter:    26 | Cost: 0.8823725 | Acc train: 0.8450000 | Acc validation: 0.8600000
# f1_score is 0.84006734006734 0.8403361344537814
# roc_auc_score is 0.81 0.81
# Iter:    27 | Cost: 0.8824291 | Acc train: 0.8100000 | Acc validation: 0.8100000
# f1_score is 0.7682832948421862 0.7462686567164178
# roc_auc_score is 0.6990000000000001 0.6599999999999999
# Iter:    28 | Cost: 0.8903258 | Acc train: 0.6990000 | Acc validation: 0.6600000
# f1_score is 0.7332843497428361 0.7194244604316548
# roc_auc_score is 0.637 0.61
# Iter:    29 | Cost: 0.8982268 | Acc train: 0.6370000 | Acc validation: 0.6100000
# f1_score is 0.7242380261248187 0.7092198581560284
# roc_auc_score is 0.62 0.5900000000000001
# Iter:    30 | Cost: 0.9003510 | Acc train: 0.6200000 | Acc validation: 0.5900000
# f1_score is 0.7365313653136532 0.7246376811594203
# roc_auc_score is 0.643 0.62
# Iter:    31 | Cost: 0.8944246 | Acc train: 0.6430000 | Acc validation: 0.6200000
# f1_score is 0.7635807192042846 0.7462686567164178
# roc_auc_score is 0.6910000000000001 0.6599999999999999
# Iter:    32 | Cost: 0.8868706 | Acc train: 0.6910000 | Acc validation: 0.6600000
# f1_score is 0.7815191855912295 0.7633587786259541
# roc_auc_score is 0.721 0.69
# Iter:    33 | Cost: 0.8811814 | Acc train: 0.7210000 | Acc validation: 0.6900000
# f1_score is 0.8393608074011775 0.8403361344537814
# roc_auc_score is 0.809 0.81
# Iter:    34 | Cost: 0.8719674 | Acc train: 0.8090000 | Acc validation: 0.8100000
# f1_score is 0.8720292504570384 0.8679245283018867
# roc_auc_score is 0.86 0.86
# Iter:    35 | Cost: 0.8681969 | Acc train: 0.8600000 | Acc validation: 0.8600000
# f1_score is 0.6861143523920653 0.5822784810126583
# roc_auc_score is 0.731 0.6699999999999999
# Iter:    36 | Cost: 0.8699180 | Acc train: 0.7310000 | Acc validation: 0.6700000
# f1_score is 0.6626794258373205 0.5789473684210525
# roc_auc_score is 0.718 0.6799999999999999
# Iter:    37 | Cost: 0.8680392 | Acc train: 0.7180000 | Acc validation: 0.6800000
# f1_score is 0.645631067961165 0.5789473684210525
# roc_auc_score is 0.708 0.6799999999999999
# Iter:    38 | Cost: 0.8659029 | Acc train: 0.7080000 | Acc validation: 0.6800000
# f1_score is 0.7425414364640884 0.6823529411764706
# roc_auc_score is 0.767 0.73
# Iter:    39 | Cost: 0.8612283 | Acc train: 0.7670000 | Acc validation: 0.7300000
# f1_score is 0.8633776091081594 0.8431372549019608
# roc_auc_score is 0.8560000000000001 0.8400000000000001
# Iter:    40 | Cost: 0.8553973 | Acc train: 0.8560000 | Acc validation: 0.8400000
# f1_score is 0.874887488748875 0.888888888888889
# roc_auc_score is 0.861 0.88
# Iter:    41 | Cost: 0.8511599 | Acc train: 0.8610000 | Acc validation: 0.8800000
# f1_score is 0.8581314878892734 0.8695652173913044
# roc_auc_score is 0.8359999999999999 0.85
# Iter:    42 | Cost: 0.8482822 | Acc train: 0.8360000 | Acc validation: 0.8500000
# f1_score is 0.8462192013593883 0.8474576271186441
# roc_auc_score is 0.8190000000000001 0.8200000000000001
# Iter:    43 | Cost: 0.8462082 | Acc train: 0.8190000 | Acc validation: 0.8200000
# f1_score is 0.8426395939086294 0.8474576271186441
# roc_auc_score is 0.814 0.8200000000000001
# Iter:    44 | Cost: 0.8435440 | Acc train: 0.8140000 | Acc validation: 0.8200000
# f1_score is 0.841927303465765 0.8333333333333333
# roc_auc_score is 0.813 0.8
# Iter:    45 | Cost: 0.8408272 | Acc train: 0.8130000 | Acc validation: 0.8000000
# f1_score is 0.8452380952380952 0.8403361344537814
# roc_auc_score is 0.8180000000000001 0.81
# Iter:    46 | Cost: 0.8375293 | Acc train: 0.8180000 | Acc validation: 0.8100000
# f1_score is 0.8541846419327007 0.8620689655172413
# roc_auc_score is 0.831 0.84
# Iter:    47 | Cost: 0.8337501 | Acc train: 0.8310000 | Acc validation: 0.8400000
# f1_score is 0.8649122807017544 0.8849557522123894
# roc_auc_score is 0.846 0.87
# Iter:    48 | Cost: 0.8303645 | Acc train: 0.8460000 | Acc validation: 0.8700000
# f1_score is 0.8705673758865248 0.8807339449541285
# roc_auc_score is 0.854 0.87
# Iter:    49 | Cost: 0.8276043 | Acc train: 0.8540000 | Acc validation: 0.8700000
# f1_score is 0.8603839441535776 0.8849557522123894
# roc_auc_score is 0.8399999999999999 0.87
# Iter:    50 | Cost: 0.8253475 | Acc train: 0.8400000 | Acc validation: 0.8700000
# f1_score is 0.8559027777777777 0.8849557522123894
# roc_auc_score is 0.8339999999999999 0.87
# Iter:    51 | Cost: 0.8232345 | Acc train: 0.8340000 | Acc validation: 0.8700000
# f1_score is 0.8593886462882098 0.882882882882883
# roc_auc_score is 0.839 0.87
# Iter:    52 | Cost: 0.8205331 | Acc train: 0.8390000 | Acc validation: 0.8700000
# f1_score is 0.8511047070124881 0.803921568627451
# roc_auc_score is 0.8450000000000001 0.7999999999999999
# Iter:    53 | Cost: 0.8191041 | Acc train: 0.8450000 | Acc validation: 0.8000000
# f1_score is 0.7227833894500562 0.65
# roc_auc_score is 0.7530000000000001 0.7200000000000001
# Iter:    54 | Cost: 0.8216142 | Acc train: 0.7530000 | Acc validation: 0.7200000
# f1_score is 0.6682867557715675 0.36923076923076925
# roc_auc_score is 0.727 0.59
# Iter:    55 | Cost: 0.8244248 | Acc train: 0.7270000 | Acc validation: 0.5900000
# f1_score is 0.6778443113772453 0.47887323943661975
# roc_auc_score is 0.731 0.6300000000000001
# Iter:    56 | Cost: 0.8206270 | Acc train: 0.7310000 | Acc validation: 0.6300000
# f1_score is 0.7644539614561028 0.6506024096385542
# roc_auc_score is 0.7799999999999999 0.71
# Iter:    57 | Cost: 0.8140482 | Acc train: 0.7800000 | Acc validation: 0.7100000
# f1_score is 0.856873822975518 0.803921568627451
# roc_auc_score is 0.8480000000000001 0.7999999999999999
# Iter:    58 | Cost: 0.8088477 | Acc train: 0.8480000 | Acc validation: 0.8000000
# f1_score is 0.8695652173913044 0.851851851851852
# roc_auc_score is 0.853 0.8400000000000001
# Iter:    59 | Cost: 0.8070002 | Acc train: 0.8530000 | Acc validation: 0.8400000
# f1_score is 0.8626421697287839 0.8727272727272728
# roc_auc_score is 0.843 0.86
# Iter:    60 | Cost: 0.8061984 | Acc train: 0.8430000 | Acc validation: 0.8600000
# f1_score is 0.8596338273757628 0.8727272727272728
# roc_auc_score is 0.839 0.86
# Iter:    61 | Cost: 0.8052657 | Acc train: 0.8390000 | Acc validation: 0.8600000
# f1_score is 0.8524590163934426 0.8620689655172413
# roc_auc_score is 0.829 0.84
# Iter:    62 | Cost: 0.8055790 | Acc train: 0.8290000 | Acc validation: 0.8400000
# f1_score is 0.8334728033472804 0.8264462809917354
# roc_auc_score is 0.8009999999999999 0.79
# Iter:    63 | Cost: 0.8072192 | Acc train: 0.8010000 | Acc validation: 0.7900000
# f1_score is 0.8051529790660226 0.8
# roc_auc_score is 0.758 0.75
# Iter:    64 | Cost: 0.8128641 | Acc train: 0.7580000 | Acc validation: 0.7500000
# f1_score is 0.7782101167315175 0.7518796992481204
# roc_auc_score is 0.7150000000000001 0.6699999999999999
# Iter:    65 | Cost: 0.8199920 | Acc train: 0.7150000 | Acc validation: 0.6700000
# f1_score is 0.7800312012480499 0.7633587786259541
# roc_auc_score is 0.718 0.69
# Iter:    66 | Cost: 0.8188778 | Acc train: 0.7180000 | Acc validation: 0.6900000
# f1_score is 0.782472613458529 0.7633587786259541
# roc_auc_score is 0.722 0.69
# Iter:    67 | Cost: 0.8173103 | Acc train: 0.7220000 | Acc validation: 0.6900000
# f1_score is 0.7800312012480499 0.7633587786259541
# roc_auc_score is 0.718 0.69
# Iter:    68 | Cost: 0.8177377 | Acc train: 0.7180000 | Acc validation: 0.6900000
# f1_score is 0.7818608287724785 0.7692307692307693
# roc_auc_score is 0.721 0.7
# Iter:    69 | Cost: 0.8172019 | Acc train: 0.7210000 | Acc validation: 0.7000000
# f1_score is 0.7886435331230284 0.7751937984496124
# roc_auc_score is 0.732 0.71
# Iter:    70 | Cost: 0.8155234 | Acc train: 0.7320000 | Acc validation: 0.7100000
# f1_score is 0.8058017727639001 0.7936507936507937
# roc_auc_score is 0.759 0.74
# Iter:    71 | Cost: 0.8109836 | Acc train: 0.7590000 | Acc validation: 0.7400000
# f1_score is 0.8409475465313029 0.8333333333333333
# roc_auc_score is 0.812 0.8
# Iter:    72 | Cost: 0.8051667 | Acc train: 0.8120000 | Acc validation: 0.8000000
# f1_score is 0.8441558441558442 0.8000000000000002
# roc_auc_score is 0.8320000000000001 0.8
# Iter:    73 | Cost: 0.8013762 | Acc train: 0.8320000 | Acc validation: 0.8000000
# f1_score is 0.7730727470141152 0.5925925925925926
# roc_auc_score is 0.7909999999999999 0.6699999999999999
# Iter:    74 | Cost: 0.8035261 | Acc train: 0.7910000 | Acc validation: 0.6700000
# f1_score is 0.7387387387387386 0.5066666666666666
# roc_auc_score is 0.768 0.63
# Iter:    75 | Cost: 0.8047102 | Acc train: 0.7680000 | Acc validation: 0.6300000
# f1_score is 0.7712418300653595 0.575
# roc_auc_score is 0.79 0.66
# Iter:    76 | Cost: 0.8032813 | Acc train: 0.7900000 | Acc validation: 0.6600000
# f1_score is 0.8158415841584158 0.7916666666666667
# roc_auc_score is 0.8140000000000001 0.7999999999999999
# Iter:    77 | Cost: 0.8008259 | Acc train: 0.8140000 | Acc validation: 0.8000000
# f1_score is 0.866785079928952 0.851851851851852
# roc_auc_score is 0.85 0.8400000000000001
# Iter:    78 | Cost: 0.8007503 | Acc train: 0.8500000 | Acc validation: 0.8400000
# f1_score is 0.8426395939086294 0.8264462809917354
# roc_auc_score is 0.814 0.79
# Iter:    79 | Cost: 0.8037555 | Acc train: 0.8140000 | Acc validation: 0.7900000
# f1_score is 0.819000819000819 0.8130081300813007
# roc_auc_score is 0.779 0.77
# Iter:    80 | Cost: 0.8071594 | Acc train: 0.7790000 | Acc validation: 0.7700000
# f1_score is 0.8295926849542808 0.819672131147541
# roc_auc_score is 0.795 0.78
# Iter:    81 | Cost: 0.8046070 | Acc train: 0.7950000 | Acc validation: 0.7800000
# f1_score is 0.8671943711521547 0.8749999999999999
# roc_auc_score is 0.849 0.8600000000000001
# Iter:    82 | Cost: 0.7996037 | Acc train: 0.8490000 | Acc validation: 0.8600000
# f1_score is 0.8774774774774774 0.8598130841121495
# roc_auc_score is 0.864 0.85
# Iter:    83 | Cost: 0.7984012 | Acc train: 0.8640000 | Acc validation: 0.8500000
# f1_score is 0.8318407960199004 0.8041237113402062
# roc_auc_score is 0.8310000000000001 0.8099999999999999
# Iter:    84 | Cost: 0.7988176 | Acc train: 0.8310000 | Acc validation: 0.8100000
# f1_score is 0.8172268907563025 0.7045454545454546
# roc_auc_score is 0.8260000000000001 0.74
# Iter:    85 | Cost: 0.7998572 | Acc train: 0.8260000 | Acc validation: 0.7400000
# f1_score is 0.7974137931034482 0.6666666666666666
# roc_auc_score is 0.8119999999999999 0.72
# Iter:    86 | Cost: 0.8007222 | Acc train: 0.8120000 | Acc validation: 0.7200000
# f1_score is 0.8140276301806588 0.6976744186046512
# roc_auc_score is 0.8250000000000001 0.7400000000000001
# Iter:    87 | Cost: 0.8002644 | Acc train: 0.8250000 | Acc validation: 0.7400000
# f1_score is 0.7714604236343366 0.5974025974025975
# roc_auc_score is 0.7949999999999999 0.69
# Iter:    88 | Cost: 0.8018367 | Acc train: 0.7950000 | Acc validation: 0.6900000
# f1_score is 0.7965367965367965 0.6829268292682927
# roc_auc_score is 0.812 0.74
# Iter:    89 | Cost: 0.8006904 | Acc train: 0.8120000 | Acc validation: 0.7400000
# f1_score is 0.8629737609329446 0.8080808080808082
# roc_auc_score is 0.8589999999999999 0.81
# Iter:    90 | Cost: 0.7976082 | Acc train: 0.8590000 | Acc validation: 0.8100000
# f1_score is 0.8907103825136612 0.8703703703703703
# roc_auc_score is 0.88 0.8600000000000001
# Iter:    91 | Cost: 0.7966780 | Acc train: 0.8800000 | Acc validation: 0.8600000
# f1_score is 0.8905109489051096 0.8598130841121495
# roc_auc_score is 0.8800000000000001 0.85
# Iter:    92 | Cost: 0.7966012 | Acc train: 0.8800000 | Acc validation: 0.8500000
# f1_score is 0.8868101028999065 0.8461538461538461
# roc_auc_score is 0.8790000000000001 0.84
# Iter:    93 | Cost: 0.7968354 | Acc train: 0.8790000 | Acc validation: 0.8400000
# f1_score is 0.8605341246290802 0.816326530612245
# roc_auc_score is 0.859 0.8200000000000001
# Iter:    94 | Cost: 0.7978573 | Acc train: 0.8590000 | Acc validation: 0.8200000
# f1_score is 0.8522267206477733 0.8125
# roc_auc_score is 0.854 0.82
# Iter:    95 | Cost: 0.7983946 | Acc train: 0.8540000 | Acc validation: 0.8200000
# f1_score is 0.8608349900596421 0.816326530612245
# roc_auc_score is 0.86 0.8200000000000001
# Iter:    96 | Cost: 0.7979542 | Acc train: 0.8600000 | Acc validation: 0.8200000
# f1_score is 0.8820709491850431 0.82
# roc_auc_score is 0.8769999999999999 0.82
# Iter:    97 | Cost: 0.7971235 | Acc train: 0.8770000 | Acc validation: 0.8200000
# f1_score is 0.896678966789668 0.8598130841121495
# roc_auc_score is 0.888 0.85
# Iter:    98 | Cost: 0.7963475 | Acc train: 0.8880000 | Acc validation: 0.8500000
# f1_score is 0.8962962962962961 0.8380952380952381
# roc_auc_score is 0.888 0.83
# Iter:    99 | Cost: 0.7964227 | Acc train: 0.8880000 | Acc validation: 0.8300000
# f1_score is 0.896678966789668 0.8598130841121495
# roc_auc_score is 0.888 0.85
# Iter:   100 | Cost: 0.7962655 | Acc train: 0.8880000 | Acc validation: 0.8500000
# f1_score is 0.8917910447761194 0.8543689320388349
# roc_auc_score is 0.8840000000000001 0.8500000000000001
# Iter:   101 | Cost: 0.7964776 | Acc train: 0.8840000 | Acc validation: 0.8500000
# f1_score is 0.8865979381443297 0.8543689320388349
# roc_auc_score is 0.879 0.8500000000000001
# Iter:   102 | Cost: 0.7965318 | Acc train: 0.8790000 | Acc validation: 0.8500000
# f1_score is 0.895852534562212 0.8598130841121495
# roc_auc_score is 0.887 0.85
# Iter:   103 | Cost: 0.7961503 | Acc train: 0.8870000 | Acc validation: 0.8500000
# f1_score is 0.8975069252077561 0.8598130841121495
# roc_auc_score is 0.8890000000000001 0.85
# Iter:   104 | Cost: 0.7961979 | Acc train: 0.8890000 | Acc validation: 0.8500000
# f1_score is 0.8975069252077561 0.8598130841121495
# roc_auc_score is 0.8890000000000001 0.85
# Iter:   105 | Cost: 0.7962161 | Acc train: 0.8890000 | Acc validation: 0.8500000
# f1_score is 0.8931297709923663 0.8543689320388349
# roc_auc_score is 0.8879999999999999 0.8500000000000001
# Iter:   106 | Cost: 0.7969385 | Acc train: 0.8880000 | Acc validation: 0.8500000
# f1_score is 0.8819512195121951 0.816326530612245
# roc_auc_score is 0.879 0.8200000000000001
# Iter:   107 | Cost: 0.7974977 | Acc train: 0.8790000 | Acc validation: 0.8200000
# f1_score is 0.874381800197824 0.8333333333333333
# roc_auc_score is 0.873 0.8400000000000001
# Iter:   108 | Cost: 0.7980101 | Acc train: 0.8730000 | Acc validation: 0.8400000
# f1_score is 0.8931665062560155 0.8431372549019608
# roc_auc_score is 0.8889999999999999 0.8400000000000001
# Iter:   109 | Cost: 0.7973340 | Acc train: 0.8890000 | Acc validation: 0.8400000
# f1_score is 0.8998178506375227 0.9009009009009009
# roc_auc_score is 0.89 0.89
# Iter:   110 | Cost: 0.7961778 | Acc train: 0.8900000 | Acc validation: 0.8900000
# f1_score is 0.8648180242634316 0.8771929824561403
# roc_auc_score is 0.844 0.86
# Iter:   111 | Cost: 0.7983675 | Acc train: 0.8440000 | Acc validation: 0.8600000
# f1_score is 0.852263023057216 0.8547008547008548
# roc_auc_score is 0.827 0.83
# Iter:   112 | Cost: 0.8001998 | Acc train: 0.8270000 | Acc validation: 0.8300000
# f1_score is 0.8244023083264632 0.8264462809917354
# roc_auc_score is 0.787 0.79
# Iter:   113 | Cost: 0.8037430 | Acc train: 0.7870000 | Acc validation: 0.7900000
# f1_score is 0.7993605115907275 0.7874015748031497
# roc_auc_score is 0.749 0.73
# Iter:   114 | Cost: 0.8082878 | Acc train: 0.7490000 | Acc validation: 0.7300000
# f1_score is 0.8051529790660226 0.7936507936507937
# roc_auc_score is 0.758 0.74
# Iter:   115 | Cost: 0.8072400 | Acc train: 0.7580000 | Acc validation: 0.7400000
# f1_score is 0.8244023083264632 0.8264462809917354
# roc_auc_score is 0.787 0.79
# Iter:   116 | Cost: 0.8036675 | Acc train: 0.7870000 | Acc validation: 0.7900000
# f1_score is 0.8508098891730606 0.8474576271186441
# roc_auc_score is 0.8250000000000001 0.8200000000000001
# Iter:   117 | Cost: 0.8002894 | Acc train: 0.8250000 | Acc validation: 0.8200000
# f1_score is 0.8655680832610582 0.8849557522123894
# roc_auc_score is 0.845 0.87
# Iter:   118 | Cost: 0.7980236 | Acc train: 0.8450000 | Acc validation: 0.8700000
# f1_score is 0.8625756266205705 0.8695652173913044
# roc_auc_score is 0.841 0.85
# Iter:   119 | Cost: 0.7984465 | Acc train: 0.8410000 | Acc validation: 0.8500000
# f1_score is 0.8529914529914531 0.8620689655172413
# roc_auc_score is 0.8279999999999998 0.84
# Iter:   120 | Cost: 0.7994785 | Acc train: 0.8280000 | Acc validation: 0.8400000
# 0.1
# f1_score is 0.051036682615629984 0.03174603174603175
# roc_auc_score is 0.405 0.39
# Iter:     1 | Cost: 0.9986057 | Acc train: 0.4050000 | Acc validation: 0.3900000
# f1_score is 0.20838971583220567 0.02857142857142857
# roc_auc_score is 0.415 0.32
# Iter:     2 | Cost: 0.9931052 | Acc train: 0.4150000 | Acc validation: 0.3200000
# f1_score is 0.4139482564679415 0.21951219512195122
# roc_auc_score is 0.47900000000000004 0.36
# Iter:     3 | Cost: 0.9890315 | Acc train: 0.4790000 | Acc validation: 0.3600000
# f1_score is 0.6182495344506518 0.5
# roc_auc_score is 0.5900000000000001 0.48
# Iter:     4 | Cost: 0.9856364 | Acc train: 0.5900000 | Acc validation: 0.4800000
# f1_score is 0.7620504973221116 0.7538461538461539
# roc_auc_score is 0.6890000000000001 0.6799999999999999
# Iter:     5 | Cost: 0.9832929 | Acc train: 0.6890000 | Acc validation: 0.6800000
# f1_score is 0.748502994011976 0.7518796992481204
# roc_auc_score is 0.6639999999999999 0.6699999999999999
# Iter:     6 | Cost: 0.9814920 | Acc train: 0.6640000 | Acc validation: 0.6700000
# f1_score is 0.7331378299120235 0.7246376811594203
# roc_auc_score is 0.636 0.62
# Iter:     7 | Cost: 0.9801009 | Acc train: 0.6360000 | Acc validation: 0.6200000
# f1_score is 0.7385524372230429 0.7299270072992701
# roc_auc_score is 0.646 0.63
# Iter:     8 | Cost: 0.9766388 | Acc train: 0.6460000 | Acc validation: 0.6300000
# f1_score is 0.741839762611276 0.7299270072992701
# roc_auc_score is 0.652 0.63
# Iter:     9 | Cost: 0.9733608 | Acc train: 0.6520000 | Acc validation: 0.6300000
# f1_score is 0.7473841554559043 0.7352941176470588
# roc_auc_score is 0.6619999999999999 0.64
# Iter:    10 | Cost: 0.9694383 | Acc train: 0.6620000 | Acc validation: 0.6400000
# f1_score is 0.7627765064836003 0.7633587786259541
# roc_auc_score is 0.6890000000000001 0.69
# Iter:    11 | Cost: 0.9644402 | Acc train: 0.6890000 | Acc validation: 0.6900000
# f1_score is 0.779423226812159 0.7692307692307693
# roc_auc_score is 0.7170000000000001 0.7
# Iter:    12 | Cost: 0.9596847 | Acc train: 0.7170000 | Acc validation: 0.7000000
# f1_score is 0.7940199335548173 0.7804878048780488
# roc_auc_score is 0.752 0.73
# Iter:    13 | Cost: 0.9547955 | Acc train: 0.7520000 | Acc validation: 0.7300000
# f1_score is 0.6938775510204082 0.5656565656565656
# roc_auc_score is 0.685 0.5700000000000001
# Iter:    14 | Cost: 0.9510370 | Acc train: 0.6850000 | Acc validation: 0.5700000
# f1_score is 0.5410958904109588 0.38461538461538464
# roc_auc_score is 0.598 0.52
# Iter:    15 | Cost: 0.9480313 | Acc train: 0.5980000 | Acc validation: 0.5200000
# f1_score is 0.3342541436464088 0.032786885245901634
# roc_auc_score is 0.518 0.41000000000000003
# Iter:    16 | Cost: 0.9465385 | Acc train: 0.5180000 | Acc validation: 0.4100000
# f1_score is 0.14492753623188406 0.03508771929824562
# roc_auc_score is 0.46900000000000003 0.45
# Iter:    17 | Cost: 0.9461054 | Acc train: 0.4690000 | Acc validation: 0.4500000
# f1_score is 0.07972270363951474 0.03636363636363636
# roc_auc_score is 0.46900000000000003 0.47000000000000003
# Iter:    18 | Cost: 0.9448396 | Acc train: 0.4690000 | Acc validation: 0.4700000
# f1_score is 0.14168039538714988 0.03508771929824562
# roc_auc_score is 0.47900000000000004 0.45
# Iter:    19 | Cost: 0.9393764 | Acc train: 0.4790000 | Acc validation: 0.4500000
# f1_score is 0.38858695652173914 0.13114754098360654
# roc_auc_score is 0.55 0.47000000000000003
# Iter:    20 | Cost: 0.9322604 | Acc train: 0.5500000 | Acc validation: 0.4700000
# f1_score is 0.5885057471264368 0.525
# roc_auc_score is 0.642 0.6200000000000001
# Iter:    21 | Cost: 0.9274245 | Acc train: 0.6420000 | Acc validation: 0.6200000
# f1_score is 0.784090909090909 0.74
# roc_auc_score is 0.7719999999999999 0.74
# Iter:    22 | Cost: 0.9238850 | Acc train: 0.7720000 | Acc validation: 0.7400000
# f1_score is 0.8378615249780895 0.8141592920353983
# roc_auc_score is 0.8149999999999998 0.7899999999999999
# Iter:    23 | Cost: 0.9216533 | Acc train: 0.8150000 | Acc validation: 0.7900000
# f1_score is 0.8243130724396337 0.819672131147541
# roc_auc_score is 0.789 0.78
# Iter:    24 | Cost: 0.9203842 | Acc train: 0.7890000 | Acc validation: 0.7800000
# f1_score is 0.8195364238410596 0.8130081300813007
# roc_auc_score is 0.782 0.77
# Iter:    25 | Cost: 0.9191111 | Acc train: 0.7820000 | Acc validation: 0.7700000
# f1_score is 0.8229426433915212 0.819672131147541
# roc_auc_score is 0.787 0.78
# Iter:    26 | Cost: 0.9177771 | Acc train: 0.7870000 | Acc validation: 0.7800000
# f1_score is 0.8444830582102518 0.8245614035087719
# roc_auc_score is 0.8209999999999998 0.7999999999999998
# Iter:    27 | Cost: 0.9161939 | Acc train: 0.8210000 | Acc validation: 0.8000000
# f1_score is 0.8455565142364105 0.8376068376068375
# roc_auc_score is 0.821 0.81
# Iter:    28 | Cost: 0.9151342 | Acc train: 0.8210000 | Acc validation: 0.8100000
# f1_score is 0.8341793570219966 0.8474576271186441
# roc_auc_score is 0.804 0.8200000000000001
# Iter:    29 | Cost: 0.9143282 | Acc train: 0.8040000 | Acc validation: 0.8200000
# f1_score is 0.8247078464106844 0.819672131147541
# roc_auc_score is 0.79 0.78
# Iter:    30 | Cost: 0.9136967 | Acc train: 0.7900000 | Acc validation: 0.7800000
# f1_score is 0.8448729184925503 0.8141592920353983
# roc_auc_score is 0.8229999999999998 0.7899999999999999
# Iter:    31 | Cost: 0.9122268 | Acc train: 0.8230000 | Acc validation: 0.7900000
# f1_score is 0.8044692737430168 0.792079207920792
# roc_auc_score is 0.7899999999999999 0.79
# Iter:    32 | Cost: 0.9116238 | Acc train: 0.7900000 | Acc validation: 0.7900000
# f1_score is 0.7909176915799432 0.7551020408163266
# roc_auc_score is 0.7789999999999999 0.76
# Iter:    33 | Cost: 0.9108048 | Acc train: 0.7790000 | Acc validation: 0.7600000
# f1_score is 0.8172635445362718 0.796116504854369
# roc_auc_score is 0.8009999999999999 0.79
# Iter:    34 | Cost: 0.9096574 | Acc train: 0.8010000 | Acc validation: 0.7900000
# f1_score is 0.7736943907156673 0.7291666666666667
# roc_auc_score is 0.766 0.74
# Iter:    35 | Cost: 0.9090662 | Acc train: 0.7660000 | Acc validation: 0.7400000
# f1_score is 0.6615044247787611 0.5783132530120482
# roc_auc_score is 0.694 0.65
# Iter:    36 | Cost: 0.9093019 | Acc train: 0.6940000 | Acc validation: 0.6500000
# f1_score is 0.5887961859356377 0.4799999999999999
# roc_auc_score is 0.6550000000000001 0.61
# Iter:    37 | Cost: 0.9091853 | Acc train: 0.6550000 | Acc validation: 0.6100000
# f1_score is 0.5096525096525096 0.30303030303030304
# roc_auc_score is 0.6189999999999999 0.54
# Iter:    38 | Cost: 0.9095872 | Acc train: 0.6190000 | Acc validation: 0.5400000
# f1_score is 0.5418227215980025 0.3943661971830986
# roc_auc_score is 0.633 0.57
# Iter:    39 | Cost: 0.9078421 | Acc train: 0.6330000 | Acc validation: 0.5700000
# f1_score is 0.7532467532467532 0.6444444444444445
# roc_auc_score is 0.753 0.68
# Iter:    40 | Cost: 0.9040517 | Acc train: 0.7530000 | Acc validation: 0.6800000
# f1_score is 0.8451957295373665 0.822429906542056
# roc_auc_score is 0.8259999999999998 0.81
# Iter:    41 | Cost: 0.9017813 | Acc train: 0.8260000 | Acc validation: 0.8100000
# f1_score is 0.8496042216358839 0.8363636363636363
# roc_auc_score is 0.829 0.82
# Iter:    42 | Cost: 0.9004557 | Acc train: 0.8290000 | Acc validation: 0.8200000
# f1_score is 0.8377230246389125 0.8333333333333333
# roc_auc_score is 0.809 0.8
# Iter:    43 | Cost: 0.8994248 | Acc train: 0.8090000 | Acc validation: 0.8000000
# f1_score is 0.8120915032679739 0.7936507936507937
# roc_auc_score is 0.77 0.74
# Iter:    44 | Cost: 0.8997083 | Acc train: 0.7700000 | Acc validation: 0.7400000
# f1_score is 0.8009630818619582 0.7751937984496124
# roc_auc_score is 0.752 0.71
# Iter:    45 | Cost: 0.8997411 | Acc train: 0.7520000 | Acc validation: 0.7100000
# f1_score is 0.7908082408874801 0.7692307692307693
# roc_auc_score is 0.736 0.7
# Iter:    46 | Cost: 0.8993787 | Acc train: 0.7360000 | Acc validation: 0.7000000
# f1_score is 0.7984 0.7751937984496124
# roc_auc_score is 0.748 0.71
# Iter:    47 | Cost: 0.8974390 | Acc train: 0.7480000 | Acc validation: 0.7100000
# ...
# roc_auc_score is 0.768 0.76
# Iter:    26 | Cost: 0.9476471 | Acc train: 0.7680000 | Acc validation: 0.7600000
# f1_score is 0.7692307692307693 0.7518796992481204
# roc_auc_score is 0.7 0.6699999999999999
# Iter:    27 | Cost: 0.9484765 | Acc train: 0.7000000 | Acc validation: 0.6700000
# f1_score is 0.7336757153338224 0.7299270072992701
# roc_auc_score is 0.637 0.63
# Iter:    28 | Cost: 0.9511122 | Acc train: 0.6370000 | Acc validation: 0.6300000
# f1_score is 0.7142857142857143 0.704225352112676
# roc_auc_score is 0.6 0.5800000000000001
# Iter:    29 | Cost: 0.9537727 | Acc train: 0.6000000 | Acc validation: 0.5800000
# f1_score is 0.7017543859649124 0.6993006993006993
# roc_auc_score is 0.575 0.5700000000000001
# Iter:    30 | Cost: 0.9570149 | Acc train: 0.5750000 | Acc validation: 0.5700000
# f1_score is 0.6988120195667366 0.6896551724137931
# roc_auc_score is 0.569 0.55
# Iter:    31 | Cost: 0.9575637 | Acc train: 0.5690000 | Acc validation: 0.5500000
# f1_score is 0.6978367062107467 0.6896551724137931
# roc_auc_score is 0.567 0.55
# Iter:    32 | Cost: 0.9575420 | Acc train: 0.5670000 | Acc validation: 0.5500000
# f1_score is 0.6958942240779401 0.684931506849315
# roc_auc_score is 0.563 0.54
# Iter:    33 | Cost: 0.9583427 | Acc train: 0.5630000 | Acc validation: 0.5400000
# f1_score is 0.6958942240779401 0.684931506849315
# roc_auc_score is 0.563 0.54
# Iter:    34 | Cost: 0.9577530 | Acc train: 0.5630000 | Acc validation: 0.5400000
# f1_score is 0.6954102920723227 0.6802721088435374
# roc_auc_score is 0.562 0.53
# Iter:    35 | Cost: 0.9576930 | Acc train: 0.5620000 | Acc validation: 0.5300000
# f1_score is 0.6963788300835655 0.6896551724137931
# roc_auc_score is 0.5640000000000001 0.55
# Iter:    36 | Cost: 0.9568500 | Acc train: 0.5640000 | Acc validation: 0.5500000
# f1_score is 0.6963788300835655 0.6896551724137931
# roc_auc_score is 0.5640000000000001 0.55
# Iter:    37 | Cost: 0.9559681 | Acc train: 0.5640000 | Acc validation: 0.5500000
# f1_score is 0.6963788300835655 0.6896551724137931
# roc_auc_score is 0.5640000000000001 0.55
# Iter:    38 | Cost: 0.9557817 | Acc train: 0.5640000 | Acc validation: 0.5500000
# f1_score is 0.6949270326615705 0.6802721088435374
# roc_auc_score is 0.5609999999999999 0.53
# Iter:    39 | Cost: 0.9562569 | Acc train: 0.5610000 | Acc validation: 0.5300000
# f1_score is 0.6954102920723227 0.684931506849315
# roc_auc_score is 0.562 0.54
# Iter:    40 | Cost: 0.9557013 | Acc train: 0.5620000 | Acc validation: 0.5400000
# f1_score is 0.697350069735007 0.6944444444444444
# roc_auc_score is 0.5660000000000001 0.56
# Iter:    41 | Cost: 0.9543390 | Acc train: 0.5660000 | Acc validation: 0.5600000
# f1_score is 0.704225352112676 0.6993006993006993
# roc_auc_score is 0.5800000000000001 0.5700000000000001
# Iter:    42 | Cost: 0.9509636 | Acc train: 0.5800000 | Acc validation: 0.5700000
# f1_score is 0.7067137809187279 0.6993006993006993
# roc_auc_score is 0.585 0.5700000000000001
# Iter:    43 | Cost: 0.9490250 | Acc train: 0.5850000 | Acc validation: 0.5700000
# f1_score is 0.7117437722419929 0.7092198581560284
# roc_auc_score is 0.595 0.5900000000000001
# Iter:    44 | Cost: 0.9474040 | Acc train: 0.5950000 | Acc validation: 0.5900000
# f1_score is 0.7283321194464676 0.7194244604316548
# roc_auc_score is 0.627 0.61
# Iter:    45 | Cost: 0.9436186 | Acc train: 0.6270000 | Acc validation: 0.6100000
# f1_score is 0.7549167927382753 0.7299270072992701
# roc_auc_score is 0.6759999999999999 0.63
# Iter:    46 | Cost: 0.9394574 | Acc train: 0.6760000 | Acc validation: 0.6300000
# f1_score is 0.7736434108527132 0.7407407407407407
# roc_auc_score is 0.708 0.65
# Iter:    47 | Cost: 0.9369999 | Acc train: 0.7080000 | Acc validation: 0.6500000
# f1_score is 0.8078817733990148 0.7936507936507937
# roc_auc_score is 0.766 0.74
# Iter:    48 | Cost: 0.9350143 | Acc train: 0.7660000 | Acc validation: 0.7400000
# f1_score is 0.8020924149956409 0.7747747747747747
# roc_auc_score is 0.7729999999999999 0.75
# Iter:    49 | Cost: 0.9345977 | Acc train: 0.7730000 | Acc validation: 0.7500000
# f1_score is 0.7391722810394611 0.6597938144329897
# roc_auc_score is 0.729 0.6699999999999999
# Iter:    50 | Cost: 0.9348025 | Acc train: 0.7290000 | Acc validation: 0.6700000
# f1_score is 0.6446104589114194 0.5411764705882354
# roc_auc_score is 0.667 0.61
# Iter:    51 | Cost: 0.9352548 | Acc train: 0.6670000 | Acc validation: 0.6100000
# f1_score is 0.48872180451127817 0.15873015873015872
# roc_auc_score is 0.5920000000000001 0.47000000000000003
# Iter:    52 | Cost: 0.9374526 | Acc train: 0.5920000 | Acc validation: 0.4700000
# f1_score is 0.37693389592123766 0.06896551724137932
# roc_auc_score is 0.5569999999999999 0.46
# Iter:    53 | Cost: 0.9396505 | Acc train: 0.5570000 | Acc validation: 0.4600000
# f1_score is 0.3118440779610195 0.03508771929824562
# roc_auc_score is 0.541 0.45
# Iter:    54 | Cost: 0.9413120 | Acc train: 0.5410000 | Acc validation: 0.4500000
# f1_score is 0.27018633540372666 0.037037037037037035
# roc_auc_score is 0.5299999999999999 0.48
# Iter:    55 | Cost: 0.9421464 | Acc train: 0.5300000 | Acc validation: 0.4800000
# f1_score is 0.19902120717781402 0.03773584905660377
# roc_auc_score is 0.509 0.49
# Iter:    56 | Cost: 0.9433470 | Acc train: 0.5090000 | Acc validation: 0.4900000
# f1_score is 0.20487804878048782 0.03773584905660377
# roc_auc_score is 0.511 0.49
# Iter:    57 | Cost: 0.9429833 | Acc train: 0.5110000 | Acc validation: 0.4900000
# f1_score is 0.20521172638436483 0.03773584905660377
# roc_auc_score is 0.512 0.49
# Iter:    58 | Cost: 0.9426051 | Acc train: 0.5120000 | Acc validation: 0.4900000
# f1_score is 0.20228384991843393 0.03773584905660377
# roc_auc_score is 0.511 0.49
# Iter:    59 | Cost: 0.9424136 | Acc train: 0.5110000 | Acc validation: 0.4900000
# f1_score is 0.26604068857589985 0.03773584905660377
# roc_auc_score is 0.5309999999999999 0.49
# Iter:    60 | Cost: 0.9407721 | Acc train: 0.5310000 | Acc validation: 0.4900000
# f1_score is 0.35242290748898675 0.03571428571428571
# roc_auc_score is 0.5589999999999999 0.46
# Iter:    61 | Cost: 0.9375335 | Acc train: 0.5590000 | Acc validation: 0.4600000
# f1_score is 0.511860174781523 0.21875000000000003
# roc_auc_score is 0.609 0.5
# Iter:    62 | Cost: 0.9325268 | Acc train: 0.6090000 | Acc validation: 0.5000000
# f1_score is 0.5866364665911666 0.4415584415584416
# roc_auc_score is 0.635 0.5700000000000001
# Iter:    63 | Cost: 0.9293321 | Acc train: 0.6350000 | Acc validation: 0.5700000
# f1_score is 0.7537878787878788 0.673469387755102
# roc_auc_score is 0.74 0.6799999999999999
# Iter:    64 | Cost: 0.9266273 | Acc train: 0.7400000 | Acc validation: 0.6800000
# f1_score is 0.8066202090592335 0.7787610619469026
# roc_auc_score is 0.778 0.75
# Iter:    65 | Cost: 0.9253768 | Acc train: 0.7780000 | Acc validation: 0.7500000
# f1_score is 0.8009748172217708 0.7812500000000001
# roc_auc_score is 0.755 0.72
# Iter:    66 | Cost: 0.9250715 | Acc train: 0.7550000 | Acc validation: 0.7200000
# f1_score is 0.7729393468118196 0.7407407407407407
# roc_auc_score is 0.708 0.65
# Iter:    67 | Cost: 0.9262602 | Acc train: 0.7080000 | Acc validation: 0.6500000
# f1_score is 0.755287009063444 0.7246376811594203
# roc_auc_score is 0.6759999999999999 0.62
# Iter:    68 | Cost: 0.9276491 | Acc train: 0.6760000 | Acc validation: 0.6200000
# f1_score is 0.7390983000739099 0.7194244604316548
# roc_auc_score is 0.647 0.61
# Iter:    69 | Cost: 0.9296133 | Acc train: 0.6470000 | Acc validation: 0.6100000
# f1_score is 0.727802037845706 0.7142857142857143
# roc_auc_score is 0.626 0.6
# Iter:    70 | Cost: 0.9308673 | Acc train: 0.6260000 | Acc validation: 0.6000000
# f1_score is 0.7220216606498194 0.7092198581560284
# roc_auc_score is 0.615 0.5900000000000001
# Iter:    71 | Cost: 0.9315609 | Acc train: 0.6150000 | Acc validation: 0.5900000
# f1_score is 0.7168458781362006 0.704225352112676
# roc_auc_score is 0.605 0.5800000000000001
# Iter:    72 | Cost: 0.9323627 | Acc train: 0.6050000 | Acc validation: 0.5800000
# f1_score is 0.7107320540156361 0.704225352112676
# roc_auc_score is 0.593 0.5800000000000001
# Iter:    73 | Cost: 0.9331391 | Acc train: 0.5930000 | Acc validation: 0.5800000
# f1_score is 0.7199424046076314 0.7092198581560284
# roc_auc_score is 0.611 0.5900000000000001
# Iter:    74 | Cost: 0.9304996 | Acc train: 0.6110000 | Acc validation: 0.5900000
# f1_score is 0.727802037845706 0.7142857142857143
# roc_auc_score is 0.626 0.6
# Iter:    75 | Cost: 0.9278873 | Acc train: 0.6260000 | Acc validation: 0.6000000
# f1_score is 0.7446016381236039 0.7194244604316548
# roc_auc_score is 0.657 0.61
# Iter:    76 | Cost: 0.9246850 | Acc train: 0.6570000 | Acc validation: 0.6100000
# f1_score is 0.7712519319938176 0.7352941176470588
# roc_auc_score is 0.704 0.64
# Iter:    77 | Cost: 0.9207374 | Acc train: 0.7040000 | Acc validation: 0.6400000
# f1_score is 0.7904382470119521 0.7692307692307693
# roc_auc_score is 0.737 0.7
# Iter:    78 | Cost: 0.9184348 | Acc train: 0.7370000 | Acc validation: 0.7000000
# f1_score is 0.8035859820700896 0.7812500000000001
# roc_auc_score is 0.7590000000000001 0.72
# Iter:    79 | Cost: 0.9173777 | Acc train: 0.7590000 | Acc validation: 0.7200000
# f1_score is 0.8143213988343048 0.7804878048780488
# roc_auc_score is 0.777 0.73
# Iter:    80 | Cost: 0.9165330 | Acc train: 0.7770000 | Acc validation: 0.7300000
# f1_score is 0.8164983164983165 0.7731092436974789
# roc_auc_score is 0.782 0.73
# Iter:    81 | Cost: 0.9159559 | Acc train: 0.7820000 | Acc validation: 0.7300000
# f1_score is 0.8143100511073252 0.7586206896551725
# roc_auc_score is 0.7819999999999999 0.72
# Iter:    82 | Cost: 0.9154480 | Acc train: 0.7820000 | Acc validation: 0.7200000
# f1_score is 0.8161888701517707 0.7731092436974789
# roc_auc_score is 0.782 0.73
# Iter:    83 | Cost: 0.9149222 | Acc train: 0.7820000 | Acc validation: 0.7300000
# f1_score is 0.8155012636899748 0.7731092436974789
# roc_auc_score is 0.781 0.73
# Iter:    84 | Cost: 0.9144336 | Acc train: 0.7810000 | Acc validation: 0.7300000
# f1_score is 0.8089117395029991 0.7543859649122807
# roc_auc_score is 0.777 0.72
# Iter:    85 | Cost: 0.9139925 | Acc train: 0.7770000 | Acc validation: 0.7200000
# f1_score is 0.7913279132791328 0.7522935779816514
# roc_auc_score is 0.7689999999999999 0.7299999999999999
# Iter:    86 | Cost: 0.9138665 | Acc train: 0.7690000 | Acc validation: 0.7300000
# f1_score is 0.7982142857142858 0.7522935779816514
# roc_auc_score is 0.774 0.7299999999999999
# Iter:    87 | Cost: 0.9132999 | Acc train: 0.7740000 | Acc validation: 0.7300000
# f1_score is 0.7989276139410187 0.7522935779816514
# roc_auc_score is 0.7750000000000001 0.7299999999999999
# Iter:    88 | Cost: 0.9128639 | Acc train: 0.7750000 | Acc validation: 0.7300000
# f1_score is 0.7989228007181328 0.7522935779816514
# roc_auc_score is 0.776 0.7299999999999999
# Iter:    89 | Cost: 0.9125234 | Acc train: 0.7760000 | Acc validation: 0.7300000
# f1_score is 0.7992831541218638 0.7522935779816514
# roc_auc_score is 0.7759999999999999 0.7299999999999999
# Iter:    90 | Cost: 0.9120910 | Acc train: 0.7760000 | Acc validation: 0.7300000
# f1_score is 0.8109965635738832 0.7678571428571428
# roc_auc_score is 0.7799999999999999 0.74
# Iter:    91 | Cost: 0.9115085 | Acc train: 0.7800000 | Acc validation: 0.7400000
# f1_score is 0.8170426065162907 0.7868852459016393
# roc_auc_score is 0.7810000000000001 0.74
# Iter:    92 | Cost: 0.9111450 | Acc train: 0.7810000 | Acc validation: 0.7400000
# f1_score is 0.8016260162601625 0.7812500000000001
# roc_auc_score is 0.756 0.72
# Iter:    93 | Cost: 0.9112365 | Acc train: 0.7560000 | Acc validation: 0.7200000
# f1_score is 0.7724458204334367 0.7352941176470588
# roc_auc_score is 0.706 0.64
# Iter:    94 | Cost: 0.9129891 | Acc train: 0.7060000 | Acc validation: 0.6400000
# f1_score is 0.7598784194528876 0.7299270072992701
# roc_auc_score is 0.6839999999999999 0.63
# Iter:    95 | Cost: 0.9140448 | Acc train: 0.6840000 | Acc validation: 0.6300000
# f1_score is 0.7496251874062969 0.7194244604316548
# roc_auc_score is 0.6659999999999999 0.61
# Iter:    96 | Cost: 0.9150115 | Acc train: 0.6660000 | Acc validation: 0.6100000
# f1_score is 0.7396449704142012 0.7142857142857143
# roc_auc_score is 0.648 0.6
# Iter:    97 | Cost: 0.9161438 | Acc train: 0.6480000 | Acc validation: 0.6000000
# f1_score is 0.7407407407407407 0.7142857142857143
# roc_auc_score is 0.65 0.6
# Iter:    98 | Cost: 0.9155125 | Acc train: 0.6500000 | Acc validation: 0.6000000
# f1_score is 0.7610350076103501 0.7299270072992701
# roc_auc_score is 0.6859999999999999 0.63
# Iter:    99 | Cost: 0.9125892 | Acc train: 0.6860000 | Acc validation: 0.6300000
# f1_score is 0.7769110764430577 0.7407407407407407
# roc_auc_score is 0.714 0.65
# Iter:   100 | Cost: 0.9106251 | Acc train: 0.7140000 | Acc validation: 0.6500000
# f1_score is 0.7983935742971887 0.7751937984496124
# roc_auc_score is 0.7490000000000001 0.71
# Iter:   101 | Cost: 0.9089166 | Acc train: 0.7490000 | Acc validation: 0.7100000
# f1_score is 0.8156146179401992 0.7868852459016393
# roc_auc_score is 0.778 0.74
# Iter:   102 | Cost: 0.9079216 | Acc train: 0.7780000 | Acc validation: 0.7400000
# f1_score is 0.8089887640449438 0.7678571428571428
# roc_auc_score is 0.7789999999999999 0.74
# Iter:   103 | Cost: 0.9076262 | Acc train: 0.7790000 | Acc validation: 0.7400000
# f1_score is 0.7384916748285996 0.6595744680851063
# roc_auc_score is 0.733 0.68
# Iter:   104 | Cost: 0.9087244 | Acc train: 0.7330000 | Acc validation: 0.6800000
# f1_score is 0.6292134831460674 0.33802816901408445
# roc_auc_score is 0.67 0.53
# Iter:   105 | Cost: 0.9112575 | Acc train: 0.6700000 | Acc validation: 0.5300000
# f1_score is 0.5625000000000001 0.3283582089552239
# roc_auc_score is 0.6499999999999999 0.5499999999999999
# Iter:   106 | Cost: 0.9154803 | Acc train: 0.6500000 | Acc validation: 0.5500000
# f1_score is 0.5340314136125655 0.28571428571428575
# roc_auc_score is 0.6439999999999999 0.5499999999999999
# Iter:   107 | Cost: 0.9180190 | Acc train: 0.6440000 | Acc validation: 0.5500000
# f1_score is 0.5342105263157896 0.25806451612903225
# roc_auc_score is 0.646 0.5399999999999999
# Iter:   108 | Cost: 0.9181963 | Acc train: 0.6460000 | Acc validation: 0.5400000
# f1_score is 0.5347313237221494 0.28571428571428575
# roc_auc_score is 0.6449999999999999 0.5499999999999999
# Iter:   109 | Cost: 0.9178218 | Acc train: 0.6450000 | Acc validation: 0.5500000
# f1_score is 0.5395590142671854 0.28571428571428575
# roc_auc_score is 0.645 0.5499999999999999
# Iter:   110 | Cost: 0.9171820 | Acc train: 0.6450000 | Acc validation: 0.5500000
# f1_score is 0.5491698595146871 0.30303030303030304
# roc_auc_score is 0.647 0.54
# Iter:   111 | Cost: 0.9163890 | Acc train: 0.6470000 | Acc validation: 0.5400000
# f1_score is 0.5503184713375796 0.30303030303030304
# roc_auc_score is 0.647 0.54
# Iter:   112 | Cost: 0.9159441 | Acc train: 0.6470000 | Acc validation: 0.5400000
# f1_score is 0.5569620253164557 0.30303030303030304
# roc_auc_score is 0.65 0.54
# Iter:   113 | Cost: 0.9152139 | Acc train: 0.6500000 | Acc validation: 0.5400000
# f1_score is 0.5510204081632653 0.30303030303030304
# roc_auc_score is 0.6479999999999999 0.54
# Iter:   114 | Cost: 0.9158875 | Acc train: 0.6480000 | Acc validation: 0.5400000
# f1_score is 0.5343915343915344 0.2622950819672131
# roc_auc_score is 0.6479999999999999 0.5499999999999999
# Iter:   115 | Cost: 0.9175068 | Acc train: 0.6480000 | Acc validation: 0.5500000
# f1_score is 0.5034199726402189 0.23333333333333336
# roc_auc_score is 0.6369999999999999 0.54
# Iter:   116 | Cost: 0.9191801 | Acc train: 0.6370000 | Acc validation: 0.5400000
# f1_score is 0.5095367847411445 0.23333333333333336
# roc_auc_score is 0.64 0.54
# Iter:   117 | Cost: 0.9189181 | Acc train: 0.6400000 | Acc validation: 0.5400000
# f1_score is 0.5358090185676393 0.2622950819672131
# roc_auc_score is 0.65 0.5499999999999999
# Iter:   118 | Cost: 0.9176305 | Acc train: 0.6500000 | Acc validation: 0.5500000
# f1_score is 0.5682102628285357 0.3283582089552239
# roc_auc_score is 0.655 0.5499999999999999
# Iter:   119 | Cost: 0.9141083 | Acc train: 0.6550000 | Acc validation: 0.5500000
# f1_score is 0.6314580941446613 0.3188405797101449
# roc_auc_score is 0.679 0.5299999999999999
# Iter:   120 | Cost: 0.9102272 | Acc train: 0.6790000 | Acc validation: 0.5300000
# 0.3

# %%
plt.plot([i for i in range(120)],his1[0], label = 'noiseless')
plt.plot([i for i in range(120)],his1[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his1[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his1[3], label = 'p=0.3')
plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Amplitude damping test accuracy')
plt.legend()
plt.savefig('Angle_Encoding_Hardware_efficient_ansatz test accuracy',dpi=600,bbox_inches='tight')
plt.show()

# %%
plt.plot([i for i in range(120)],his2[0], label = 'noiseless')
plt.plot([i for i in range(120)],his2[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his2[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his2[3], label = 'p=0.3')
plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Amplitude damping train accuracy')
plt.legend()
plt.savefig('Angle_Encoding_Hardware_efficient_ansatz train accuracy',dpi=600,bbox_inches='tight')
plt.show()

# %%
plt.plot([i for i in range(120)],his3[0], label = 'noiseless')
plt.plot([i for i in range(120)],his3[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his3[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his3[3], label = 'p=0.3')
#plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Amplitude damping cost function')
plt.legend()
plt.savefig('Angle_Encoding_Hardware_efficient_ansatz cost function',dpi=600,bbox_inches='tight')
plt.show()

# %%
print(his1)
print(his2)
print(his3)
# Out:
# [[0.5, 0.5, 0.5, 0.48, 0.45, 0.42, 0.71, 0.75, 0.69, 0.66, 0.65, 0.64, 0.62, 0.61, 0.59, 0.59, 0.59, 0.59, 0.59, 0.61, 0.65, 0.81, 0.89, 0.86, 0.83, 0.79, 0.78, 0.71, 0.74, 0.86, 0.88, 0.88, 0.87, 0.87, 0.87, 0.86, 0.85, 0.86, 0.86, 0.84, 0.8, 0.76, 0.81, 0.82, 0.89, 0.89, 0.88, 0.88, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.85, 0.82, 0.83, 0.82, 0.87, 0.89, 0.89, 0.89, 0.84, 0.86, 0.85, 0.83, 0.78, 0.78, 0.8, 0.85, 0.86, 0.82, 0.85, 0.87, 0.85, 0.82, 0.85, 0.85, 0.89, 0.88, 0.88, 0.89, 0.85, 0.78, 0.68, 0.67, 0.67, 0.65, 0.83, 0.85, 0.88, 0.87, 0.85, 0.84, 0.85, 0.85, 0.86, 0.85, 0.84, 0.85, 0.87, 0.86, 0.78, 0.76, 0.7, 0.67, 0.67, 0.83, 0.85, 0.86, 0.85, 0.77, 0.69, 0.67, 0.74, 0.85, 0.85, 0.85, 0.88, 0.89], [0.5, 0.45, 0.35, 0.62, 0.66, 0.56, 0.51, 0.51, 0.51, 0.55, 0.58, 0.65, 0.67, 0.7, 0.74, 0.77, 0.84, 0.83, 0.82, 0.85, 0.85, 0.78, 0.59, 0.57, 0.72, 0.86, 0.81, 0.66, 0.61, 0.59, 0.62, 0.66, 0.69, 0.81, 0.86, 0.67, 0.68, 0.68, 0.73, 0.84, 0.88, 0.85, 0.82, 0.82, 0.8, 0.81, 0.84, 0.87, 0.87, 0.87, 0.87, 0.87, 0.8, 0.72, 0.59, 0.63, 0.71, 0.8, 0.84, 0.86, 0.86, 0.84, 0.79, 0.75, 0.67, 0.69, 0.69, 0.69, 0.7, 0.71, 0.74, 0.8, 0.8, 0.67, 0.63, 0.66, 0.8, 0.84, 0.79, 0.77, 0.78, 0.86, 0.85, 0.81, 0.74, 0.72, 0.74, 0.69, 0.74, 0.81, 0.86, 0.85, 0.84, 0.82, 0.82, 0.82, 0.82, 0.85, 0.83, 0.85, 0.85, 0.85, 0.85, 0.85, 0.85, 0.85, 0.82, 0.84, 0.84, 0.89, 0.86, 0.83, 0.79, 0.73, 0.74, 0.79, 0.82, 0.87, 0.85, 0.84], [0.39, 0.32, 0.36, 0.48, 0.68, 0.67, 0.62, 0.63, 0.63, 0.64, 0.69, 0.7, 0.73, 0.57, 0.52, 0.41, 0.45, 0.47, 0.45, 0.47, 0.62, 0.74, 0.79, 0.78, 0.77, 0.78, 0.8, 0.81, 0.82, 0.78, 0.79, 0.79, 0.76, 0.79, 0.74, 0.65, 0.61, 0.54, 0.57, 0.68, 0.81, 0.82, 0.8, 0.74, 0.71, 0.7, 0.71, 0.69, 0.67, 0.65, 0.69, 0.71, 0.76, 0.8, 0.77, 0.71, 0.54, 0.54, 0.54, 0.56, 0.55, 0.55, 0.6, 0.64, 0.73, 0.8, 0.8, 0.8, 0.8, 0.81, 0.8, 0.8, 0.8, 0.78, 0.8, 0.81, 0.79, 0.72, 0.64, 0.62, 0.61, 0.62, 0.63, 0.71, 0.76, 0.8, 0.79, 0.77, 0.69, 0.6, 0.57, 0.59, 0.55, 0.51, 0.51, 0.55, 0.6, 0.59, 0.63, 0.79, 0.79, 0.75, 0.66, 0.61, 0.61, 0.61, 0.65, 0.75, 0.81, 0.8, 0.73, 0.62, 0.61, 0.63, 0.62, 0.71, 0.8, 0.84, 0.81, 0.8], [0.69, 0.69, 0.67, 0.57, 0.52, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.55, 0.57, 0.66, 0.69, 0.54, 0.4, 0.41, 0.45, 0.47, 0.49, 0.45, 0.43, 0.43, 0.62, 0.76, 0.67, 0.63, 0.58, 0.57, 0.55, 0.55, 0.54, 0.54, 0.53, 0.55, 0.55, 0.55, 0.53, 0.54, 0.56, 0.57, 0.57, 0.59, 0.61, 0.63, 0.65, 0.74, 0.75, 0.67, 0.61, 0.47, 0.46, 0.45, 0.48, 0.49, 0.49, 0.49, 0.49, 0.49, 0.46, 0.5, 0.57, 0.68, 0.75, 0.72, 0.65, 0.62, 0.61, 0.6, 0.59, 0.58, 0.58, 0.59, 0.6, 0.61, 0.64, 0.7, 0.72, 0.73, 0.73, 0.72, 0.73, 0.73, 0.72, 0.73, 0.73, 0.73, 0.73, 0.73, 0.74, 0.74, 0.72, 0.64, 0.63, 0.61, 0.6, 0.6, 0.63, 0.65, 0.71, 0.74, 0.74, 0.68, 0.53, 0.55, 0.55, 0.54, 0.55, 0.55, 0.54, 0.54, 0.54, 0.54, 0.55, 0.54, 0.54, 0.55, 0.55, 0.53]]
# [[0.5, 0.499, 0.498, 0.47, 0.426, 0.482, 0.745, 0.758, 0.701, 0.698, 0.696, 0.678, 0.633, 0.63, 0.619, 0.597, 0.59, 0.6, 0.609, 0.631, 0.66, 0.791, 0.858, 0.828, 0.804, 0.747, 0.734, 0.666, 0.701, 0.824, 0.85, 0.859, 0.857, 0.855, 0.843, 0.845, 0.84, 0.847, 0.851, 0.838, 0.805, 0.773, 0.814, 0.825, 0.862, 0.873, 0.901, 0.902, 0.888, 0.886, 0.878, 0.882, 0.871, 0.889, 0.9, 0.849, 0.845, 0.885, 0.89, 0.87, 0.864, 0.852, 0.832, 0.846, 0.832, 0.828, 0.787, 0.791, 0.815, 0.837, 0.888, 0.869, 0.891, 0.891, 0.844, 0.823, 0.836, 0.844, 0.879, 0.906, 0.906, 0.906, 0.881, 0.84, 0.785, 0.785, 0.782, 0.772, 0.851, 0.904, 0.899, 0.872, 0.839, 0.831, 0.84, 0.844, 0.854, 0.853, 0.827, 0.837, 0.874, 0.895, 0.846, 0.843, 0.817, 0.787, 0.783, 0.859, 0.896, 0.895, 0.888, 0.847, 0.797, 0.787, 0.826, 0.881, 0.896, 0.896, 0.909, 0.897], [0.479, 0.448, 0.407, 0.659, 0.649, 0.564, 0.513, 0.512, 0.517, 0.559, 0.602, 0.65, 0.702, 0.736, 0.756, 0.791, 0.829, 0.83, 0.826, 0.838, 0.847, 0.808, 0.614, 0.601, 0.76, 0.845, 0.81, 0.699, 0.637, 0.62, 0.643, 0.691, 0.721, 0.809, 0.86, 0.731, 0.718, 0.708, 0.767, 0.856, 0.861, 0.836, 0.819, 0.814, 0.813, 0.818, 0.831, 0.846, 0.854, 0.84, 0.834, 0.839, 0.845, 0.753, 0.727, 0.731, 0.78, 0.848, 0.853, 0.843, 0.839, 0.829, 0.801, 0.758, 0.715, 0.718, 0.722, 0.718, 0.721, 0.732, 0.759, 0.812, 0.832, 0.791, 0.768, 0.79, 0.814, 0.85, 0.814, 0.779, 0.795, 0.849, 0.864, 0.831, 0.826, 0.812, 0.825, 0.795, 0.812, 0.859, 0.88, 0.88, 0.879, 0.859, 0.854, 0.86, 0.877, 0.888, 0.888, 0.888, 0.884, 0.879, 0.887, 0.889, 0.889, 0.888, 0.879, 0.873, 0.889, 0.89, 0.844, 0.827, 0.787, 0.749, 0.758, 0.787, 0.825, 0.845, 0.841, 0.828], [0.405, 0.415, 0.479, 0.59, 0.689, 0.664, 0.636, 0.646, 0.652, 0.662, 0.689, 0.717, 0.752, 0.685, 0.598, 0.518, 0.469, 0.469, 0.479, 0.55, 0.642, 0.772, 0.815, 0.789, 0.782, 0.787, 0.821, 0.821, 0.804, 0.79, 0.823, 0.79, 0.779, 0.801, 0.766, 0.694, 0.655, 0.619, 0.633, 0.753, 0.826, 0.829, 0.809, 0.77, 0.752, 0.736, 0.748, 0.727, 0.719, 0.703, 0.723, 0.743, 0.777, 0.824, 0.803, 0.751, 0.661, 0.663, 0.664, 0.659, 0.668, 0.687, 0.701, 0.711, 0.78, 0.821, 0.822, 0.818, 0.819, 0.805, 0.793, 0.799, 0.821, 0.821, 0.817, 0.828, 0.791, 0.754, 0.707, 0.675, 0.663, 0.671, 0.702, 0.744, 0.777, 0.8, 0.824, 0.818, 0.757, 0.721, 0.716, 0.674, 0.646, 0.623, 0.623, 0.659, 0.683, 0.721, 0.744, 0.811, 0.817, 0.767, 0.702, 0.662, 0.652, 0.662, 0.702, 0.77, 0.833, 0.821, 0.795, 0.745, 0.738, 0.729, 0.739, 0.78, 0.826, 0.846, 0.817, 0.808], [0.698, 0.697, 0.66, 0.587, 0.531, 0.52, 0.515, 0.505, 0.505, 0.515, 0.521, 0.549, 0.59, 0.668, 0.731, 0.62, 0.505, 0.441, 0.436, 0.448, 0.454, 0.447, 0.469, 0.531, 0.686, 0.768, 0.7, 0.637, 0.6, 0.575, 0.569, 0.567, 0.563, 0.563, 0.562, 0.564, 0.564, 0.564, 0.561, 0.562, 0.566, 0.58, 0.585, 0.595, 0.627, 0.676, 0.708, 0.766, 0.773, 0.729, 0.667, 0.592, 0.557, 0.541, 0.53, 0.509, 0.511, 0.512, 0.511, 0.531, 0.559, 0.609, 0.635, 0.74, 0.778, 0.755, 0.708, 0.676, 0.647, 0.626, 0.615, 0.605, 0.593, 0.611, 0.626, 0.657, 0.704, 0.737, 0.759, 0.777, 0.782, 0.782, 0.782, 0.781, 0.777, 0.769, 0.774, 0.775, 0.776, 0.776, 0.78, 0.781, 0.756, 0.706, 0.684, 0.666, 0.648, 0.65, 0.686, 0.714, 0.749, 0.778, 0.779, 0.733, 0.67, 0.65, 0.644, 0.646, 0.645, 0.645, 0.647, 0.647, 0.65, 0.648, 0.648, 0.637, 0.64, 0.65, 0.655, 0.679]]
# [[1.06230646701364, 1.0440390159062174, 1.019540728532737, 0.9927581325079217, 0.9727536834639425, 0.9566355305596719, 0.9443677936757118, 0.9350682490532197, 0.9286041965820462, 0.9208845523174363, 0.9135723266947816, 0.9087611250331483, 0.907044398283654, 0.9027175543227944, 0.9004420974677312, 0.9030524213148268, 0.9015318209920945, 0.8981885468695601, 0.893660049734715, 0.8860488993802925, 0.8808607136144635, 0.8680002987263999, 0.8617870951257737, 0.8612271712912043, 0.859817413856856, 0.8591770256935586, 0.8568007924763915, 0.8565044923830754, 0.852025323295406, 0.8438178676973789, 0.837673743647112, 0.833232004787083, 0.8293419285461462, 0.8255053870289002, 0.8216931016909519, 0.8176861545088765, 0.8139271914756107, 0.8094519224469888, 0.8050181333210332, 0.801911611244349, 0.8009858306847442, 0.8004441558811763, 0.7919455905639017, 0.7867800551480403, 0.7799766096481056, 0.7760804565186269, 0.7757117474004813, 0.7714504261816704, 0.7655732962185773, 0.7619355373005746, 0.7579190550391424, 0.7546898567078746, 0.7513576944265976, 0.7490337430007553, 0.748633658165817, 0.7530893538661192, 0.7511123903156313, 0.744131242666755, 0.7397552546405805, 0.7386660084065955, 0.7384864439391177, 0.7390233161537247, 0.741852065590132, 0.7398875890975036, 0.7415410977115827, 0.7424327255181503, 0.7498014699289764, 0.7491464736523941, 0.744288418499221, 0.7403246229947338, 0.736165748257034, 0.738610278141321, 0.7363549015034113, 0.7351536610356236, 0.737844447659059, 0.7412961212636846, 0.738375508623722, 0.7368694614574345, 0.7335169685665623, 0.733892594254699, 0.7337578166151664, 0.7333717284523572, 0.7377890234641228, 0.7420919512882636, 0.7481764010847608, 0.7482641670423873, 0.7482500295540201, 0.750215071346752, 0.738593670013854, 0.7338160549008671, 0.7330760906849353, 0.7336323847999362, 0.7375331057224886, 0.7386318654723297, 0.7372409782216718, 0.7370558680136083, 0.7360913365231212, 0.7366357244005403, 0.7408219344479398, 0.738595499122686, 0.7345756412955289, 0.7339782190233487, 0.7389107556930234, 0.7394912445188545, 0.7421731819053814, 0.7466382174964257, 0.7480840207299139, 0.7372840273206313, 0.7340301562325898, 0.7345705768196932, 0.7350875811052412, 0.7392022863762653, 0.7456502981604312, 0.7465633243375897, 0.7415024147048443, 0.7363823911105308, 0.7355297333136868, 0.7356577435494307, 0.7337949246351525, 0.7325421817421442], [1.0189451141597514, 1.0052659872101304, 0.9901846428991067, 0.9800992540094388, 0.9778032891915036, 0.9809804254437507, 0.9856623435842339, 0.9829171346369929, 0.9771665962793384, 0.9643647683836812, 0.9537624306839075, 0.943811561676663, 0.9343700158684465, 0.9263996688695918, 0.9200812844029632, 0.9135793541028276, 0.9080133729573816, 0.9033768104365054, 0.8994237410054876, 0.8958567501073531, 0.8928988803826392, 0.8914051376013686, 0.8930220874262824, 0.891704725201666, 0.8858914447434911, 0.8823725267030639, 0.8824290816534228, 0.8903257906237517, 0.8982268086049917, 0.9003509988869159, 0.8944246420567489, 0.8868706034144799, 0.8811814295760643, 0.8719673958697902, 0.868196927037249, 0.8699179844981316, 0.8680392071704728, 0.8659028742795214, 0.8612283329743733, 0.855397339923354, 0.851159906581404, 0.8482821569827107, 0.8462081821004127, 0.8435440438868052, 0.8408272099302442, 0.8375293321727654, 0.8337501134688218, 0.8303645413866287, 0.8276043085112015, 0.8253474852414364, 0.8232345034887452, 0.8205331055588811, 0.81910407477685, 0.8216142408160264, 0.8244247796761836, 0.8206270296838399, 0.8140482310325589, 0.8088477261111251, 0.8070002128373529, 0.8061983531176946, 0.8052657278957853, 0.8055789868067067, 0.8072192436278294, 0.8128641345071588, 0.8199920438622651, 0.8188778471725982, 0.817310318945423, 0.8177376839184244, 0.817201910355627, 0.8155234370897867, 0.8109836068708647, 0.8051667015780438, 0.8013762141236599, 0.8035261373254261, 0.8047101847059052, 0.8032812656160857, 0.8008258613138047, 0.8007503308914108, 0.8037555227783206, 0.8071594223026153, 0.8046069658374637, 0.79960 ...

# %%
#plot 1:

plt.figure(figsize=(18, 4))
plt.subplot(1, 3, 1)

plt.plot([i for i in range(120)],his1[0], label = 'noiseless')
plt.plot([i for i in range(120)],his1[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his1[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his1[3], label = 'p=0.3')
plt.ylim((0.26, 0.9))
plt.xlabel('Training steps')
plt.ylabel('Amplitude damping test accuracy')
plt.legend()
#plt.title("plot 1")

plt.subplot(1, 3, 2)

plt.plot([i for i in range(120)],his2[0], label = 'noiseless')
plt.plot([i for i in range(120)],his2[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his2[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his2[3], label = 'p=0.3')
plt.ylim((0.26, 0.8))
plt.xlabel('Training steps')
plt.ylabel('Amplitude damping train accuracy')
plt.legend()
#plt.title("plot 2")

plt.subplot(1, 3, 3)

plt.plot([i for i in range(120)],his3[0], label = 'noiseless')
plt.plot([i for i in range(120)],his3[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his3[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his3[3], label = 'p=0.3')
#plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Amplitude damping cost function')
plt.legend()
#plt.title("plot 2")

#plt.suptitle("RUNOOB subplot Test")
plt.savefig('Angle_Encoding_Hardware_efficient_ansatz4',dpi=800,bbox_inches='tight')
plt.show()
