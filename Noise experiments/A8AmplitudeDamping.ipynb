# %%
import pennylane as qml
from pennylane import numpy as np
from sklearn.decomposition import PCA
import random
from collections import Counter
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
wire = 2

wires = wire * 2
dim = 2 ** wire
dim1 = 2 * dim
dev = qml.device('default.mixed', wires=wires)
#dev = qml.device("lightning.qubit", wires=wires, shots=None)
#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
dev1 = qml.device("lightning.qubit", wires=wire, shots=None)
wires = dev.wires.tolist()

@qml.qnode(dev1)
def StateVector(x):
    qml.AmplitudeEmbedding(features=x, wires=range(wire), 
                           pad_with=0.0, normalize=True)
    return qml.state()

def accuracy(labels, predictions):

    loss = 0
    for l, p in zip(labels, predictions):
        if abs(l - p) < 1e-5:
            loss = loss + 1
    loss = loss / len(labels)

    return loss

def square_loss(labels, predictions):
    loss = 0
    for l, p in zip(labels, predictions):
        loss = loss + (l - p) ** 2

    loss = loss / len(labels)
    return loss

def noramlization(data):
    minVals = data.min(0)
    maxVals = data.max(0)
    ranges = maxVals - minVals
    normData = np.zeros(np.shape(data))
    m = data.shape[0]
    normData = data - np.tile(minVals, (m, 1))
    normData = normData/np.tile(ranges, (m, 1))
    return normData

def random_params(num_wires):
    """Generate random variational parameters in the shape for the ansatz."""
    return np.random.uniform(0, 2 * np.pi, num_wires, requires_grad=True)

num_para = 5
params_init = random_params(3 * num_para + wire)
print(params_init)
# Out:
# [3.09825438 0.87020412 1.28913386 3.4535243  5.10493448 0.82811934
#  3.55234941 0.1734307  5.39051749 5.18378943 3.34382601 4.37813688
#  0.8807117  1.78842265 4.02760165 2.96307731 0.8645957 ]

# %%
def ProcessingData(datapoints, train_size, test_size):
    train_data = np.loadtxt("./mnist_train.csv", delimiter=",")
    print(train_data.shape)
    #Extracting features and labels from the dataset 
    train_data_features = train_data[:datapoints, 1:]
    train_data_labels = train_data[:datapoints, :1].reshape(datapoints,)

    # Use PCA technique to reduce dimensions to 4
    DimReduce = PCA(n_components= dim1)
    train_data_features_reduced = DimReduce.fit_transform(train_data_features)
    # normalize dataset
    train_data_features_reduced = noramlization(train_data_features_reduced)
    s1 = np.array([StateVector(x) for x in train_data_features_reduced[:,:dim]])
    s2 = np.array([StateVector(x) for x in train_data_features_reduced[:,dim:]])
    train_data_features_reduced = np.hstack((s1, s2)).tolist()

    zero_one_datapoint_array = []
    label_0_1 = []
    zero_datapoints_array = [] #an array of the data points containing value 0
    one_datapoints_array = []# an array of the data points containing value 1
    label_0 = []
    label_1 = []
        
    for i in range(datapoints):
        if train_data_labels[i] == 0:                   # extracting zeros
            label_0.append(-1)
            zero_datapoints_array.append(train_data_features_reduced[i])
        elif train_data_labels[i] == 1:                   # extracting ones
            label_1.append(1)
            one_datapoints_array.append(train_data_features_reduced[i]) 
    print(len(zero_datapoints_array), len(one_datapoints_array))
    if (len(label_0) + len(label_1)) < 2 * (train_size + test_size):
        print("datapoints is too small!")
    else:
        print((len(label_0),len(label_1)))
        zero_datapoints_array_train = zero_datapoints_array[:train_size]
        one_datapoints_array_train = one_datapoints_array[:train_size]
        label_0_train = label_0[:train_size]
        label_1_train = label_1[:train_size]
        zero_datapoints_array_test = zero_datapoints_array[train_size + 1:train_size + test_size + 1]
        one_datapoints_array_test = one_datapoints_array[train_size + 1:train_size + test_size + 1]
        label_0_test = label_0[train_size + 1:train_size + test_size + 1]
        label_1_test = label_1[train_size + 1:train_size + test_size + 1]
        #print(len(zero_datapoints_array_train), len(label_1_train))
        #print(len(one_datapoints_array_test), len(label_0_test))

        zero_one_datapoint_array_train = zero_datapoints_array_train + one_datapoints_array_train
        label_0_1_train = label_0_train + label_1_train
        zero_one_datapoint_array_test = zero_datapoints_array_test + one_datapoints_array_test
        label_0_1_test = label_0_test + label_1_test
        #print(len(zero_one_datapoint_array_train), label_0_1_train)
        #print(len(zero_one_datapoint_array_test), label_0_1_test)

        np.random.seed(10)
        index_train = np.random.permutation(range(2 * train_size))
        index_test = np.random.permutation(range(2 * test_size))

        feats_train = []
        Y_train = []
        feats_val = []
        Y_val = []
        for i in range(2 * train_size):
            feats_train.append(zero_one_datapoint_array_train[index_train[i]])
            Y_train.append(label_0_1_train[index_train[i]])


        for i in range(2 * test_size):
            feats_val.append(zero_one_datapoint_array_test[index_test[i]])
            Y_val.append(label_0_1_test[index_test[i]])

        #print(feats_val, Y_val)

        features = feats_train + feats_val
        features = np.array(features, requires_grad=False)
        Y = Y_train + Y_val
        Y = np.array(Y, requires_grad=False)
        feats_train = np.array(feats_train, requires_grad=False)
        Y_train = np.array(Y_train, requires_grad=False)
        feats_val = np.array(feats_val, requires_grad=False)
        Y_val = np.array(Y_val, requires_grad=False)
    return feats_train, Y_train, feats_val, Y_val, features, Y

datapoints = 6000
train_size = 500
test_size = 50
feats_train, Y_train, feats_val, Y_val, features, Y = ProcessingData(datapoints, train_size, test_size)
# Out:
# (60000, 785)
# 592 671
# (592, 671)

# %%
#Block-encoding + Hardware-efficient Ansatz
def DataEncoding(x, wires_start, wires_end):
    wires = np.arange(wires_start, wires_end).tolist()
    qml.MottonenStatePreparation(state_vector=x, wires=wires)
    #qml.AmplitudeEmbedding(features=x, wires=wires, pad_with=0., normalize=True)

def Ansatz(params, wires_start, wires_end):
    for i in np.arange(wires_start, wires_end):
        qml.Hadamard(wires=wires[i])
        qml.RY(params[i - wires_start], wires=wires[i])
    qml.CNOT(wires=[wires[wires_start], wires[wires_end - 1]])
    qml.RZ(params[wires_end - wires_start], wires=wires[wires_end - 1])
    qml.CNOT(wires=[wires_start, wires_end - 1])
    for i in np.arange(wires_start, wires_end):
        qml.RY(params[i + wires_end - 2 * wires_start], wires=wires[i])
        qml.Hadamard(wires=wires[i])

p = 0
#@qml.qnode(dev, interface="torch", diff_method="parameter-shift")
@qml.qnode(dev)
def QKSAN(feat, params):
    x1 = feat[0:4]
    x2 = feat[4:8]
    DataEncoding(x1, 0, wire)
    Ansatz(params[0: num_para], 0, wire)
    qml.adjoint(Ansatz)(params[num_para: 2 * num_para], 0, wire)
    qml.adjoint(DataEncoding)(x2, 0, wire)


    DataEncoding(x2, wire, (2 * wire))
    Ansatz(params[2 * num_para: 3 * num_para], wire, (2 * wire))
    if p != 0:
        for i in range(2 * wire):
            qml.AmplitudeDamping(p, wires=i)
    for i in range(wire):
        qml.cond(qml.measure(i), qml.RY)(params[3 * num_para + i], wires=wires[i + wire])
    return qml.expval(qml.PauliZ(2 * wire - 1))

qml.drawer.use_style('black_white')
fig, ax = qml.draw_mpl(QKSAN, show_all_wires=True)(feats_train[0], params_init)
fig.set_size_inches((7, 5))

def variational_classifier(params, feat):
    return QKSAN(feat, params)


def cost(params, features, labels):
    predictions = [variational_classifier(params, feat) for feat in features]
    return square_loss(labels, predictions)

def TrainQKSAN(params_init):
    opt = qml.NesterovMomentumOptimizer(0.09)
    batch_size = 30
    weights = params_init
    #bias = np.array(0.0, requires_grad=True)
    his_acc_val = []
    his_acc_train = []
    his_cost = []
    f1_train = []
    f1_test = []
    roc_auc_train = []
    roc_auc_test = []
    for it in range(120):

        # Update the weights by one optimizer step
        batch_index = np.random.randint(0, 2 * train_size, (batch_size,))
        feats_train_batch = feats_train[batch_index]
        Y_train_batch = Y_train[batch_index]
        
        weights, _, _ = opt.step(cost, weights, feats_train_batch, Y_train_batch)

        # Compute predictions on train and validation set
        predictions_train = [np.sign(variational_classifier(weights, feat)) for feat in feats_train]
        predictions_val = [np.sign(variational_classifier(weights, feat)) for feat in feats_val]
        #print(probs(Y_train, predictions_val))
        c = cost(weights, features, Y).numpy()
        #print(c)
        # Compute accuracy on train and validation set
        acc_train = accuracy_score(Y_train, predictions_train)
        acc_val = accuracy_score(Y_val, predictions_val)
        a = f1_score(Y_train, predictions_train)
        b = f1_score(Y_val, predictions_val)
        
        print("f1_score is", a, b)
        d = roc_auc_score(Y_train, predictions_train)
        e = roc_auc_score(Y_val, predictions_val)
        print("roc_auc_score is", d, e)


        f1_train.append(a)
        f1_test.append(b)
        roc_auc_train.append(d)
        roc_auc_test.append(e)
        his_acc_val.append(acc_val)
        his_acc_train.append(acc_train)
        his_cost.append(c)
        print("Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
            "".format(it + 1, c, acc_train, acc_val))
    print(p)
    return his_acc_val, his_acc_train, his_cost, f1_train, f1_test, roc_auc_train, roc_auc_test

# %%
ps = [0, 0.1, 0.2, 0.3]
his1 = []
his2 = []
his3 = []

for p in ps:
    his_acc_val, his_acc_train, his_cost, _, _, _, _ = TrainQKSAN(params_init)
    his1.append(his_acc_val)
    his2.append(his_acc_train)
    his3.append(his_cost)
# Out:
# f1_score is 0.38470451911935116 0.27848101265822783
# roc_auc_score is 0.46900000000000003 0.43000000000000005
# Iter:     1 | Cost: 1.0947356 | Acc train: 0.4690000 | Acc validation: 0.4300000
# f1_score is 0.3719298245614035 0.25641025641025644
# roc_auc_score is 0.463 0.42
# Iter:     2 | Cost: 1.0916867 | Acc train: 0.4630000 | Acc validation: 0.4200000
# f1_score is 0.3907514450867052 0.27848101265822783
# roc_auc_score is 0.473 0.43000000000000005
# Iter:     3 | Cost: 1.0824096 | Acc train: 0.4730000 | Acc validation: 0.4300000
# f1_score is 0.47413793103448276 0.3488372093023256
# roc_auc_score is 0.512 0.44000000000000006
# Iter:     4 | Cost: 1.0632865 | Acc train: 0.5120000 | Acc validation: 0.4400000
# f1_score is 0.5292307692307692 0.38636363636363635
# roc_auc_score is 0.541 0.4600000000000001
# Iter:     5 | Cost: 1.0439076 | Acc train: 0.5410000 | Acc validation: 0.4600000
# f1_score is 0.5705765407554672 0.4044943820224719
# roc_auc_score is 0.5680000000000001 0.47000000000000003
# Iter:     6 | Cost: 1.0221123 | Acc train: 0.5680000 | Acc validation: 0.4700000
# f1_score is 0.5909090909090909 0.4222222222222222
# roc_auc_score is 0.5860000000000001 0.48
# Iter:     7 | Cost: 0.9981133 | Acc train: 0.5860000 | Acc validation: 0.4800000
# f1_score is 0.6468401486988846 0.4731182795698925
# roc_auc_score is 0.62 0.51
# Iter:     8 | Cost: 0.9694975 | Acc train: 0.6200000 | Acc validation: 0.5100000
# f1_score is 0.6832740213523132 0.5208333333333334
# roc_auc_score is 0.644 0.54
# Iter:     9 | Cost: 0.9418474 | Acc train: 0.6440000 | Acc validation: 0.5400000
# f1_score is 0.6990116801437556 0.5208333333333334
# roc_auc_score is 0.665 0.54
# Iter:    10 | Cost: 0.9053891 | Acc train: 0.6650000 | Acc validation: 0.5400000
# f1_score is 0.7155797101449274 0.5510204081632654
# roc_auc_score is 0.686 0.56
# Iter:    11 | Cost: 0.8688019 | Acc train: 0.6860000 | Acc validation: 0.5600000
# f1_score is 0.743521000893655 0.607843137254902
# roc_auc_score is 0.7129999999999999 0.6000000000000001
# Iter:    12 | Cost: 0.8344367 | Acc train: 0.7130000 | Acc validation: 0.6000000
# f1_score is 0.782006920415225 0.709090909090909
# roc_auc_score is 0.7480000000000001 0.6800000000000002
# Iter:    13 | Cost: 0.8057475 | Acc train: 0.7480000 | Acc validation: 0.6800000
# f1_score is 0.7905346187554777 0.7272727272727272
# roc_auc_score is 0.761 0.7000000000000001
# Iter:    14 | Cost: 0.7742726 | Acc train: 0.7610000 | Acc validation: 0.7000000
# f1_score is 0.8113207547169811 0.743362831858407
# roc_auc_score is 0.78 0.7100000000000001
# Iter:    15 | Cost: 0.7528497 | Acc train: 0.7800000 | Acc validation: 0.7100000
# f1_score is 0.8182572614107884 0.8264462809917354
# roc_auc_score is 0.781 0.79
# Iter:    16 | Cost: 0.7452106 | Acc train: 0.7810000 | Acc validation: 0.7900000
# f1_score is 0.8211920529801324 0.8264462809917354
# roc_auc_score is 0.784 0.79
# Iter:    17 | Cost: 0.7259441 | Acc train: 0.7840000 | Acc validation: 0.7900000
# f1_score is 0.8316666666666667 0.8264462809917354
# roc_auc_score is 0.798 0.79
# Iter:    18 | Cost: 0.7007185 | Acc train: 0.7980000 | Acc validation: 0.7900000
# f1_score is 0.8473998294970162 0.8547008547008548
# roc_auc_score is 0.821 0.83
# Iter:    19 | Cost: 0.6692891 | Acc train: 0.8210000 | Acc validation: 0.8300000
# f1_score is 0.8618881118881119 0.8620689655172413
# roc_auc_score is 0.8419999999999999 0.84
# Iter:    20 | Cost: 0.6386191 | Acc train: 0.8420000 | Acc validation: 0.8400000
# f1_score is 0.870026525198939 0.8928571428571428
# roc_auc_score is 0.853 0.88
# Iter:    21 | Cost: 0.6149572 | Acc train: 0.8530000 | Acc validation: 0.8800000
# f1_score is 0.9113441372735939 0.8598130841121495
# roc_auc_score is 0.907 0.85
# Iter:    22 | Cost: 0.5958980 | Acc train: 0.9070000 | Acc validation: 0.8500000
# f1_score is 0.9481180061037641 0.8775510204081632
# roc_auc_score is 0.949 0.88
# Iter:    23 | Cost: 0.5877738 | Acc train: 0.9490000 | Acc validation: 0.8800000
# f1_score is 0.969325153374233 0.8979591836734694
# roc_auc_score is 0.97 0.9
# Iter:    24 | Cost: 0.5743128 | Acc train: 0.9700000 | Acc validation: 0.9000000
# f1_score is 0.9809428284854563 0.9514563106796116
# roc_auc_score is 0.981 0.9500000000000001
# Iter:    25 | Cost: 0.5548428 | Acc train: 0.9810000 | Acc validation: 0.9500000
# f1_score is 0.9791459781529294 0.9514563106796116
# roc_auc_score is 0.979 0.9500000000000001
# Iter:    26 | Cost: 0.5441496 | Acc train: 0.9790000 | Acc validation: 0.9500000
# f1_score is 0.9647749510763209 0.9333333333333333
# roc_auc_score is 0.964 0.9299999999999999
# Iter:    27 | Cost: 0.5376953 | Acc train: 0.9640000 | Acc validation: 0.9300000
# f1_score is 0.9535783365570599 0.9423076923076924
# roc_auc_score is 0.952 0.9400000000000001
# Iter:    28 | Cost: 0.5350377 | Acc train: 0.9520000 | Acc validation: 0.9400000
# f1_score is 0.9445506692160612 0.9259259259259259
# roc_auc_score is 0.942 0.9199999999999999
# Iter:    29 | Cost: 0.5340455 | Acc train: 0.9420000 | Acc validation: 0.9200000
# f1_score is 0.9383886255924171 0.9174311926605504
# roc_auc_score is 0.935 0.91
# Iter:    30 | Cost: 0.5347102 | Acc train: 0.9350000 | Acc validation: 0.9100000
# f1_score is 0.9304511278195489 0.9174311926605504
# roc_auc_score is 0.9259999999999999 0.91
# Iter:    31 | Cost: 0.5342704 | Acc train: 0.9260000 | Acc validation: 0.9100000
# f1_score is 0.9274269557021677 0.9074074074074074
# roc_auc_score is 0.9229999999999999 0.9000000000000001
# Iter:    32 | Cost: 0.5327568 | Acc train: 0.9230000 | Acc validation: 0.9000000
# f1_score is 0.9301435406698564 0.9056603773584904
# roc_auc_score is 0.9269999999999999 0.8999999999999999
# Iter:    33 | Cost: 0.5331955 | Acc train: 0.9270000 | Acc validation: 0.9000000
# f1_score is 0.9173955296404275 0.9142857142857144
# roc_auc_score is 0.9149999999999999 0.91
# Iter:    34 | Cost: 0.5356100 | Acc train: 0.9150000 | Acc validation: 0.9100000
# f1_score is 0.9082031249999999 0.9142857142857144
# roc_auc_score is 0.906 0.91
# Iter:    35 | Cost: 0.5390991 | Acc train: 0.9060000 | Acc validation: 0.9100000
# f1_score is 0.9020368574199806 0.9142857142857144
# roc_auc_score is 0.899 0.91
# Iter:    36 | Cost: 0.5413603 | Acc train: 0.8990000 | Acc validation: 0.9100000
# f1_score is 0.8984674329501916 0.9142857142857144
# roc_auc_score is 0.894 0.91
# Iter:    37 | Cost: 0.5423438 | Acc train: 0.8940000 | Acc validation: 0.9100000
# f1_score is 0.898854961832061 0.9142857142857144
# roc_auc_score is 0.8939999999999999 0.91
# Iter:    38 | Cost: 0.5423467 | Acc train: 0.8940000 | Acc validation: 0.9100000
# f1_score is 0.897998093422307 0.9056603773584904
# roc_auc_score is 0.8929999999999999 0.8999999999999999
# Iter:    39 | Cost: 0.5437169 | Acc train: 0.8930000 | Acc validation: 0.9000000
# f1_score is 0.895910780669145 0.888888888888889
# roc_auc_score is 0.8880000000000001 0.88
# Iter:    40 | Cost: 0.5467771 | Acc train: 0.8880000 | Acc validation: 0.8800000
# f1_score is 0.8907103825136612 0.888888888888889
# roc_auc_score is 0.88 0.88
# Iter:    41 | Cost: 0.5507400 | Acc train: 0.8800000 | Acc validation: 0.8800000
# f1_score is 0.8900900900900901 0.8928571428571428
# roc_auc_score is 0.878 0.88
# Iter:    42 | Cost: 0.5538155 | Acc train: 0.8780000 | Acc validation: 0.8800000
# f1_score is 0.897179253867152 0.9090909090909091
# roc_auc_score is 0.887 0.9
# Iter:    43 | Cost: 0.5460840 | Acc train: 0.8870000 | Acc validation: 0.9000000
# f1_score is 0.9013824884792627 0.8990825688073395
# roc_auc_score is 0.893 0.89
# Iter:    44 | Cost: 0.5402697 | Acc train: 0.8930000 | Acc validation: 0.8900000
# f1_score is 0.9279538904899136 0.9056603773584904
# roc_auc_score is 0.9249999999999999 0.8999999999999999
# Iter:    45 | Cost: 0.5358848 | Acc train: 0.9250000 | Acc validation: 0.9000000
# f1_score is 0.9333333333333333 0.9142857142857144
# roc_auc_score is 0.931 0.91
# Iter:    46 | Cost: 0.5353146 | Acc train: 0.9310000 | Acc validation: 0.9100000
# f1_score is 0.9285014691478943 0.923076923076923
# roc_auc_score is 0.927 0.9199999999999999
# Iter:    47 | Cost: 0.5382544 | Acc train: 0.9270000 | Acc validation: 0.9200000
# f1_score is 0.9338521400778209 0.923076923076923
# roc_auc_score is 0.932 0.9199999999999999
# Iter:    48 | Cost: 0.5356777 | Acc train: 0.9320000 | Acc validation: 0.9200000
# f1_score is 0.9361702127659575 0.9056603773584904
# roc_auc_score is 0.934 0.8999999999999999
# Iter:    49 | Cost: 0.5320772 | Acc train: 0.9340000 | Acc validation: 0.9000000
# f1_score is 0.9394812680115274 0.9158878504672898
# roc_auc_score is 0.937 0.91
# Iter:    50 | Cost: 0.5306098 | Acc train: 0.9370000 | Acc validation: 0.9100000
# f1_score is 0.9328287606433302 0.9158878504672898
# roc_auc_score is 0.929 0.91
# Iter:    51 | Cost: 0.5304389 | Acc train: 0.9290000 | Acc validation: 0.9100000
# f1_score is 0.9354838709677419 0.9158878504672898
# roc_auc_score is 0.932 0.91
# Iter:    52 | Cost: 0.5288425 | Acc train: 0.9320000 | Acc validation: 0.9100000
# f1_score is 0.9356060606060607 0.9259259259259259
# roc_auc_score is 0.9319999999999999 0.9199999999999999
# Iter:    53 | Cost: 0.5281219 | Acc train: 0.9320000 | Acc validation: 0.9200000
# f1_score is 0.9426386233269598 0.9333333333333333
# roc_auc_score is 0.9400000000000001 0.9299999999999999
# Iter:    54 | Cost: 0.5263868 | Acc train: 0.9400000 | Acc validation: 0.9300000
# f1_score is 0.9554263565891473 0.9423076923076924
# roc_auc_score is 0.9540000000000001 0.9400000000000001
# Iter:    55 | Cost: 0.5279417 | Acc train: 0.9540000 | Acc validation: 0.9400000
# f1_score is 0.9544554455445544 0.9514563106796116
# roc_auc_score is 0.954 0.9500000000000001
# Iter:    56 | Cost: 0.5352435 | Acc train: 0.9540000 | Acc validation: 0.9500000
# f1_score is 0.9592039800995025 0.9183673469387755
# roc_auc_score is 0.959 0.9199999999999999
# Iter:    57 | Cost: 0.5354842 | Acc train: 0.9590000 | Acc validation: 0.9200000
# f1_score is 0.963402571711177 0.9090909090909091
# roc_auc_score is 0.9629999999999999 0.91
# Iter:    58 | Cost: 0.5291320 | Acc train: 0.9630000 | Acc validation: 0.9100000
# f1_score is 0.9569471624266145 0.9320388349514563
# roc_auc_score is 0.956 0.93
# Iter:    59 | Cost: 0.5249038 | Acc train: 0.9560000 | Acc validation: 0.9300000
# f1_score is 0.9522882181110028 0.9423076923076924
# roc_auc_score is 0.951 0.9400000000000001
# Iter:    60 | Cost: 0.5245369 | Acc train: 0.9510000 | Acc validation: 0.9400000
# f1_score is 0.9469623915139826 0.9423076923076924
# roc_auc_score is 0.9450000000000001 0.9400000000000001
# Iter:    61 | Cost: 0.5252434 | Acc train: 0.9450000 | Acc validation: 0.9400000
# f1_score is 0.943432406519655 0.9333333333333333
# roc_auc_score is 0.9410000000000001 0.9299999999999999
# Iter:    62 | Cost: 0.5267809 | Acc train: 0.9410000 | Acc validation: 0.9300000
# f1_score is 0.9398280802292264 0.9245283018867924
# roc_auc_score is 0.937 0.9199999999999999
# Iter:    63 | Cost: 0.5305260 | Acc train: 0.9370000 | Acc validation: 0.9200000
# f1_score is 0.9442307692307692 0.9019607843137256
# roc_auc_score is 0.9420000000000001 0.9
# Iter:    64 | Cost: 0.5291697 | Acc train: 0.9420000 | Acc validation: 0.9000000
# f1_score is 0.9406130268199233 0.8932038834951457
# roc_auc_score is 0.9380000000000001 0.89
# Iter:    65 | Cost: 0.5313087 | Acc train: 0.9380000 | Acc validation: 0.8900000
# f1_score is 0.938814531548757 0.9038461538461539
# roc_auc_score is 0.936 0.8999999999999999
# Iter:    66 | Cost: 0.5323511 | Acc train: 0.9360000 | Acc validation: 0.9000000
# f1_score is 0.9335863377609108 0.9074074074074074
# roc_auc_score is 0.9299999999999999 0.9000000000000001
# Iter:    67 | Cost: 0.5374593 | Acc train: 0.9300000 | Acc validation: 0.9000000
# f1_score is 0.9407265774378586 0.9245283018867924
# roc_auc_score is 0.938 0.9199999999999999
# Iter:    68 | Cost: 0.5315041 | Acc train: 0.9380000 | Acc validation: 0.9200000
# f1_score is 0.9497098646034817 0.9019607843137256
# roc_auc_score is 0.9480000000000001 0.9
# Iter:    69 | Cost: 0.5269369 | Acc train: 0.9480000 | Acc validation: 0.9000000
# f1_score is 0.9504373177842567 0.9019607843137256
# roc_auc_score is 0.9490000000000001 0.9
# Iter:    70 | Cost: 0.5256035 | Acc train: 0.9490000 | Acc validation: 0.9000000
# f1_score is 0.9542743538767396 0.9108910891089109
# roc_auc_score is 0.954 0.91
# Iter:    71 | Cost: 0.5267253 | Acc train: 0.9540000 | Acc validation: 0.9100000
# f1_score is 0.9571286141575274 0.9108910891089109
# roc_auc_score is 0.957 0.91
# Iter:    72 | Cost: 0.5275238 | Acc train: 0.9570000 | Acc validation: 0.9100000
# f1_score is 0.9578017664376839 0.9108910891089109
# roc_auc_score is 0.9569999999999999 0.91
# Iter:    73 | Cost: 0.5240669 | Acc train: 0.9570000 | Acc validation: 0.9100000
# f1_score is 0.9544131910766247 0.9423076923076924
# roc_auc_score is 0.953 0.9400000000000001
# Iter:    74 | Cost: 0.5240637 | Acc train: 0.9530000 | Acc validation: 0.9400000
# f1_score is 0.9387370405278039 0.9259259259259259
# roc_auc_score is 0.935 0.9199999999999999
# Iter:    75 | Cost: 0.5319333 | Acc train: 0.9350000 | Acc validation: 0.9200000
# f1_score is 0.9265116279069767 0.9009009009009009
# roc_auc_score is 0.9209999999999999 0.89
# Iter:    76 | Cost: 0.5375153 | Acc train: 0.9210000 | Acc validation: 0.8900000
# f1_score is 0.9334582942830366 0.9090909090909091
# roc_auc_score is 0.929 0.9
# Iter:    77 | Cost: 0.5332282 | Acc train: 0.9290000 | Acc validation: 0.9000000
# f1_score is 0.9378531073446329 0.9174311926605504
# roc_auc_score is 0.934 0.91
# Iter:    78 | Cost: 0.5292881 | Acc train: 0.9340000 | Acc validation: 0.9100000
# f1_score is 0.9546769527483123 0.9523809523809523
# roc_auc_score is 0.953 0.9500000000000001
# Iter:    79 | Cost: 0.5233182 | Acc train: 0.9530000 | Acc validation: 0.9500000
# f1_score is 0.9610136452241715 0.9523809523809523
# roc_auc_score is 0.9599999999999999 0.9500000000000001
# Iter:    80 | Cost: 0.5230963 | Acc train: 0.9600000 | Acc validation: 0.9500000
# f1_score is 0.9618768328445747 0.9523809523809523
# roc_auc_score is 0.961 0.9500000000000001
# Iter:    81 | Cost: 0.5234009 | Acc train: 0.9610000 | Acc validation: 0.9500000
# f1_score is 0.9610136452241715 0.9523809523809523
# roc_auc_score is 0.9599999999999999 0.9500000000000001
# Iter:    82 | Cost: 0.5237125 | Acc train: 0.9600000 | Acc validation: 0.9500000
# f1_score is 0.9654491609081934 0.9320388349514563
# roc_auc_score is 0.965 0.93
# Iter:    83 | Cost: 0.5253431 | Acc train: 0.9650000 | Acc validation: 0.9300000
# f1_score is 0.9681908548707753 0.92
# roc_auc_score is 0.968 0.9199999999999999
# Iter:    84 | Cost: 0.5267492 | Acc train: 0.9680000 | Acc validation: 0.9200000
# f1_score is 0.971028971028971 0.9292929292929293
# roc_auc_score is 0.971 0.9299999999999998
# Iter:    85 | Cost: 0.5285081 | Acc train: 0.9710000 | Acc validation: 0.9300000
# f1_score is 0.9666329625884732 0.9183673469387755
# roc_auc_score is 0.967 0.9199999999999999
# Iter:    86 | Cost: 0.5305115 | Acc train: 0.9670000 | Acc validation: 0.9200000
# f1_score is 0.9600818833162743 0.9072164948453608
# roc_auc_score is 0.961 0.9099999999999999
# Iter:    87 | Cost: 0.5342275 | Acc train: 0.9610000 | Acc validation: 0.9100000
# f1_score is 0.9522821576763486 0.8723404255319149
# roc_auc_score is 0.9540000000000001 0.8799999999999998
# Iter:    88 | Cost: 0.5387863 | Acc train: 0.9540000 | Acc validation: 0.8800000
# f1_score is 0.9626639757820383 0.9183673469387755
# roc_auc_score is 0.963 0.9199999999999999
# Iter:    89 | Cost: 0.5306102 | Acc train: 0.9630000 | Acc validation: 0.9200000
# f1_score is 0.9625984251968503 0.9108910891089109
# roc_auc_score is 0.962 0.91
# Iter:    90 | Cost: 0.5262658 | Acc train: 0.9620000 | Acc validation: 0.9100000
# f1_score is 0.9607843137254902 0.9108910891089109
# roc_auc_score is 0.96 0.91
# Iter:    91 | Cost: 0.5255918 | Acc train: 0.9600000 | Acc validation: 0.9100000
# f1_score is 0.9524733268671193 0.923076923076923
# roc_auc_score is 0.9510000000000001 0.9199999999999999
# Iter:    92 | Cost: 0.5253845 | Acc train: 0.9510000 | Acc validation: 0.9200000
# f1_score is 0.9508196721311475 0.9433962264150945
# roc_auc_score is 0.949 0.94
# Iter:    93 | Cost: 0.5267474 | Acc train: 0.9490000 | Acc validation: 0.9400000
# f1_score is 0.9538461538461539 0.9433962264150945
# roc_auc_score is 0.9520000000000001 0.94
# Iter:    94 | Cost: 0.5255333 | Acc train: 0.9520000 | Acc validation: 0.9400000
# f1_score is 0.9593023255813953 0.9523809523809523
# roc_auc_score is 0.958 0.9500000000000001
# Iter:    95 | Cost: 0.5237087 | Acc train: 0.9580000 | Acc validation: 0.9500000
# f1_score is 0.9565217391304348 0.9523809523809523
# roc_auc_score is 0.955 0.9500000000000001
# Iter:    96 | Cost: 0.5236594 | Acc train: 0.9550000 | Acc validation: 0.9500000
# f1_score is 0.9547641963426372 0.9433962264150945
# roc_auc_score is 0.9530000000000001 0.94
# Iter:    97 | Cost: 0.5246359 | Acc train: 0.9530000 | Acc validation: 0.9400000
# f1_score is 0.9521988527724666 0.9345794392523363
# roc_auc_score is 0.95 0.9299999999999999
# Iter:    98 | Cost: 0.5266595 | Acc train: 0.9500000 | Acc validation: 0.9300000
# f1_score is 0.9405099150141643 0.9259259259259259
# roc_auc_score is 0.937 0.9199999999999999
# Iter:    99 | Cost: 0.5319355 | Acc train: 0.9370000 | Acc validation: 0.9200000
# f1_score is 0.941398865784499 0.9259259259259259
# roc_auc_score is 0.9380000000000001 0.9199999999999999
# Iter:   100 | Cost: 0.5332493 | Acc train: 0.9380000 | Acc validation: 0.9200000
# f1_score is 0.9521988527724666 0.9345794392523363
# roc_auc_score is 0.95 0.9299999999999999
# Iter:   101 | Cost: 0.5284155 | Acc train: 0.9500000 | Acc validation: 0.9300000
# f1_score is 0.963972736124635 0.9345794392523363
# roc_auc_score is 0.963 0.9299999999999999
# Iter:   102 | Cost: 0.5259817 | Acc train: 0.9630000 | Acc validation: 0.9300000
# f1_score is 0.9713155291790307 0.9615384615384615
# roc_auc_score is 0.971 0.9600000000000001
# Iter:   103 | Cost: 0.5272567 | Acc train: 0.9710000 | Acc validation: 0.9600000
# f1_score is 0.9731876861966237 0.970873786407767
# roc_auc_score is 0.973 0.97
# Iter:   104 | Cost: 0.5284765 | Acc train: 0.9730000 | Acc validation: 0.9700000
# f1_score is 0.979020979020979 0.9514563106796116
# roc_auc_score is 0.979 0.9500000000000001
# Iter:   105 | Cost: 0.5303709 | Acc train: 0.9790000 | Acc validation: 0.9500000
# f1_score is 0.9809428284854563 0.92
# roc_auc_score is 0.981 0.9199999999999999
# Iter:   106 | Cost: 0.5330873 | Acc train: 0.9810000 | Acc validation: 0.9200000
# f1_score is 0.9788519637462235 0.9292929292929293
# roc_auc_score is 0.979 0.9299999999999998
# Iter:   107 | Cost: 0.5351588 | Acc train: 0.9790000 | Acc validation: 0.9300000
# f1_score is 0.974155069582505 0.9411764705882353
# roc_auc_score is 0.974 0.9400000000000001
# Iter:   108 | Cost: 0.5300805 | Acc train: 0.9740000 | Acc validation: 0.9400000
# f1_score is 0.9714285714285713 0.9523809523809523
# roc_auc_score is 0.971 0.9500000000000001
# Iter:   109 | Cost: 0.5277488 | Acc train: 0.9710000 | Acc validation: 0.9500000
# f1_score is 0.974155069582505 0.9411764705882353
# roc_auc_score is 0.974 0.9400000000000001
# Iter:   110 | Cost: 0.5290626 | Acc train: 0.9740000 | Acc validation: 0.9400000
# f1_score is 0.978978978978979 0.9306930693069307
# roc_auc_score is 0.979 0.9299999999999999
# Iter:   111 | Cost: 0.5295961 | Acc train: 0.9790000 | Acc validation: 0.9300000
# f1_score is 0.9799196787148594 0.9292929292929293
# roc_auc_score is 0.98 0.9299999999999998
# Iter:   112 | Cost: 0.5331266 | Acc train: 0.9800000 | Acc validation: 0.9300000
# f1_score is 0.9725888324873097 0.9387755102040817
# roc_auc_score is 0.973 0.94
# Iter:   113 | Cost: 0.5364811 | Acc train: 0.9730000 | Acc validation: 0.9400000
# f1_score is 0.974974974974975 0.9292929292929293
# roc_auc_score is 0.975 0.9299999999999998
# Iter:   114 | Cost: 0.5320724 | Acc train: 0.9750000 | Acc validation: 0.9300000
# f1_score is 0.9693372898120672 0.9514563106796116
# roc_auc_score is 0.969 0.9500000000000001
# Iter:   115 | Cost: 0.5268367 | Acc train: 0.9690000 | Acc validation: 0.9500000
# f1_score is 0.9667318982387476 0.9433962264150945
# roc_auc_score is 0.966 0.94
# Iter:   116 | Cost: 0.5241113 | Acc train: 0.9660000 | Acc validation: 0.9400000
# f1_score is 0.96484375 0.9523809523809523
# roc_auc_score is 0.964 0.9500000000000001
# Iter:   117 | Cost: 0.5230944 | Acc train: 0.9640000 | Acc validation: 0.9500000
# f1_score is 0.9638318670576735 0.9523809523809523
# roc_auc_score is 0.963 0.9500000000000001
# Iter:   118 | Cost: 0.5227608 | Acc train: 0.9630000 | Acc validation: 0.9500000
# f1_score is 0.9620253164556962 0.9523809523809523
# roc_auc_score is 0.9609999999999999 0.9500000000000001
# Iter:   119 | Cost: 0.5223963 | Acc train: 0.9610000 | Acc validation: 0.9500000
# f1_score is 0.9593023255813953 0.9523809523809523
# roc_auc_score is 0.958 0.9500000000000001
# Iter:   120 | Cost: 0.5229523 | Acc train: 0.9580000 | Acc validation: 0.9500000
# 0
# f1_score is 0.5650916104146576 0.4175824175824176
# roc_auc_score is 0.5489999999999999 0.47000000000000003
# Iter:     1 | Cost: 1.0654307 | Acc train: 0.5490000 | Acc validation: 0.4700000
# f1_score is 0.5918944392082941 0.4301075268817204
# roc_auc_score is 0.5670000000000001 0.47000000000000003
# Iter:     2 | Cost: 1.0597859 | Acc train: 0.5670000 | Acc validation: 0.4700000
# f1_score is 0.6189164370982553 0.4631578947368421
# roc_auc_score is 0.585 0.49000000000000005
# Iter:     3 | Cost: 1.0512258 | Acc train: 0.5850000 | Acc validation: 0.4900000
# f1_score is 0.6637706342311035 0.5050505050505051
# roc_auc_score is 0.613 0.51
# Iter:     4 | Cost: 1.0447098 | Acc train: 0.6130000 | Acc validation: 0.5100000
# f1_score is 0.6859083191850595 0.576923076923077
# roc_auc_score is 0.63 0.56
# Iter:     5 | Cost: 1.0345051 | Acc train: 0.6300000 | Acc validation: 0.5600000
# f1_score is 0.7125103562551782 0.6238532110091743
# roc_auc_score is 0.6529999999999999 0.5900000000000001
# Iter:     6 | Cost: 1.0224258 | Acc train: 0.6530000 | Acc validation: 0.5900000
# f1_score is 0.7287581699346406 0.6306306306306306
# roc_auc_score is 0.6679999999999999 0.59
# Iter:     7 | Cost: 1.0034748 | Acc train: 0.6680000 | Acc validation: 0.5900000
# f1_score is 0.6970740103270223 0.5825242718446602
# roc_auc_score is 0.648 0.5700000000000001
# Iter:     8 | Cost: 0.9639778 | Acc train: 0.6480000 | Acc validation: 0.5700000
# f1_score is 0.689407540394973 0.5208333333333334
# roc_auc_score is 0.6540000000000001 0.54
# Iter:     9 | Cost: 0.9266106 | Acc train: 0.6540000 | Acc validation: 0.5400000
# f1_score is 0.6569200779727096 0.48888888888888893
# roc_auc_score is 0.648 0.54
# Iter:    10 | Cost: 0.8901436 | Acc train: 0.6480000 | Acc validation: 0.5400000
# f1_score is 0.6462793068297654 0.47058823529411764
# roc_auc_score is 0.6529999999999999 0.5499999999999999
# Iter:    11 | Cost: 0.8605282 | Acc train: 0.6530000 | Acc validation: 0.5500000
# f1_score is 0.651804670912951 0.4523809523809524
# roc_auc_score is 0.6719999999999999 0.5399999999999999
# Iter:    12 | Cost: 0.8308096 | Acc train: 0.6720000 | Acc validation: 0.5400000
# f1_score is 0.6715634837355718 0.49411764705882355
# roc_auc_score is 0.687 0.57
# Iter:    13 | Cost: 0.7982504 | Acc train: 0.6870000 | Acc validation: 0.5700000
# f1_score is 0.7318045862412761 0.5454545454545454
# roc_auc_score is 0.731 0.6
# Iter:    14 | Cost: 0.7620520 | Acc train: 0.7310000 | Acc validation: 0.6000000
# f1_score is 0.8022388059701492 0.7
# roc_auc_score is 0.7879999999999999 0.7
# Iter:    15 | Cost: 0.7294070 | Acc train: 0.7880000 | Acc validation: 0.7000000
# f1_score is 0.8400000000000001 0.8256880733944953
# roc_auc_score is 0.8240000000000001 0.8099999999999999
# Iter:    16 | Cost: 0.7012148 | Acc train: 0.8240000 | Acc validation: 0.8100000
# f1_score is 0.8633093525179857 0.8648648648648649
# roc_auc_score is 0.8479999999999999 0.85
# Iter:    17 | Cost: 0.6763729 | Acc train: 0.8480000 | Acc validation: 0.8500000
# f1_score is 0.8731144631765749 0.8928571428571428
# roc_auc_score is 0.857 0.88
# Iter:    18 | Cost: 0.6526583 | Acc train: 0.8570000 | Acc validation: 0.8800000
# f1_score is 0.882142857142857 0.8928571428571428
# roc_auc_score is 0.868 0.88
# Iter:    19 | Cost: 0.6323557 | Acc train: 0.8680000 | Acc validation: 0.8800000
# f1_score is 0.9039341262580055 0.882882882882883
# roc_auc_score is 0.895 0.87
# Iter:    20 | Cost: 0.6147028 | Acc train: 0.8950000 | Acc validation: 0.8700000
# f1_score is 0.9238005644402634 0.9158878504672898
# roc_auc_score is 0.9189999999999999 0.91
# Iter:    21 | Cost: 0.5999076 | Acc train: 0.9190000 | Acc validation: 0.9100000
# f1_score is 0.9580487804878048 0.9423076923076924
# roc_auc_score is 0.9569999999999999 0.9400000000000001
# Iter:    22 | Cost: 0.5898053 | Acc train: 0.9570000 | Acc validation: 0.9400000
# f1_score is 0.9718875502008033 0.9514563106796116
# roc_auc_score is 0.972 0.9500000000000001
# Iter:    23 | Cost: 0.5819428 | Acc train: 0.9720000 | Acc validation: 0.9500000
# f1_score is 0.9673590504451038 0.9333333333333333
# roc_auc_score is 0.967 0.9299999999999999
# Iter:    24 | Cost: 0.5703388 | Acc train: 0.9670000 | Acc validation: 0.9300000
# f1_score is 0.9400570884871551 0.9345794392523363
# roc_auc_score is 0.937 0.9299999999999999
# Iter:    25 | Cost: 0.5647821 | Acc train: 0.9370000 | Acc validation: 0.9300000
# f1_score is 0.9271028037383178 0.8928571428571428
# roc_auc_score is 0.922 0.88
# Iter:    26 | Cost: 0.5678952 | Acc train: 0.9220000 | Acc validation: 0.8800000
# f1_score is 0.911764705882353 0.8771929824561403
# roc_auc_score is 0.904 0.86
# Iter:    27 | Cost: 0.5728879 | Acc train: 0.9040000 | Acc validation: 0.8600000
# f1_score is 0.8853333333333332 0.8620689655172413
# roc_auc_score is 0.871 0.84
# Iter:    28 | Cost: 0.5868713 | Acc train: 0.8710000 | Acc validation: 0.8400000
# f1_score is 0.883762200532387 0.8547008547008548
# roc_auc_score is 0.869 0.83
# Iter:    29 | Cost: 0.5884892 | Acc train: 0.8690000 | Acc validation: 0.8300000
# f1_score is 0.8995475113122172 0.8849557522123894
# roc_auc_score is 0.889 0.87
# Iter:    30 | Cost: 0.5735782 | Acc train: 0.8890000 | Acc validation: 0.8700000
# f1_score is 0.9219330855018587 0.8928571428571428
# roc_auc_score is 0.9159999999999999 0.88
# Iter:    31 | Cost: 0.5584344 | Acc train: 0.9160000 | Acc validation: 0.8800000
# f1_score is 0.9380362249761677 0.9158878504672898
# roc_auc_score is 0.935 0.91
# Iter:    32 | Cost: 0.5532253 | Acc train: 0.9350000 | Acc validation: 0.9100000
# f1_score is 0.9443378119001918 0.9158878504672898
# roc_auc_score is 0.9420000000000001 0.91
# Iter:    33 | Cost: 0.5526392 | Acc train: 0.9420000 | Acc validation: 0.9100000
# f1_score is 0.9434697855750487 0.9320388349514563
# roc_auc_score is 0.9420000000000001 0.93
# Iter:    34 | Cost: 0.5577160 | Acc train: 0.9420000 | Acc validation: 0.9300000
# f1_score is 0.9346733668341709 0.9504950495049505
# roc_auc_score is 0.935 0.95
# Iter:    35 | Cost: 0.5693693 | Acc train: 0.9350000 | Acc validation: 0.9500000
# f1_score is 0.9356136820925554 0.9504950495049505
# roc_auc_score is 0.936 0.95
# Iter:    36 | Cost: 0.5720374 | Acc train: 0.9360000 | Acc validation: 0.9500000
# f1_score is 0.9471624266144814 0.9320388349514563
# roc_auc_score is 0.9460000000000001 0.93
# Iter:    37 | Cost: 0.5615813 | Acc train: 0.9460000 | Acc validation: 0.9300000
# f1_score is 0.9479768786127166 0.9245283018867924
# roc_auc_score is 0.946 0.9199999999999999
# Iter:    38 | Cost: 0.5561442 | Acc train: 0.9460000 | Acc validation: 0.9200000
# f1_score is 0.9401709401709402 0.9174311926605504
# roc_auc_score is 0.937 0.91
# Iter:    39 | Cost: 0.5541372 | Acc train: 0.9370000 | Acc validation: 0.9100000
# f1_score is 0.9279700654817588 0.9174311926605504
# roc_auc_score is 0.923 0.91
# Iter:    40 | Cost: 0.5572854 | Acc train: 0.9230000 | Acc validation: 0.9100000
# f1_score is 0.9162833486660533 0.9009009009009009
# roc_auc_score is 0.909 0.89
# Iter:    41 | Cost: 0.5604762 | Acc train: 0.9090000 | Acc validation: 0.8900000
# f1_score is 0.9087591240875913 0.8928571428571428
# roc_auc_score is 0.9 0.88
# Iter:    42 | Cost: 0.5644213 | Acc train: 0.9000000 | Acc validation: 0.8800000
# f1_score is 0.9179723502304147 0.9009009009009009
# roc_auc_score is 0.911 0.89
# Iter:    43 | Cost: 0.5610974 | Acc train: 0.9110000 | Acc validation: 0.8900000
# f1_score is 0.9299719887955181 0.9090909090909091
# roc_auc_score is 0.9249999999999999 0.9
# Iter:    44 | Cost: 0.5558503 | Acc train: 0.9250000 | Acc validation: 0.9000000
# f1_score is 0.941398865784499 0.9345794392523363
# roc_auc_score is 0.9380000000000001 0.9299999999999999
# Iter:    45 | Cost: 0.5529995 | Acc train: 0.9380000 | Acc validation: 0.9300000
# f1_score is 0.9528392685274302 0.9433962264150945
# roc_auc_score is 0.9510000000000001 0.94
# Iter:    46 | Cost: 0.5531674 | Acc train: 0.9510000 | Acc validation: 0.9400000
# f1_score is 0.9609375000000001 0.923076923076923
# roc_auc_score is 0.9599999999999999 0.9199999999999999
# Iter:    47 | Cost: 0.5554153 | Acc train: 0.9600000 | Acc validation: 0.9200000
# f1_score is 0.9653808110781404 0.9292929292929293
# roc_auc_score is 0.965 0.9299999999999998
# Iter:    48 | Cost: 0.5585299 | Acc train: 0.9650000 | Acc validation: 0.9300000
# f1_score is 0.9662698412698413 0.92
# roc_auc_score is 0.966 0.9199999999999999
# Iter:    49 | Cost: 0.5586197 | Acc train: 0.9660000 | Acc validation: 0.9200000
# f1_score is 0.9571150097465886 0.9019607843137256
# roc_auc_score is 0.956 0.9
# Iter:    50 | Cost: 0.5553949 | Acc train: 0.9560000 | Acc validation: 0.9000000
# f1_score is 0.9535783365570599 0.9433962264150945
# roc_auc_score is 0.952 0.94
# Iter:    51 | Cost: 0.5549706 | Acc train: 0.9520000 | Acc validation: 0.9400000
# f1_score is 0.9535783365570599 0.9433962264150945
# roc_auc_score is 0.952 0.94
# Iter:    52 | Cost: 0.5548572 | Acc train: 0.9520000 | Acc validation: 0.9400000
# f1_score is 0.9626719056974459 0.9108910891089109
# roc_auc_score is 0.962 0.91
# Iter:    53 | Cost: 0.5559624 | Acc train: 0.9620000 | Acc validation: 0.9100000
# f1_score is 0.9655172413793104 0.9090909090909091
# roc_auc_score is 0.966 0.91
# Iter:    54 | Cost: 0.5648879 | Acc train: 0.9660000 | Acc validation: 0.9100000
# f1_score is 0.9610655737704918 0.9072164948453608
# roc_auc_score is 0.962 0.9099999999999999
# Iter:    55 | Cost: 0.5705929 | Acc train: 0.9620000 | Acc validation: 0.9100000
# f1_score is 0.9687184661957617 0.9292929292929293
# roc_auc_score is 0.969 0.9299999999999998
# Iter:    56 | Cost: 0.5638723 | Acc train: 0.9690000 | Acc validation: 0.9300000
# f1_score is 0.9666011787819253 0.9514563106796116
# roc_auc_score is 0.966 0.9500000000000001
# Iter:    57 | Cost: 0.5552067 | Acc train: 0.9660000 | Acc validation: 0.9500000
# f1_score is 0.9566891241578441 0.9345794392523363
# roc_auc_score is 0.9550000000000001 0.9299999999999999
# Iter:    58 | Cost: 0.5543720 | Acc train: 0.9550000 | Acc validation: 0.9300000
# f1_score is 0.9512893982808024 0.9259259259259259
# roc_auc_score is 0.949 0.9199999999999999
# Iter:    59 | Cost: 0.5558893 | Acc train: 0.9490000 | Acc validation: 0.9200000
# f1_score is 0.9485714285714286 0.9259259259259259
# roc_auc_score is 0.946 0.9199999999999999
# Iter:    60 | Cost: 0.5561068 | Acc train: 0.9460000 | Acc validation: 0.9200000
# f1_score is 0.9512893982808024 0.9345794392523363
# roc_auc_score is 0.949 0.9299999999999999
# Iter:    61 | Cost: 0.5552794 | Acc train: 0.9490000 | Acc validation: 0.9300000
# f1_score is 0.9449715370018976 0.9259259259259259
# roc_auc_score is 0.9420000000000001 0.9199999999999999
# Iter:    62 | Cost: 0.5566962 | Acc train: 0.9420000 | Acc validation: 0.9200000
# f1_score is 0.9378531073446329 0.9174311926605504
# roc_auc_score is 0.934 0.91
# Iter:    63 | Cost: 0.5610121 | Acc train: 0.9340000 | Acc validation: 0.9100000
# f1_score is 0.9222222222222223 0.9009009009009009
# roc_auc_score is 0.9159999999999999 0.89
# Iter:    64 | Cost: 0.5681144 | Acc train: 0.9160000 | Acc validation: 0.8900000
# f1_score is 0.9146005509641874 0.9009009009009009
# roc_auc_score is 0.907 0.89
# Iter:    65 | Cost: 0.5729082 | Acc train: 0.9070000 | Acc validation: 0.8900000
# f1_score is 0.9256505576208178 0.9009009009009009
# roc_auc_score is 0.9199999999999999 0.89
# Iter:    66 | Cost: 0.5656107 | Acc train: 0.9200000 | Acc validation: 0.8900000
# f1_score is 0.9378531073446329 0.9174311926605504
# roc_auc_score is 0.934 0.91
# Iter:    67 | Cost: 0.5604991 | Acc train: 0.9340000 | Acc validation: 0.9100000
# f1_score is 0.9378531073446329 0.9174311926605504
# roc_auc_score is 0.934 0.91
# Iter:    68 | Cost: 0.5590422 | Acc train: 0.9340000 | Acc validation: 0.9100000
# f1_score is 0.9387370405278039 0.9174311926605504
# roc_auc_score is 0.935 0.91
# Iter:    69 | Cost: 0.5577775 | Acc train: 0.9350000 | Acc validation: 0.9100000
# f1_score is 0.9422894985808893 0.9174311926605504
# roc_auc_score is 0.9390000000000001 0.91
# Iter:    70 | Cost: 0.5571192 | Acc train: 0.9390000 | Acc validation: 0.9100000
# f1_score is 0.950381679389313 0.9345794392523363
# roc_auc_score is 0.948 0.9299999999999999
# Iter:    71 | Cost: 0.5549343 | Acc train: 0.9480000 | Acc validation: 0.9300000
# f1_score is 0.958614051973051 0.9433962264150945
# roc_auc_score is 0.9570000000000001 0.94
# Iter:    72 | Cost: 0.5528615 | Acc train: 0.9570000 | Acc validation: 0.9400000
# f1_score is 0.9734513274336284 0.9523809523809523
# roc_auc_score is 0.973 0.9500000000000001
# Iter:    73 | Cost: 0.5555668 | Acc train: 0.9730000 | Acc validation: 0.9500000
# f1_score is 0.9751737835153922 0.9292929292929293
# roc_auc_score is 0.9749999999999999 0.9299999999999998
# Iter:    74 | Cost: 0.5607220 | Acc train: 0.9750000 | Acc validation: 0.9300000
# f1_score is 0.9753208292201383 0.970873786407767
# roc_auc_score is 0.975 0.97
# Iter:    75 | Cost: 0.5573571 | Acc train: 0.9750000 | Acc validation: 0.9700000
# f1_score is 0.9688109161793372 0.9433962264150945
# roc_auc_score is 0.968 0.94
# Iter:    76 | Cost: 0.5515843 | Acc train: 0.9680000 | Acc validation: 0.9400000
# f1_score is 0.9540229885057471 0.9345794392523363
# roc_auc_score is 0.952 0.9299999999999999
# Iter:    77 | Cost: 0.5508653 | Acc train: 0.9520000 | Acc validation: 0.9300000
# f1_score is 0.931711880261927 0.9090909090909091
# roc_auc_score is 0.9269999999999999 0.9
# Iter:    78 | Cost: 0.5576098 | Acc train: 0.9270000 | Acc validation: 0.9000000
# f1_score is 0.9222222222222223 0.8928571428571428
# roc_auc_score is 0.9159999999999999 0.88
# Iter:    79 | Cost: 0.5639747 | Acc train: 0.9160000 | Acc validation: 0.8800000
# f1_score is 0.9162833486660533 0.8849557522123894
# roc_auc_score is 0.909 0.87
# Iter:    80 | Cost: 0.5660304 | Acc train: 0.9090000 | Acc validation: 0.8700000
# f1_score is 0.924791086350975 0.8928571428571428
# roc_auc_score is 0.9189999999999999 0.88
# Iter:    81 | Cost: 0.5584571 | Acc train: 0.9190000 | Acc validation: 0.8800000
# f1_score is 0.9447619047619048 0.9259259259259259
# roc_auc_score is 0.942 0.9199999999999999
# Iter:    82 | Cost: 0.5497689 | Acc train: 0.9420000 | Acc validation: 0.9200000
# f1_score is 0.9510086455331412 0.9433962264150945
# roc_auc_score is 0.9490000000000001 0.94
# Iter:    83 | Cost: 0.5487088 | Acc train: 0.9490000 | Acc validation: 0.9400000
# f1_score is 0.9582929194956353 0.9523809523809523
# roc_auc_score is 0.9570000000000001 0.9500000000000001
# Iter:    84 | Cost: 0.5504605 | Acc train: 0.9570000 | Acc validation: 0.9500000
# f1_score is 0.958130477117819 0.9423076923076924
# roc_auc_score is 0.957 0.9400000000000001
# Iter:    85 | Cost: 0.5528808 | Acc train: 0.9570000 | Acc validation: 0.9400000
# f1_score is 0.953125 0.9320388349514563
# roc_auc_score is 0.952 0.93
# Iter:    86 | Cost: 0.5546984 | Acc train: 0.9520000 | Acc validation: 0.9300000
# f1_score is 0.9512670565302146 0.9320388349514563
# roc_auc_score is 0.9500000000000001 0.93
# Iter:    87 | Cost: 0.5547667 | Acc train: 0.9500000 | Acc validation: 0.9300000
# f1_score is 0.9492187500000001 0.9320388349514563
# roc_auc_score is 0.948 0.93
# Iter:    88 | Cost: 0.5549136 | Acc train: 0.9480000 | Acc validation: 0.9300000
# f1_score is 0.9505334626576141 0.9320388349514563
# roc_auc_score is 0.9490000000000001 0.93
# Iter:    89 | Cost: 0.5522375 | Acc train: 0.9490000 | Acc validation: 0.9300000
# f1_score is 0.940952380952381 0.9259259259259259
# roc_auc_score is 0.9380000000000001 0.9199999999999999
# Iter:    90 | Cost: 0.5492130 | Acc train: 0.9380000 | Acc validation: 0.9200000
# f1_score is 0.9358490566037736 0.9090909090909091
# roc_auc_score is 0.9319999999999999 0.9
# Iter:    91 | Cost: 0.5507079 | Acc train: 0.9320000 | Acc validation: 0.9000000
# f1_score is 0.9358490566037736 0.9174311926605504
# roc_auc_score is 0.9319999999999999 0.91
# Iter:    92 | Cost: 0.5506401 | Acc train: 0.9320000 | Acc validation: 0.9100000
# f1_score is 0.9437559580552907 0.9259259259259259
# roc_auc_score is 0.941 0.9199999999999999
# Iter:    93 | Cost: 0.5488047 | Acc train: 0.9410000 | Acc validation: 0.9200000
# f1_score is 0.95 0.9433962264150945
# roc_auc_score is 0.9480000000000001 0.94
# Iter:    94 | Cost: 0.5487927 | Acc train: 0.9480000 | Acc validation: 0.9400000
# f1_score is 0.95274831243973 0.9433962264150945
# roc_auc_score is 0.951 0.94
# Iter:    95 | Cost: 0.5490085 | Acc train: 0.9510000 | Acc validation: 0.9400000
# f1_score is 0.9518304431599229 0.9433962264150945
# roc_auc_score is 0.95 0.94
# Iter:    96 | Cost: 0.5487665 | Acc train: 0.9500000 | Acc validation: 0.9400000
# f1_score is 0.9482758620689654 0.9433962264150945
# roc_auc_score is 0.9460000000000001 0.94
# Iter:    97 | Cost: 0.5482848 | Acc train: 0.9460000 | Acc validation: 0.9400000
# f1_score is 0.9438629876308278 0.9259259259259259
# roc_auc_score is 0.9410000000000001 0.9199999999999999
# Iter:    98 | Cost: 0.5489591 | Acc train: 0.9410000 | Acc validation: 0.9200000
# f1_score is 0.9519230769230769 0.9345794392523363
# roc_auc_score is 0.95 0.9299999999999999
# Iter:    99 | Cost: 0.5484571 | Acc train: 0.9500000 | Acc validation: 0.9300000
# f1_score is 0.9546769527483123 0.9433962264150945
# roc_auc_score is 0.953 0.94
# Iter:   100 | Cost: 0.5484062 | Acc train: 0.9530000 | Acc validation: 0.9400000
# f1_score is 0.9564375605033882 0.9523809523809523
# roc_auc_score is 0.9550000000000001 0.9500000000000001
# Iter:   101 | Cost: 0.5493230 | Acc train: 0.9550000 | Acc validation: 0.9500000
# f1_score is 0.9592233009708738 0.9523809523809523
# roc_auc_score is 0.9580000000000001 0.9500000000000001
# Iter:   102 | Cost: 0.5503188 | Acc train: 0.9580000 | Acc validation: 0.9500000
# f1_score is 0.9573643410852714 0.9433962264150945
# roc_auc_score is 0.9560000000000001 0.94
# Iter:   103 | Cost: 0.5492948 | Acc train: 0.9560000 | Acc validation: 0.9400000
# f1_score is 0.9555125725338491 0.9433962264150945
# roc_auc_score is 0.9540000000000001 0.94
# Iter:   104 | Cost: 0.5489331 | Acc train: 0.9540000 | Acc validation: 0.9400000
# f1_score is 0.95 0.9433962264150945
# roc_auc_score is 0.9480000000000001 0.94
# Iter:   105 | Cost: 0.5484608 | Acc train: 0.9480000 | Acc validation: 0.9400000
# f1_score is 0.95274831243973 0.9433962264150945
# roc_auc_score is 0.951 0.94
# Iter:   106 | Cost: 0.5488348 | Acc train: 0.9510000 | Acc validation: 0.9400000
# f1_score is 0.95 0.9433962264150945
# roc_auc_score is 0.9480000000000001 0.94
# Iter:   107 | Cost: 0.5486875 | Acc train: 0.9480000 | Acc validation: 0.9400000
# f1_score is 0.9444444444444445 0.9433962264150945
# roc_auc_score is 0.942 0.94
# Iter:   108 | Cost: 0.5487870 | Acc train: 0.9420000 | Acc validation: 0.9400000
# f1_score is 0.9408396946564886 0.9259259259259259
# roc_auc_score is 0.9380000000000001 0.9199999999999999
# Iter:   109 | Cost: 0.5492001 | Acc train: 0.9380000 | Acc validation: 0.9200000
# f1_score is 0.9357277882797732 0.9174311926605504
# roc_auc_score is 0.932 0.91
# Iter:   110 | Cost: 0.5511048 | Acc train: 0.9320000 | Acc validation: 0.9100000
# f1_score is 0.9126034958601655 0.9090909090909091
# roc_auc_score is 0.905 0.9
# Iter:   111 | Cost: 0.5567280 | Acc train: 0.9050000 | Acc validation: 0.9000000
# f1_score is 0.9116022099447514 0.9090909090909091
# roc_auc_score is 0.904 0.9
# Iter:   112 | Cost: 0.5568095 | Acc train: 0.9040000 | Acc validation: 0.9000000
# f1_score is 0.9032846715328466 0.9009009009009009
# roc_auc_score is 0.894 0.89
# Iter:   113 | Cost: 0.5598432 | Acc train: 0.8940000 | Acc validation: 0.8900000
# f1_score is 0.8954954954954955 0.8849557522123894
# roc_auc_score is 0.884 0.87
# Iter:   114 | Cost: 0.5664767 | Acc train: 0.8840000 | Acc validation: 0.8700000
# f1_score is 0.8963029756537421 0.8849557522123894
# roc_auc_score is 0.885 0.87
# Iter:   115 | Cost: 0.5658902 | Acc train: 0.8850000 | Acc validation: 0.8700000
# f1_score is 0.9049360146252287 0.9090909090909091
# roc_auc_score is 0.8960000000000001 0.9
# Iter:   116 | Cost: 0.5593664 | Acc train: 0.8960000 | Acc validation: 0.9000000
# f1_score is 0.907083716651334 0.9090909090909091
# roc_auc_score is 0.899 0.9
# Iter:   117 | Cost: 0.5579970 | Acc train: 0.8990000 | Acc validation: 0.9000000
# f1_score is 0.9109461966604824 0.9074074074074074
# roc_auc_score is 0.904 0.9000000000000001
# Iter:   118 | Cost: 0.5558845 | Acc train: 0.9040000 | Acc validation: 0.9000000
# f1_score is 0.911439114391144 0.9090909090909091
# roc_auc_score is 0.904 0.9
# Iter:   119 | Cost: 0.5569559 | Acc train: 0.9040000 | Acc validation: 0.9000000
# f1_score is 0.9042844120328167 0.9009009009009009
# roc_auc_score is 0.895 0.89
# Iter:   120 | Cost: 0.5591427 | Acc train: 0.8950000 | Acc validation: 0.8900000
# 0.1
# f1_score is 0.6706586826347306 0.5192307692307693
# roc_auc_score is 0.615 0.5
# Iter:     1 | Cost: 1.0618257 | Acc train: 0.6150000 | Acc validation: 0.5000000
# f1_score is 0.6872909698996655 0.5688073394495413
# roc_auc_score is 0.6260000000000001 0.53
# Iter:     2 | Cost: 1.0620555 | Acc train: 0.6260000 | Acc validation: 0.5300000
# f1_score is 0.6857142857142857 0.574074074074074
# roc_auc_score is 0.626 0.54
# Iter:     3 | Cost: 1.0551905 | Acc train: 0.6260000 | Acc validation: 0.5400000
# f1_score is 0.6712683347713546 0.5346534653465347
# roc_auc_score is 0.619 0.53
# Iter:     4 | Cost: 1.0424950 | Acc train: 0.6190000 | Acc validation: 0.5300000
# f1_score is 0.6712922810060711 0.5050505050505051
# roc_auc_score is 0.621 0.51
# Iter:     5 | Cost: 1.0315393 | Acc train: 0.6210000 | Acc validation: 0.5100000
# f1_score is 0.6512042818911686 0.4631578947368421
# roc_auc_score is 0.609 0.49000000000000005
# Iter:     6 | Cost: 1.0157049 | Acc train: 0.6090000 | Acc validation: 0.4900000
# f1_score is 0.6436363636363636 0.46808510638297873
# roc_auc_score is 0.608 0.5
# Iter:     7 | Cost: 0.9995989 | Acc train: 0.6080000 | Acc validation: 0.5000000
# f1_score is 0.6317792578496669 0.4731182795698925
# roc_auc_score is 0.6130000000000001 0.51
# Iter:     8 | Cost: 0.9817544 | Acc train: 0.6130000 | Acc validation: 0.5100000
# f1_score is 0.6203522504892369 0.4565217391304348
# roc_auc_score is 0.612 0.5
# Iter:     9 | Cost: 0.9632647 | Acc train: 0.6120000 | Acc validation: 0.5000000
# f1_score is 0.6253687315634219 0.4565217391304348
# roc_auc_score is 0.619 0.5
# Iter:    10 | Cost: 0.9426812 | Acc train: 0.6190000 | Acc validation: 0.5000000
# f1_score is 0.6116207951070337 0.4418604651162791
# roc_auc_score is 0.6190000000000001 0.5199999999999999
# Iter:    11 | Cost: 0.9208089 | Acc train: 0.6190000 | Acc validation: 0.5200000
# f1_score is 0.6050420168067226 0.4523809523809524
# roc_auc_score is 0.624 0.5399999999999999
# Iter:    12 | Cost: 0.8982938 | Acc train: 0.6240000 | Acc validation: 0.5400000
# f1_score is 0.5949506037321625 0.4523809523809524
# roc_auc_score is 0.631 0.5399999999999999
# Iter:    13 | Cost: 0.8795942 | Acc train: 0.6310000 | Acc validation: 0.5400000
# f1_score is 0.5885005636978579 0.4197530864197531
# roc_auc_score is 0.635 0.53
# Iter:    14 | Cost: 0.8600028 | Acc train: 0.6350000 | Acc validation: 0.5300000
# f1_score is 0.6146993318485523 0.46341463414634143
# roc_auc_score is 0.654 0.5599999999999999
# Iter:    15 | Cost: 0.8360975 | Acc train: 0.6540000 | Acc validation: 0.5600000
# f1_score is 0.6181818181818182 0.46341463414634143
# roc_auc_score is 0.664 0.5599999999999999
# Iter:    16 | Cost: 0.8167123 | Acc train: 0.6640000 | Acc validation: 0.5600000
# f1_score is 0.6351039260969976 0.46913580246913583
# roc_auc_score is 0.684 0.57
# Iter:    17 | Cost: 0.7980670 | Acc train: 0.6840000 | Acc validation: 0.5700000
# f1_score is 0.6821705426356589 0.46913580246913583
# roc_auc_score is 0.7130000000000001 0.57
# Iter:    18 | Cost: 0.7711057 | Acc train: 0.7130000 | Acc validation: 0.5700000
# f1_score is 0.7808219178082192 0.6595744680851063
# roc_auc_score is 0.776 0.68
# Iter:    19 | Cost: 0.7364417 | Acc train: 0.7760000 | Acc validation: 0.6800000
# f1_score is 0.8551236749116607 0.8596491228070174
# roc_auc_score is 0.8359999999999999 0.84
# Iter:    20 | Cost: 0.7139024 | Acc train: 0.8360000 | Acc validation: 0.8400000
# f1_score is 0.8551724137931034 0.8620689655172413
# roc_auc_score is 0.8319999999999999 0.84
# Iter:    21 | Cost: 0.6994971 | Acc train: 0.8320000 | Acc validation: 0.8400000
# f1_score is 0.8655680832610582 0.8620689655172413
# roc_auc_score is 0.845 0.84
# Iter:    22 | Cost: 0.6826329 | Acc train: 0.8450000 | Acc validation: 0.8400000
# f1_score is 0.8706293706293705 0.8771929824561403
# roc_auc_score is 0.852 0.86
# Iter:    23 | Cost: 0.6677324 | Acc train: 0.8520000 | Acc validation: 0.8600000
# f1_score is 0.8729184925503943 0.8695652173913044
# roc_auc_score is 0.855 0.85
# Iter:    24 | Cost: 0.6553020 | Acc train: 0.8550000 | Acc validation: 0.8500000
# f1_score is 0.891674127126231 0.8928571428571428
# roc_auc_score is 0.879 0.88
# Iter:    25 | Cost: 0.6408489 | Acc train: 0.8790000 | Acc validation: 0.8800000
# f1_score is 0.9161290322580645 0.9174311926605504
# roc_auc_score is 0.909 0.91
# Iter:    26 | Cost: 0.6294156 | Acc train: 0.9090000 | Acc validation: 0.9100000
# f1_score is 0.9657869012707723 0.9433962264150945
# roc_auc_score is 0.965 0.94
# Iter:    27 | Cost: 0.6249968 | Acc train: 0.9650000 | Acc validation: 0.9400000
# f1_score is 0.974308300395257 0.9615384615384615
# roc_auc_score is 0.974 0.9600000000000001
# Iter:    28 | Cost: 0.6157257 | Acc train: 0.9740000 | Acc validation: 0.9600000
# f1_score is 0.9705304518664047 0.9523809523809523
# roc_auc_score is 0.9699999999999999 0.9500000000000001
# Iter:    29 | Cost: 0.6051543 | Acc train: 0.9700000 | Acc validation: 0.9500000
# f1_score is 0.953020134228188 0.9345794392523363
# roc_auc_score is 0.9510000000000001 0.9299999999999999
# Iter:    30 | Cost: 0.5976851 | Acc train: 0.9510000 | Acc validation: 0.9300000
# f1_score is 0.9493791786055397 0.9345794392523363
# roc_auc_score is 0.947 0.9299999999999999
# Iter:    31 | Cost: 0.5950622 | Acc train: 0.9470000 | Acc validation: 0.9300000
# f1_score is 0.9456625357483317 0.9259259259259259
# roc_auc_score is 0.943 0.9199999999999999
# Iter:    32 | Cost: 0.5930995 | Acc train: 0.9430000 | Acc validation: 0.9200000
# f1_score is 0.9340866290018832 0.9090909090909091
# roc_auc_score is 0.9299999999999999 0.9
# Iter:    33 | Cost: 0.5920374 | Acc train: 0.9300000 | Acc validation: 0.9000000
# f1_score is 0.925512104283054 0.9009009009009009
# roc_auc_score is 0.9199999999999999 0.89
# Iter:    34 | Cost: 0.5929156 | Acc train: 0.9200000 | Acc validation: 0.8900000
# f1_score is 0.9246511627906977 0.9009009009009009
# roc_auc_score is 0.919 0.89
# Iter:    35 | Cost: 0.5915691 | Acc train: 0.9190000 | Acc validation: 0.8900000
# f1_score is 0.935969868173258 0.9090909090909091
# roc_auc_score is 0.9319999999999999 0.9
# Iter:    36 | Cost: 0.5902691 | Acc train: 0.9320000 | Acc validation: 0.9000000
# f1_score is 0.9367327667610954 0.9174311926605504
# roc_auc_score is 0.9329999999999999 0.91
# Iter:    37 | Cost: 0.5904234 | Acc train: 0.9330000 | Acc validation: 0.9100000
# f1_score is 0.9395973154362416 0.9174311926605504
# roc_auc_score is 0.9369999999999999 0.91
# Iter:    38 | Cost: 0.5920925 | Acc train: 0.9370000 | Acc validation: 0.9100000
# f1_score is 0.9357622243528285 0.9158878504672898
# roc_auc_score is 0.9329999999999999 0.91
# Iter:    39 | Cost: 0.5924794 | Acc train: 0.9330000 | Acc validation: 0.9100000
# f1_score is 0.9166666666666666 0.9090909090909091
# roc_auc_score is 0.9099999999999999 0.9
# Iter:    40 | Cost: 0.5910494 | Acc train: 0.9100000 | Acc validation: 0.9000000
# f1_score is 0.902638762511374 0.9009009009009009
# roc_auc_score is 0.893 0.89
# Iter:    41 | Cost: 0.5932149 | Acc train: 0.8930000 | Acc validation: 0.8900000
# f1_score is 0.9042844120328167 0.9009009009009009
# roc_auc_score is 0.895 0.89
# Iter:    42 | Cost: 0.5934507 | Acc train: 0.8950000 | Acc validation: 0.8900000
# f1_score is 0.8985507246376812 0.9009009009009009
# roc_auc_score is 0.888 0.89
# ...
# f1_score is 0.852263023057216 0.8547008547008548
# roc_auc_score is 0.827 0.83
# Iter:    24 | Cost: 0.7137744 | Acc train: 0.8270000 | Acc validation: 0.8300000
# f1_score is 0.8257638315441783 0.8264462809917354
# roc_auc_score is 0.789 0.79
# Iter:    25 | Cost: 0.7105404 | Acc train: 0.7890000 | Acc validation: 0.7900000
# f1_score is 0.8130081300813007 0.819672131147541
# roc_auc_score is 0.77 0.78
# Iter:    26 | Cost: 0.7055219 | Acc train: 0.7700000 | Acc validation: 0.7800000
# f1_score is 0.7987220447284346 0.7936507936507937
# roc_auc_score is 0.748 0.74
# Iter:    27 | Cost: 0.7032329 | Acc train: 0.7480000 | Acc validation: 0.7400000
# f1_score is 0.8153594771241831 0.8130081300813007
# roc_auc_score is 0.774 0.77
# Iter:    28 | Cost: 0.6882325 | Acc train: 0.7740000 | Acc validation: 0.7700000
# f1_score is 0.8450465707027942 0.8264462809917354
# roc_auc_score is 0.8170000000000001 0.79
# Iter:    29 | Cost: 0.6694880 | Acc train: 0.8170000 | Acc validation: 0.7900000
# f1_score is 0.8767605633802816 0.8620689655172413
# roc_auc_score is 0.86 0.84
# Iter:    30 | Cost: 0.6568255 | Acc train: 0.8600000 | Acc validation: 0.8400000
# f1_score is 0.906934306569343 0.8771929824561403
# roc_auc_score is 0.898 0.86
# Iter:    31 | Cost: 0.6468888 | Acc train: 0.8980000 | Acc validation: 0.8600000
# f1_score is 0.9169741697416974 0.8928571428571428
# roc_auc_score is 0.9100000000000001 0.88
# Iter:    32 | Cost: 0.6422584 | Acc train: 0.9100000 | Acc validation: 0.8800000
# f1_score is 0.9169741697416974 0.9009009009009009
# roc_auc_score is 0.9100000000000001 0.89
# Iter:    33 | Cost: 0.6403982 | Acc train: 0.9100000 | Acc validation: 0.8900000
# f1_score is 0.9119266055045873 0.9009009009009009
# roc_auc_score is 0.904 0.89
# Iter:    34 | Cost: 0.6396541 | Acc train: 0.9040000 | Acc validation: 0.8900000
# f1_score is 0.8979223125564589 0.8771929824561403
# roc_auc_score is 0.887 0.86
# Iter:    35 | Cost: 0.6402350 | Acc train: 0.8870000 | Acc validation: 0.8600000
# f1_score is 0.8898836168307968 0.8771929824561403
# roc_auc_score is 0.877 0.86
# Iter:    36 | Cost: 0.6412933 | Acc train: 0.8770000 | Acc validation: 0.8600000
# f1_score is 0.8804251550044287 0.8771929824561403
# roc_auc_score is 0.865 0.86
# Iter:    37 | Cost: 0.6425745 | Acc train: 0.8650000 | Acc validation: 0.8600000
# f1_score is 0.8757709251101322 0.8771929824561403
# roc_auc_score is 0.859 0.86
# Iter:    38 | Cost: 0.6435368 | Acc train: 0.8590000 | Acc validation: 0.8600000
# f1_score is 0.8716157205240174 0.8695652173913044
# roc_auc_score is 0.853 0.85
# Iter:    39 | Cost: 0.6443996 | Acc train: 0.8530000 | Acc validation: 0.8500000
# f1_score is 0.8700959023539668 0.8695652173913044
# roc_auc_score is 0.851 0.85
# Iter:    40 | Cost: 0.6444544 | Acc train: 0.8510000 | Acc validation: 0.8500000
# f1_score is 0.8708551483420593 0.8695652173913044
# roc_auc_score is 0.852 0.85
# Iter:    41 | Cost: 0.6439399 | Acc train: 0.8520000 | Acc validation: 0.8500000
# f1_score is 0.8769771528998241 0.8771929824561403
# roc_auc_score is 0.86 0.86
# Iter:    42 | Cost: 0.6414711 | Acc train: 0.8600000 | Acc validation: 0.8600000
# f1_score is 0.8863232682060391 0.8849557522123894
# roc_auc_score is 0.872 0.87
# Iter:    43 | Cost: 0.6398624 | Acc train: 0.8720000 | Acc validation: 0.8700000
# f1_score is 0.8910714285714285 0.8928571428571428
# roc_auc_score is 0.878 0.88
# Iter:    44 | Cost: 0.6388167 | Acc train: 0.8780000 | Acc validation: 0.8800000
# f1_score is 0.8999098286744815 0.8928571428571428
# roc_auc_score is 0.889 0.88
# Iter:    45 | Cost: 0.6379331 | Acc train: 0.8890000 | Acc validation: 0.8800000
# f1_score is 0.9147571035747022 0.9009009009009009
# roc_auc_score is 0.907 0.89
# Iter:    46 | Cost: 0.6384560 | Acc train: 0.9070000 | Acc validation: 0.8900000
# f1_score is 0.9213691026827011 0.9090909090909091
# roc_auc_score is 0.9149999999999999 0.9
# Iter:    47 | Cost: 0.6396645 | Acc train: 0.9150000 | Acc validation: 0.9000000
# f1_score is 0.931711880261927 0.9090909090909091
# roc_auc_score is 0.9269999999999999 0.9
# Iter:    48 | Cost: 0.6424175 | Acc train: 0.9270000 | Acc validation: 0.9000000
# f1_score is 0.9352112676056338 0.9090909090909091
# roc_auc_score is 0.931 0.9
# Iter:    49 | Cost: 0.6445605 | Acc train: 0.9310000 | Acc validation: 0.9000000
# f1_score is 0.9352112676056338 0.9174311926605504
# roc_auc_score is 0.931 0.91
# Iter:    50 | Cost: 0.6449731 | Acc train: 0.9310000 | Acc validation: 0.9100000
# f1_score is 0.9318394024276379 0.9174311926605504
# roc_auc_score is 0.927 0.91
# Iter:    51 | Cost: 0.6447377 | Acc train: 0.9270000 | Acc validation: 0.9100000
# f1_score is 0.9387370405278039 0.9174311926605504
# roc_auc_score is 0.935 0.91
# Iter:    52 | Cost: 0.6484006 | Acc train: 0.9350000 | Acc validation: 0.9100000
# f1_score is 0.9405099150141643 0.9259259259259259
# roc_auc_score is 0.937 0.9199999999999999
# Iter:    53 | Cost: 0.6494356 | Acc train: 0.9370000 | Acc validation: 0.9200000
# f1_score is 0.9369708372530573 0.9174311926605504
# roc_auc_score is 0.933 0.91
# Iter:    54 | Cost: 0.6475142 | Acc train: 0.9330000 | Acc validation: 0.9100000
# f1_score is 0.9275092936802974 0.9090909090909091
# roc_auc_score is 0.9219999999999999 0.9
# Iter:    55 | Cost: 0.6443835 | Acc train: 0.9220000 | Acc validation: 0.9000000
# f1_score is 0.9215143120960296 0.9090909090909091
# roc_auc_score is 0.9149999999999999 0.9
# Iter:    56 | Cost: 0.6429425 | Acc train: 0.9150000 | Acc validation: 0.9000000
# f1_score is 0.9181232750689972 0.9090909090909091
# roc_auc_score is 0.911 0.9
# Iter:    57 | Cost: 0.6415808 | Acc train: 0.9110000 | Acc validation: 0.9000000
# f1_score is 0.9155963302752292 0.9090909090909091
# roc_auc_score is 0.908 0.9
# Iter:    58 | Cost: 0.6412663 | Acc train: 0.9080000 | Acc validation: 0.9000000
# f1_score is 0.9172794117647058 0.9090909090909091
# roc_auc_score is 0.91 0.9
# Iter:    59 | Cost: 0.6414839 | Acc train: 0.9100000 | Acc validation: 0.9000000
# f1_score is 0.9164370982552802 0.9090909090909091
# roc_auc_score is 0.909 0.9
# Iter:    60 | Cost: 0.6410114 | Acc train: 0.9090000 | Acc validation: 0.9000000
# f1_score is 0.9147571035747022 0.9090909090909091
# roc_auc_score is 0.907 0.9
# Iter:    61 | Cost: 0.6404145 | Acc train: 0.9070000 | Acc validation: 0.9000000
# f1_score is 0.9039855072463768 0.9009009009009009
# roc_auc_score is 0.8940000000000001 0.89
# Iter:    62 | Cost: 0.6396884 | Acc train: 0.8940000 | Acc validation: 0.8900000
# f1_score is 0.8999098286744815 0.8928571428571428
# roc_auc_score is 0.889 0.88
# Iter:    63 | Cost: 0.6398470 | Acc train: 0.8890000 | Acc validation: 0.8800000
# f1_score is 0.8950672645739911 0.8928571428571428
# roc_auc_score is 0.883 0.88
# Iter:    64 | Cost: 0.6407004 | Acc train: 0.8830000 | Acc validation: 0.8800000
# f1_score is 0.8982898289828983 0.8928571428571428
# roc_auc_score is 0.887 0.88
# Iter:    65 | Cost: 0.6402763 | Acc train: 0.8870000 | Acc validation: 0.8800000
# f1_score is 0.8886910062333038 0.8928571428571428
# roc_auc_score is 0.875 0.88
# Iter:    66 | Cost: 0.6416146 | Acc train: 0.8750000 | Acc validation: 0.8800000
# f1_score is 0.879295154185022 0.8771929824561403
# roc_auc_score is 0.863 0.86
# Iter:    67 | Cost: 0.6427035 | Acc train: 0.8630000 | Acc validation: 0.8600000
# f1_score is 0.8800705467372134 0.8849557522123894
# roc_auc_score is 0.864 0.87
# Iter:    68 | Cost: 0.6422297 | Acc train: 0.8640000 | Acc validation: 0.8700000
# f1_score is 0.8769771528998241 0.8771929824561403
# roc_auc_score is 0.86 0.86
# Iter:    69 | Cost: 0.6431306 | Acc train: 0.8600000 | Acc validation: 0.8600000
# f1_score is 0.8777484608619175 0.8771929824561403
# roc_auc_score is 0.861 0.86
# Iter:    70 | Cost: 0.6430543 | Acc train: 0.8610000 | Acc validation: 0.8600000
# f1_score is 0.8777484608619175 0.8771929824561403
# roc_auc_score is 0.861 0.86
# Iter:    71 | Cost: 0.6425131 | Acc train: 0.8610000 | Acc validation: 0.8600000
# f1_score is 0.8769771528998241 0.8771929824561403
# roc_auc_score is 0.86 0.86
# Iter:    72 | Cost: 0.6428105 | Acc train: 0.8600000 | Acc validation: 0.8600000
# f1_score is 0.8754385964912281 0.8695652173913044
# roc_auc_score is 0.858 0.85
# Iter:    73 | Cost: 0.6432811 | Acc train: 0.8580000 | Acc validation: 0.8500000
# f1_score is 0.8894830659536542 0.8928571428571428
# roc_auc_score is 0.876 0.88
# Iter:    74 | Cost: 0.6409360 | Acc train: 0.8760000 | Acc validation: 0.8800000
# f1_score is 0.8990990990990991 0.8928571428571428
# roc_auc_score is 0.8880000000000001 0.88
# Iter:    75 | Cost: 0.6395661 | Acc train: 0.8880000 | Acc validation: 0.8800000
# f1_score is 0.9064486830154406 0.9009009009009009
# roc_auc_score is 0.897 0.89
# Iter:    76 | Cost: 0.6389455 | Acc train: 0.8970000 | Acc validation: 0.8900000
# f1_score is 0.9249304911955514 0.9090909090909091
# roc_auc_score is 0.919 0.9
# Iter:    77 | Cost: 0.6401098 | Acc train: 0.9190000 | Acc validation: 0.9000000
# f1_score is 0.9308411214953272 0.9090909090909091
# roc_auc_score is 0.9259999999999999 0.9
# Iter:    78 | Cost: 0.6407589 | Acc train: 0.9260000 | Acc validation: 0.9000000
# f1_score is 0.9299719887955181 0.9090909090909091
# roc_auc_score is 0.9249999999999999 0.9
# Iter:    79 | Cost: 0.6394460 | Acc train: 0.9250000 | Acc validation: 0.9000000
# f1_score is 0.9275092936802974 0.9090909090909091
# roc_auc_score is 0.9219999999999999 0.9
# Iter:    80 | Cost: 0.6384379 | Acc train: 0.9220000 | Acc validation: 0.9000000
# f1_score is 0.9215143120960296 0.9090909090909091
# roc_auc_score is 0.9149999999999999 0.9
# Iter:    81 | Cost: 0.6374476 | Acc train: 0.9150000 | Acc validation: 0.9000000
# f1_score is 0.9198156682027651 0.9090909090909091
# roc_auc_score is 0.913 0.9
# Iter:    82 | Cost: 0.6374884 | Acc train: 0.9130000 | Acc validation: 0.9000000
# f1_score is 0.9097538742023702 0.9009009009009009
# roc_auc_score is 0.901 0.89
# Iter:    83 | Cost: 0.6379370 | Acc train: 0.9010000 | Acc validation: 0.8900000
# f1_score is 0.9039855072463768 0.9009009009009009
# roc_auc_score is 0.8940000000000001 0.89
# Iter:    84 | Cost: 0.6388435 | Acc train: 0.8940000 | Acc validation: 0.8900000
# f1_score is 0.9056261343012704 0.9009009009009009
# roc_auc_score is 0.8960000000000001 0.89
# Iter:    85 | Cost: 0.6386943 | Acc train: 0.8960000 | Acc validation: 0.8900000
# f1_score is 0.9155963302752292 0.9009009009009009
# roc_auc_score is 0.908 0.89
# Iter:    86 | Cost: 0.6378497 | Acc train: 0.9080000 | Acc validation: 0.8900000
# f1_score is 0.9122486288848263 0.9009009009009009
# roc_auc_score is 0.9040000000000001 0.89
# Iter:    87 | Cost: 0.6378210 | Acc train: 0.9040000 | Acc validation: 0.8900000
# f1_score is 0.9105839416058394 0.9009009009009009
# roc_auc_score is 0.9020000000000001 0.89
# Iter:    88 | Cost: 0.6380590 | Acc train: 0.9020000 | Acc validation: 0.8900000
# f1_score is 0.9105839416058394 0.9009009009009009
# roc_auc_score is 0.9020000000000001 0.89
# Iter:    89 | Cost: 0.6379079 | Acc train: 0.9020000 | Acc validation: 0.8900000
# f1_score is 0.9139194139194139 0.9090909090909091
# roc_auc_score is 0.906 0.9
# Iter:    90 | Cost: 0.6373149 | Acc train: 0.9060000 | Acc validation: 0.9000000
# f1_score is 0.9114155251141554 0.9009009009009009
# roc_auc_score is 0.903 0.89
# Iter:    91 | Cost: 0.6372344 | Acc train: 0.9030000 | Acc validation: 0.8900000
# f1_score is 0.9048050770625566 0.8928571428571428
# roc_auc_score is 0.895 0.88
# Iter:    92 | Cost: 0.6375873 | Acc train: 0.8950000 | Acc validation: 0.8800000
# f1_score is 0.8950672645739911 0.8695652173913044
# roc_auc_score is 0.883 0.85
# Iter:    93 | Cost: 0.6385539 | Acc train: 0.8830000 | Acc validation: 0.8500000
# f1_score is 0.8746713409290097 0.8695652173913044
# roc_auc_score is 0.8569999999999999 0.85
# Iter:    94 | Cost: 0.6430890 | Acc train: 0.8570000 | Acc validation: 0.8500000
# f1_score is 0.8663194444444445 0.8695652173913044
# roc_auc_score is 0.846 0.85
# Iter:    95 | Cost: 0.6449888 | Acc train: 0.8460000 | Acc validation: 0.8500000
# f1_score is 0.8693379790940766 0.8695652173913044
# roc_auc_score is 0.85 0.85
# Iter:    96 | Cost: 0.6438099 | Acc train: 0.8500000 | Acc validation: 0.8500000
# f1_score is 0.8723776223776224 0.8695652173913044
# roc_auc_score is 0.854 0.85
# Iter:    97 | Cost: 0.6434514 | Acc train: 0.8540000 | Acc validation: 0.8500000
# f1_score is 0.8754385964912281 0.8771929824561403
# roc_auc_score is 0.858 0.86
# Iter:    98 | Cost: 0.6414108 | Acc train: 0.8580000 | Acc validation: 0.8600000
# f1_score is 0.895870736086176 0.8928571428571428
# roc_auc_score is 0.884 0.88
# Iter:    99 | Cost: 0.6373944 | Acc train: 0.8840000 | Acc validation: 0.8800000
# f1_score is 0.9085923217550275 0.8928571428571428
# roc_auc_score is 0.9 0.88
# Iter:   100 | Cost: 0.6366060 | Acc train: 0.9000000 | Acc validation: 0.8800000
# f1_score is 0.9203703703703703 0.9009009009009009
# roc_auc_score is 0.9139999999999999 0.89
# Iter:   101 | Cost: 0.6374166 | Acc train: 0.9140000 | Acc validation: 0.8900000
# f1_score is 0.9281045751633986 0.9090909090909091
# roc_auc_score is 0.9229999999999999 0.9
# Iter:   102 | Cost: 0.6387049 | Acc train: 0.9230000 | Acc validation: 0.9000000
# f1_score is 0.9289719626168224 0.9090909090909091
# roc_auc_score is 0.924 0.9
# Iter:   103 | Cost: 0.6395969 | Acc train: 0.9240000 | Acc validation: 0.9000000
# f1_score is 0.935969868173258 0.9259259259259259
# roc_auc_score is 0.9319999999999999 0.9199999999999999
# Iter:   104 | Cost: 0.6422846 | Acc train: 0.9320000 | Acc validation: 0.9200000
# f1_score is 0.9393939393939394 0.9259259259259259
# roc_auc_score is 0.936 0.9199999999999999
# Iter:   105 | Cost: 0.6447433 | Acc train: 0.9360000 | Acc validation: 0.9200000
# f1_score is 0.9401709401709402 0.9259259259259259
# roc_auc_score is 0.937 0.9199999999999999
# Iter:   106 | Cost: 0.6461930 | Acc train: 0.9370000 | Acc validation: 0.9200000
# f1_score is 0.9314553990610328 0.9259259259259259
# roc_auc_score is 0.927 0.9199999999999999
# Iter:   107 | Cost: 0.6432898 | Acc train: 0.9270000 | Acc validation: 0.9200000
# f1_score is 0.9203703703703703 0.9009009009009009
# roc_auc_score is 0.9139999999999999 0.89
# Iter:   108 | Cost: 0.6392087 | Acc train: 0.9140000 | Acc validation: 0.8900000
# f1_score is 0.9077625570776257 0.8928571428571428
# roc_auc_score is 0.899 0.88
# Iter:   109 | Cost: 0.6372095 | Acc train: 0.8990000 | Acc validation: 0.8800000
# f1_score is 0.9011786038077969 0.8928571428571428
# roc_auc_score is 0.891 0.88
# Iter:   110 | Cost: 0.6364761 | Acc train: 0.8910000 | Acc validation: 0.8800000
# f1_score is 0.9019963702359348 0.8928571428571428
# roc_auc_score is 0.892 0.88
# Iter:   111 | Cost: 0.6363548 | Acc train: 0.8920000 | Acc validation: 0.8800000
# f1_score is 0.9021739130434783 0.8928571428571428
# roc_auc_score is 0.892 0.88
# Iter:   112 | Cost: 0.6363745 | Acc train: 0.8920000 | Acc validation: 0.8800000
# f1_score is 0.9046321525885559 0.8928571428571428
# roc_auc_score is 0.895 0.88
# Iter:   113 | Cost: 0.6364014 | Acc train: 0.8950000 | Acc validation: 0.8800000
# f1_score is 0.9212233549582948 0.9009009009009009
# roc_auc_score is 0.915 0.89
# Iter:   114 | Cost: 0.6371329 | Acc train: 0.9150000 | Acc validation: 0.8900000
# f1_score is 0.9307116104868914 0.9090909090909091
# roc_auc_score is 0.926 0.9
# Iter:   115 | Cost: 0.6399611 | Acc train: 0.9260000 | Acc validation: 0.9000000
# f1_score is 0.9421800947867298 0.9259259259259259
# roc_auc_score is 0.9390000000000001 0.9199999999999999
# Iter:   116 | Cost: 0.6453628 | Acc train: 0.9390000 | Acc validation: 0.9200000
# f1_score is 0.9412878787878788 0.9259259259259259
# roc_auc_score is 0.938 0.9199999999999999
# Iter:   117 | Cost: 0.6458809 | Acc train: 0.9380000 | Acc validation: 0.9200000
# f1_score is 0.9350893697083725 0.9174311926605504
# roc_auc_score is 0.9309999999999999 0.91
# Iter:   118 | Cost: 0.6430672 | Acc train: 0.9310000 | Acc validation: 0.9100000
# f1_score is 0.9237918215613383 0.9090909090909091
# roc_auc_score is 0.9179999999999999 0.9
# Iter:   119 | Cost: 0.6388069 | Acc train: 0.9180000 | Acc validation: 0.9000000
# f1_score is 0.9056261343012704 0.8928571428571428
# roc_auc_score is 0.8960000000000001 0.88
# Iter:   120 | Cost: 0.6370753 | Acc train: 0.8960000 | Acc validation: 0.8800000
# 0.3

# %%
plt.plot([i for i in range(120)],his1[0], label = 'noiseless')
plt.plot([i for i in range(120)],his1[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his1[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his1[3], label = 'p=0.3')
plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Amplitude damping test accuracy')
plt.legend()
plt.savefig('Amplitude_Encoding_QAOA_ansatz test accuracy',dpi=600,bbox_inches='tight')
plt.show()

# %%
plt.plot([i for i in range(120)],his2[0], label = 'noiseless')
plt.plot([i for i in range(120)],his2[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his2[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his2[3], label = 'p=0.3')
plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Amplitude damping train accuracy')
plt.legend()
plt.savefig('Amplitude_Encoding_QAOA_ansatz train accuracy',dpi=600,bbox_inches='tight')
plt.show()

# %%
plt.plot([i for i in range(120)],his3[0], label = 'noiseless')
plt.plot([i for i in range(120)],his3[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his3[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his3[3], label = 'p=0.3')
#plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Amplitude damping cost function')
plt.legend()
plt.savefig('Amplitude_Encoding_QAOA_ansatz cost function',dpi=600,bbox_inches='tight')
plt.show()

# %%
print(his1)
print(his2)
print(his3)
# Out:
# [[0.43, 0.42, 0.43, 0.44, 0.46, 0.47, 0.48, 0.51, 0.54, 0.54, 0.56, 0.6, 0.68, 0.7, 0.71, 0.79, 0.79, 0.79, 0.83, 0.84, 0.88, 0.85, 0.88, 0.9, 0.95, 0.95, 0.93, 0.94, 0.92, 0.91, 0.91, 0.9, 0.9, 0.91, 0.91, 0.91, 0.91, 0.91, 0.9, 0.88, 0.88, 0.88, 0.9, 0.89, 0.9, 0.91, 0.92, 0.92, 0.9, 0.91, 0.91, 0.91, 0.92, 0.93, 0.94, 0.95, 0.92, 0.91, 0.93, 0.94, 0.94, 0.93, 0.92, 0.9, 0.89, 0.9, 0.9, 0.92, 0.9, 0.9, 0.91, 0.91, 0.91, 0.94, 0.92, 0.89, 0.9, 0.91, 0.95, 0.95, 0.95, 0.95, 0.93, 0.92, 0.93, 0.92, 0.91, 0.88, 0.92, 0.91, 0.91, 0.92, 0.94, 0.94, 0.95, 0.95, 0.94, 0.93, 0.92, 0.92, 0.93, 0.93, 0.96, 0.97, 0.95, 0.92, 0.93, 0.94, 0.95, 0.94, 0.93, 0.93, 0.94, 0.93, 0.95, 0.94, 0.95, 0.95, 0.95, 0.95], [0.47, 0.47, 0.49, 0.51, 0.56, 0.59, 0.59, 0.57, 0.54, 0.54, 0.55, 0.54, 0.57, 0.6, 0.7, 0.81, 0.85, 0.88, 0.88, 0.87, 0.91, 0.94, 0.95, 0.93, 0.93, 0.88, 0.86, 0.84, 0.83, 0.87, 0.88, 0.91, 0.91, 0.93, 0.95, 0.95, 0.93, 0.92, 0.91, 0.91, 0.89, 0.88, 0.89, 0.9, 0.93, 0.94, 0.92, 0.93, 0.92, 0.9, 0.94, 0.94, 0.91, 0.91, 0.91, 0.93, 0.95, 0.93, 0.92, 0.92, 0.93, 0.92, 0.91, 0.89, 0.89, 0.89, 0.91, 0.91, 0.91, 0.91, 0.93, 0.94, 0.95, 0.93, 0.97, 0.94, 0.93, 0.9, 0.88, 0.87, 0.88, 0.92, 0.94, 0.95, 0.94, 0.93, 0.93, 0.93, 0.93, 0.92, 0.9, 0.91, 0.92, 0.94, 0.94, 0.94, 0.94, 0.92, 0.93, 0.94, 0.95, 0.95, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.92, 0.91, 0.9, 0.9, 0.89, 0.87, 0.87, 0.9, 0.9, 0.9, 0.9, 0.89], [0.5, 0.53, 0.54, 0.53, 0.51, 0.49, 0.5, 0.51, 0.5, 0.5, 0.52, 0.54, 0.54, 0.53, 0.56, 0.56, 0.57, 0.57, 0.68, 0.84, 0.84, 0.84, 0.86, 0.85, 0.88, 0.91, 0.94, 0.96, 0.95, 0.93, 0.93, 0.92, 0.9, 0.89, 0.89, 0.9, 0.91, 0.91, 0.91, 0.9, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.9, 0.91, 0.91, 0.92, 0.92, 0.92, 0.94, 0.94, 0.94, 0.94, 0.93, 0.91, 0.91, 0.91, 0.91, 0.9, 0.9, 0.91, 0.91, 0.91, 0.9, 0.9, 0.91, 0.94, 0.94, 0.91, 0.9, 0.88, 0.86, 0.86, 0.86, 0.86, 0.9, 0.91, 0.91, 0.92, 0.91, 0.91, 0.91, 0.92, 0.92, 0.94, 0.93, 0.95, 0.96, 0.94, 0.93, 0.92, 0.9, 0.86, 0.86, 0.86, 0.86, 0.86, 0.88, 0.91, 0.92, 0.94, 0.95, 0.95, 0.95, 0.94, 0.93, 0.93, 0.91, 0.88, 0.87, 0.85, 0.85, 0.88], [0.66, 0.64, 0.6, 0.67, 0.67, 0.64, 0.6, 0.58, 0.54, 0.51, 0.51, 0.54, 0.52, 0.51, 0.47, 0.46, 0.48, 0.53, 0.57, 0.6, 0.61, 0.81, 0.85, 0.83, 0.79, 0.78, 0.74, 0.77, 0.79, 0.84, 0.86, 0.88, 0.89, 0.89, 0.86, 0.86, 0.86, 0.86, 0.85, 0.85, 0.85, 0.86, 0.87, 0.88, 0.88, 0.89, 0.9, 0.9, 0.9, 0.91, 0.91, 0.91, 0.92, 0.91, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.89, 0.88, 0.88, 0.88, 0.88, 0.86, 0.87, 0.86, 0.86, 0.86, 0.86, 0.85, 0.88, 0.88, 0.89, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.9, 0.89, 0.88, 0.85, 0.85, 0.85, 0.85, 0.85, 0.86, 0.88, 0.88, 0.89, 0.9, 0.9, 0.92, 0.92, 0.92, 0.92, 0.89, 0.88, 0.88, 0.88, 0.88, 0.88, 0.89, 0.9, 0.92, 0.92, 0.91, 0.9, 0.88]]
# [[0.469, 0.463, 0.473, 0.512, 0.541, 0.568, 0.586, 0.62, 0.644, 0.665, 0.686, 0.713, 0.748, 0.761, 0.78, 0.781, 0.784, 0.798, 0.821, 0.842, 0.853, 0.907, 0.949, 0.97, 0.981, 0.979, 0.964, 0.952, 0.942, 0.935, 0.926, 0.923, 0.927, 0.915, 0.906, 0.899, 0.894, 0.894, 0.893, 0.888, 0.88, 0.878, 0.887, 0.893, 0.925, 0.931, 0.927, 0.932, 0.934, 0.937, 0.929, 0.932, 0.932, 0.94, 0.954, 0.954, 0.959, 0.963, 0.956, 0.951, 0.945, 0.941, 0.937, 0.942, 0.938, 0.936, 0.93, 0.938, 0.948, 0.949, 0.954, 0.957, 0.957, 0.953, 0.935, 0.921, 0.929, 0.934, 0.953, 0.96, 0.961, 0.96, 0.965, 0.968, 0.971, 0.967, 0.961, 0.954, 0.963, 0.962, 0.96, 0.951, 0.949, 0.952, 0.958, 0.955, 0.953, 0.95, 0.937, 0.938, 0.95, 0.963, 0.971, 0.973, 0.979, 0.981, 0.979, 0.974, 0.971, 0.974, 0.979, 0.98, 0.973, 0.975, 0.969, 0.966, 0.964, 0.963, 0.961, 0.958], [0.549, 0.567, 0.585, 0.613, 0.63, 0.653, 0.668, 0.648, 0.654, 0.648, 0.653, 0.672, 0.687, 0.731, 0.788, 0.824, 0.848, 0.857, 0.868, 0.895, 0.919, 0.957, 0.972, 0.967, 0.937, 0.922, 0.904, 0.871, 0.869, 0.889, 0.916, 0.935, 0.942, 0.942, 0.935, 0.936, 0.946, 0.946, 0.937, 0.923, 0.909, 0.9, 0.911, 0.925, 0.938, 0.951, 0.96, 0.965, 0.966, 0.956, 0.952, 0.952, 0.962, 0.966, 0.962, 0.969, 0.966, 0.955, 0.949, 0.946, 0.949, 0.942, 0.934, 0.916, 0.907, 0.92, 0.934, 0.934, 0.935, 0.939, 0.948, 0.957, 0.973, 0.975, 0.975, 0.968, 0.952, 0.927, 0.916, 0.909, 0.919, 0.942, 0.949, 0.957, 0.957, 0.952, 0.95, 0.948, 0.949, 0.938, 0.932, 0.932, 0.941, 0.948, 0.951, 0.95, 0.946, 0.941, 0.95, 0.953, 0.955, 0.958, 0.956, 0.954, 0.948, 0.951, 0.948, 0.942, 0.938, 0.932, 0.905, 0.904, 0.894, 0.884, 0.885, 0.896, 0.899, 0.904, 0.904, 0.895], [0.615, 0.626, 0.626, 0.619, 0.621, 0.609, 0.608, 0.613, 0.612, 0.619, 0.619, 0.624, 0.631, 0.635, 0.654, 0.664, 0.684, 0.713, 0.776, 0.836, 0.832, 0.845, 0.852, 0.855, 0.879, 0.909, 0.965, 0.974, 0.97, 0.951, 0.947, 0.943, 0.93, 0.92, 0.919, 0.932, 0.933, 0.937, 0.933, 0.91, 0.893, 0.895, 0.888, 0.878, 0.878, 0.882, 0.895, 0.901, 0.905, 0.906, 0.914, 0.923, 0.928, 0.937, 0.941, 0.941, 0.951, 0.947, 0.945, 0.948, 0.939, 0.931, 0.928, 0.929, 0.923, 0.919, 0.92, 0.928, 0.932, 0.925, 0.921, 0.919, 0.93, 0.942, 0.95, 0.937, 0.92, 0.899, 0.887, 0.88, 0.88, 0.887, 0.905, 0.922, 0.936, 0.935, 0.928, 0.924, 0.928, 0.93, 0.933, 0.953, 0.965, 0.969, 0.968, 0.959, 0.938, 0.925, 0.91, 0.901, 0.901, 0.895, 0.887, 0.898, 0.903, 0.922, 0.941, 0.954, 0.968, 0.968, 0.966, 0.962, 0.955, 0.948, 0.93, 0.909, 0.894, 0.888, 0.888, 0.897], [0.646, 0.65, 0.653, 0.653, 0.655, 0.669, 0.662, 0.656, 0.641, 0.642, 0.638, 0.622, 0.615, 0.602, 0.588, 0.593, 0.607, 0.629, 0.656, 0.714, 0.761, 0.843, 0.85, 0.827, 0.789, 0.77, 0.748, 0.774, 0.817, 0.86, 0.898, 0.91, 0.91, 0.904, 0.887, 0.877, 0.865, 0.859, 0.853, 0.851, 0.852, 0.86, 0.872, 0.878, 0.889, 0.907, 0.915, 0.927, 0.931, 0.931, 0.927, 0.935, 0.937, 0.933, 0.922, 0.915, 0.911, 0.908, 0.91, 0.909, 0.907, 0.894, 0.889, 0.883, 0.887, 0.875, 0.863, 0.864, 0.86, 0.861, 0.861, 0.86, 0.858, 0.876, 0.888, 0.897, 0.919, 0.926, 0.925, 0.922, 0.915, 0.913, 0.901, 0.894, 0.896, 0.908, 0.904, 0.902, 0.902, 0.906, 0.903, 0.895, 0.883, 0.857, 0.846, 0.85, 0.854, 0.858, 0.884, 0.9, 0.914, 0.923, 0.924, 0.932, 0.936, 0.937, 0.927, 0.914, 0.899, 0.891, 0.892, 0.892, 0.895, 0.915, 0.926, 0.939, 0.938, 0.931, 0.918, 0.896]]
# [[1.0947355732936428, 1.0916866816178494, 1.0824096460485062, 1.0632864862169302, 1.0439076096902706, 1.0221122887869385, 0.9981132784191439, 0.9694975323828391, 0.9418474055369308, 0.9053890890022033, 0.8688018563795443, 0.8344366623653696, 0.8057474759528573, 0.774272614392382, 0.7528496594035364, 0.7452105535542642, 0.7259441093688794, 0.7007185388257712, 0.6692891085805182, 0.6386191149212748, 0.6149572399450324, 0.5958980203426981, 0.5877738217052316, 0.574312794079935, 0.5548428396277304, 0.5441495558956911, 0.5376952858765183, 0.5350376560047543, 0.5340455467231214, 0.5347101709967359, 0.5342704081079316, 0.532756754265575, 0.5331955479722028, 0.5356100256473499, 0.5390991491238543, 0.5413603417471484, 0.5423437869624301, 0.5423467379667738, 0.5437168576916597, 0.5467770549657013, 0.5507400123027253, 0.553815486096012, 0.5460840045653614, 0.5402697365511117, 0.5358848026771075, 0.5353145503312351, 0.5382543539350884, 0.5356777118423491, 0.532077210672245, 0.53060980360981, 0.5304389285358158, 0.5288424803560623, 0.5281219162036341, 0.5263868459452662, 0.5279416921595868, 0.5352435143684703, 0.5354842462353989, 0.5291319786663863, 0.5249037881435817, 0.524536885236988, 0.5252434313499179, 0.526780886117846, 0.5305260208776352, 0.529169712056769, 0.5313087023226288, 0.5323510913170391, 0.537459290126113, 0.531504102989491, 0.52693688260151, 0.5256035040207028, 0.5267252615914815, 0.5275238259815489, 0.5240669322356186, 0.5240636808995022, 0.5319332566553039, 0.5375153181516995, 0.5332281632804816, 0.5292881295976237, 0.523318163569925, 0.5230963229238451, 0.5234009369831332, 0.5237125173414487, 0.5253431088755214, 0.5267491701492463, 0.5285080973018045, 0.5305114647149656, 0.534227516720484, 0.5387863413563659, 0.5306101854328554, 0.5262658111949654, 0.5255918409678605, 0.5253844908232677, 0.5267474077184403, 0.5255332912194435, 0.5237086519104549, 0.5236593593008845, 0.5246358616113027, 0.5266595005456954, 0.5319354537077537, 0.5332492732040243, 0.5284155383257777, 0.5259817228128164, 0.5272566613691883, 0.5284764891392179, 0.530370934309026, 0.5330873346489114, 0.535158754689329, 0.5300804628898039, 0.5277488271535113, 0.52906257308941, 0.529596082766951, 0.5331265637275846, 0.5364811413835848, 0.5320724354074419, 0.5268367126839649, 0.5241113453881361, 0.5230943992982716, 0.5227607527495721, 0.5223962899747453, 0.5229523428966796], [1.0654307019954317, 1.0597859416909725, 1.0512257886565433, 1.0447097589501315, 1.0345051194386907, 1.0224258473991281, 1.003474759323557, 0.963977817697279, 0.926610627863308, 0.890143603770122, 0.8605281567879182, 0.8308096136196925, 0.7982504302406395, 0.7620519749585083, 0.7294069733362608, 0.7012147589871156, 0.6763729059150745, 0.6526583412984588, 0.6323556812536383, 0.6147028243739657, 0.5999075946355605, 0.5898053322415523, 0.5819427989926385, 0.5703387597040539, 0.564782090301211, 0.5678952353218378, 0.5728879020831588, 0.586871311129128, 0.5884891665991159, 0.5735781634791135, 0.558434443338724, 0.553225336187213, 0.552639229442729, 0.5577159583410192, 0.5693692779895192, 0.5720374127757438, 0.5615812673536977, 0.5561441556186777, 0.5541372238380352, 0.5572853898637, 0.5604761645858821, 0.5644213359662362, 0.5610973527570838, 0.5558502604408494, 0.5529995202773557, 0.5531674422550668, 0.5554153101408135, 0.5585299219243557, 0.558619714409129, 0.5553949352574802, 0.5549705973198329, 0.5548572471909374, 0.5559623827610503, 0.5648878825070516, 0.5705929020961185, 0.5638722988010331, 0.555206738180909, 0.5543719755294676, 0.5558893120033416, 0.5561067732693309, 0.5552794263301252, 0.5566961991790895, 0.5610121254066671, 0.5681144091142244, 0.5729081613985775, 0.5656106860679827, 0.5604991231328278, 0.5590421872849638, 0.5577774818533997, 0.5571192263959973, 0.554934340170414, 0.5528615344830922, 0.5555668141916601, 0.5607219588646293, 0.5573571159733995, 0.551584313552832, 0.5508652747025763, 0.5576097871767832, 0.563974658085816, 0.5660303746160892, 0.558457126208293, 0.5497688811792 ...

# %%
#plot 1:

plt.figure(figsize=(18, 4))
plt.subplot(1, 3, 1)

plt.plot([i for i in range(120)],his1[0], label = 'noiseless')
plt.plot([i for i in range(120)],his1[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his1[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his1[3], label = 'p=0.3')
plt.ylim((0.4, 1))
plt.xlabel('Training steps')
plt.ylabel('Amplitude damping test accuracy')
plt.legend()
#plt.title("plot 1")

plt.subplot(1, 3, 2)

plt.plot([i for i in range(120)],his2[0], label = 'noiseless')
plt.plot([i for i in range(120)],his2[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his2[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his2[3], label = 'p=0.3')
plt.ylim((0.42, 1))
plt.xlabel('Training steps')
plt.ylabel('Amplitude damping train accuracy')
plt.legend()
#plt.title("plot 2")

plt.subplot(1, 3, 3)

plt.plot([i for i in range(120)],his3[0], label = 'noiseless')
plt.plot([i for i in range(120)],his3[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his3[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his3[3], label = 'p=0.3')

plt.xlabel('Training steps')
plt.ylabel('Amplitude damping cost function')
plt.legend()
#plt.title("plot 2")

#plt.suptitle("RUNOOB subplot Test")
plt.savefig('Amplitude_Encoding_QAOA_ansatz4',dpi=800,bbox_inches='tight')
plt.show()
