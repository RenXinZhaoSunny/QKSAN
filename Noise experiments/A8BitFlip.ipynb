# %%
import pennylane as qml
from pennylane import numpy as np
from sklearn.decomposition import PCA
import random
from collections import Counter
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
wire = 2

wires = wire * 2
dim = 2 ** wire
dim1 = 2 * dim
dev = qml.device('default.mixed', wires=wires)
#dev = qml.device("lightning.qubit", wires=wires, shots=None)
#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
dev1 = qml.device("lightning.qubit", wires=wire, shots=None)
wires = dev.wires.tolist()

@qml.qnode(dev1)
def StateVector(x):
    qml.AmplitudeEmbedding(features=x, wires=range(wire), 
                           pad_with=0.0, normalize=True)
    return qml.state()

def accuracy(labels, predictions):

    loss = 0
    for l, p in zip(labels, predictions):
        if abs(l - p) < 1e-5:
            loss = loss + 1
    loss = loss / len(labels)

    return loss

def square_loss(labels, predictions):
    loss = 0
    for l, p in zip(labels, predictions):
        loss = loss + (l - p) ** 2

    loss = loss / len(labels)
    return loss

def noramlization(data):
    minVals = data.min(0)
    maxVals = data.max(0)
    ranges = maxVals - minVals
    normData = np.zeros(np.shape(data))
    m = data.shape[0]
    normData = data - np.tile(minVals, (m, 1))
    normData = normData/np.tile(ranges, (m, 1))
    return normData

def random_params(num_wires):
    """Generate random variational parameters in the shape for the ansatz."""
    return np.random.uniform(0, 2 * np.pi, num_wires, requires_grad=True)

num_para = 5
params_init = random_params(3 * num_para + wire)
print(params_init)
# Out:
# [1.797877   5.04424089 4.11861185 1.11038198 1.75832763 2.05237952
#  0.39467452 0.73410584 0.0428098  3.34166099 0.42198226 0.37016252
#  3.56804103 3.13918212 5.30420415 4.09686921 4.74443242]

# %%
def ProcessingData(datapoints, train_size, test_size):
    train_data = np.loadtxt("./mnist_train.csv", delimiter=",")
    print(train_data.shape)
    #Extracting features and labels from the dataset 
    train_data_features = train_data[:datapoints, 1:]
    train_data_labels = train_data[:datapoints, :1].reshape(datapoints,)

    # Use PCA technique to reduce dimensions to 4
    DimReduce = PCA(n_components= dim1)
    train_data_features_reduced = DimReduce.fit_transform(train_data_features)
    # normalize dataset
    train_data_features_reduced = noramlization(train_data_features_reduced)
    s1 = np.array([StateVector(x) for x in train_data_features_reduced[:,:dim]])
    s2 = np.array([StateVector(x) for x in train_data_features_reduced[:,dim:]])
    train_data_features_reduced = np.hstack((s1, s2)).tolist()

    zero_one_datapoint_array = []
    label_0_1 = []
    zero_datapoints_array = [] #an array of the data points containing value 0
    one_datapoints_array = []# an array of the data points containing value 1
    label_0 = []
    label_1 = []
        
    for i in range(datapoints):
        if train_data_labels[i] == 0:                   # extracting zeros
            label_0.append(-1)
            zero_datapoints_array.append(train_data_features_reduced[i])
        elif train_data_labels[i] == 1:                   # extracting ones
            label_1.append(1)
            one_datapoints_array.append(train_data_features_reduced[i]) 
    print(len(zero_datapoints_array), len(one_datapoints_array))
    if (len(label_0) + len(label_1)) < 2 * (train_size + test_size):
        print("datapoints is too small!")
    else:
        print((len(label_0),len(label_1)))
        zero_datapoints_array_train = zero_datapoints_array[:train_size]
        one_datapoints_array_train = one_datapoints_array[:train_size]
        label_0_train = label_0[:train_size]
        label_1_train = label_1[:train_size]
        zero_datapoints_array_test = zero_datapoints_array[train_size + 1:train_size + test_size + 1]
        one_datapoints_array_test = one_datapoints_array[train_size + 1:train_size + test_size + 1]
        label_0_test = label_0[train_size + 1:train_size + test_size + 1]
        label_1_test = label_1[train_size + 1:train_size + test_size + 1]
        #print(len(zero_datapoints_array_train), len(label_1_train))
        #print(len(one_datapoints_array_test), len(label_0_test))

        zero_one_datapoint_array_train = zero_datapoints_array_train + one_datapoints_array_train
        label_0_1_train = label_0_train + label_1_train
        zero_one_datapoint_array_test = zero_datapoints_array_test + one_datapoints_array_test
        label_0_1_test = label_0_test + label_1_test
        #print(len(zero_one_datapoint_array_train), label_0_1_train)
        #print(len(zero_one_datapoint_array_test), label_0_1_test)

        np.random.seed(10)
        index_train = np.random.permutation(range(2 * train_size))
        index_test = np.random.permutation(range(2 * test_size))

        feats_train = []
        Y_train = []
        feats_val = []
        Y_val = []
        for i in range(2 * train_size):
            feats_train.append(zero_one_datapoint_array_train[index_train[i]])
            Y_train.append(label_0_1_train[index_train[i]])


        for i in range(2 * test_size):
            feats_val.append(zero_one_datapoint_array_test[index_test[i]])
            Y_val.append(label_0_1_test[index_test[i]])

        #print(feats_val, Y_val)

        features = feats_train + feats_val
        features = np.array(features, requires_grad=False)
        Y = Y_train + Y_val
        Y = np.array(Y, requires_grad=False)
        feats_train = np.array(feats_train, requires_grad=False)
        Y_train = np.array(Y_train, requires_grad=False)
        feats_val = np.array(feats_val, requires_grad=False)
        Y_val = np.array(Y_val, requires_grad=False)
    return feats_train, Y_train, feats_val, Y_val, features, Y

datapoints = 6000
train_size = 500
test_size = 50
feats_train, Y_train, feats_val, Y_val, features, Y = ProcessingData(datapoints, train_size, test_size)
# Out:
# (60000, 785)
# 592 671
# (592, 671)

# %%
#Block-encoding + Hardware-efficient Ansatz
def DataEncoding(x, wires_start, wires_end):
    wires = np.arange(wires_start, wires_end).tolist()
    qml.MottonenStatePreparation(state_vector=x, wires=wires)
    #qml.AmplitudeEmbedding(features=x, wires=wires, pad_with=0., normalize=True)

def Ansatz(params, wires_start, wires_end):
    for i in np.arange(wires_start, wires_end):
        qml.Hadamard(wires=wires[i])
        qml.RY(params[i - wires_start], wires=wires[i])
    qml.CNOT(wires=[wires[wires_start], wires[wires_end - 1]])
    qml.RZ(params[wires_end - wires_start], wires=wires[wires_end - 1])
    qml.CNOT(wires=[wires_start, wires_end - 1])
    for i in np.arange(wires_start, wires_end):
        qml.RY(params[i + wires_end - 2 * wires_start], wires=wires[i])
        qml.Hadamard(wires=wires[i])

p = 0
#@qml.qnode(dev, interface="torch", diff_method="parameter-shift")
@qml.qnode(dev)
def QKSAN(feat, params):
    x1 = feat[0:4]
    x2 = feat[4:8]
    DataEncoding(x1, 0, wire)
    Ansatz(params[0: num_para], 0, wire)
    qml.adjoint(Ansatz)(params[num_para: 2 * num_para], 0, wire)
    qml.adjoint(DataEncoding)(x2, 0, wire)


    DataEncoding(x2, wire, (2 * wire))
    Ansatz(params[2 * num_para: 3 * num_para], wire, (2 * wire))
    if p != 0:
        for i in range(2 * wire):
            qml.BitFlip(p, wires=i)
    for i in range(wire):
        qml.cond(qml.measure(i), qml.RY)(params[3 * num_para + i], wires=wires[i + wire])
    return qml.expval(qml.PauliZ(2 * wire - 1))

qml.drawer.use_style('black_white')
fig, ax = qml.draw_mpl(QKSAN, show_all_wires=True)(feats_train[0], params_init)
fig.set_size_inches((7, 5))

def variational_classifier(params, feat):
    return QKSAN(feat, params)


def cost(params, features, labels):
    predictions = [variational_classifier(params, feat) for feat in features]
    return square_loss(labels, predictions)

def TrainQKSAN(params_init):
    opt = qml.NesterovMomentumOptimizer(0.09)
    batch_size = 30
    weights = params_init
    #bias = np.array(0.0, requires_grad=True)
    his_acc_val = []
    his_acc_train = []
    his_cost = []
    f1_train = []
    f1_test = []
    roc_auc_train = []
    roc_auc_test = []
    for it in range(120):

        # Update the weights by one optimizer step
        batch_index = np.random.randint(0, 2 * train_size, (batch_size,))
        feats_train_batch = feats_train[batch_index]
        Y_train_batch = Y_train[batch_index]
        
        weights, _, _ = opt.step(cost, weights, feats_train_batch, Y_train_batch)

        # Compute predictions on train and validation set
        predictions_train = [np.sign(variational_classifier(weights, feat)) for feat in feats_train]
        predictions_val = [np.sign(variational_classifier(weights, feat)) for feat in feats_val]
        #print(probs(Y_train, predictions_val))
        c = cost(weights, features, Y).numpy()
        #print(c)
        # Compute accuracy on train and validation set
        acc_train = accuracy_score(Y_train, predictions_train)
        acc_val = accuracy_score(Y_val, predictions_val)
        a = f1_score(Y_train, predictions_train)
        b = f1_score(Y_val, predictions_val)
        
        print("f1_score is", a, b)
        d = roc_auc_score(Y_train, predictions_train)
        e = roc_auc_score(Y_val, predictions_val)
        print("roc_auc_score is", d, e)


        f1_train.append(a)
        f1_test.append(b)
        roc_auc_train.append(d)
        roc_auc_test.append(e)
        his_acc_val.append(acc_val)
        his_acc_train.append(acc_train)
        his_cost.append(c)
        print("Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
            "".format(it + 1, c, acc_train, acc_val))
    print(p)
    return his_acc_val, his_acc_train, his_cost, f1_train, f1_test, roc_auc_train, roc_auc_test

# %%
ps = [0, 0.1, 0.2, 0.3]
his1 = []
his2 = []
his3 = []

for p in ps:
    his_acc_val, his_acc_train, his_cost, _, _, _, _ = TrainQKSAN(params_init)
    his1.append(his_acc_val)
    his2.append(his_acc_train)
    his3.append(his_cost)
# Out:
# f1_score is 0.0031347962382445144 0.0
# roc_auc_score is 0.364 0.39
# Iter:     1 | Cost: 1.5000351 | Acc train: 0.3640000 | Acc validation: 0.3900000
# f1_score is 0.003174603174603175 0.0
# roc_auc_score is 0.372 0.4
# Iter:     2 | Cost: 1.4677728 | Acc train: 0.3720000 | Acc validation: 0.4000000
# f1_score is 0.0031347962382445144 0.0
# roc_auc_score is 0.364 0.41000000000000003
# Iter:     3 | Cost: 1.4026126 | Acc train: 0.3640000 | Acc validation: 0.4100000
# f1_score is 0.011747430249632892 0.0
# roc_auc_score is 0.32699999999999996 0.36
# Iter:     4 | Cost: 1.2966652 | Acc train: 0.3270000 | Acc validation: 0.3600000
# f1_score is 0.25862068965517243 0.05714285714285714
# roc_auc_score is 0.398 0.34
# Iter:     5 | Cost: 1.1915265 | Acc train: 0.3980000 | Acc validation: 0.3400000
# f1_score is 0.4963954685890834 0.2531645569620254
# roc_auc_score is 0.511 0.41000000000000003
# Iter:     6 | Cost: 1.0928872 | Acc train: 0.5110000 | Acc validation: 0.4100000
# f1_score is 0.583969465648855 0.41860465116279066
# roc_auc_score is 0.5640000000000001 0.5
# Iter:     7 | Cost: 1.0095486 | Acc train: 0.5640000 | Acc validation: 0.5000000
# f1_score is 0.7134599504541702 0.6415094339622641
# roc_auc_score is 0.6529999999999999 0.6200000000000001
# Iter:     8 | Cost: 0.9504550 | Acc train: 0.6530000 | Acc validation: 0.6200000
# f1_score is 0.765079365079365 0.7413793103448276
# roc_auc_score is 0.704 0.7
# Iter:     9 | Cost: 0.9006427 | Acc train: 0.7040000 | Acc validation: 0.7000000
# f1_score is 0.7923904052936311 0.7543859649122807
# roc_auc_score is 0.749 0.72
# Iter:    10 | Cost: 0.8387066 | Acc train: 0.7490000 | Acc validation: 0.7200000
# f1_score is 0.8198433420365535 0.7889908256880733
# roc_auc_score is 0.7929999999999999 0.7699999999999998
# Iter:    11 | Cost: 0.7952562 | Acc train: 0.7930000 | Acc validation: 0.7700000
# f1_score is 0.8413547237076648 0.8037383177570094
# roc_auc_score is 0.8219999999999998 0.79
# Iter:    12 | Cost: 0.7730062 | Acc train: 0.8220000 | Acc validation: 0.7900000
# f1_score is 0.8472468916518651 0.8256880733944953
# roc_auc_score is 0.828 0.8099999999999999
# Iter:    13 | Cost: 0.7646621 | Acc train: 0.8280000 | Acc validation: 0.8100000
# f1_score is 0.8509840674789128 0.7766990291262137
# roc_auc_score is 0.841 0.77
# Iter:    14 | Cost: 0.7529652 | Acc train: 0.8410000 | Acc validation: 0.7700000
# f1_score is 0.8590102707749766 0.8000000000000002
# roc_auc_score is 0.849 0.7899999999999999
# Iter:    15 | Cost: 0.7499728 | Acc train: 0.8490000 | Acc validation: 0.7900000
# f1_score is 0.8498233215547703 0.8288288288288288
# roc_auc_score is 0.83 0.8099999999999999
# Iter:    16 | Cost: 0.7527469 | Acc train: 0.8300000 | Acc validation: 0.8100000
# f1_score is 0.8488576449912126 0.831858407079646
# roc_auc_score is 0.828 0.8099999999999999
# Iter:    17 | Cost: 0.7430140 | Acc train: 0.8280000 | Acc validation: 0.8100000
# f1_score is 0.8579040852575487 0.8214285714285714
# roc_auc_score is 0.84 0.7999999999999999
# Iter:    18 | Cost: 0.7221152 | Acc train: 0.8400000 | Acc validation: 0.8000000
# f1_score is 0.873394495412844 0.8380952380952381
# roc_auc_score is 0.862 0.83
# Iter:    19 | Cost: 0.6918368 | Acc train: 0.8620000 | Acc validation: 0.8300000
# f1_score is 0.8717454194792671 0.7916666666666667
# roc_auc_score is 0.867 0.7999999999999999
# Iter:    20 | Cost: 0.6642799 | Acc train: 0.8670000 | Acc validation: 0.8000000
# f1_score is 0.8736532810969637 0.7872340425531915
# roc_auc_score is 0.8709999999999999 0.7999999999999999
# Iter:    21 | Cost: 0.6449902 | Acc train: 0.8710000 | Acc validation: 0.8000000
# f1_score is 0.8281938325991188 0.6341463414634146
# roc_auc_score is 0.844 0.7000000000000001
# Iter:    22 | Cost: 0.6317948 | Acc train: 0.8440000 | Acc validation: 0.7000000
# f1_score is 0.7976878612716762 0.6329113924050632
# roc_auc_score is 0.825 0.7100000000000001
# Iter:    23 | Cost: 0.6254778 | Acc train: 0.8250000 | Acc validation: 0.7100000
# f1_score is 0.828054298642534 0.65
# roc_auc_score is 0.848 0.7200000000000001
# Iter:    24 | Cost: 0.6110938 | Acc train: 0.8480000 | Acc validation: 0.7200000
# f1_score is 0.8977505112474438 0.8260869565217391
# roc_auc_score is 0.9000000000000001 0.84
# Iter:    25 | Cost: 0.5882195 | Acc train: 0.9000000 | Acc validation: 0.8400000
# f1_score is 0.9183266932270916 0.888888888888889
# roc_auc_score is 0.918 0.89
# Iter:    26 | Cost: 0.5747422 | Acc train: 0.9180000 | Acc validation: 0.8900000
# f1_score is 0.9338521400778209 0.9038461538461539
# roc_auc_score is 0.932 0.8999999999999999
# Iter:    27 | Cost: 0.5645281 | Acc train: 0.9320000 | Acc validation: 0.9000000
# f1_score is 0.9337231968810915 0.9038461538461539
# roc_auc_score is 0.932 0.8999999999999999
# Iter:    28 | Cost: 0.5587319 | Acc train: 0.9320000 | Acc validation: 0.9000000
# f1_score is 0.9304099142040038 0.9142857142857144
# roc_auc_score is 0.927 0.91
# Iter:    29 | Cost: 0.5531305 | Acc train: 0.9270000 | Acc validation: 0.9100000
# f1_score is 0.9079189686924494 0.9259259259259259
# roc_auc_score is 0.9000000000000001 0.9199999999999999
# Iter:    30 | Cost: 0.5542159 | Acc train: 0.9000000 | Acc validation: 0.9200000
# f1_score is 0.9064220183486239 0.9090909090909091
# roc_auc_score is 0.8980000000000001 0.9
# Iter:    31 | Cost: 0.5526983 | Acc train: 0.8980000 | Acc validation: 0.9000000
# f1_score is 0.9095940959409594 0.9090909090909091
# roc_auc_score is 0.902 0.9
# Iter:    32 | Cost: 0.5483741 | Acc train: 0.9020000 | Acc validation: 0.9000000
# f1_score is 0.924953095684803 0.9174311926605504
# roc_auc_score is 0.9199999999999999 0.91
# Iter:    33 | Cost: 0.5447351 | Acc train: 0.9200000 | Acc validation: 0.9100000
# f1_score is 0.9262759924385633 0.9158878504672898
# roc_auc_score is 0.922 0.91
# Iter:    34 | Cost: 0.5447270 | Acc train: 0.9220000 | Acc validation: 0.9100000
# f1_score is 0.9204545454545455 0.9074074074074074
# roc_auc_score is 0.9159999999999999 0.9000000000000001
# Iter:    35 | Cost: 0.5458060 | Acc train: 0.9160000 | Acc validation: 0.9000000
# f1_score is 0.9080568720379147 0.9074074074074074
# roc_auc_score is 0.9029999999999999 0.9000000000000001
# Iter:    36 | Cost: 0.5467230 | Acc train: 0.9030000 | Acc validation: 0.9000000
# f1_score is 0.9022556390977444 0.8990825688073395
# roc_auc_score is 0.896 0.89
# Iter:    37 | Cost: 0.5476147 | Acc train: 0.8960000 | Acc validation: 0.8900000
# f1_score is 0.9001883239171375 0.8990825688073395
# roc_auc_score is 0.894 0.89
# Iter:    38 | Cost: 0.5473945 | Acc train: 0.8940000 | Acc validation: 0.8900000
# f1_score is 0.8949858088930936 0.890909090909091
# roc_auc_score is 0.8889999999999999 0.88
# Iter:    39 | Cost: 0.5485653 | Acc train: 0.8890000 | Acc validation: 0.8800000
# f1_score is 0.8930581613508443 0.890909090909091
# roc_auc_score is 0.886 0.88
# Iter:    40 | Cost: 0.5506027 | Acc train: 0.8860000 | Acc validation: 0.8800000
# f1_score is 0.892623716153128 0.882882882882883
# roc_auc_score is 0.885 0.87
# Iter:    41 | Cost: 0.5521643 | Acc train: 0.8850000 | Acc validation: 0.8700000
# f1_score is 0.8942486085343228 0.882882882882883
# roc_auc_score is 0.886 0.87
# Iter:    42 | Cost: 0.5522787 | Acc train: 0.8860000 | Acc validation: 0.8700000
# f1_score is 0.902803738317757 0.890909090909091
# roc_auc_score is 0.896 0.88
# Iter:    43 | Cost: 0.5481342 | Acc train: 0.8960000 | Acc validation: 0.8800000
# f1_score is 0.9078947368421053 0.890909090909091
# roc_auc_score is 0.902 0.88
# Iter:    44 | Cost: 0.5461247 | Acc train: 0.9020000 | Acc validation: 0.8800000
# f1_score is 0.9188156638013372 0.9158878504672898
# roc_auc_score is 0.9149999999999999 0.91
# Iter:    45 | Cost: 0.5440648 | Acc train: 0.9150000 | Acc validation: 0.9100000
# f1_score is 0.9220404234841193 0.9245283018867924
# roc_auc_score is 0.9189999999999999 0.9199999999999999
# Iter:    46 | Cost: 0.5439561 | Acc train: 0.9190000 | Acc validation: 0.9200000
# f1_score is 0.9256038647342995 0.9333333333333333
# roc_auc_score is 0.923 0.9299999999999999
# Iter:    47 | Cost: 0.5455560 | Acc train: 0.9230000 | Acc validation: 0.9300000
# f1_score is 0.925 0.9245283018867924
# roc_auc_score is 0.9219999999999999 0.9199999999999999
# Iter:    48 | Cost: 0.5418057 | Acc train: 0.9220000 | Acc validation: 0.9200000
# f1_score is 0.9251184834123223 0.9074074074074074
# roc_auc_score is 0.921 0.9000000000000001
# Iter:    49 | Cost: 0.5399325 | Acc train: 0.9210000 | Acc validation: 0.9000000
# f1_score is 0.9174484052532833 0.8990825688073395
# roc_auc_score is 0.9119999999999999 0.89
# Iter:    50 | Cost: 0.5403616 | Acc train: 0.9120000 | Acc validation: 0.8900000
# f1_score is 0.9165885660731021 0.8990825688073395
# roc_auc_score is 0.911 0.89
# Iter:    51 | Cost: 0.5409473 | Acc train: 0.9110000 | Acc validation: 0.8900000
# f1_score is 0.9280303030303031 0.9074074074074074
# roc_auc_score is 0.9239999999999999 0.9000000000000001
# Iter:    52 | Cost: 0.5373127 | Acc train: 0.9240000 | Acc validation: 0.9000000
# f1_score is 0.9335863377609108 0.9158878504672898
# roc_auc_score is 0.9299999999999999 0.91
# Iter:    53 | Cost: 0.5357327 | Acc train: 0.9300000 | Acc validation: 0.9100000
# f1_score is 0.9466537342386033 0.9423076923076924
# roc_auc_score is 0.9450000000000001 0.9400000000000001
# Iter:    54 | Cost: 0.5374021 | Acc train: 0.9450000 | Acc validation: 0.9400000
# f1_score is 0.9556650246305418 0.9615384615384615
# roc_auc_score is 0.955 0.9600000000000001
# Iter:    55 | Cost: 0.5439324 | Acc train: 0.9550000 | Acc validation: 0.9600000
# f1_score is 0.9524772497472194 0.98
# roc_auc_score is 0.953 0.98
# Iter:    56 | Cost: 0.5563425 | Acc train: 0.9530000 | Acc validation: 0.9800000
# f1_score is 0.9587939698492463 0.98
# roc_auc_score is 0.959 0.98
# Iter:    57 | Cost: 0.5538003 | Acc train: 0.9590000 | Acc validation: 0.9800000
# f1_score is 0.9663366336633663 0.9615384615384615
# roc_auc_score is 0.966 0.9600000000000001
# Iter:    58 | Cost: 0.5410674 | Acc train: 0.9660000 | Acc validation: 0.9600000
# f1_score is 0.9618768328445747 0.9523809523809523
# roc_auc_score is 0.961 0.9500000000000001
# Iter:    59 | Cost: 0.5341986 | Acc train: 0.9610000 | Acc validation: 0.9500000
# f1_score is 0.9583736689254597 0.9523809523809523
# roc_auc_score is 0.9570000000000001 0.9500000000000001
# Iter:    60 | Cost: 0.5335498 | Acc train: 0.9570000 | Acc validation: 0.9500000
# f1_score is 0.9492822966507177 0.9523809523809523
# roc_auc_score is 0.947 0.9500000000000001
# Iter:    61 | Cost: 0.5342808 | Acc train: 0.9470000 | Acc validation: 0.9500000
# f1_score is 0.9466666666666668 0.9523809523809523
# roc_auc_score is 0.9440000000000001 0.9500000000000001
# Iter:    62 | Cost: 0.5350552 | Acc train: 0.9440000 | Acc validation: 0.9500000
# f1_score is 0.9422894985808893 0.9433962264150945
# roc_auc_score is 0.9390000000000001 0.94
# Iter:    63 | Cost: 0.5380465 | Acc train: 0.9390000 | Acc validation: 0.9400000
# f1_score is 0.9493791786055397 0.9433962264150945
# roc_auc_score is 0.947 0.94
# Iter:    64 | Cost: 0.5338157 | Acc train: 0.9470000 | Acc validation: 0.9400000
# f1_score is 0.9476688867745006 0.9433962264150945
# roc_auc_score is 0.9450000000000001 0.94
# Iter:    65 | Cost: 0.5351015 | Acc train: 0.9450000 | Acc validation: 0.9400000
# f1_score is 0.9405099150141643 0.9433962264150945
# roc_auc_score is 0.937 0.94
# Iter:    66 | Cost: 0.5360688 | Acc train: 0.9370000 | Acc validation: 0.9400000
# f1_score is 0.9291044776119403 0.9259259259259259
# roc_auc_score is 0.9239999999999999 0.9199999999999999
# Iter:    67 | Cost: 0.5426053 | Acc train: 0.9240000 | Acc validation: 0.9200000
# f1_score is 0.9422894985808893 0.9433962264150945
# roc_auc_score is 0.9390000000000001 0.94
# Iter:    68 | Cost: 0.5347815 | Acc train: 0.9390000 | Acc validation: 0.9400000
# f1_score is 0.9546769527483123 0.9433962264150945
# roc_auc_score is 0.953 0.94
# Iter:    69 | Cost: 0.5311425 | Acc train: 0.9530000 | Acc validation: 0.9400000
# f1_score is 0.9611650485436893 0.9433962264150945
# roc_auc_score is 0.9599999999999999 0.94
# Iter:    70 | Cost: 0.5315781 | Acc train: 0.9600000 | Acc validation: 0.9400000
# f1_score is 0.9695780176643769 0.9615384615384615
# roc_auc_score is 0.9689999999999999 0.9600000000000001
# Iter:    71 | Cost: 0.5350598 | Acc train: 0.9690000 | Acc validation: 0.9600000
# f1_score is 0.9667318982387476 0.9615384615384615
# roc_auc_score is 0.966 0.9600000000000001
# Iter:    72 | Cost: 0.5349523 | Acc train: 0.9660000 | Acc validation: 0.9600000
# f1_score is 0.9546769527483123 0.9433962264150945
# roc_auc_score is 0.953 0.94
# Iter:    73 | Cost: 0.5315378 | Acc train: 0.9530000 | Acc validation: 0.9400000
# f1_score is 0.9419600380589914 0.9345794392523363
# roc_auc_score is 0.9390000000000001 0.9299999999999999
# Iter:    74 | Cost: 0.5332039 | Acc train: 0.9390000 | Acc validation: 0.9300000
# f1_score is 0.9120879120879121 0.9174311926605504
# roc_auc_score is 0.9040000000000001 0.91
# Iter:    75 | Cost: 0.5477233 | Acc train: 0.9040000 | Acc validation: 0.9100000
# f1_score is 0.9038112522686025 0.9009009009009009
# roc_auc_score is 0.894 0.89
# Iter:    76 | Cost: 0.5518744 | Acc train: 0.8940000 | Acc validation: 0.8900000
# f1_score is 0.9152854511970534 0.9174311926605504
# roc_auc_score is 0.9080000000000001 0.91
# Iter:    77 | Cost: 0.5423676 | Acc train: 0.9080000 | Acc validation: 0.9100000
# f1_score is 0.925512104283054 0.9345794392523363
# roc_auc_score is 0.9199999999999999 0.9299999999999999
# Iter:    78 | Cost: 0.5367131 | Acc train: 0.9200000 | Acc validation: 0.9300000
# f1_score is 0.9537572254335259 0.9523809523809523
# roc_auc_score is 0.9520000000000001 0.9500000000000001
# Iter:    79 | Cost: 0.5294441 | Acc train: 0.9520000 | Acc validation: 0.9500000
# f1_score is 0.9666011787819253 0.9615384615384615
# roc_auc_score is 0.966 0.9600000000000001
# Iter:    80 | Cost: 0.5310049 | Acc train: 0.9660000 | Acc validation: 0.9600000
# f1_score is 0.9695181907571288 0.9615384615384615
# roc_auc_score is 0.969 0.9600000000000001
# Iter:    81 | Cost: 0.5314919 | Acc train: 0.9690000 | Acc validation: 0.9600000
# f1_score is 0.9656526005888125 0.9615384615384615
# roc_auc_score is 0.965 0.9600000000000001
# Iter:    82 | Cost: 0.5318279 | Acc train: 0.9650000 | Acc validation: 0.9600000
# f1_score is 0.9701195219123506 0.9607843137254902
# roc_auc_score is 0.97 0.96
# Iter:    83 | Cost: 0.5361782 | Acc train: 0.9700000 | Acc validation: 0.9600000
# f1_score is 0.971028971028971 0.9504950495049505
# roc_auc_score is 0.971 0.95
# Iter:    84 | Cost: 0.5381105 | Acc train: 0.9710000 | Acc validation: 0.9500000
# f1_score is 0.9625884732052579 0.94
# roc_auc_score is 0.9629999999999999 0.94
# Iter:    85 | Cost: 0.5415365 | Acc train: 0.9630000 | Acc validation: 0.9400000
# f1_score is 0.9531568228105907 0.9072164948453608
# roc_auc_score is 0.954 0.9099999999999999
# Iter:    86 | Cost: 0.5421352 | Acc train: 0.9540000 | Acc validation: 0.9100000
# f1_score is 0.9416581371545548 0.8958333333333334
# roc_auc_score is 0.943 0.8999999999999999
# Iter:    87 | Cost: 0.5424803 | Acc train: 0.9430000 | Acc validation: 0.9000000
# f1_score is 0.9320987654320988 0.8958333333333334
# roc_auc_score is 0.9339999999999999 0.8999999999999999
# Iter:    88 | Cost: 0.5444783 | Acc train: 0.9340000 | Acc validation: 0.9000000
# f1_score is 0.9474727452923686 0.9320388349514563
# roc_auc_score is 0.947 0.93
# Iter:    89 | Cost: 0.5347610 | Acc train: 0.9470000 | Acc validation: 0.9300000
# f1_score is 0.9460500963391137 0.923076923076923
# roc_auc_score is 0.9440000000000001 0.9199999999999999
# Iter:    90 | Cost: 0.5322464 | Acc train: 0.9440000 | Acc validation: 0.9200000
# f1_score is 0.9431051108968178 0.9333333333333333
# roc_auc_score is 0.941 0.9299999999999999
# Iter:    91 | Cost: 0.5321535 | Acc train: 0.9410000 | Acc validation: 0.9300000
# f1_score is 0.9290444654683067 0.9345794392523363
# roc_auc_score is 0.9249999999999999 0.9299999999999999
# Iter:    92 | Cost: 0.5326029 | Acc train: 0.9250000 | Acc validation: 0.9300000
# f1_score is 0.9222118088097468 0.9259259259259259
# roc_auc_score is 0.9169999999999999 0.9199999999999999
# Iter:    93 | Cost: 0.5339196 | Acc train: 0.9170000 | Acc validation: 0.9200000
# f1_score is 0.9259606373008433 0.9345794392523363
# roc_auc_score is 0.9209999999999999 0.9299999999999999
# Iter:    94 | Cost: 0.5323268 | Acc train: 0.9210000 | Acc validation: 0.9300000
# f1_score is 0.9293119698397739 0.9433962264150945
# roc_auc_score is 0.9249999999999999 0.94
# Iter:    95 | Cost: 0.5308276 | Acc train: 0.9250000 | Acc validation: 0.9400000
# f1_score is 0.9382716049382717 0.9433962264150945
# roc_auc_score is 0.935 0.94
# Iter:    96 | Cost: 0.5295050 | Acc train: 0.9350000 | Acc validation: 0.9400000
# f1_score is 0.9491850431447747 0.9523809523809523
# roc_auc_score is 0.9470000000000001 0.9500000000000001
# Iter:    97 | Cost: 0.5288326 | Acc train: 0.9470000 | Acc validation: 0.9500000
# f1_score is 0.9474689589302769 0.9433962264150945
# roc_auc_score is 0.945 0.94
# Iter:    98 | Cost: 0.5302206 | Acc train: 0.9450000 | Acc validation: 0.9400000
# f1_score is 0.9378531073446329 0.9433962264150945
# roc_auc_score is 0.934 0.94
# Iter:    99 | Cost: 0.5357109 | Acc train: 0.9340000 | Acc validation: 0.9400000
# f1_score is 0.9431818181818182 0.9259259259259259
# roc_auc_score is 0.9400000000000001 0.9199999999999999
# Iter:   100 | Cost: 0.5353016 | Acc train: 0.9400000 | Acc validation: 0.9200000
# f1_score is 0.9529298751200768 0.9345794392523363
# roc_auc_score is 0.9510000000000001 0.9299999999999999
# Iter:   101 | Cost: 0.5315484 | Acc train: 0.9510000 | Acc validation: 0.9300000
# f1_score is 0.9667968749999999 0.9523809523809523
# roc_auc_score is 0.966 0.9500000000000001
# Iter:   102 | Cost: 0.5326876 | Acc train: 0.9660000 | Acc validation: 0.9500000
# f1_score is 0.9771598808341607 0.9615384615384615
# roc_auc_score is 0.977 0.9600000000000001
# Iter:   103 | Cost: 0.5396819 | Acc train: 0.9770000 | Acc validation: 0.9600000
# f1_score is 0.9655850540806292 0.9433962264150945
# roc_auc_score is 0.965 0.94
# Iter:   104 | Cost: 0.5416900 | Acc train: 0.9650000 | Acc validation: 0.9400000
# f1_score is 0.9515503875968992 0.9433962264150945
# roc_auc_score is 0.9500000000000001 0.94
# Iter:   105 | Cost: 0.5448223 | Acc train: 0.9500000 | Acc validation: 0.9400000
# f1_score is 0.9478764478764479 0.9345794392523363
# roc_auc_score is 0.946 0.9299999999999999
# Iter:   106 | Cost: 0.5476575 | Acc train: 0.9460000 | Acc validation: 0.9300000
# f1_score is 0.9543245869776482 0.9433962264150945
# roc_auc_score is 0.9530000000000001 0.94
# Iter:   107 | Cost: 0.5466409 | Acc train: 0.9530000 | Acc validation: 0.9400000
# f1_score is 0.9501915708812262 0.9259259259259259
# roc_auc_score is 0.9480000000000001 0.9199999999999999
# Iter:   108 | Cost: 0.5409334 | Acc train: 0.9480000 | Acc validation: 0.9200000
# f1_score is 0.9429657794676806 0.9259259259259259
# roc_auc_score is 0.9400000000000001 0.9199999999999999
# Iter:   109 | Cost: 0.5385285 | Acc train: 0.9400000 | Acc validation: 0.9200000
# f1_score is 0.9695780176643769 0.9433962264150945
# roc_auc_score is 0.9689999999999999 0.94
# Iter:   110 | Cost: 0.5359714 | Acc train: 0.9690000 | Acc validation: 0.9400000
# f1_score is 0.9771144278606965 0.9615384615384615
# roc_auc_score is 0.977 0.9600000000000001
# Iter:   111 | Cost: 0.5350550 | Acc train: 0.9770000 | Acc validation: 0.9600000
# f1_score is 0.9749247743229689 0.970873786407767
# roc_auc_score is 0.975 0.97
# Iter:   112 | Cost: 0.5374881 | Acc train: 0.9750000 | Acc validation: 0.9700000
# f1_score is 0.9717741935483871 0.9504950495049505
# roc_auc_score is 0.972 0.95
# Iter:   113 | Cost: 0.5413903 | Acc train: 0.9720000 | Acc validation: 0.9500000
# f1_score is 0.968 0.9504950495049505
# roc_auc_score is 0.9679999999999999 0.95
# Iter:   114 | Cost: 0.5370249 | Acc train: 0.9680000 | Acc validation: 0.9500000
# f1_score is 0.9644970414201183 0.9615384615384615
# roc_auc_score is 0.964 0.9600000000000001
# Iter:   115 | Cost: 0.5302600 | Acc train: 0.9640000 | Acc validation: 0.9600000
# f1_score is 0.96 0.9523809523809523
# roc_auc_score is 0.9589999999999999 0.9500000000000001
# Iter:   116 | Cost: 0.5273397 | Acc train: 0.9590000 | Acc validation: 0.9500000
# f1_score is 0.9571984435797666 0.9523809523809523
# roc_auc_score is 0.9560000000000001 0.9500000000000001
# Iter:   117 | Cost: 0.5278754 | Acc train: 0.9560000 | Acc validation: 0.9500000
# f1_score is 0.9580487804878048 0.9523809523809523
# roc_auc_score is 0.9569999999999999 0.9500000000000001
# Iter:   118 | Cost: 0.5287319 | Acc train: 0.9570000 | Acc validation: 0.9500000
# f1_score is 0.9561830574488802 0.9523809523809523
# roc_auc_score is 0.9550000000000001 0.9500000000000001
# Iter:   119 | Cost: 0.5287255 | Acc train: 0.9550000 | Acc validation: 0.9500000
# f1_score is 0.958984375 0.9523809523809523
# roc_auc_score is 0.958 0.9500000000000001
# Iter:   120 | Cost: 0.5282295 | Acc train: 0.9580000 | Acc validation: 0.9500000
# 0
# f1_score is 0.0031847133757961785 0.0
# roc_auc_score is 0.374 0.41000000000000003
# Iter:     1 | Cost: 1.3901313 | Acc train: 0.3740000 | Acc validation: 0.4100000
# f1_score is 0.0029629629629629632 0.0
# roc_auc_score is 0.327 0.35
# Iter:     2 | Cost: 1.3389584 | Acc train: 0.3270000 | Acc validation: 0.3500000
# f1_score is 0.05412371134020619 0.02666666666666667
# roc_auc_score is 0.266 0.27
# Iter:     3 | Cost: 1.2692287 | Acc train: 0.2660000 | Acc validation: 0.2700000
# f1_score is 0.49605609114811566 0.33962264150943394
# roc_auc_score is 0.425 0.3
# Iter:     4 | Cost: 1.2111184 | Acc train: 0.4250000 | Acc validation: 0.3000000
# f1_score is 0.6286571642910728 0.5040650406504065
# roc_auc_score is 0.505 0.39
# Iter:     5 | Cost: 1.1951312 | Acc train: 0.5050000 | Acc validation: 0.3900000
# f1_score is 0.6832986832986834 0.684931506849315
# roc_auc_score is 0.5429999999999999 0.54
# Iter:     6 | Cost: 1.1999719 | Acc train: 0.5430000 | Acc validation: 0.5400000
# f1_score is 0.6784260515603798 0.6711409395973155
# roc_auc_score is 0.526 0.51
# Iter:     7 | Cost: 1.2036167 | Acc train: 0.5260000 | Acc validation: 0.5100000
# f1_score is 0.6858710562414266 0.6756756756756758
# roc_auc_score is 0.542 0.52
# Iter:     8 | Cost: 1.1651884 | Acc train: 0.5420000 | Acc validation: 0.5200000
# f1_score is 0.6965034965034964 0.6993006993006993
# roc_auc_score is 0.5660000000000001 0.5700000000000001
# Iter:     9 | Cost: 1.1144486 | Acc train: 0.5660000 | Acc validation: 0.5700000
# f1_score is 0.710843373493976 0.6451612903225806
# roc_auc_score is 0.616 0.56
# Iter:    10 | Cost: 1.0395514 | Acc train: 0.6160000 | Acc validation: 0.5600000
# f1_score is 0.6890611541774334 0.5825242718446602
# roc_auc_score is 0.639 0.5700000000000001
# Iter:    11 | Cost: 0.9775556 | Acc train: 0.6390000 | Acc validation: 0.5700000
# f1_score is 0.6576402321083173 0.5434782608695652
# roc_auc_score is 0.6460000000000001 0.58
# Iter:    12 | Cost: 0.9244564 | Acc train: 0.6460000 | Acc validation: 0.5800000
# f1_score is 0.6512118018967333 0.5
# roc_auc_score is 0.6689999999999999 0.5599999999999999
# Iter:    13 | Cost: 0.8822848 | Acc train: 0.6690000 | Acc validation: 0.5600000
# f1_score is 0.709812108559499 0.5747126436781609
# roc_auc_score is 0.7220000000000001 0.6300000000000001
# Iter:    14 | Cost: 0.8517321 | Acc train: 0.7220000 | Acc validation: 0.6300000
# f1_score is 0.8081791626095424 0.7216494845360825
# roc_auc_score is 0.803 0.73
# Iter:    15 | Cost: 0.8348330 | Acc train: 0.8030000 | Acc validation: 0.7300000
# f1_score is 0.8246816846229186 0.803921568627451
# roc_auc_score is 0.8210000000000002 0.7999999999999999
# Iter:    16 | Cost: 0.8296273 | Acc train: 0.8210000 | Acc validation: 0.8000000
# f1_score is 0.786235662148071 0.8316831683168315
# roc_auc_score is 0.7949999999999999 0.83
# Iter:    17 | Cost: 0.8317350 | Acc train: 0.7950000 | Acc validation: 0.8300000
# f1_score is 0.7814432989690722 0.8785046728971964
# roc_auc_score is 0.788 0.87
# Iter:    18 | Cost: 0.8367672 | Acc train: 0.7880000 | Acc validation: 0.8700000
# f1_score is 0.7738589211618258 0.888888888888889
# roc_auc_score is 0.782 0.88
# Iter:    19 | Cost: 0.8377076 | Acc train: 0.7820000 | Acc validation: 0.8800000
# f1_score is 0.7660944206008583 0.9142857142857144
# roc_auc_score is 0.7819999999999999 0.91
# Iter:    20 | Cost: 0.8302344 | Acc train: 0.7820000 | Acc validation: 0.9100000
# f1_score is 0.761478163493841 0.8932038834951457
# roc_auc_score is 0.787 0.89
# Iter:    21 | Cost: 0.8160879 | Acc train: 0.7870000 | Acc validation: 0.8900000
# f1_score is 0.7004950495049505 0.7640449438202247
# roc_auc_score is 0.7579999999999999 0.7900000000000001
# Iter:    22 | Cost: 0.8007191 | Acc train: 0.7580000 | Acc validation: 0.7900000
# f1_score is 0.24525043177892913 0.23728813559322035
# roc_auc_score is 0.563 0.55
# Iter:    23 | Cost: 0.7936405 | Acc train: 0.5630000 | Acc validation: 0.5500000
# f1_score is 0.1801801801801802 0.14285714285714285
# roc_auc_score is 0.5449999999999999 0.52
# Iter:    24 | Cost: 0.7837151 | Acc train: 0.5450000 | Acc validation: 0.5200000
# f1_score is 0.6525198938992042 0.5945945945945945
# roc_auc_score is 0.738 0.7
# Iter:    25 | Cost: 0.7625287 | Acc train: 0.7380000 | Acc validation: 0.7000000
# f1_score is 0.8984293193717278 0.8775510204081632
# roc_auc_score is 0.903 0.88
# Iter:    26 | Cost: 0.7455475 | Acc train: 0.9030000 | Acc validation: 0.8800000
# f1_score is 0.9305019305019305 0.923076923076923
# roc_auc_score is 0.928 0.9199999999999999
# Iter:    27 | Cost: 0.7368453 | Acc train: 0.9280000 | Acc validation: 0.9200000
# f1_score is 0.8874887488748874 0.882882882882883
# roc_auc_score is 0.875 0.87
# Iter:    28 | Cost: 0.7432266 | Acc train: 0.8750000 | Acc validation: 0.8700000
# f1_score is 0.8666085440278989 0.8521739130434782
# roc_auc_score is 0.847 0.8299999999999998
# Iter:    29 | Cost: 0.7494940 | Acc train: 0.8470000 | Acc validation: 0.8300000
# f1_score is 0.8696412948381452 0.8672566371681417
# roc_auc_score is 0.851 0.85
# Iter:    30 | Cost: 0.7424405 | Acc train: 0.8510000 | Acc validation: 0.8500000
# f1_score is 0.8931159420289855 0.8990825688073395
# roc_auc_score is 0.8820000000000001 0.89
# Iter:    31 | Cost: 0.7252699 | Acc train: 0.8820000 | Acc validation: 0.8900000
# f1_score is 0.9246704331450094 0.9245283018867924
# roc_auc_score is 0.9199999999999999 0.9199999999999999
# Iter:    32 | Cost: 0.7123326 | Acc train: 0.9200000 | Acc validation: 0.9200000
# f1_score is 0.9514563106796116 0.9333333333333333
# roc_auc_score is 0.9500000000000001 0.9299999999999999
# Iter:    33 | Cost: 0.7057881 | Acc train: 0.9500000 | Acc validation: 0.9300000
# f1_score is 0.958627648839556 0.9494949494949495
# roc_auc_score is 0.959 0.95
# Iter:    34 | Cost: 0.7024906 | Acc train: 0.9590000 | Acc validation: 0.9500000
# f1_score is 0.9087003222341568 0.8571428571428571
# roc_auc_score is 0.915 0.8699999999999999
# Iter:    35 | Cost: 0.7071424 | Acc train: 0.9150000 | Acc validation: 0.8700000
# f1_score is 0.8561721404303511 0.7857142857142857
# roc_auc_score is 0.873 0.8200000000000001
# Iter:    36 | Cost: 0.7091566 | Acc train: 0.8730000 | Acc validation: 0.8200000
# f1_score is 0.8992416034669556 0.8181818181818181
# roc_auc_score is 0.907 0.84
# Iter:    37 | Cost: 0.7024316 | Acc train: 0.9070000 | Acc validation: 0.8400000
# f1_score is 0.938860103626943 0.9387755102040817
# roc_auc_score is 0.9410000000000001 0.94
# Iter:    38 | Cost: 0.6958372 | Acc train: 0.9410000 | Acc validation: 0.9400000
# f1_score is 0.9538152610441766 0.9504950495049505
# roc_auc_score is 0.954 0.95
# Iter:    39 | Cost: 0.6892981 | Acc train: 0.9540000 | Acc validation: 0.9500000
# f1_score is 0.9589041095890412 0.9423076923076924
# roc_auc_score is 0.958 0.9400000000000001
# Iter:    40 | Cost: 0.6855448 | Acc train: 0.9580000 | Acc validation: 0.9400000
# f1_score is 0.943432406519655 0.9245283018867924
# roc_auc_score is 0.9410000000000001 0.9199999999999999
# Iter:    41 | Cost: 0.6848526 | Acc train: 0.9410000 | Acc validation: 0.9200000
# f1_score is 0.918918918918919 0.9345794392523363
# roc_auc_score is 0.913 0.9299999999999999
# Iter:    42 | Cost: 0.6848953 | Acc train: 0.9130000 | Acc validation: 0.9300000
# f1_score is 0.9134883720930232 0.9259259259259259
# roc_auc_score is 0.9069999999999999 0.9199999999999999
# Iter:    43 | Cost: 0.6826997 | Acc train: 0.9070000 | Acc validation: 0.9200000
# f1_score is 0.9167446211412534 0.9345794392523363
# roc_auc_score is 0.911 0.9299999999999999
# Iter:    44 | Cost: 0.6800750 | Acc train: 0.9110000 | Acc validation: 0.9300000
# f1_score is 0.9242424242424243 0.9142857142857144
# roc_auc_score is 0.9199999999999999 0.91
# Iter:    45 | Cost: 0.6781920 | Acc train: 0.9200000 | Acc validation: 0.9100000
# f1_score is 0.9117361784675073 0.8932038834951457
# roc_auc_score is 0.9089999999999999 0.89
# Iter:    46 | Cost: 0.6782449 | Acc train: 0.9090000 | Acc validation: 0.8900000
# f1_score is 0.9137254901960785 0.8823529411764707
# roc_auc_score is 0.912 0.88
# Iter:    47 | Cost: 0.6790231 | Acc train: 0.9120000 | Acc validation: 0.8800000
# f1_score is 0.906930693069307 0.8712871287128714
# roc_auc_score is 0.906 0.8699999999999999
# Iter:    48 | Cost: 0.6799469 | Acc train: 0.9060000 | Acc validation: 0.8700000
# f1_score is 0.906930693069307 0.8712871287128714
# roc_auc_score is 0.906 0.8699999999999999
# Iter:    49 | Cost: 0.6795224 | Acc train: 0.9060000 | Acc validation: 0.8700000
# f1_score is 0.9147286821705426 0.8932038834951457
# roc_auc_score is 0.912 0.89
# Iter:    50 | Cost: 0.6766986 | Acc train: 0.9120000 | Acc validation: 0.8900000
# f1_score is 0.923368022705771 0.9142857142857144
# roc_auc_score is 0.9189999999999999 0.91
# Iter:    51 | Cost: 0.6750083 | Acc train: 0.9190000 | Acc validation: 0.9100000
# f1_score is 0.9242424242424243 0.9345794392523363
# roc_auc_score is 0.9199999999999999 0.9299999999999999
# Iter:    52 | Cost: 0.6742582 | Acc train: 0.9200000 | Acc validation: 0.9300000
# f1_score is 0.9319271332694151 0.9142857142857144
# roc_auc_score is 0.929 0.91
# Iter:    53 | Cost: 0.6746962 | Acc train: 0.9290000 | Acc validation: 0.9100000
# f1_score is 0.9299111549851925 0.912621359223301
# roc_auc_score is 0.929 0.91
# Iter:    54 | Cost: 0.6779321 | Acc train: 0.9290000 | Acc validation: 0.9100000
# f1_score is 0.927710843373494 0.9108910891089109
# roc_auc_score is 0.9279999999999999 0.91
# Iter:    55 | Cost: 0.6805786 | Acc train: 0.9280000 | Acc validation: 0.9100000
# f1_score is 0.9266331658291457 0.92
# roc_auc_score is 0.927 0.9199999999999999
# Iter:    56 | Cost: 0.6812221 | Acc train: 0.9270000 | Acc validation: 0.9200000
# f1_score is 0.9332003988035893 0.9215686274509804
# roc_auc_score is 0.9329999999999999 0.92
# Iter:    57 | Cost: 0.6789919 | Acc train: 0.9330000 | Acc validation: 0.9200000
# f1_score is 0.9356725146198831 0.923076923076923
# roc_auc_score is 0.9339999999999999 0.9199999999999999
# Iter:    58 | Cost: 0.6762917 | Acc train: 0.9340000 | Acc validation: 0.9200000
# f1_score is 0.9346153846153847 0.9245283018867924
# roc_auc_score is 0.9319999999999999 0.9199999999999999
# Iter:    59 | Cost: 0.6745414 | Acc train: 0.9320000 | Acc validation: 0.9200000
# f1_score is 0.9330783938814532 0.9345794392523363
# roc_auc_score is 0.9299999999999999 0.9299999999999999
# Iter:    60 | Cost: 0.6734995 | Acc train: 0.9300000 | Acc validation: 0.9300000
# f1_score is 0.9340974212034384 0.9345794392523363
# roc_auc_score is 0.931 0.9299999999999999
# Iter:    61 | Cost: 0.6731634 | Acc train: 0.9310000 | Acc validation: 0.9300000
# f1_score is 0.9306742640075973 0.9259259259259259
# roc_auc_score is 0.927 0.9199999999999999
# Iter:    62 | Cost: 0.6729303 | Acc train: 0.9270000 | Acc validation: 0.9200000
# f1_score is 0.9246704331450094 0.9259259259259259
# roc_auc_score is 0.9199999999999999 0.9199999999999999
# Iter:    63 | Cost: 0.6733501 | Acc train: 0.9200000 | Acc validation: 0.9200000
# f1_score is 0.9072543617998163 0.9174311926605504
# roc_auc_score is 0.899 0.91
# Iter:    64 | Cost: 0.6756658 | Acc train: 0.8990000 | Acc validation: 0.9100000
# f1_score is 0.8961156278229448 0.9009009009009009
# roc_auc_score is 0.885 0.89
# Iter:    65 | Cost: 0.6791142 | Acc train: 0.8850000 | Acc validation: 0.8900000
# f1_score is 0.8920863309352518 0.9009009009009009
# roc_auc_score is 0.8800000000000001 0.89
# Iter:    66 | Cost: 0.6799934 | Acc train: 0.8800000 | Acc validation: 0.8900000
# f1_score is 0.8920863309352518 0.8928571428571428
# roc_auc_score is 0.8800000000000001 0.88
# Iter:    67 | Cost: 0.6803926 | Acc train: 0.8800000 | Acc validation: 0.8800000
# f1_score is 0.8857142857142858 0.8928571428571428
# roc_auc_score is 0.872 0.88
# Iter:    68 | Cost: 0.6816351 | Acc train: 0.8720000 | Acc validation: 0.8800000
# f1_score is 0.8849241748438894 0.8928571428571428
# roc_auc_score is 0.871 0.88
# Iter:    69 | Cost: 0.6821997 | Acc train: 0.8710000 | Acc validation: 0.8800000
# f1_score is 0.8860986547085202 0.9009009009009009
# roc_auc_score is 0.873 0.89
# Iter:    70 | Cost: 0.6810133 | Acc train: 0.8730000 | Acc validation: 0.8900000
# f1_score is 0.8921124206708976 0.9009009009009009
# roc_auc_score is 0.881 0.89
# Iter:    71 | Cost: 0.6787476 | Acc train: 0.8810000 | Acc validation: 0.8900000
# f1_score is 0.9075785582255084 0.9158878504672898
# roc_auc_score is 0.9000000000000001 0.91
# Iter:    72 | Cost: 0.6768456 | Acc train: 0.9000000 | Acc validation: 0.9100000
# f1_score is 0.9156398104265403 0.9142857142857144
# roc_auc_score is 0.9109999999999999 0.91
# Iter:    73 | Cost: 0.6764003 | Acc train: 0.9110000 | Acc validation: 0.9100000
# f1_score is 0.9157792836398837 0.8932038834951457
# roc_auc_score is 0.913 0.89
# Iter:    74 | Cost: 0.6769458 | Acc train: 0.9130000 | Acc validation: 0.8900000
# f1_score is 0.9278152069297402 0.9142857142857144
# roc_auc_score is 0.925 0.91
# Iter:    75 | Cost: 0.6758029 | Acc train: 0.9250000 | Acc validation: 0.9100000
# f1_score is 0.9314285714285715 0.9345794392523363
# roc_auc_score is 0.9279999999999999 0.9299999999999999
# Iter:    76 | Cost: 0.6741037 | Acc train: 0.9280000 | Acc validation: 0.9300000
# f1_score is 0.9274269557021677 0.9345794392523363
# roc_auc_score is 0.9229999999999999 0.9299999999999999
# Iter:    77 | Cost: 0.6734042 | Acc train: 0.9230000 | Acc validation: 0.9300000
# f1_score is 0.9245107176141658 0.9259259259259259
# roc_auc_score is 0.9189999999999999 0.9199999999999999
# Iter:    78 | Cost: 0.6746759 | Acc train: 0.9190000 | Acc validation: 0.9200000
# f1_score is 0.9239332096474953 0.9090909090909091
# roc_auc_score is 0.9179999999999999 0.9
# Iter:    79 | Cost: 0.6773081 | Acc train: 0.9180000 | Acc validation: 0.9000000
# f1_score is 0.9154411764705882 0.9090909090909091
# roc_auc_score is 0.9080000000000001 0.9
# Iter:    80 | Cost: 0.6798269 | Acc train: 0.9080000 | Acc validation: 0.9000000
# f1_score is 0.9186691312384474 0.9259259259259259
# roc_auc_score is 0.9119999999999999 0.9199999999999999
# Iter:    81 | Cost: 0.6796709 | Acc train: 0.9120000 | Acc validation: 0.9200000
# f1_score is 0.9386213408876297 0.9345794392523363
# roc_auc_score is 0.935 0.9299999999999999
# Iter:    82 | Cost: 0.6768311 | Acc train: 0.9350000 | Acc validation: 0.9300000
# f1_score is 0.9475691134413727 0.9433962264150945
# roc_auc_score is 0.945 0.94
# Iter:    83 | Cost: 0.6750459 | Acc train: 0.9450000 | Acc validation: 0.9400000
# f1_score is 0.9538461538461539 0.9523809523809523
# roc_auc_score is 0.9520000000000001 0.9500000000000001
# Iter:    84 | Cost: 0.6732472 | Acc train: 0.9520000 | Acc validation: 0.9500000
# f1_score is 0.9593023255813953 0.9523809523809523
# roc_auc_score is 0.958 0.9500000000000001
# Iter:    85 | Cost: 0.6727080 | Acc train: 0.9580000 | Acc validation: 0.9500000
# f1_score is 0.9620253164556962 0.9523809523809523
# roc_auc_score is 0.9609999999999999 0.9500000000000001
# Iter:    86 | Cost: 0.6726030 | Acc train: 0.9610000 | Acc validation: 0.9500000
# f1_score is 0.9608610567514677 0.9423076923076924
# roc_auc_score is 0.9599999999999999 0.9400000000000001
# Iter:    87 | Cost: 0.6728397 | Acc train: 0.9600000 | Acc validation: 0.9400000
# f1_score is 0.9598432908912831 0.9523809523809523
# roc_auc_score is 0.9589999999999999 0.9500000000000001
# Iter:    88 | Cost: 0.6727495 | Acc train: 0.9590000 | Acc validation: 0.9500000
# f1_score is 0.9628180039138943 0.9523809523809523
# roc_auc_score is 0.962 0.9500000000000001
# Iter:    89 | Cost: 0.6727895 | Acc train: 0.9620000 | Acc validation: 0.9500000
# f1_score is 0.9610136452241715 0.9523809523809523
# roc_auc_score is 0.9599999999999999 0.9500000000000001
# Iter:    90 | Cost: 0.6722867 | Acc train: 0.9600000 | Acc validation: 0.9500000
# f1_score is 0.9561830574488802 0.9433962264150945
# roc_auc_score is 0.9550000000000001 0.94
# Iter:    91 | Cost: 0.6719906 | Acc train: 0.9550000 | Acc validation: 0.9400000
# f1_score is 0.9475728155339807 0.9433962264150945
# roc_auc_score is 0.9460000000000001 0.94
# Iter:    92 | Cost: 0.6726115 | Acc train: 0.9460000 | Acc validation: 0.9400000
# f1_score is 0.9453124999999999 0.923076923076923
# roc_auc_score is 0.944 0.9199999999999999
# Iter:    93 | Cost: 0.6737876 | Acc train: 0.9440000 | Acc validation: 0.9200000
# f1_score is 0.9441723800195887 0.923076923076923
# roc_auc_score is 0.943 0.9199999999999999
# Iter:    94 | Cost: 0.6744452 | Acc train: 0.9430000 | Acc validation: 0.9200000
# f1_score is 0.9415204678362573 0.923076923076923
# roc_auc_score is 0.94 0.9199999999999999
# Iter:    95 | Cost: 0.6740300 | Acc train: 0.9400000 | Acc validation: 0.9200000
# f1_score is 0.9353905496624878 0.9142857142857144
# roc_auc_score is 0.933 0.91
# Iter:    96 | Cost: 0.6731757 | Acc train: 0.9330000 | Acc validation: 0.9100000
# f1_score is 0.9329501915708812 0.9245283018867924
# roc_auc_score is 0.9299999999999999 0.9199999999999999
# Iter:    97 | Cost: 0.6728759 | Acc train: 0.9300000 | Acc validation: 0.9200000
# f1_score is 0.9340974212034384 0.9245283018867924
# roc_auc_score is 0.931 0.9199999999999999
# Iter:    98 | Cost: 0.6726703 | Acc train: 0.9310000 | Acc validation: 0.9200000
# f1_score is 0.9296046287367407 0.9142857142857144
# roc_auc_score is 0.9269999999999999 0.91
# Iter:    99 | Cost: 0.6734409 | Acc train: 0.9270000 | Acc validation: 0.9100000
# f1_score is 0.9296046287367407 0.9142857142857144
# roc_auc_score is 0.9269999999999999 0.91
# Iter:   100 | Cost: 0.6733691 | Acc train: 0.9270000 | Acc validation: 0.9100000
# f1_score is 0.9273959341723137 0.9142857142857144
# roc_auc_score is 0.925 0.91
# Iter:   101 | Cost: 0.6737137 | Acc train: 0.9250000 | Acc validation: 0.9100000
# f1_score is 0.929740134744947 0.9142857142857144
# roc_auc_score is 0.927 0.91
# Iter:   102 | Cost: 0.6730759 | Acc train: 0.9270000 | Acc validation: 0.9100000
# f1_score is 0.9315589353612167 0.9345794392523363
# roc_auc_score is 0.928 0.9299999999999999
# Iter:   103 | Cost: 0.6721128 | Acc train: 0.9280000 | Acc validation: 0.9300000
# f1_score is 0.9308056872037914 0.9259259259259259
# roc_auc_score is 0.927 0.9199999999999999
# Iter:   104 | Cost: 0.6720407 | Acc train: 0.9270000 | Acc validation: 0.9200000
# f1_score is 0.9308056872037914 0.9259259259259259
# roc_auc_score is 0.927 0.9199999999999999
# Iter:   105 | Cost: 0.6720033 | Acc train: 0.9270000 | Acc validation: 0.9200000
# f1_score is 0.9334600760456274 0.9259259259259259
# roc_auc_score is 0.93 0.9199999999999999
# Iter:   106 | Cost: 0.6715197 | Acc train: 0.9300000 | Acc validation: 0.9200000
# f1_score is 0.9343482397716459 0.9259259259259259
# roc_auc_score is 0.9309999999999999 0.9199999999999999
# Iter:   107 | Cost: 0.6712366 | Acc train: 0.9310000 | Acc validation: 0.9200000
# f1_score is 0.9351145038167938 0.9345794392523363
# roc_auc_score is 0.932 0.9299999999999999
# Iter:   108 | Cost: 0.6711550 | Acc train: 0.9320000 | Acc validation: 0.9300000
# f1_score is 0.9381541389153187 0.9259259259259259
# roc_auc_score is 0.935 0.9199999999999999
# Iter:   109 | Cost: 0.6710626 | Acc train: 0.9350000 | Acc validation: 0.9200000
# f1_score is 0.9340866290018832 0.9259259259259259
# roc_auc_score is 0.9299999999999999 0.9199999999999999
# Iter:   110 | Cost: 0.6716670 | Acc train: 0.9300000 | Acc validation: 0.9200000
# f1_score is 0.9272388059701492 0.9174311926605504
# roc_auc_score is 0.9219999999999999 0.91
# Iter:   111 | Cost: 0.6740251 | Acc train: 0.9220000 | Acc validation: 0.9100000
# f1_score is 0.9263746505125815 0.9259259259259259
# roc_auc_score is 0.921 0.9199999999999999
# Iter:   112 | Cost: 0.6743308 | Acc train: 0.9210000 | Acc validation: 0.9200000
# f1_score is 0.9186691312384474 0.9090909090909091
# roc_auc_score is 0.9119999999999999 0.9
# Iter:   113 | Cost: 0.6752679 | Acc train: 0.9120000 | Acc validation: 0.9000000
# f1_score is 0.9161290322580645 0.9090909090909091
# roc_auc_score is 0.909 0.9
# Iter:   114 | Cost: 0.6755593 | Acc train: 0.9090000 | Acc validation: 0.9000000
# f1_score is 0.917820867959372 0.9090909090909091
# roc_auc_score is 0.911 0.9
# Iter:   115 | Cost: 0.6743441 | Acc train: 0.9110000 | Acc validation: 0.9000000
# f1_score is 0.9227906976744186 0.9174311926605504
# roc_auc_score is 0.9169999999999999 0.91
# Iter:   116 | Cost: 0.6725644 | Acc train: 0.9170000 | Acc validation: 0.9100000
# f1_score is 0.9252336448598131 0.9174311926605504
# roc_auc_score is 0.92 0.91
# Iter:   117 | Cost: 0.6720465 | Acc train: 0.9200000 | Acc validation: 0.9100000
# f1_score is 0.9278350515463918 0.9174311926605504
# roc_auc_score is 0.923 0.91
# Iter:   118 | Cost: 0.6717953 | Acc train: 0.9230000 | Acc validation: 0.9100000
# f1_score is 0.9209302325581394 0.9174311926605504
# roc_auc_score is 0.915 0.91
# Iter:   119 | Cost: 0.6724866 | Acc train: 0.9150000 | Acc validation: 0.9100000
# f1_score is 0.9074243813015582 0.9009009009009009
# roc_auc_score is 0.899 0.89
# Iter:   120 | Cost: 0.6739123 | Acc train: 0.8990000 | Acc validation: 0.8900000
# 0.1
# f1_score is 0.0 0.0
# roc_auc_score is 0.396 0.41000000000000003
# Iter:     1 | Cost: 1.3128857 | Acc train: 0.3960000 | Acc validation: 0.4100000
# f1_score is 0.0029985007496251873 0.0
# roc_auc_score is 0.33499999999999996 0.36
# Iter:     2 | Cost: 1.2638112 | Acc train: 0.3350000 | Acc validation: 0.3600000
# f1_score is 0.01366120218579235 0.0
# roc_auc_score is 0.278 0.3
# Iter:     3 | Cost: 1.2213726 | Acc train: 0.2780000 | Acc validation: 0.3000000
# f1_score is 0.25055432372505543 0.11627906976744186
# roc_auc_score is 0.324 0.24000000000000002
# Iter:     4 | Cost: 1.1885154 | Acc train: 0.3240000 | Acc validation: 0.2400000
# f1_score is 0.5588723051409619 0.3853211009174312
# roc_auc_score is 0.46799999999999997 0.32999999999999996
# Iter:     5 | Cost: 1.1650162 | Acc train: 0.4680000 | Acc validation: 0.3300000
# f1_score is 0.6401202103681441 0.5161290322580645
# roc_auc_score is 0.5209999999999999 0.4
# Iter:     6 | Cost: 1.1588415 | Acc train: 0.5210000 | Acc validation: 0.4000000
# f1_score is 0.6818505338078291 0.6470588235294118
# roc_auc_score is 0.5529999999999999 0.52
# Iter:     7 | Cost: 1.1590123 | Acc train: 0.5530000 | Acc validation: 0.5200000
# f1_score is 0.6855524079320113 0.6762589928057553
# roc_auc_score is 0.556 0.55
# Iter:     8 | Cost: 1.1521776 | Acc train: 0.5560000 | Acc validation: 0.5500000
# f1_score is 0.6884779516358464 0.6762589928057553
# roc_auc_score is 0.562 0.55
# Iter:     9 | Cost: 1.1416634 | Acc train: 0.5620000 | Acc validation: 0.5500000
# f1_score is 0.6898047722342733 0.6518518518518519
# roc_auc_score is 0.571 0.53
# Iter:    10 | Cost: 1.1272453 | Acc train: 0.5710000 | Acc validation: 0.5300000
# f1_score is 0.6547987616099071 0.5289256198347108
# roc_auc_score is 0.554 0.43000000000000005
# Iter:    11 | Cost: 1.1045645 | Acc train: 0.5540000 | Acc validation: 0.4300000
# f1_score is 0.6086956521739131 0.4230769230769231
# roc_auc_score is 0.5409999999999999 0.4
# Iter:    12 | Cost: 1.0805365 | Acc train: 0.5410000 | Acc validation: 0.4000000
# f1_score is 0.5166498486377397 0.3529411764705882
# roc_auc_score is 0.521 0.45
# Iter:    13 | Cost: 1.0590289 | Acc train: 0.5210000 | Acc validation: 0.4500000
# f1_score is 0.40423031727379555 0.19178082191780824
# roc_auc_score is 0.493 0.41000000000000003
# Iter:    14 | Cost: 1.0414686 | Acc train: 0.4930000 | Acc validation: 0.4100000
# f1_score is 0.36408977556109723 0.08695652173913043
# roc_auc_score is 0.48999999999999994 0.37
# Iter:    15 | Cost: 1.0191409 | Acc train: 0.4900000 | Acc validation: 0.3700000
# f1_score is 0.2177068214804064 0.0
# roc_auc_score is 0.46099999999999997 0.38
# Iter:    16 | Cost: 0.9971322 | Acc train: 0.4610000 | Acc validation: 0.3800000
# f1_score is 0.03722504230118443 0.0
# roc_auc_score is 0.431 0.44
# Iter:    17 | Cost: 0.9765854 | Acc train: 0.4310000 | Acc validation: 0.4400000
# f1_score is 0.007017543859649123 0.0
# roc_auc_score is 0.434 0.44
# Iter:    18 | Cost: 0.9534056 | Acc train: 0.4340000 | Acc validation: 0.4400000
# f1_score is 0.08333333333333334 0.0
# roc_auc_score is 0.44999999999999996 0.43
# Iter:    19 | Cost: 0.9278429 | Acc train: 0.4500000 | Acc validation: 0.4300000
# f1_score is 0.48180677540777916 0.28571428571428575
# roc_auc_score is 0.587 0.5
# Iter:    20 | Cost: 0.9132074 | Acc train: 0.5870000 | Acc validation: 0.5000000
# f1_score is 0.5894263217097863 0.48780487804878053
# roc_auc_score is 0.635 0.58
# Iter:    21 | Cost: 0.9102936 | Acc train: 0.6350000 | Acc validation: 0.5800000
# f1_score is 0.6659663865546219 0.5777777777777778
# roc_auc_score is 0.682 0.62
# Iter:    22 | Cost: 0.9120938 | Acc train: 0.6820000 | Acc validation: 0.6200000
# f1_score is 0.7181544633901705 0.5934065934065934
# roc_auc_score is 0.7189999999999999 0.63
# Iter:    23 | Cost: 0.9146938 | Acc train: 0.7190000 | Acc validation: 0.6300000
# f1_score is 0.7614503816793894 0.631578947368421
# roc_auc_score is 0.75 0.6499999999999999
# Iter:    24 | Cost: 0.9179855 | Acc train: 0.7500000 | Acc validation: 0.6500000
# f1_score is 0.7009249743062693 0.6000000000000001
# roc_auc_score is 0.709 0.64
# Iter:    25 | Cost: 0.9141872 | Acc train: 0.7090000 | Acc validation: 0.6400000
# f1_score is 0.5823665893271462 0.5238095238095238
# roc_auc_score is 0.64 0.6
# Iter:    26 | Cost: 0.9100027 | Acc train: 0.6400000 | Acc validation: 0.6000000
# f1_score is 0.15780998389694043 0.13114754098360654
# roc_auc_score is 0.47700000000000004 0.47000000000000003
# Iter:    27 | Cost: 0.9044559 | Acc train: 0.4770000 | Acc validation: 0.4700000
# f1_score is 0.038869257950530034 0.03571428571428571
# roc_auc_score is 0.456 0.46
# Iter:    28 | Cost: 0.8994860 | Acc train: 0.4560000 | Acc validation: 0.4600000
# f1_score is 0.04676258992805755 0.03571428571428571
# roc_auc_score is 0.47000000000000003 0.46
# Iter:    29 | Cost: 0.8932642 | Acc train: 0.4700000 | Acc validation: 0.4600000
# f1_score is 0.11208406304728546 0.07017543859649124
# roc_auc_score is 0.49300000000000005 0.47000000000000003
# Iter:    30 | Cost: 0.8866879 | Acc train: 0.4930000 | Acc validation: 0.4700000
# f1_score is 0.0038834951456310682 0.0
# roc_auc_score is 0.487 0.47
# Iter:    31 | Cost: 0.8854710 | Acc train: 0.4870000 | Acc validation: 0.4700000
# f1_score is 0.0 0.0
# roc_auc_score is 0.491 0.47
# Iter:    32 | Cost: 0.8859341 | Acc train: 0.4910000 | Acc validation: 0.4700000
# f1_score is 0.015625 0.0
# roc_auc_score is 0.496 0.48
# Iter:    33 | Cost: 0.8820464 | Acc train: 0.4960000 | Acc validation: 0.4800000
# f1_score is 0.23875432525951562 0.0
# roc_auc_score is 0.5599999999999999 0.47
# Iter:    34 | Cost: 0.8748370 | Acc train: 0.5600000 | Acc validation: 0.4700000
# f1_score is 0.3474025974025974 0.037037037037037035
# roc_auc_score is 0.598 0.48
# Iter:    35 | Cost: 0.8702364 | Acc train: 0.5980000 | Acc validation: 0.4800000
# f1_score is 0.35864297253634897 0.03773584905660377
# roc_auc_score is 0.603 0.49
# Iter:    36 | Cost: 0.8685958 | Acc train: 0.6030000 | Acc validation: 0.4900000
# f1_score is 0.4345146379044684 0.07407407407407407
# roc_auc_score is 0.633 0.5
# Iter:    37 | Cost: 0.8627789 | Acc train: 0.6330000 | Acc validation: 0.5000000
# f1_score is 0.49779086892488955 0.1090909090909091
# roc_auc_score is 0.659 0.51
# Iter:    38 | Cost: 0.8572617 | Acc train: 0.6590000 | Acc validation: 0.5100000
# f1_score is 0.5848275862068966 0.23333333333333336
# roc_auc_score is 0.699 0.54
# Iter:    39 | Cost: 0.8489649 | Acc train: 0.6990000 | Acc validation: 0.5400000
# f1_score is 0.680745341614907 0.5526315789473685
# roc_auc_score is 0.743 0.66
# Iter:    40 | Cost: 0.8419939 | Acc train: 0.7430000 | Acc validation: 0.6600000
# f1_score is 0.7792494481236203 0.6172839506172839
# roc_auc_score is 0.7999999999999999 0.6900000000000001
# Iter:    41 | Cost: 0.8395765 | Acc train: 0.8000000 | Acc validation: 0.6900000
# f1_score is 0.7916207276736494 0.6341463414634146
# roc_auc_score is 0.811 0.7000000000000001
# ...
# roc_auc_score is 0.708 0.6699999999999999
# Iter:    25 | Cost: 0.9881578 | Acc train: 0.7080000 | Acc validation: 0.6700000
# f1_score is 0.7711404189294027 0.7407407407407407
# roc_auc_score is 0.7050000000000001 0.65
# Iter:    26 | Cost: 0.9826606 | Acc train: 0.7050000 | Acc validation: 0.6500000
# f1_score is 0.7520723436322531 0.7352941176470588
# roc_auc_score is 0.671 0.64
# Iter:    27 | Cost: 0.9760349 | Acc train: 0.6710000 | Acc validation: 0.6400000
# f1_score is 0.7412898443291327 0.7299270072992701
# roc_auc_score is 0.651 0.63
# Iter:    28 | Cost: 0.9704154 | Acc train: 0.6510000 | Acc validation: 0.6300000
# f1_score is 0.7451564828614009 0.7299270072992701
# roc_auc_score is 0.6579999999999999 0.63
# Iter:    29 | Cost: 0.9653362 | Acc train: 0.6580000 | Acc validation: 0.6300000
# f1_score is 0.741839762611276 0.7299270072992701
# roc_auc_score is 0.652 0.63
# Iter:    30 | Cost: 0.9612297 | Acc train: 0.6520000 | Acc validation: 0.6300000
# f1_score is 0.7468259895444361 0.7352941176470588
# roc_auc_score is 0.661 0.64
# Iter:    31 | Cost: 0.9573894 | Acc train: 0.6610000 | Acc validation: 0.6400000
# f1_score is 0.748502994011976 0.7352941176470588
# roc_auc_score is 0.6639999999999999 0.64
# Iter:    32 | Cost: 0.9540873 | Acc train: 0.6640000 | Acc validation: 0.6400000
# f1_score is 0.7440476190476191 0.7299270072992701
# roc_auc_score is 0.656 0.63
# Iter:    33 | Cost: 0.9512218 | Acc train: 0.6560000 | Acc validation: 0.6300000
# f1_score is 0.7451564828614009 0.7352941176470588
# roc_auc_score is 0.6579999999999999 0.64
# Iter:    34 | Cost: 0.9482780 | Acc train: 0.6580000 | Acc validation: 0.6400000
# f1_score is 0.741839762611276 0.7299270072992701
# roc_auc_score is 0.652 0.63
# Iter:    35 | Cost: 0.9459324 | Acc train: 0.6520000 | Acc validation: 0.6300000
# f1_score is 0.7401924500370096 0.7299270072992701
# roc_auc_score is 0.649 0.63
# Iter:    36 | Cost: 0.9439856 | Acc train: 0.6490000 | Acc validation: 0.6300000
# f1_score is 0.7352941176470588 0.7299270072992701
# roc_auc_score is 0.64 0.63
# Iter:    37 | Cost: 0.9428284 | Acc train: 0.6400000 | Acc validation: 0.6300000
# f1_score is 0.7320644216691068 0.7194244604316548
# roc_auc_score is 0.634 0.61
# Iter:    38 | Cost: 0.9424983 | Acc train: 0.6340000 | Acc validation: 0.6100000
# f1_score is 0.7235890014471781 0.7142857142857143
# roc_auc_score is 0.618 0.6
# Iter:    39 | Cost: 0.9429182 | Acc train: 0.6180000 | Acc validation: 0.6000000
# f1_score is 0.7183908045977011 0.7092198581560284
# roc_auc_score is 0.608 0.5900000000000001
# Iter:    40 | Cost: 0.9424532 | Acc train: 0.6080000 | Acc validation: 0.5900000
# f1_score is 0.7178750897343862 0.7092198581560284
# roc_auc_score is 0.607 0.5900000000000001
# Iter:    41 | Cost: 0.9412899 | Acc train: 0.6070000 | Acc validation: 0.5900000
# f1_score is 0.7251631617113851 0.7194244604316548
# roc_auc_score is 0.621 0.61
# Iter:    42 | Cost: 0.9372698 | Acc train: 0.6210000 | Acc validation: 0.6100000
# f1_score is 0.7304601899196494 0.7194244604316548
# roc_auc_score is 0.631 0.61
# Iter:    43 | Cost: 0.9341886 | Acc train: 0.6310000 | Acc validation: 0.6100000
# f1_score is 0.7320644216691068 0.7246376811594203
# roc_auc_score is 0.634 0.62
# Iter:    44 | Cost: 0.9317900 | Acc train: 0.6340000 | Acc validation: 0.6200000
# f1_score is 0.741839762611276 0.7352941176470588
# roc_auc_score is 0.652 0.64
# Iter:    45 | Cost: 0.9263096 | Acc train: 0.6520000 | Acc validation: 0.6400000
# f1_score is 0.7600913937547601 0.7407407407407407
# roc_auc_score is 0.685 0.65
# Iter:    46 | Cost: 0.9206327 | Acc train: 0.6850000 | Acc validation: 0.6500000
# f1_score is 0.7700617283950617 0.7407407407407407
# roc_auc_score is 0.702 0.65
# Iter:    47 | Cost: 0.9169183 | Acc train: 0.7020000 | Acc validation: 0.6500000
# f1_score is 0.7895569620253164 0.7812500000000001
# roc_auc_score is 0.734 0.72
# Iter:    48 | Cost: 0.9140428 | Acc train: 0.7340000 | Acc validation: 0.7200000
# f1_score is 0.809098294069862 0.819672131147541
# roc_auc_score is 0.7650000000000001 0.78
# Iter:    49 | Cost: 0.9137699 | Acc train: 0.7650000 | Acc validation: 0.7800000
# f1_score is 0.7993254637436763 0.8166666666666667
# roc_auc_score is 0.762 0.78
# Iter:    50 | Cost: 0.9143201 | Acc train: 0.7620000 | Acc validation: 0.7800000
# f1_score is 0.7673179396092362 0.8
# roc_auc_score is 0.738 0.77
# Iter:    51 | Cost: 0.9155277 | Acc train: 0.7380000 | Acc validation: 0.7700000
# f1_score is 0.6237006237006236 0.673469387755102
# roc_auc_score is 0.6379999999999999 0.6799999999999999
# Iter:    52 | Cost: 0.9214361 | Acc train: 0.6380000 | Acc validation: 0.6800000
# f1_score is 0.49061032863849763 0.6382978723404256
# roc_auc_score is 0.566 0.6599999999999999
# Iter:    53 | Cost: 0.9259590 | Acc train: 0.5660000 | Acc validation: 0.6600000
# f1_score is 0.44308445532435736 0.5777777777777778
# roc_auc_score is 0.545 0.62
# Iter:    54 | Cost: 0.9277678 | Acc train: 0.5450000 | Acc validation: 0.6200000
# f1_score is 0.4774346793349169 0.6236559139784946
# roc_auc_score is 0.56 0.65
# Iter:    55 | Cost: 0.9251308 | Acc train: 0.5600000 | Acc validation: 0.6500000
# f1_score is 0.49648711943793916 0.6382978723404256
# roc_auc_score is 0.57 0.6599999999999999
# Iter:    56 | Cost: 0.9235583 | Acc train: 0.5700000 | Acc validation: 0.6600000
# f1_score is 0.5798687089715536 0.6597938144329897
# roc_auc_score is 0.616 0.6699999999999999
# Iter:    57 | Cost: 0.9194642 | Acc train: 0.6160000 | Acc validation: 0.6700000
# f1_score is 0.626304801670146 0.686868686868687
# roc_auc_score is 0.642 0.69
# Iter:    58 | Cost: 0.9166090 | Acc train: 0.6420000 | Acc validation: 0.6900000
# f1_score is 0.6517311608961304 0.712871287128713
# roc_auc_score is 0.658 0.71
# Iter:    59 | Cost: 0.9147726 | Acc train: 0.6580000 | Acc validation: 0.7100000
# f1_score is 0.7313854853911405 0.7428571428571428
# roc_auc_score is 0.7150000000000001 0.73
# Iter:    60 | Cost: 0.9109089 | Acc train: 0.7150000 | Acc validation: 0.7300000
# f1_score is 0.8024369016536118 0.8245614035087719
# roc_auc_score is 0.7730000000000001 0.7999999999999998
# Iter:    61 | Cost: 0.9057200 | Acc train: 0.7730000 | Acc validation: 0.8000000
# f1_score is 0.8100649350649352 0.8130081300813007
# roc_auc_score is 0.766 0.77
# Iter:    62 | Cost: 0.8998783 | Acc train: 0.7660000 | Acc validation: 0.7700000
# f1_score is 0.7901821060965953 0.7692307692307693
# roc_auc_score is 0.735 0.7
# Iter:    63 | Cost: 0.8980640 | Acc train: 0.7350000 | Acc validation: 0.7000000
# f1_score is 0.7724458204334367 0.7462686567164178
# roc_auc_score is 0.706 0.6599999999999999
# Iter:    64 | Cost: 0.8989374 | Acc train: 0.7060000 | Acc validation: 0.6600000
# f1_score is 0.7618320610687023 0.7407407407407407
# roc_auc_score is 0.688 0.65
# Iter:    65 | Cost: 0.9003283 | Acc train: 0.6880000 | Acc validation: 0.6500000
# f1_score is 0.7429420505200595 0.7407407407407407
# roc_auc_score is 0.654 0.65
# Iter:    66 | Cost: 0.9046576 | Acc train: 0.6540000 | Acc validation: 0.6500000
# f1_score is 0.7309941520467835 0.7194244604316548
# roc_auc_score is 0.632 0.61
# Iter:    67 | Cost: 0.9087975 | Acc train: 0.6320000 | Acc validation: 0.6100000
# f1_score is 0.7267441860465117 0.7194244604316548
# roc_auc_score is 0.624 0.61
# Iter:    68 | Cost: 0.9104327 | Acc train: 0.6240000 | Acc validation: 0.6100000
# f1_score is 0.7194244604316548 0.704225352112676
# roc_auc_score is 0.61 0.5800000000000001
# Iter:    69 | Cost: 0.9120477 | Acc train: 0.6100000 | Acc validation: 0.5800000
# f1_score is 0.7194244604316548 0.704225352112676
# roc_auc_score is 0.61 0.5800000000000001
# Iter:    70 | Cost: 0.9111818 | Acc train: 0.6100000 | Acc validation: 0.5800000
# f1_score is 0.7235890014471781 0.7092198581560284
# roc_auc_score is 0.618 0.5900000000000001
# Iter:    71 | Cost: 0.9089492 | Acc train: 0.6180000 | Acc validation: 0.5900000
# f1_score is 0.7299270072992701 0.7194244604316548
# roc_auc_score is 0.63 0.61
# Iter:    72 | Cost: 0.9066032 | Acc train: 0.6300000 | Acc validation: 0.6100000
# f1_score is 0.7342143906020558 0.7246376811594203
# roc_auc_score is 0.638 0.62
# Iter:    73 | Cost: 0.9042522 | Acc train: 0.6380000 | Acc validation: 0.6200000
# f1_score is 0.7524454477050414 0.7407407407407407
# roc_auc_score is 0.671 0.65
# Iter:    74 | Cost: 0.8990115 | Acc train: 0.6710000 | Acc validation: 0.6500000
# f1_score is 0.7647509578544062 0.7407407407407407
# roc_auc_score is 0.6930000000000001 0.65
# Iter:    75 | Cost: 0.8953809 | Acc train: 0.6930000 | Acc validation: 0.6500000
# f1_score is 0.7809076682316118 0.7575757575757575
# roc_auc_score is 0.72 0.6799999999999999
# Iter:    76 | Cost: 0.8927532 | Acc train: 0.7200000 | Acc validation: 0.6800000
# f1_score is 0.8009630818619582 0.7936507936507937
# roc_auc_score is 0.752 0.74
# Iter:    77 | Cost: 0.8920165 | Acc train: 0.7520000 | Acc validation: 0.7400000
# f1_score is 0.8180327868852459 0.8130081300813007
# roc_auc_score is 0.7780000000000001 0.77
# Iter:    78 | Cost: 0.8930651 | Acc train: 0.7780000 | Acc validation: 0.7700000
# f1_score is 0.8227535037098103 0.8264462809917354
# roc_auc_score is 0.785 0.79
# Iter:    79 | Cost: 0.8931537 | Acc train: 0.7850000 | Acc validation: 0.7900000
# f1_score is 0.8258706467661692 0.8403361344537814
# roc_auc_score is 0.7900000000000001 0.81
# Iter:    80 | Cost: 0.8933163 | Acc train: 0.7900000 | Acc validation: 0.8100000
# f1_score is 0.8220757825370675 0.8264462809917354
# roc_auc_score is 0.784 0.79
# Iter:    81 | Cost: 0.8924293 | Acc train: 0.7840000 | Acc validation: 0.7900000
# f1_score is 0.8180327868852459 0.8130081300813007
# roc_auc_score is 0.7780000000000001 0.77
# Iter:    82 | Cost: 0.8915647 | Acc train: 0.7780000 | Acc validation: 0.7700000
# f1_score is 0.8009630818619582 0.7936507936507937
# roc_auc_score is 0.752 0.74
# Iter:    83 | Cost: 0.8902608 | Acc train: 0.7520000 | Acc validation: 0.7400000
# f1_score is 0.7933227344992051 0.7874015748031497
# roc_auc_score is 0.74 0.73
# Iter:    84 | Cost: 0.8897830 | Acc train: 0.7400000 | Acc validation: 0.7300000
# f1_score is 0.7920634920634921 0.7812500000000001
# roc_auc_score is 0.738 0.72
# Iter:    85 | Cost: 0.8895573 | Acc train: 0.7380000 | Acc validation: 0.7200000
# f1_score is 0.7977617905675459 0.7874015748031497
# roc_auc_score is 0.747 0.73
# Iter:    86 | Cost: 0.8893039 | Acc train: 0.7470000 | Acc validation: 0.7300000
# f1_score is 0.7901821060965953 0.7751937984496124
# roc_auc_score is 0.735 0.71
# Iter:    87 | Cost: 0.8891296 | Acc train: 0.7350000 | Acc validation: 0.7100000
# f1_score is 0.7870662460567824 0.7692307692307693
# roc_auc_score is 0.73 0.7
# Iter:    88 | Cost: 0.8890626 | Acc train: 0.7300000 | Acc validation: 0.7000000
# f1_score is 0.7864460204885737 0.7692307692307693
# roc_auc_score is 0.729 0.7
# Iter:    89 | Cost: 0.8888732 | Acc train: 0.7290000 | Acc validation: 0.7000000
# f1_score is 0.7852084972462627 0.7692307692307693
# roc_auc_score is 0.727 0.7
# Iter:    90 | Cost: 0.8886347 | Acc train: 0.7270000 | Acc validation: 0.7000000
# f1_score is 0.7766536964980545 0.7633587786259541
# roc_auc_score is 0.7130000000000001 0.69
# Iter:    91 | Cost: 0.8888501 | Acc train: 0.7130000 | Acc validation: 0.6900000
# f1_score is 0.7676923076923078 0.7575757575757575
# roc_auc_score is 0.698 0.6799999999999999
# Iter:    92 | Cost: 0.8892529 | Acc train: 0.6980000 | Acc validation: 0.6800000
# f1_score is 0.7595129375951294 0.7462686567164178
# roc_auc_score is 0.6839999999999999 0.6599999999999999
# Iter:    93 | Cost: 0.8902006 | Acc train: 0.6840000 | Acc validation: 0.6600000
# f1_score is 0.7434944237918216 0.7246376811594203
# roc_auc_score is 0.655 0.62
# Iter:    94 | Cost: 0.8933564 | Acc train: 0.6550000 | Acc validation: 0.6200000
# f1_score is 0.7374631268436578 0.7194244604316548
# roc_auc_score is 0.644 0.61
# Iter:    95 | Cost: 0.8945314 | Acc train: 0.6440000 | Acc validation: 0.6100000
# f1_score is 0.7336757153338224 0.7194244604316548
# roc_auc_score is 0.637 0.61
# Iter:    96 | Cost: 0.8949920 | Acc train: 0.6370000 | Acc validation: 0.6100000
# f1_score is 0.7309941520467835 0.7194244604316548
# roc_auc_score is 0.632 0.61
# Iter:    97 | Cost: 0.8955828 | Acc train: 0.6320000 | Acc validation: 0.6100000
# f1_score is 0.7380073800738007 0.7194244604316548
# roc_auc_score is 0.645 0.61
# Iter:    98 | Cost: 0.8941159 | Acc train: 0.6450000 | Acc validation: 0.6100000
# f1_score is 0.7543461829176115 0.7407407407407407
# roc_auc_score is 0.675 0.65
# Iter:    99 | Cost: 0.8903758 | Acc train: 0.6750000 | Acc validation: 0.6500000
# f1_score is 0.7659247889485802 0.7575757575757575
# roc_auc_score is 0.6950000000000001 0.6799999999999999
# Iter:   100 | Cost: 0.8881690 | Acc train: 0.6950000 | Acc validation: 0.6800000
# f1_score is 0.7889328063241107 0.7692307692307693
# roc_auc_score is 0.733 0.7
# Iter:   101 | Cost: 0.8867584 | Acc train: 0.7330000 | Acc validation: 0.7000000
# f1_score is 0.8022508038585208 0.7936507936507937
# roc_auc_score is 0.754 0.74
# Iter:   102 | Cost: 0.8865431 | Acc train: 0.7540000 | Acc validation: 0.7400000
# f1_score is 0.8193760262725781 0.8264462809917354
# roc_auc_score is 0.7800000000000001 0.79
# Iter:   103 | Cost: 0.8872981 | Acc train: 0.7800000 | Acc validation: 0.7900000
# f1_score is 0.8413910093299405 0.8547008547008548
# roc_auc_score is 0.8130000000000001 0.83
# Iter:   104 | Cost: 0.8906358 | Acc train: 0.8130000 | Acc validation: 0.8300000
# f1_score is 0.8260481712756469 0.8256880733944953
# roc_auc_score is 0.8049999999999999 0.8099999999999999
# Iter:   105 | Cost: 0.8957127 | Acc train: 0.8050000 | Acc validation: 0.8100000
# f1_score is 0.7142857142857142 0.7551020408163266
# roc_auc_score is 0.72 0.76
# Iter:   106 | Cost: 0.9028551 | Acc train: 0.7200000 | Acc validation: 0.7600000
# f1_score is 0.6652406417112299 0.6739130434782609
# roc_auc_score is 0.6869999999999999 0.7000000000000001
# Iter:   107 | Cost: 0.9052221 | Acc train: 0.6870000 | Acc validation: 0.7000000
# f1_score is 0.6989690721649484 0.7291666666666667
# roc_auc_score is 0.708 0.74
# Iter:   108 | Cost: 0.9031797 | Acc train: 0.7080000 | Acc validation: 0.7400000
# f1_score is 0.7570731707317074 0.8037383177570094
# roc_auc_score is 0.7510000000000001 0.79
# Iter:   109 | Cost: 0.9006308 | Acc train: 0.7510000 | Acc validation: 0.7900000
# f1_score is 0.7992599444958371 0.8037383177570094
# roc_auc_score is 0.7829999999999999 0.79
# Iter:   110 | Cost: 0.8979841 | Acc train: 0.7830000 | Acc validation: 0.7900000
# f1_score is 0.8251121076233183 0.8148148148148148
# roc_auc_score is 0.8049999999999999 0.7999999999999999
# Iter:   111 | Cost: 0.8957096 | Acc train: 0.8050000 | Acc validation: 0.8000000
# f1_score is 0.8368421052631579 0.8181818181818182
# roc_auc_score is 0.814 0.7999999999999999
# Iter:   112 | Cost: 0.8939202 | Acc train: 0.8140000 | Acc validation: 0.8000000
# f1_score is 0.842560553633218 0.8448275862068965
# roc_auc_score is 0.818 0.8199999999999998
# Iter:   113 | Cost: 0.8921160 | Acc train: 0.8180000 | Acc validation: 0.8200000
# f1_score is 0.8437500000000001 0.8521739130434782
# roc_auc_score is 0.8199999999999998 0.8299999999999998
# Iter:   114 | Cost: 0.8921969 | Acc train: 0.8200000 | Acc validation: 0.8300000
# f1_score is 0.8408091468777485 0.8363636363636363
# roc_auc_score is 0.819 0.82
# Iter:   115 | Cost: 0.8934461 | Acc train: 0.8190000 | Acc validation: 0.8200000
# f1_score is 0.8204193254329991 0.8148148148148148
# roc_auc_score is 0.8029999999999999 0.7999999999999999
# Iter:   116 | Cost: 0.8956922 | Acc train: 0.8030000 | Acc validation: 0.8000000
# f1_score is 0.8200913242009131 0.8037383177570094
# roc_auc_score is 0.803 0.79
# Iter:   117 | Cost: 0.8957309 | Acc train: 0.8030000 | Acc validation: 0.7900000
# f1_score is 0.8333333333333334 0.8256880733944953
# roc_auc_score is 0.8140000000000001 0.8099999999999999
# Iter:   118 | Cost: 0.8941272 | Acc train: 0.8140000 | Acc validation: 0.8100000
# f1_score is 0.8483290488431877 0.8547008547008548
# roc_auc_score is 0.8230000000000001 0.83
# Iter:   119 | Cost: 0.8900344 | Acc train: 0.8230000 | Acc validation: 0.8300000
# f1_score is 0.8323603002502086 0.8474576271186441
# roc_auc_score is 0.7989999999999999 0.8200000000000001
# Iter:   120 | Cost: 0.8863983 | Acc train: 0.7990000 | Acc validation: 0.8200000
# 0.3

# %%
plt.plot([i for i in range(120)],his1[0], label = 'noiseless')
plt.plot([i for i in range(120)],his1[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his1[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his1[3], label = 'p=0.3')
plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Bit flip test accuracy')
plt.legend()
plt.savefig('Amplitude_Encoding_QAOA_ansatz test accuracy1',dpi=600,bbox_inches='tight')
plt.show()

# %%
plt.plot([i for i in range(120)],his2[0], label = 'noiseless')
plt.plot([i for i in range(120)],his2[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his2[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his2[3], label = 'p=0.3')
plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Bit flip train accuracy')
plt.legend()
plt.savefig('Amplitude_Encoding_QAOA_ansatz train accuracy2',dpi=600,bbox_inches='tight')
plt.show()

# %%
plt.plot([i for i in range(120)],his3[0], label = 'noiseless')
plt.plot([i for i in range(120)],his3[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his3[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his3[3], label = 'p=0.3')
#plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Bit flip cost function')
plt.legend()
plt.savefig('Amplitude_Encoding_QAOA_ansatz cost function3',dpi=600,bbox_inches='tight')
plt.show()

# %%
print(his1)
print(his2)
print(his3)
# Out:
# [[0.39, 0.4, 0.41, 0.36, 0.34, 0.41, 0.5, 0.62, 0.7, 0.72, 0.77, 0.79, 0.81, 0.77, 0.79, 0.81, 0.81, 0.8, 0.83, 0.8, 0.8, 0.7, 0.71, 0.72, 0.84, 0.89, 0.9, 0.9, 0.91, 0.92, 0.9, 0.9, 0.91, 0.91, 0.9, 0.9, 0.89, 0.89, 0.88, 0.88, 0.87, 0.87, 0.88, 0.88, 0.91, 0.92, 0.93, 0.92, 0.9, 0.89, 0.89, 0.9, 0.91, 0.94, 0.96, 0.98, 0.98, 0.96, 0.95, 0.95, 0.95, 0.95, 0.94, 0.94, 0.94, 0.94, 0.92, 0.94, 0.94, 0.94, 0.96, 0.96, 0.94, 0.93, 0.91, 0.89, 0.91, 0.93, 0.95, 0.96, 0.96, 0.96, 0.96, 0.95, 0.94, 0.91, 0.9, 0.9, 0.93, 0.92, 0.93, 0.93, 0.92, 0.93, 0.94, 0.94, 0.95, 0.94, 0.94, 0.92, 0.93, 0.95, 0.96, 0.94, 0.94, 0.93, 0.94, 0.92, 0.92, 0.94, 0.96, 0.97, 0.95, 0.95, 0.96, 0.95, 0.95, 0.95, 0.95, 0.95], [0.41, 0.35, 0.27, 0.3, 0.39, 0.54, 0.51, 0.52, 0.57, 0.56, 0.57, 0.58, 0.56, 0.63, 0.73, 0.8, 0.83, 0.87, 0.88, 0.91, 0.89, 0.79, 0.55, 0.52, 0.7, 0.88, 0.92, 0.87, 0.83, 0.85, 0.89, 0.92, 0.93, 0.95, 0.87, 0.82, 0.84, 0.94, 0.95, 0.94, 0.92, 0.93, 0.92, 0.93, 0.91, 0.89, 0.88, 0.87, 0.87, 0.89, 0.91, 0.93, 0.91, 0.91, 0.91, 0.92, 0.92, 0.92, 0.92, 0.93, 0.93, 0.92, 0.92, 0.91, 0.89, 0.89, 0.88, 0.88, 0.88, 0.89, 0.89, 0.91, 0.91, 0.89, 0.91, 0.93, 0.93, 0.92, 0.9, 0.9, 0.92, 0.93, 0.94, 0.95, 0.95, 0.95, 0.94, 0.95, 0.95, 0.95, 0.94, 0.94, 0.92, 0.92, 0.92, 0.91, 0.92, 0.92, 0.91, 0.91, 0.91, 0.91, 0.93, 0.92, 0.92, 0.92, 0.92, 0.93, 0.92, 0.92, 0.91, 0.92, 0.9, 0.9, 0.9, 0.91, 0.91, 0.91, 0.91, 0.89], [0.41, 0.36, 0.3, 0.24, 0.33, 0.4, 0.52, 0.55, 0.55, 0.53, 0.43, 0.4, 0.45, 0.41, 0.37, 0.38, 0.44, 0.44, 0.43, 0.5, 0.58, 0.62, 0.63, 0.65, 0.64, 0.6, 0.47, 0.46, 0.46, 0.47, 0.47, 0.47, 0.48, 0.47, 0.48, 0.49, 0.5, 0.51, 0.54, 0.66, 0.69, 0.7, 0.74, 0.78, 0.78, 0.8, 0.77, 0.8, 0.8, 0.83, 0.8, 0.82, 0.77, 0.69, 0.68, 0.67, 0.68, 0.68, 0.67, 0.66, 0.69, 0.74, 0.77, 0.79, 0.83, 0.88, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.9, 0.88, 0.87, 0.9, 0.9, 0.89, 0.87, 0.86, 0.85, 0.86, 0.87, 0.89, 0.89, 0.9, 0.88, 0.82, 0.75, 0.68, 0.64, 0.63, 0.62, 0.61, 0.63, 0.65, 0.68, 0.74, 0.79, 0.82, 0.86, 0.86, 0.84, 0.84, 0.84, 0.85, 0.86, 0.85, 0.8, 0.75, 0.71, 0.65, 0.65, 0.65, 0.73, 0.78, 0.85, 0.87, 0.88, 0.86], [0.46, 0.43, 0.37, 0.29, 0.4, 0.56, 0.51, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.37, 0.37, 0.38, 0.4, 0.67, 0.65, 0.64, 0.63, 0.63, 0.63, 0.64, 0.64, 0.63, 0.64, 0.63, 0.63, 0.63, 0.61, 0.6, 0.59, 0.59, 0.61, 0.61, 0.62, 0.64, 0.65, 0.65, 0.72, 0.78, 0.78, 0.77, 0.68, 0.66, 0.62, 0.65, 0.66, 0.67, 0.69, 0.71, 0.73, 0.8, 0.77, 0.7, 0.66, 0.65, 0.65, 0.61, 0.61, 0.58, 0.58, 0.59, 0.61, 0.62, 0.65, 0.65, 0.68, 0.74, 0.77, 0.79, 0.81, 0.79, 0.77, 0.74, 0.73, 0.72, 0.73, 0.71, 0.7, 0.7, 0.7, 0.69, 0.68, 0.66, 0.62, 0.61, 0.61, 0.61, 0.61, 0.65, 0.68, 0.7, 0.74, 0.79, 0.83, 0.81, 0.76, 0.7, 0.74, 0.79, 0.79, 0.8, 0.8, 0.82, 0.83, 0.82, 0.8, 0.79, 0.81, 0.83, 0.82]]
# [[0.364, 0.372, 0.364, 0.327, 0.398, 0.511, 0.564, 0.653, 0.704, 0.749, 0.793, 0.822, 0.828, 0.841, 0.849, 0.83, 0.828, 0.84, 0.862, 0.867, 0.871, 0.844, 0.825, 0.848, 0.9, 0.918, 0.932, 0.932, 0.927, 0.9, 0.898, 0.902, 0.92, 0.922, 0.916, 0.903, 0.896, 0.894, 0.889, 0.886, 0.885, 0.886, 0.896, 0.902, 0.915, 0.919, 0.923, 0.922, 0.921, 0.912, 0.911, 0.924, 0.93, 0.945, 0.955, 0.953, 0.959, 0.966, 0.961, 0.957, 0.947, 0.944, 0.939, 0.947, 0.945, 0.937, 0.924, 0.939, 0.953, 0.96, 0.969, 0.966, 0.953, 0.939, 0.904, 0.894, 0.908, 0.92, 0.952, 0.966, 0.969, 0.965, 0.97, 0.971, 0.963, 0.954, 0.943, 0.934, 0.947, 0.944, 0.941, 0.925, 0.917, 0.921, 0.925, 0.935, 0.947, 0.945, 0.934, 0.94, 0.951, 0.966, 0.977, 0.965, 0.95, 0.946, 0.953, 0.948, 0.94, 0.969, 0.977, 0.975, 0.972, 0.968, 0.964, 0.959, 0.956, 0.957, 0.955, 0.958], [0.374, 0.327, 0.266, 0.425, 0.505, 0.543, 0.526, 0.542, 0.566, 0.616, 0.639, 0.646, 0.669, 0.722, 0.803, 0.821, 0.795, 0.788, 0.782, 0.782, 0.787, 0.758, 0.563, 0.545, 0.738, 0.903, 0.928, 0.875, 0.847, 0.851, 0.882, 0.92, 0.95, 0.959, 0.915, 0.873, 0.907, 0.941, 0.954, 0.958, 0.941, 0.913, 0.907, 0.911, 0.92, 0.909, 0.912, 0.906, 0.906, 0.912, 0.919, 0.92, 0.929, 0.929, 0.928, 0.927, 0.933, 0.934, 0.932, 0.93, 0.931, 0.927, 0.92, 0.899, 0.885, 0.88, 0.88, 0.872, 0.871, 0.873, 0.881, 0.9, 0.911, 0.913, 0.925, 0.928, 0.923, 0.919, 0.918, 0.908, 0.912, 0.935, 0.945, 0.952, 0.958, 0.961, 0.96, 0.959, 0.962, 0.96, 0.955, 0.946, 0.944, 0.943, 0.94, 0.933, 0.93, 0.931, 0.927, 0.927, 0.925, 0.927, 0.928, 0.927, 0.927, 0.93, 0.931, 0.932, 0.935, 0.93, 0.922, 0.921, 0.912, 0.909, 0.911, 0.917, 0.92, 0.923, 0.915, 0.899], [0.396, 0.335, 0.278, 0.324, 0.468, 0.521, 0.553, 0.556, 0.562, 0.571, 0.554, 0.541, 0.521, 0.493, 0.49, 0.461, 0.431, 0.434, 0.45, 0.587, 0.635, 0.682, 0.719, 0.75, 0.709, 0.64, 0.477, 0.456, 0.47, 0.493, 0.487, 0.491, 0.496, 0.56, 0.598, 0.603, 0.633, 0.659, 0.699, 0.743, 0.8, 0.811, 0.844, 0.859, 0.862, 0.873, 0.867, 0.882, 0.888, 0.889, 0.896, 0.889, 0.871, 0.828, 0.811, 0.8, 0.779, 0.784, 0.794, 0.796, 0.817, 0.828, 0.86, 0.875, 0.888, 0.895, 0.894, 0.894, 0.891, 0.893, 0.893, 0.893, 0.887, 0.893, 0.893, 0.894, 0.891, 0.879, 0.871, 0.853, 0.851, 0.854, 0.872, 0.881, 0.89, 0.896, 0.893, 0.864, 0.811, 0.773, 0.742, 0.724, 0.72, 0.711, 0.722, 0.744, 0.781, 0.81, 0.844, 0.857, 0.863, 0.851, 0.836, 0.831, 0.832, 0.842, 0.855, 0.866, 0.853, 0.815, 0.78, 0.754, 0.751, 0.751, 0.785, 0.832, 0.869, 0.872, 0.872, 0.858], [0.445, 0.424, 0.356, 0.34, 0.519, 0.564, 0.533, 0.509, 0.502, 0.501, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.501, 0.502, 0.507, 0.517, 0.485, 0.525, 0.559, 0.453, 0.708, 0.705, 0.671, 0.651, 0.658, 0.652, 0.661, 0.664, 0.656, 0.658, 0.652, 0.649, 0.64, 0.634, 0.618, 0.608, 0.607, 0.621, 0.631, 0.634, 0.652, 0.685, 0.702, 0.734, 0.765, 0.762, 0.738, 0.638, 0.566, 0.545, 0.56, 0.57, 0.616, 0.642, 0.658, 0.715, 0.773, 0.766, 0.735, 0.706, 0.688, 0.654, 0.632, 0.624, 0.61, 0.61, 0.618, 0.63, 0.638, 0.671, 0.693, 0.72, 0.752, 0.778, 0.785, 0.79, 0.784, 0.778, 0.752, 0.74, 0.738, 0.747, 0.735, 0.73, 0.729, 0.727, 0.713, 0.698, 0.684, 0.655, 0.644, 0.637, 0.632, 0.645, 0.675, 0.695, 0.733, 0.754, 0.78, 0.813, 0.805, 0.72, 0.687, 0.708, 0.751, 0.783, 0.805, 0.814, 0.818, 0.82, 0.819, 0.803, 0.803, 0.814, 0.823, 0.799]]
# [[1.500035119323882, 1.4677728068907145, 1.4026126048188423, 1.2966651842314598, 1.191526508854827, 1.0928871930917625, 1.0095485596609612, 0.9504550273379716, 0.9006426538470115, 0.8387065662739142, 0.7952561982513834, 0.7730062169997945, 0.7646621496119845, 0.7529651603629904, 0.749972809416154, 0.7527469077305734, 0.7430139892160247, 0.7221152059456606, 0.6918368285225492, 0.6642798967186136, 0.6449902401377773, 0.631794805930643, 0.6254777619475433, 0.6110938265130325, 0.5882195099613078, 0.5747421606427711, 0.5645281021507276, 0.5587318930764076, 0.5531305457831066, 0.5542159271673772, 0.5526983415856033, 0.5483741130499534, 0.5447351481508185, 0.5447269573669852, 0.5458060003319659, 0.5467229796589185, 0.5476147181052023, 0.5473945147884587, 0.548565298842979, 0.5506026974297483, 0.5521643045934166, 0.5522786675867833, 0.5481341782660634, 0.546124690880439, 0.5440647757940866, 0.5439561441985284, 0.5455560136366966, 0.541805748789514, 0.5399325270863844, 0.5403616353747528, 0.5409472827936117, 0.5373127130798419, 0.5357327200470385, 0.5374021305381592, 0.5439324281342148, 0.556342451984552, 0.5538002659071547, 0.5410674344586689, 0.5341986080082097, 0.5335498205880891, 0.5342808387821176, 0.5350552179425155, 0.538046450320619, 0.5338157322352651, 0.5351014841767995, 0.5360688282492346, 0.5426053096978771, 0.5347815206127929, 0.5311425485945621, 0.5315780972474711, 0.5350598495605735, 0.534952315517129, 0.5315378263117017, 0.5332039193371186, 0.5477232551584476, 0.5518743718909086, 0.5423675991028956, 0.5367130829069845, 0.5294441241901103, 0.5310048844602611, 0.531491906355489, 0.5318278794424819, 0.536178154850083, 0.5381105071412337, 0.5415364820264429, 0.5421351690872165, 0.5424803364339114, 0.5444783107381966, 0.5347609999873422, 0.5322463951174278, 0.5321535204098535, 0.5326028705752921, 0.5339196325142108, 0.532326826680233, 0.5308275631548995, 0.5295049693989149, 0.528832647536569, 0.5302206011655941, 0.5357109221213167, 0.535301642600623, 0.5315484352128216, 0.5326875906932748, 0.5396819346398388, 0.5416899662485278, 0.5448222881954708, 0.547657538186624, 0.5466408519822218, 0.540933448542585, 0.5385284717730695, 0.5359714318495593, 0.5350550185723361, 0.537488103996525, 0.5413903068218571, 0.5370248583085179, 0.530260026975702, 0.5273396851192165, 0.5278753860117048, 0.5287318630748178, 0.5287255479286179, 0.5282294643660606], [1.3901312960153134, 1.3389584250003397, 1.2692287259057042, 1.2111184475227097, 1.195131178219013, 1.199971897136873, 1.203616728751017, 1.1651883782612125, 1.1144485676771898, 1.0395513604201654, 0.977555593834373, 0.9244564303096899, 0.8822848232002107, 0.8517320846327325, 0.8348330016036969, 0.8296272981106706, 0.831734951681493, 0.8367671896879595, 0.8377075613267877, 0.8302343827718565, 0.8160879414682591, 0.8007191494553733, 0.7936404926451642, 0.7837151003528169, 0.7625286889630445, 0.7455474512925806, 0.7368452840708928, 0.7432266018935352, 0.7494939841021055, 0.7424404791100839, 0.7252698811811445, 0.7123326172595964, 0.7057881299417272, 0.7024906067288751, 0.7071424062370839, 0.7091565669285725, 0.7024315730690147, 0.6958371689446979, 0.6892981151149065, 0.6855447872764178, 0.6848526049443427, 0.6848953078421463, 0.6826996748363884, 0.6800750104008564, 0.6781919505333521, 0.67824490988856, 0.6790230602745236, 0.6799468985414855, 0.6795223699403893, 0.6766985838959406, 0.6750083288757345, 0.674258173145906, 0.6746961658210096, 0.6779321290871011, 0.68057856383327, 0.6812220508328645, 0.6789919012410276, 0.6762917429930674, 0.6745414211968739, 0.6734995304371489, 0.6731634215420981, 0.6729302651979604, 0.6733500826995206, 0.6756658040269553, 0.6791142148503082, 0.6799934246368998, 0.6803926305287613, 0.6816350984630349, 0.6821996733512922, 0.6810132601987807, 0.6787476321699023, 0.6768455517673895, 0.6764002778270984, 0.6769458116032597, 0.6758029345896749, 0.6741036911746435, 0.6734041687534876, 0.6746759417898321, 0.6773081104376767, 0.6798269448153625, 0.6796708913053258, 0.676 ...

# %%
plt.figure(figsize=(18, 4))
plt.subplot(1, 3, 1)

plt.plot([i for i in range(120)],his1[0], label = 'noiseless')
plt.plot([i for i in range(120)],his1[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his1[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his1[3], label = 'p=0.3')
#plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Bit flip test accuracy')
plt.legend()
#plt.title("plot 1")

plt.subplot(1, 3, 2)

plt.plot([i for i in range(120)],his2[0], label = 'noiseless')
plt.plot([i for i in range(120)],his2[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his2[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his2[3], label = 'p=0.3')
plt.ylim((0.48, 1.))
plt.xlabel('Training steps')
plt.ylabel('Bit flip train accuracy')
plt.legend()
#plt.title("plot 2")

plt.subplot(1, 3, 3)

plt.plot([i for i in range(120)],his3[0], label = 'noiseless')
plt.plot([i for i in range(120)],his3[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his3[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his3[3], label = 'p=0.3')
#plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Bit flip cost function')
plt.legend()
#plt.title("plot 2")

#plt.suptitle("RUNOOB subplot Test")
plt.savefig('Amplitude_Encoding_QAOA_ansatz5',dpi=800,bbox_inches='tight')
plt.show()
