# %%
import pennylane as qml
from pennylane import numpy as np
from sklearn.decomposition import PCA
import random
from collections import Counter
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
wire = 2

wires = wire * 2
dim = 2 ** wire
dim1 = 2 * dim
dev = qml.device('default.mixed', wires=wires)
#dev = qml.device("lightning.qubit", wires=wires, shots=None)
#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
dev1 = qml.device("lightning.qubit", wires=wire, shots=None)
wires = dev.wires.tolist()

@qml.qnode(dev1)
def StateVector(x):
    qml.AmplitudeEmbedding(features=x, wires=range(wire), 
                           pad_with=0.0, normalize=True)
    return qml.state()

def accuracy(labels, predictions):

    loss = 0
    for l, p in zip(labels, predictions):
        if abs(l - p) < 1e-5:
            loss = loss + 1
    loss = loss / len(labels)

    return loss

def square_loss(labels, predictions):
    loss = 0
    for l, p in zip(labels, predictions):
        loss = loss + (l - p) ** 2

    loss = loss / len(labels)
    return loss

def noramlization(data):
    minVals = data.min(0)
    maxVals = data.max(0)
    ranges = maxVals - minVals
    normData = np.zeros(np.shape(data))
    m = data.shape[0]
    normData = data - np.tile(minVals, (m, 1))
    normData = normData/np.tile(ranges, (m, 1))
    return normData

def random_params(num_wires):
    """Generate random variational parameters in the shape for the ansatz."""
    return np.random.uniform(0, 2 * np.pi, num_wires, requires_grad=True)

num_para = int(wire + (wire - 1) * wire / 2)
params_init = random_params(3 * num_para + wire)
print(params_init)
# Out:
# [5.95841975 3.25772985 4.28785972 1.35475221 3.96339524 1.59965014
#  3.45648315 4.43249703 3.01109272 0.87866111 4.4227737 ]

# %%
def ProcessingData(datapoints, train_size, test_size):
    train_data = np.loadtxt("./mnist_train.csv", delimiter=",")
    #Extracting features and labels from the dataset 
    train_data_features = train_data[:datapoints, 1:]
    train_data_labels = train_data[:datapoints, :1].reshape(datapoints,)

    # Use PCA technique to reduce dimensions to 4
    DimReduce = PCA(n_components= dim1)
    train_data_features_reduced = DimReduce.fit_transform(train_data_features)
    # normalize dataset
    train_data_features_reduced = noramlization(train_data_features_reduced)
    s1 = np.array([StateVector(x) for x in train_data_features_reduced[:,:dim]])
    s2 = np.array([StateVector(x) for x in train_data_features_reduced[:,dim:dim1]])
    train_data_features_reduced = np.hstack((s1, s2)).tolist()

    zero_one_datapoint_array = []
    label_0_1 = []
    zero_datapoints_array = [] #an array of the data points containing value 0
    one_datapoints_array = []# an array of the data points containing value 1
    label_0 = []
    label_1 = []

    for i in range(datapoints):
        if train_data_labels[i] == 0:                   # extracting zeros
            label_0.append(-1)
            zero_datapoints_array.append(train_data_features_reduced[i])
        elif train_data_labels[i] == 1:                   # extracting ones
            label_1.append(1)
            one_datapoints_array.append(train_data_features_reduced[i]) 

    if (len(label_0) + len(label_1)) < 2 * (train_size + test_size):
        print("datapoints is too small!")
    else:
        print((len(label_0),len(label_1)))
        zero_datapoints_array_train = zero_datapoints_array[:train_size]
        one_datapoints_array_train = one_datapoints_array[:train_size]
        label_0_train = label_0[:train_size]
        label_1_train = label_1[:train_size]
        zero_datapoints_array_test = zero_datapoints_array[train_size + 1:train_size + test_size + 1]
        one_datapoints_array_test = one_datapoints_array[train_size + 1:train_size + test_size + 1]
        label_0_test = label_0[train_size + 1:train_size + test_size + 1]
        label_1_test = label_1[train_size + 1:train_size + test_size + 1]
        #print(len(zero_datapoints_array_train), len(label_1_train))
        #print(len(one_datapoints_array_test), len(label_0_test))

        zero_one_datapoint_array_train = zero_datapoints_array_train + one_datapoints_array_train
        label_0_1_train = label_0_train + label_1_train
        zero_one_datapoint_array_test = zero_datapoints_array_test + one_datapoints_array_test
        label_0_1_test = label_0_test + label_1_test
        #print(len(zero_one_datapoint_array_train), label_0_1_train)
        #print(len(zero_one_datapoint_array_test), label_0_1_test)

        np.random.seed(10)
        index_train = np.random.permutation(range(2 * train_size))
        index_test = np.random.permutation(range(2 * test_size))

        feats_train = []
        Y_train = []
        feats_val = []
        Y_val = []
        for i in range(2 * train_size):
            feats_train.append(zero_one_datapoint_array_train[index_train[i]])
            Y_train.append(label_0_1_train[index_train[i]])


        for i in range(2 * test_size):
            feats_val.append(zero_one_datapoint_array_test[index_test[i]])
            Y_val.append(label_0_1_test[index_test[i]])

        #print(feats_val, Y_val)

        features = feats_train + feats_val
        features = np.array(features, requires_grad=False)
        Y = Y_train + Y_val
        Y = np.array(Y, requires_grad=False)
        feats_train = np.array(feats_train, requires_grad=False)
        Y_train = np.array(Y_train, requires_grad=False)
        feats_val = np.array(feats_val, requires_grad=False)
        Y_val = np.array(Y_val, requires_grad=False)
    return feats_train, Y_train, feats_val, Y_val, features, Y

datapoints = 6000
train_size = 500
test_size = 50
feats_train, Y_train, feats_val, Y_val, features, Y = ProcessingData(datapoints, train_size, test_size)
# Out:
# (592, 671)

# %%
#Block-encoding + Hardware-efficient Ansatz
def DataEncoding(x, wires_start, wires_end):
    wires = np.arange(wires_start, wires_end).tolist()
    qml.RX(x[0], wires=wires_start)
    qml.RX(x[1], wires=wires_start + 1)
    qml.RY(x[2], wires=wires_start)
    qml.RY(x[3], wires=wires_start + 1)
    #qml.AmplitudeEmbedding(features=x, wires=wires, pad_with=0., normalize=True)

def Ansatz(params, wires_start, wires_end):
    for i in np.arange(wires_start, wires_end):
        qml.Hadamard(wires=wires[i])
        qml.RY(params[i - wires_start], wires=wires[i])
        #print(i)
    for i in np.arange(wires_start, wires_end):
        for j in np.arange(i + 1, wires_end):
            qml.CRZ(params[i - wires_start + wires_end - wires_start], wires=[wires[i], wires[j]])

p = 0
#@qml.qnode(dev, interface="torch", diff_method="parameter-shift")
@qml.qnode(dev)
def QKSAN(feat, params):
    x1 = feat[0:4]
    x2 = feat[4:8]
    DataEncoding(x1, 0, wire)
    Ansatz(params[0: num_para], 0, wire)
    qml.adjoint(Ansatz)(params[num_para: 2 * num_para], 0, wire)
    qml.adjoint(DataEncoding)(x2, 0, wire)


    DataEncoding(x2, wire, (2 * wire))
    Ansatz(params[2 * num_para: 3 * num_para], wire, (2 * wire))
    if p != 0:
        for i in range(2 * wire):
            qml.BitFlip(p, wires=i)
    for i in range(wire):
        qml.cond(qml.measure(i), qml.RY)(params[3 * num_para + i], wires=wires[i + wire])
    return qml.expval(qml.PauliZ(2 * wire - 1))

qml.drawer.use_style('black_white')
fig, ax = qml.draw_mpl(QKSAN, show_all_wires=True)(feats_train[0], params_init)
fig.set_size_inches((7, 5))

def variational_classifier(params, feat):
    return QKSAN(feat, params)


def cost(params, features, labels):
    predictions = [variational_classifier(params, feat) for feat in features]
    return square_loss(labels, predictions)

def TrainQKSAN(params_init):
    opt = qml.NesterovMomentumOptimizer(0.09)
    batch_size = 30
    weights = params_init
    #bias = np.array(0.0, requires_grad=True)
    his_acc_val = []
    his_acc_train = []
    his_cost = []
    f1_train = []
    f1_test = []
    roc_auc_train = []
    roc_auc_test = []
    for it in range(120):

        # Update the weights by one optimizer step
        batch_index = np.random.randint(0, 2 * train_size, (batch_size,))
        feats_train_batch = feats_train[batch_index]
        Y_train_batch = Y_train[batch_index]
        
        weights, _, _ = opt.step(cost, weights, feats_train_batch, Y_train_batch)

        # Compute predictions on train and validation set
        predictions_train = [np.sign(variational_classifier(weights, feat)) for feat in feats_train]
        predictions_val = [np.sign(variational_classifier(weights, feat)) for feat in feats_val]
        #print(probs(Y_train, predictions_val))
        c = cost(weights, features, Y).numpy()
        #print(c)
        # Compute accuracy on train and validation set
        acc_train = accuracy_score(Y_train, predictions_train)
        acc_val = accuracy_score(Y_val, predictions_val)
        a = f1_score(Y_train, predictions_train)
        b = f1_score(Y_val, predictions_val)
        
        print("f1_score is", a, b)
        d = roc_auc_score(Y_train, predictions_train)
        e = roc_auc_score(Y_val, predictions_val)
        print("roc_auc_score is", d, e)


        f1_train.append(a)
        f1_test.append(b)
        roc_auc_train.append(d)
        roc_auc_test.append(e)
        his_acc_val.append(acc_val)
        his_acc_train.append(acc_train)
        his_cost.append(c)
        print("Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
            "".format(it + 1, c, acc_train, acc_val))
    print(p)    
    return his_acc_val, his_acc_train, his_cost, f1_train, f1_test, roc_auc_train, roc_auc_test

# %%
ps = [0, 0.1, 0.2, 0.3]
his1 = []
his2 = []
his3 = []

for p in ps:
    his_acc_val, his_acc_train, his_cost, _, _, _, _ = TrainQKSAN(params_init)
    his1.append(his_acc_val)
    his2.append(his_acc_train)
    his3.append(his_cost)
# Out:
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     1 | Cost: 1.1512805 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     2 | Cost: 1.1082278 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     3 | Cost: 1.0607641 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     4 | Cost: 1.0194065 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     5 | Cost: 0.9878209 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6807928913192071 0.684931506849315
# roc_auc_score is 0.5329999999999999 0.54
# Iter:     6 | Cost: 0.9697340 | Acc train: 0.5330000 | Acc validation: 0.5400000
# f1_score is 0.7140319715808171 0.7213114754098361
# roc_auc_score is 0.678 0.6599999999999999
# Iter:     7 | Cost: 0.9629231 | Acc train: 0.6780000 | Acc validation: 0.6600000
# f1_score is 0.4116743471582182 0.47058823529411764
# roc_auc_score is 0.617 0.64
# Iter:     8 | Cost: 0.9629418 | Acc train: 0.6170000 | Acc validation: 0.6400000
# f1_score is 0.12336448598130842 0.0392156862745098
# roc_auc_score is 0.531 0.51
# Iter:     9 | Cost: 0.9656091 | Acc train: 0.5310000 | Acc validation: 0.5100000
# f1_score is 0.027613412228796843 0.0
# roc_auc_score is 0.507 0.5
# Iter:    10 | Cost: 0.9692099 | Acc train: 0.5070000 | Acc validation: 0.5000000
# f1_score is 0.003992015968063872 0.0
# roc_auc_score is 0.501 0.5
# Iter:    11 | Cost: 0.9720385 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.003992015968063872 0.0
# roc_auc_score is 0.501 0.5
# Iter:    12 | Cost: 0.9729588 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.003992015968063872 0.0
# roc_auc_score is 0.501 0.5
# Iter:    13 | Cost: 0.9722362 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.003992015968063872 0.0
# roc_auc_score is 0.501 0.5
# Iter:    14 | Cost: 0.9712603 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.003992015968063872 0.0
# roc_auc_score is 0.501 0.5
# Iter:    15 | Cost: 0.9695923 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.015810276679841896 0.0
# roc_auc_score is 0.502 0.5
# Iter:    16 | Cost: 0.9678723 | Acc train: 0.5020000 | Acc validation: 0.5000000
# f1_score is 0.042884990253411304 0.0
# roc_auc_score is 0.509 0.5
# Iter:    17 | Cost: 0.9669061 | Acc train: 0.5090000 | Acc validation: 0.5000000
# f1_score is 0.09416195856873823 0.07692307692307693
# roc_auc_score is 0.519 0.52
# Iter:    18 | Cost: 0.9663479 | Acc train: 0.5190000 | Acc validation: 0.5200000
# f1_score is 0.18181818181818182 0.07547169811320754
# roc_auc_score is 0.541 0.51
# Iter:    19 | Cost: 0.9660189 | Acc train: 0.5410000 | Acc validation: 0.5100000
# f1_score is 0.3125996810207337 0.20338983050847456
# roc_auc_score is 0.569 0.53
# Iter:    20 | Cost: 0.9659604 | Acc train: 0.5690000 | Acc validation: 0.5300000
# f1_score is 0.46025104602510464 0.3283582089552239
# roc_auc_score is 0.613 0.5499999999999999
# Iter:    21 | Cost: 0.9661232 | Acc train: 0.6130000 | Acc validation: 0.5500000
# f1_score is 0.4959785522788204 0.3529411764705882
# roc_auc_score is 0.624 0.5599999999999999
# Iter:    22 | Cost: 0.9650272 | Acc train: 0.6240000 | Acc validation: 0.5600000
# f1_score is 0.5020026702269693 0.30303030303030304
# roc_auc_score is 0.6269999999999999 0.54
# Iter:    23 | Cost: 0.9632570 | Acc train: 0.6270000 | Acc validation: 0.5400000
# f1_score is 0.47696476964769646 0.25
# roc_auc_score is 0.6139999999999999 0.52
# Iter:    24 | Cost: 0.9614772 | Acc train: 0.6140000 | Acc validation: 0.5200000
# f1_score is 0.47297297297297297 0.21875000000000003
# roc_auc_score is 0.6100000000000001 0.5
# Iter:    25 | Cost: 0.9599149 | Acc train: 0.6100000 | Acc validation: 0.5000000
# f1_score is 0.3700440528634361 0.19672131147540983
# roc_auc_score is 0.571 0.5100000000000001
# Iter:    26 | Cost: 0.9574748 | Acc train: 0.5710000 | Acc validation: 0.5100000
# f1_score is 0.25161290322580643 0.10714285714285712
# roc_auc_score is 0.536 0.5
# Iter:    27 | Cost: 0.9552233 | Acc train: 0.5360000 | Acc validation: 0.5000000
# f1_score is 0.11806797853309484 0.07407407407407407
# roc_auc_score is 0.507 0.5
# Iter:    28 | Cost: 0.9531501 | Acc train: 0.5070000 | Acc validation: 0.5000000
# f1_score is 0.052730696798493404 0.0
# roc_auc_score is 0.497 0.49
# Iter:    29 | Cost: 0.9519226 | Acc train: 0.4970000 | Acc validation: 0.4900000
# f1_score is 0.04554079696394687 0.0
# roc_auc_score is 0.497 0.49
# Iter:    30 | Cost: 0.9510279 | Acc train: 0.4970000 | Acc validation: 0.4900000
# f1_score is 0.034351145038167934 0.0
# roc_auc_score is 0.494 0.49
# Iter:    31 | Cost: 0.9501685 | Acc train: 0.4940000 | Acc validation: 0.4900000
# f1_score is 0.01171875 0.0
# roc_auc_score is 0.494 0.5
# Iter:    32 | Cost: 0.9495834 | Acc train: 0.4940000 | Acc validation: 0.5000000
# f1_score is 0.007874015748031496 0.0
# roc_auc_score is 0.496 0.5
# Iter:    33 | Cost: 0.9491045 | Acc train: 0.4960000 | Acc validation: 0.5000000
# f1_score is 0.007874015748031496 0.0
# roc_auc_score is 0.496 0.5
# Iter:    34 | Cost: 0.9484943 | Acc train: 0.4960000 | Acc validation: 0.5000000
# f1_score is 0.003944773175542406 0.0
# roc_auc_score is 0.495 0.5
# Iter:    35 | Cost: 0.9476069 | Acc train: 0.4950000 | Acc validation: 0.5000000
# f1_score is 0.003929273084479371 0.0
# roc_auc_score is 0.493 0.5
# Iter:    36 | Cost: 0.9464175 | Acc train: 0.4930000 | Acc validation: 0.5000000
# f1_score is 0.0078125 0.0
# roc_auc_score is 0.492 0.49
# Iter:    37 | Cost: 0.9446002 | Acc train: 0.4920000 | Acc validation: 0.4900000
# f1_score is 0.011650485436893204 0.0
# roc_auc_score is 0.491 0.48
# Iter:    38 | Cost: 0.9427581 | Acc train: 0.4910000 | Acc validation: 0.4800000
# f1_score is 0.015414258188824663 0.0
# roc_auc_score is 0.489 0.48
# Iter:    39 | Cost: 0.9407170 | Acc train: 0.4890000 | Acc validation: 0.4800000
# f1_score is 0.02973977695167286 0.0
# roc_auc_score is 0.478 0.47
# Iter:    40 | Cost: 0.9380529 | Acc train: 0.4780000 | Acc validation: 0.4700000
# f1_score is 0.11564625850340136 0.03636363636363636
# roc_auc_score is 0.48000000000000004 0.47000000000000003
# Iter:    41 | Cost: 0.9355885 | Acc train: 0.4800000 | Acc validation: 0.4700000
# f1_score is 0.2943722943722944 0.3142857142857143
# roc_auc_score is 0.511 0.52
# Iter:    42 | Cost: 0.9342847 | Acc train: 0.5110000 | Acc validation: 0.5200000
# f1_score is 0.4367816091954023 0.43373493975903615
# roc_auc_score is 0.559 0.5299999999999999
# Iter:    43 | Cost: 0.9334105 | Acc train: 0.5590000 | Acc validation: 0.5300000
# f1_score is 0.6466809421841542 0.5918367346938774
# roc_auc_score is 0.67 0.6
# Iter:    44 | Cost: 0.9330502 | Acc train: 0.6700000 | Acc validation: 0.6000000
# f1_score is 0.6708463949843261 0.673076923076923
# roc_auc_score is 0.685 0.66
# Iter:    45 | Cost: 0.9319596 | Acc train: 0.6850000 | Acc validation: 0.6600000
# f1_score is 0.7141444114737884 0.6981132075471698
# roc_auc_score is 0.7109999999999999 0.6799999999999999
# Iter:    46 | Cost: 0.9310198 | Acc train: 0.7110000 | Acc validation: 0.6800000
# f1_score is 0.6603375527426161 0.673076923076923
# roc_auc_score is 0.6779999999999999 0.66
# Iter:    47 | Cost: 0.9291036 | Acc train: 0.6780000 | Acc validation: 0.6600000
# f1_score is 0.6797520661157024 0.6857142857142857
# roc_auc_score is 0.69 0.67
# Iter:    48 | Cost: 0.9278849 | Acc train: 0.6900000 | Acc validation: 0.6700000
# f1_score is 0.7118977384464109 0.6981132075471698
# roc_auc_score is 0.707 0.6799999999999999
# Iter:    49 | Cost: 0.9269143 | Acc train: 0.7070000 | Acc validation: 0.6800000
# f1_score is 0.646186440677966 0.673076923076923
# roc_auc_score is 0.6659999999999999 0.66
# Iter:    50 | Cost: 0.9252744 | Acc train: 0.6660000 | Acc validation: 0.6600000
# f1_score is 0.6263498920086393 0.6470588235294118
# roc_auc_score is 0.6539999999999999 0.6400000000000001
# Iter:    51 | Cost: 0.9240336 | Acc train: 0.6540000 | Acc validation: 0.6400000
# f1_score is 0.5153664302600472 0.5531914893617023
# roc_auc_score is 0.59 0.58
# Iter:    52 | Cost: 0.9228167 | Acc train: 0.5900000 | Acc validation: 0.5800000
# f1_score is 0.5510907003444316 0.5833333333333334
# roc_auc_score is 0.609 0.6000000000000001
# Iter:    53 | Cost: 0.9218651 | Acc train: 0.6090000 | Acc validation: 0.6000000
# f1_score is 0.41836734693877553 0.4418604651162791
# roc_auc_score is 0.5439999999999999 0.5199999999999999
# Iter:    54 | Cost: 0.9210160 | Acc train: 0.5440000 | Acc validation: 0.5200000
# f1_score is 0.30268741159830265 0.3287671232876712
# roc_auc_score is 0.507 0.51
# Iter:    55 | Cost: 0.9206511 | Acc train: 0.5070000 | Acc validation: 0.5100000
# f1_score is 0.15723270440251572 0.0967741935483871
# roc_auc_score is 0.4640000000000001 0.44000000000000006
# Iter:    56 | Cost: 0.9216883 | Acc train: 0.4640000 | Acc validation: 0.4400000
# f1_score is 0.11400651465798048 0.06779661016949154
# roc_auc_score is 0.456 0.45
# Iter:    57 | Cost: 0.9219694 | Acc train: 0.4560000 | Acc validation: 0.4500000
# f1_score is 0.14556962025316456 0.0967741935483871
# roc_auc_score is 0.46 0.44000000000000006
# Iter:    58 | Cost: 0.9208724 | Acc train: 0.4600000 | Acc validation: 0.4400000
# f1_score is 0.23318385650224216 0.208955223880597
# roc_auc_score is 0.487 0.4700000000000001
# Iter:    59 | Cost: 0.9193105 | Acc train: 0.4870000 | Acc validation: 0.4700000
# f1_score is 0.3231197771587744 0.32
# roc_auc_score is 0.514 0.49
# Iter:    60 | Cost: 0.9179054 | Acc train: 0.5140000 | Acc validation: 0.4900000
# f1_score is 0.3653333333333334 0.42857142857142855
# roc_auc_score is 0.524 0.5199999999999999
# Iter:    61 | Cost: 0.9171826 | Acc train: 0.5240000 | Acc validation: 0.5200000
# f1_score is 0.4789410348977136 0.5376344086021505
# roc_auc_score is 0.5670000000000001 0.57
# Iter:    62 | Cost: 0.9163270 | Acc train: 0.5670000 | Acc validation: 0.5700000
# f1_score is 0.717201166180758 0.7222222222222223
# roc_auc_score is 0.7089999999999999 0.7
# Iter:    63 | Cost: 0.9158720 | Acc train: 0.7090000 | Acc validation: 0.7000000
# f1_score is 0.7476459510357816 0.7387387387387387
# roc_auc_score is 0.732 0.71
# Iter:    64 | Cost: 0.9157012 | Acc train: 0.7320000 | Acc validation: 0.7100000
# f1_score is 0.805128205128205 0.7833333333333332
# roc_auc_score is 0.772 0.74
# Iter:    65 | Cost: 0.9165807 | Acc train: 0.7720000 | Acc validation: 0.7400000
# f1_score is 0.8195364238410596 0.7967479674796748
# roc_auc_score is 0.782 0.75
# Iter:    66 | Cost: 0.9174750 | Acc train: 0.7820000 | Acc validation: 0.7500000
# f1_score is 0.7930214115781127 0.7936507936507937
# roc_auc_score is 0.739 0.74
# Iter:    67 | Cost: 0.9216748 | Acc train: 0.7390000 | Acc validation: 0.7400000
# f1_score is 0.778816199376947 0.7812500000000001
# roc_auc_score is 0.716 0.72
# Iter:    68 | Cost: 0.9242011 | Acc train: 0.7160000 | Acc validation: 0.7200000
# f1_score is 0.7710100231303008 0.7812500000000001
# roc_auc_score is 0.7030000000000001 0.72
# Iter:    69 | Cost: 0.9254360 | Acc train: 0.7030000 | Acc validation: 0.7200000
# f1_score is 0.7686395080707148 0.7692307692307693
# roc_auc_score is 0.6990000000000001 0.7
# Iter:    70 | Cost: 0.9266854 | Acc train: 0.6990000 | Acc validation: 0.7000000
# f1_score is 0.8045052292839903 0.7936507936507937
# roc_auc_score is 0.757 0.74
# Iter:    71 | Cost: 0.9188036 | Acc train: 0.7570000 | Acc validation: 0.7400000
# f1_score is 0.8164291701592623 0.7833333333333332
# roc_auc_score is 0.7810000000000001 0.74
# Iter:    72 | Cost: 0.9151609 | Acc train: 0.7810000 | Acc validation: 0.7400000
# f1_score is 0.8144416456759025 0.7833333333333332
# roc_auc_score is 0.779 0.74
# Iter:    73 | Cost: 0.9148671 | Acc train: 0.7790000 | Acc validation: 0.7400000
# f1_score is 0.8038029386343993 0.7627118644067796
# roc_auc_score is 0.7730000000000001 0.72
# Iter:    74 | Cost: 0.9141092 | Acc train: 0.7730000 | Acc validation: 0.7200000
# f1_score is 0.8197530864197532 0.8064516129032258
# roc_auc_score is 0.781 0.76
# Iter:    75 | Cost: 0.9160774 | Acc train: 0.7810000 | Acc validation: 0.7600000
# f1_score is 0.8153594771241831 0.7936507936507937
# roc_auc_score is 0.774 0.74
# Iter:    76 | Cost: 0.9164284 | Acc train: 0.7740000 | Acc validation: 0.7400000
# f1_score is 0.8177257525083612 0.7833333333333332
# roc_auc_score is 0.7820000000000001 0.74
# Iter:    77 | Cost: 0.9144840 | Acc train: 0.7820000 | Acc validation: 0.7400000
# f1_score is 0.802405498281787 0.7731092436974789
# roc_auc_score is 0.77 0.73
# Iter:    78 | Cost: 0.9136414 | Acc train: 0.7700000 | Acc validation: 0.7300000
# f1_score is 0.7134502923976609 0.7387387387387387
# roc_auc_score is 0.706 0.71
# Iter:    79 | Cost: 0.9126146 | Acc train: 0.7060000 | Acc validation: 0.7100000
# f1_score is 0.4544349939246659 0.5274725274725274
# roc_auc_score is 0.551 0.57
# Iter:    80 | Cost: 0.9130804 | Acc train: 0.5510000 | Acc validation: 0.5700000
# f1_score is 0.491725768321513 0.5434782608695652
# roc_auc_score is 0.57 0.58
# Iter:    81 | Cost: 0.9128017 | Acc train: 0.5700000 | Acc validation: 0.5800000
# f1_score is 0.5621500559910414 0.6122448979591836
# roc_auc_score is 0.609 0.62
# Iter:    82 | Cost: 0.9124056 | Acc train: 0.6090000 | Acc validation: 0.6200000
# f1_score is 0.33105335157318744 0.35443037974683544
# roc_auc_score is 0.511 0.48999999999999994
# Iter:    83 | Cost: 0.9136141 | Acc train: 0.5110000 | Acc validation: 0.4900000
# f1_score is 0.21921921921921922 0.18181818181818182
# roc_auc_score is 0.48 0.4600000000000001
# Iter:    84 | Cost: 0.9150980 | Acc train: 0.4800000 | Acc validation: 0.4600000
# f1_score is 0.0949263502454992 0.06779661016949154
# roc_auc_score is 0.447 0.45
# Iter:    85 | Cost: 0.9180287 | Acc train: 0.4470000 | Acc validation: 0.4500000
# f1_score is 0.07118644067796612 0.0
# roc_auc_score is 0.452 0.43
# Iter:    86 | Cost: 0.9193243 | Acc train: 0.4520000 | Acc validation: 0.4300000
# f1_score is 0.0353356890459364 0.0
# roc_auc_score is 0.454 0.45
# Iter:    87 | Cost: 0.9217002 | Acc train: 0.4540000 | Acc validation: 0.4500000
# f1_score is 0.018450184501845015 0.0
# roc_auc_score is 0.468 0.46
# Iter:    88 | Cost: 0.9256232 | Acc train: 0.4680000 | Acc validation: 0.4600000
# f1_score is 0.02527075812274368 0.0
# roc_auc_score is 0.46 0.46
# Iter:    89 | Cost: 0.9219712 | Acc train: 0.4600000 | Acc validation: 0.4600000
# f1_score is 0.05217391304347826 0.0
# roc_auc_score is 0.455 0.44
# Iter:    90 | Cost: 0.9186051 | Acc train: 0.4550000 | Acc validation: 0.4400000
# f1_score is 0.08053691275167786 0.03508771929824562
# roc_auc_score is 0.452 0.45
# Iter:    91 | Cost: 0.9162840 | Acc train: 0.4520000 | Acc validation: 0.4500000
# f1_score is 0.33055555555555555 0.32432432432432434
# roc_auc_score is 0.518 0.5
# Iter:    92 | Cost: 0.9110538 | Acc train: 0.5180000 | Acc validation: 0.5000000
# f1_score is 0.7274509803921568 0.7454545454545455
# roc_auc_score is 0.722 0.72
# Iter:    93 | Cost: 0.9093986 | Acc train: 0.7220000 | Acc validation: 0.7200000
# f1_score is 0.8186528497409327 0.7933884297520661
# roc_auc_score is 0.79 0.75
# Iter:    94 | Cost: 0.9103943 | Acc train: 0.7900000 | Acc validation: 0.7500000
# f1_score is 0.8255813953488372 0.8130081300813007
# roc_auc_score is 0.79 0.77
# Iter:    95 | Cost: 0.9116642 | Acc train: 0.7900000 | Acc validation: 0.7700000
# f1_score is 0.8123476848090984 0.7936507936507937
# roc_auc_score is 0.769 0.74
# Iter:    96 | Cost: 0.9141921 | Acc train: 0.7690000 | Acc validation: 0.7400000
# f1_score is 0.7980845969672785 0.7874015748031497
# roc_auc_score is 0.747 0.73
# Iter:    97 | Cost: 0.9162585 | Acc train: 0.7470000 | Acc validation: 0.7300000
# f1_score is 0.7886435331230284 0.7812500000000001
# roc_auc_score is 0.732 0.72
# Iter:    98 | Cost: 0.9186015 | Acc train: 0.7320000 | Acc validation: 0.7200000
# f1_score is 0.7604562737642586 0.7518796992481204
# roc_auc_score is 0.685 0.6699999999999999
# Iter:    99 | Cost: 0.9246527 | Acc train: 0.6850000 | Acc validation: 0.6700000
# f1_score is 0.7598784194528876 0.7518796992481204
# roc_auc_score is 0.6839999999999999 0.6699999999999999
# Iter:   100 | Cost: 0.9243984 | Acc train: 0.6840000 | Acc validation: 0.6700000
# f1_score is 0.7836990595611286 0.7751937984496124
# roc_auc_score is 0.724 0.71
# Iter:   101 | Cost: 0.9187394 | Acc train: 0.7240000 | Acc validation: 0.7100000
# f1_score is 0.8183306055646482 0.8064516129032258
# roc_auc_score is 0.778 0.76
# Iter:   102 | Cost: 0.9120250 | Acc train: 0.7780000 | Acc validation: 0.7600000
# f1_score is 0.8058076225045371 0.7894736842105263
# roc_auc_score is 0.7859999999999999 0.76
# Iter:   103 | Cost: 0.9071413 | Acc train: 0.7860000 | Acc validation: 0.7600000
# f1_score is 0.6340378197997776 0.6666666666666666
# roc_auc_score is 0.671 0.68
# Iter:   104 | Cost: 0.9059880 | Acc train: 0.6710000 | Acc validation: 0.6800000
# f1_score is 0.2404870624048706 0.1875
# roc_auc_score is 0.5009999999999999 0.48000000000000004
# Iter:   105 | Cost: 0.9075886 | Acc train: 0.5010000 | Acc validation: 0.4800000
# f1_score is 0.03663003663003663 0.0
# roc_auc_score is 0.47400000000000003 0.47
# Iter:   106 | Cost: 0.9134727 | Acc train: 0.4740000 | Acc validation: 0.4700000
# f1_score is 0.0038834951456310682 0.0
# roc_auc_score is 0.487 0.48
# Iter:   107 | Cost: 0.9209708 | Acc train: 0.4870000 | Acc validation: 0.4800000
# f1_score is 0.007736943907156673 0.0
# roc_auc_score is 0.487 0.48
# Iter:   108 | Cost: 0.9189401 | Acc train: 0.4870000 | Acc validation: 0.4800000
# f1_score is 0.007677543186180423 0.0
# roc_auc_score is 0.483 0.48
# Iter:   109 | Cost: 0.9155042 | Acc train: 0.4830000 | Acc validation: 0.4800000
# f1_score is 0.007751937984496124 0.0
# roc_auc_score is 0.488 0.48
# Iter:   110 | Cost: 0.9159541 | Acc train: 0.4880000 | Acc validation: 0.4800000
# f1_score is 0.007722007722007721 0.0
# roc_auc_score is 0.486 0.48
# Iter:   111 | Cost: 0.9136342 | Acc train: 0.4860000 | Acc validation: 0.4800000
# f1_score is 0.007751937984496124 0.0
# roc_auc_score is 0.488 0.48
# Iter:   112 | Cost: 0.9138497 | Acc train: 0.4880000 | Acc validation: 0.4800000
# f1_score is 0.007782101167315174 0.0
# roc_auc_score is 0.49 0.48
# Iter:   113 | Cost: 0.9136707 | Acc train: 0.4900000 | Acc validation: 0.4800000
# f1_score is 0.0077669902912621365 0.0
# roc_auc_score is 0.489 0.48
# Iter:   114 | Cost: 0.9104405 | Acc train: 0.4890000 | Acc validation: 0.4800000
# f1_score is 0.015296367112810709 0.0
# roc_auc_score is 0.485 0.48
# Iter:   115 | Cost: 0.9052656 | Acc train: 0.4850000 | Acc validation: 0.4800000
# f1_score is 0.08912655971479502 0.14285714285714285
# roc_auc_score is 0.48900000000000005 0.52
# Iter:   116 | Cost: 0.9002696 | Acc train: 0.4890000 | Acc validation: 0.5200000
# f1_score is 0.11538461538461539 0.1754385964912281
# roc_auc_score is 0.49400000000000005 0.53
# Iter:   117 | Cost: 0.8984541 | Acc train: 0.4940000 | Acc validation: 0.5300000
# f1_score is 0.1460101867572156 0.1754385964912281
# roc_auc_score is 0.49700000000000005 0.53
# Iter:   118 | Cost: 0.8966740 | Acc train: 0.4970000 | Acc validation: 0.5300000
# f1_score is 0.33282904689863846 0.4117647058823529
# roc_auc_score is 0.559 0.6
# Iter:   119 | Cost: 0.8940128 | Acc train: 0.5590000 | Acc validation: 0.6000000
# f1_score is 0.6194477791116446 0.8085106382978724
# roc_auc_score is 0.6829999999999999 0.82
# Iter:   120 | Cost: 0.8916117 | Acc train: 0.6830000 | Acc validation: 0.8200000
# 0
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     1 | Cost: 1.0859732 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     2 | Cost: 1.0769674 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     3 | Cost: 1.0657887 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     4 | Cost: 1.0559285 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     5 | Cost: 1.0410322 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     6 | Cost: 1.0279014 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     7 | Cost: 1.0151092 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     8 | Cost: 1.0005571 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     9 | Cost: 0.9889597 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.66711140760507 0.6756756756756758
# roc_auc_score is 0.501 0.52
# Iter:    10 | Cost: 0.9787633 | Acc train: 0.5010000 | Acc validation: 0.5200000
# f1_score is 0.6793997271487039 0.6896551724137931
# roc_auc_score is 0.53 0.55
# Iter:    11 | Cost: 0.9724628 | Acc train: 0.5300000 | Acc validation: 0.5500000
# f1_score is 0.7272727272727273 0.7259259259259259
# roc_auc_score is 0.628 0.63
# Iter:    12 | Cost: 0.9685677 | Acc train: 0.6280000 | Acc validation: 0.6300000
# f1_score is 0.7306088407005837 0.7377049180327869
# roc_auc_score is 0.6769999999999999 0.6799999999999999
# Iter:    13 | Cost: 0.9663692 | Acc train: 0.6770000 | Acc validation: 0.6800000
# f1_score is 0.648936170212766 0.673076923076923
# roc_auc_score is 0.6699999999999999 0.66
# Iter:    14 | Cost: 0.9653654 | Acc train: 0.6700000 | Acc validation: 0.6600000
# f1_score is 0.5345501955671447 0.5842696629213484
# roc_auc_score is 0.643 0.63
# Iter:    15 | Cost: 0.9647291 | Acc train: 0.6430000 | Acc validation: 0.6300000
# f1_score is 0.35109717868338564 0.36363636363636365
# roc_auc_score is 0.586 0.5800000000000001
# Iter:    16 | Cost: 0.9644559 | Acc train: 0.5860000 | Acc validation: 0.5800000
# f1_score is 0.22758620689655173 0.14035087719298248
# roc_auc_score is 0.552 0.51
# Iter:    17 | Cost: 0.9644398 | Acc train: 0.5520000 | Acc validation: 0.5100000
# f1_score is 0.20350877192982456 0.14285714285714285
# roc_auc_score is 0.546 0.52
# Iter:    18 | Cost: 0.9638199 | Acc train: 0.5460000 | Acc validation: 0.5200000
# f1_score is 0.17173524150268338 0.07407407407407407
# roc_auc_score is 0.5369999999999999 0.5
# Iter:    19 | Cost: 0.9630407 | Acc train: 0.5370000 | Acc validation: 0.5000000
# f1_score is 0.15189873417721522 0.03773584905660377
# roc_auc_score is 0.531 0.49
# Iter:    20 | Cost: 0.9624468 | Acc train: 0.5310000 | Acc validation: 0.4900000
# f1_score is 0.11808118081180811 0.03773584905660377
# roc_auc_score is 0.522 0.49
# Iter:    21 | Cost: 0.9620379 | Acc train: 0.5220000 | Acc validation: 0.4900000
# f1_score is 0.08712121212121211 0.038461538461538464
# roc_auc_score is 0.518 0.5
# Iter:    22 | Cost: 0.9620161 | Acc train: 0.5180000 | Acc validation: 0.5000000
# f1_score is 0.03898635477582846 0.038461538461538464
# roc_auc_score is 0.507 0.5
# Iter:    23 | Cost: 0.9624997 | Acc train: 0.5070000 | Acc validation: 0.5000000
# f1_score is 0.03515624999999999 0.0
# roc_auc_score is 0.506 0.49
# Iter:    24 | Cost: 0.9620479 | Acc train: 0.5060000 | Acc validation: 0.4900000
# f1_score is 0.06095238095238095 0.038461538461538464
# roc_auc_score is 0.507 0.5
# Iter:    25 | Cost: 0.9604099 | Acc train: 0.5070000 | Acc validation: 0.5000000
# f1_score is 0.10720887245841035 0.037037037037037035
# roc_auc_score is 0.517 0.48
# Iter:    26 | Cost: 0.9586091 | Acc train: 0.5170000 | Acc validation: 0.4800000
# f1_score is 0.16925734024179623 0.07017543859649124
# roc_auc_score is 0.519 0.47000000000000003
# Iter:    27 | Cost: 0.9569753 | Acc train: 0.5190000 | Acc validation: 0.4700000
# f1_score is 0.3967828418230563 0.3896103896103896
# roc_auc_score is 0.55 0.53
# Iter:    28 | Cost: 0.9552789 | Acc train: 0.5500000 | Acc validation: 0.5300000
# f1_score is 0.6444212721584984 0.6862745098039216
# roc_auc_score is 0.6589999999999999 0.6799999999999999
# Iter:    29 | Cost: 0.9545918 | Acc train: 0.6590000 | Acc validation: 0.6800000
# f1_score is 0.7423255813953489 0.7155963302752293
# roc_auc_score is 0.7230000000000001 0.6900000000000001
# Iter:    30 | Cost: 0.9543095 | Acc train: 0.7230000 | Acc validation: 0.6900000
# f1_score is 0.7688219663418955 0.736842105263158
# roc_auc_score is 0.7389999999999999 0.7
# Iter:    31 | Cost: 0.9539209 | Acc train: 0.7390000 | Acc validation: 0.7000000
# f1_score is 0.7928082191780822 0.7394957983193275
# roc_auc_score is 0.7580000000000002 0.69
# Iter:    32 | Cost: 0.9535829 | Acc train: 0.7580000 | Acc validation: 0.6900000
# f1_score is 0.7969924812030075 0.7540983606557377
# roc_auc_score is 0.757 0.7
# Iter:    33 | Cost: 0.9534617 | Acc train: 0.7570000 | Acc validation: 0.7000000
# f1_score is 0.7979539641943734 0.7394957983193275
# roc_auc_score is 0.7630000000000001 0.69
# Iter:    34 | Cost: 0.9527541 | Acc train: 0.7630000 | Acc validation: 0.6900000
# f1_score is 0.7601809954751132 0.7207207207207207
# roc_auc_score is 0.735 0.6900000000000002
# Iter:    35 | Cost: 0.9517648 | Acc train: 0.7350000 | Acc validation: 0.6900000
# f1_score is 0.7008712487899323 0.6857142857142857
# roc_auc_score is 0.691 0.67
# Iter:    36 | Cost: 0.9509581 | Acc train: 0.6910000 | Acc validation: 0.6700000
# f1_score is 0.7114093959731544 0.6981132075471698
# roc_auc_score is 0.699 0.6799999999999999
# Iter:    37 | Cost: 0.9503850 | Acc train: 0.6990000 | Acc validation: 0.6800000
# f1_score is 0.7126436781609194 0.6981132075471698
# roc_auc_score is 0.7 0.6799999999999999
# Iter:    38 | Cost: 0.9498301 | Acc train: 0.7000000 | Acc validation: 0.6800000
# f1_score is 0.7155090390104663 0.6981132075471698
# roc_auc_score is 0.7010000000000001 0.6799999999999999
# Iter:    39 | Cost: 0.9493038 | Acc train: 0.7010000 | Acc validation: 0.6800000
# f1_score is 0.7497708524289642 0.7027027027027027
# roc_auc_score is 0.7270000000000001 0.67
# Iter:    40 | Cost: 0.9488652 | Acc train: 0.7270000 | Acc validation: 0.6700000
# f1_score is 0.7717099373321398 0.7256637168141592
# roc_auc_score is 0.7450000000000001 0.6900000000000001
# Iter:    41 | Cost: 0.9484145 | Acc train: 0.7450000 | Acc validation: 0.6900000
# f1_score is 0.8 0.7603305785123967
# roc_auc_score is 0.763 0.71
# Iter:    42 | Cost: 0.9483140 | Acc train: 0.7630000 | Acc validation: 0.7100000
# f1_score is 0.8056713928273561 0.7642276422764229
# roc_auc_score is 0.767 0.71
# Iter:    43 | Cost: 0.9480290 | Acc train: 0.7670000 | Acc validation: 0.7100000
# f1_score is 0.8046550290939318 0.7642276422764229
# roc_auc_score is 0.765 0.71
# Iter:    44 | Cost: 0.9475914 | Acc train: 0.7650000 | Acc validation: 0.7100000
# f1_score is 0.8036154478225144 0.7679999999999999
# roc_auc_score is 0.7610000000000001 0.71
# Iter:    45 | Cost: 0.9473903 | Acc train: 0.7610000 | Acc validation: 0.7100000
# f1_score is 0.8035859820700896 0.7679999999999999
# roc_auc_score is 0.7590000000000001 0.71
# Iter:    46 | Cost: 0.9471072 | Acc train: 0.7590000 | Acc validation: 0.7100000
# f1_score is 0.8029678483099751 0.7741935483870968
# roc_auc_score is 0.761 0.72
# Iter:    47 | Cost: 0.9466155 | Acc train: 0.7610000 | Acc validation: 0.7200000
# f1_score is 0.802675585284281 0.7540983606557377
# roc_auc_score is 0.764 0.7
# Iter:    48 | Cost: 0.9460164 | Acc train: 0.7640000 | Acc validation: 0.7000000
# f1_score is 0.7986463620981387 0.7666666666666667
# roc_auc_score is 0.762 0.72
# Iter:    49 | Cost: 0.9455380 | Acc train: 0.7620000 | Acc validation: 0.7200000
# f1_score is 0.8013245033112583 0.7642276422764229
# roc_auc_score is 0.76 0.71
# Iter:    50 | Cost: 0.9456327 | Acc train: 0.7600000 | Acc validation: 0.7100000
# f1_score is 0.803265306122449 0.7679999999999999
# roc_auc_score is 0.759 0.71
# Iter:    51 | Cost: 0.9455560 | Acc train: 0.7590000 | Acc validation: 0.7100000
# f1_score is 0.801980198019802 0.7741935483870968
# roc_auc_score is 0.76 0.72
# Iter:    52 | Cost: 0.9451796 | Acc train: 0.7600000 | Acc validation: 0.7200000
# f1_score is 0.7657657657657658 0.7256637168141592
# roc_auc_score is 0.74 0.6900000000000001
# Iter:    53 | Cost: 0.9443567 | Acc train: 0.7400000 | Acc validation: 0.6900000
# f1_score is 0.6313603322949117 0.5894736842105264
# roc_auc_score is 0.645 0.61
# Iter:    54 | Cost: 0.9444243 | Acc train: 0.6450000 | Acc validation: 0.6100000
# f1_score is 0.42821782178217815 0.35443037974683544
# roc_auc_score is 0.538 0.48999999999999994
# Iter:    55 | Cost: 0.9450979 | Acc train: 0.5380000 | Acc validation: 0.4900000
# f1_score is 0.3567708333333333 0.29333333333333333
# roc_auc_score is 0.506 0.47
# Iter:    56 | Cost: 0.9454447 | Acc train: 0.5060000 | Acc validation: 0.4700000
# f1_score is 0.37948717948717947 0.3116883116883117
# roc_auc_score is 0.516 0.47
# Iter:    57 | Cost: 0.9453251 | Acc train: 0.5160000 | Acc validation: 0.4700000
# f1_score is 0.4887839433293979 0.37499999999999994
# roc_auc_score is 0.567 0.49999999999999994
# Iter:    58 | Cost: 0.9448077 | Acc train: 0.5670000 | Acc validation: 0.5000000
# f1_score is 0.5479143179255919 0.4146341463414634
# roc_auc_score is 0.599 0.52
# Iter:    59 | Cost: 0.9444938 | Acc train: 0.5990000 | Acc validation: 0.5200000
# f1_score is 0.5819761129207384 0.42857142857142855
# roc_auc_score is 0.615 0.5199999999999999
# Iter:    60 | Cost: 0.9442862 | Acc train: 0.6150000 | Acc validation: 0.5200000
# f1_score is 0.6010695187165777 0.5333333333333332
# roc_auc_score is 0.627 0.58
# Iter:    61 | Cost: 0.9441700 | Acc train: 0.6270000 | Acc validation: 0.5800000
# f1_score is 0.684931506849315 0.6538461538461539
# roc_auc_score is 0.6779999999999999 0.64
# Iter:    62 | Cost: 0.9438051 | Acc train: 0.6780000 | Acc validation: 0.6400000
# f1_score is 0.7774846086191732 0.7521367521367521
# roc_auc_score is 0.7469999999999999 0.7100000000000001
# Iter:    63 | Cost: 0.9437054 | Acc train: 0.7470000 | Acc validation: 0.7100000
# f1_score is 0.7990353697749196 0.7777777777777777
# roc_auc_score is 0.75 0.72
# Iter:    64 | Cost: 0.9447034 | Acc train: 0.7500000 | Acc validation: 0.7200000
# f1_score is 0.7727975270479134 0.7633587786259541
# roc_auc_score is 0.706 0.69
# Iter:    65 | Cost: 0.9470921 | Acc train: 0.7060000 | Acc validation: 0.6900000
# f1_score is 0.757002271006813 0.7633587786259541
# roc_auc_score is 0.679 0.69
# Iter:    66 | Cost: 0.9487797 | Acc train: 0.6790000 | Acc validation: 0.6900000
# f1_score is 0.7451564828614009 0.7575757575757575
# roc_auc_score is 0.6579999999999999 0.6799999999999999
# Iter:    67 | Cost: 0.9509349 | Acc train: 0.6580000 | Acc validation: 0.6800000
# f1_score is 0.7272727272727273 0.7246376811594203
# roc_auc_score is 0.625 0.62
# Iter:    68 | Cost: 0.9544516 | Acc train: 0.6250000 | Acc validation: 0.6200000
# f1_score is 0.7072135785007072 0.7092198581560284
# roc_auc_score is 0.5860000000000001 0.5900000000000001
# Iter:    69 | Cost: 0.9582778 | Acc train: 0.5860000 | Acc validation: 0.5900000
# f1_score is 0.6925207756232686 0.6993006993006993
# roc_auc_score is 0.556 0.5700000000000001
# Iter:    70 | Cost: 0.9622350 | Acc train: 0.5560000 | Acc validation: 0.5700000
# f1_score is 0.6858710562414266 0.6802721088435374
# roc_auc_score is 0.542 0.53
# Iter:    71 | Cost: 0.9641049 | Acc train: 0.5420000 | Acc validation: 0.5300000
# f1_score is 0.6891798759476223 0.684931506849315
# roc_auc_score is 0.5489999999999999 0.54
# Iter:    72 | Cost: 0.9629157 | Acc train: 0.5490000 | Acc validation: 0.5400000
# f1_score is 0.7077140835102619 0.7092198581560284
# roc_auc_score is 0.587 0.5900000000000001
# Iter:    73 | Cost: 0.9580207 | Acc train: 0.5870000 | Acc validation: 0.5900000
# f1_score is 0.7369196757553427 0.7407407407407407
# roc_auc_score is 0.643 0.65
# Iter:    74 | Cost: 0.9523701 | Acc train: 0.6430000 | Acc validation: 0.6500000
# f1_score is 0.7496251874062969 0.7633587786259541
# roc_auc_score is 0.6659999999999999 0.69
# Iter:    75 | Cost: 0.9496124 | Acc train: 0.6660000 | Acc validation: 0.6900000
# f1_score is 0.7581501137225171 0.7633587786259541
# roc_auc_score is 0.681 0.69
# Iter:    76 | Cost: 0.9481485 | Acc train: 0.6810000 | Acc validation: 0.6900000
# f1_score is 0.7651109410864575 0.7633587786259541
# roc_auc_score is 0.6930000000000001 0.69
# Iter:    77 | Cost: 0.9476087 | Acc train: 0.6930000 | Acc validation: 0.6900000
# f1_score is 0.7610350076103501 0.7633587786259541
# roc_auc_score is 0.6859999999999999 0.69
# Iter:    78 | Cost: 0.9479028 | Acc train: 0.6860000 | Acc validation: 0.6900000
# f1_score is 0.7587253414264037 0.7633587786259541
# roc_auc_score is 0.6819999999999999 0.69
# Iter:    79 | Cost: 0.9481426 | Acc train: 0.6820000 | Acc validation: 0.6900000
# f1_score is 0.759301442672741 0.7633587786259541
# roc_auc_score is 0.683 0.69
# Iter:    80 | Cost: 0.9480780 | Acc train: 0.6830000 | Acc validation: 0.6900000
# f1_score is 0.777000777000777 0.765625
# roc_auc_score is 0.7130000000000001 0.7
# Iter:    81 | Cost: 0.9461988 | Acc train: 0.7130000 | Acc validation: 0.7000000
# f1_score is 0.8019639934533551 0.7679999999999999
# roc_auc_score is 0.758 0.71
# Iter:    82 | Cost: 0.9443423 | Acc train: 0.7580000 | Acc validation: 0.7100000
# f1_score is 0.7739665787159191 0.736842105263158
# roc_auc_score is 0.7429999999999999 0.7
# Iter:    83 | Cost: 0.9440640 | Acc train: 0.7430000 | Acc validation: 0.7000000
# f1_score is 0.6174636174636176 0.5054945054945056
# roc_auc_score is 0.6319999999999999 0.55
# Iter:    84 | Cost: 0.9447587 | Acc train: 0.6320000 | Acc validation: 0.5500000
# f1_score is 0.4707287933094385 0.35443037974683544
# roc_auc_score is 0.557 0.48999999999999994
# Iter:    85 | Cost: 0.9458154 | Acc train: 0.5570000 | Acc validation: 0.4900000
# f1_score is 0.27939142461964045 0.11764705882352941
# roc_auc_score is 0.479 0.4
# Iter:    86 | Cost: 0.9470584 | Acc train: 0.4790000 | Acc validation: 0.4000000
# f1_score is 0.21700879765395892 0.09230769230769231
# roc_auc_score is 0.46599999999999997 0.41000000000000003
# Iter:    87 | Cost: 0.9477837 | Acc train: 0.4660000 | Acc validation: 0.4100000
# f1_score is 0.12140575079872203 0.032786885245901634
# roc_auc_score is 0.45000000000000007 0.41000000000000003
# Iter:    88 | Cost: 0.9493552 | Acc train: 0.4500000 | Acc validation: 0.4100000
# f1_score is 0.1132686084142395 0.032786885245901634
# roc_auc_score is 0.452 0.41000000000000003
# Iter:    89 | Cost: 0.9495268 | Acc train: 0.4520000 | Acc validation: 0.4100000
# f1_score is 0.18947368421052632 0.09523809523809523
# roc_auc_score is 0.46099999999999997 0.43000000000000005
# Iter:    90 | Cost: 0.9476477 | Acc train: 0.4610000 | Acc validation: 0.4300000
# f1_score is 0.32843791722296395 0.1971830985915493
# roc_auc_score is 0.497 0.43000000000000005
# Iter:    91 | Cost: 0.9459843 | Acc train: 0.4970000 | Acc validation: 0.4300000
# f1_score is 0.3066485753052917 0.11764705882352941
# roc_auc_score is 0.489 0.4
# Iter:    92 | Cost: 0.9459713 | Acc train: 0.4890000 | Acc validation: 0.4000000
# f1_score is 0.24103299856527982 0.09230769230769231
# roc_auc_score is 0.471 0.41000000000000003
# Iter:    93 | Cost: 0.9463905 | Acc train: 0.4710000 | Acc validation: 0.4100000
# f1_score is 0.18484848484848485 0.09523809523809523
# roc_auc_score is 0.46199999999999997 0.43000000000000005
# Iter:    94 | Cost: 0.9470735 | Acc train: 0.4620000 | Acc validation: 0.4300000
# f1_score is 0.16383307573415767 0.06451612903225806
# roc_auc_score is 0.459 0.42000000000000004
# Iter:    95 | Cost: 0.9471466 | Acc train: 0.4590000 | Acc validation: 0.4200000
# f1_score is 0.1851289833080425 0.09523809523809523
# roc_auc_score is 0.463 0.43000000000000005
# Iter:    96 | Cost: 0.9466192 | Acc train: 0.4630000 | Acc validation: 0.4300000
# f1_score is 0.2514285714285714 0.09230769230769231
# roc_auc_score is 0.476 0.41000000000000003
# Iter:    97 | Cost: 0.9456801 | Acc train: 0.4760000 | Acc validation: 0.4100000
# f1_score is 0.38095238095238093 0.2702702702702703
# roc_auc_score is 0.519 0.46
# Iter:    98 | Cost: 0.9445923 | Acc train: 0.5190000 | Acc validation: 0.4600000
# f1_score is 0.4070796460176991 0.3157894736842105
# roc_auc_score is 0.531 0.48
# Iter:    99 | Cost: 0.9443844 | Acc train: 0.5310000 | Acc validation: 0.4800000
# f1_score is 0.47172081829121537 0.35443037974683544
# roc_auc_score is 0.5609999999999999 0.48999999999999994
# Iter:   100 | Cost: 0.9440355 | Acc train: 0.5610000 | Acc validation: 0.4900000
# f1_score is 0.43896424167694204 0.35443037974683544
# roc_auc_score is 0.5449999999999999 0.48999999999999994
# Iter:   101 | Cost: 0.9440764 | Acc train: 0.5450000 | Acc validation: 0.4900000
# f1_score is 0.43424317617866004 0.35443037974683544
# roc_auc_score is 0.544 0.48999999999999994
# Iter:   102 | Cost: 0.9440461 | Acc train: 0.5440000 | Acc validation: 0.4900000
# f1_score is 0.5070093457943925 0.37499999999999994
# roc_auc_score is 0.578 0.49999999999999994
# Iter:   103 | Cost: 0.9437226 | Acc train: 0.5780000 | Acc validation: 0.5000000
# f1_score is 0.48506571087216255 0.35443037974683544
# roc_auc_score is 0.5690000000000001 0.48999999999999994
# Iter:   104 | Cost: 0.9438443 | Acc train: 0.5690000 | Acc validation: 0.4900000
# f1_score is 0.43811881188118806 0.35443037974683544
# roc_auc_score is 0.546 0.48999999999999994
# Iter:   105 | Cost: 0.9439491 | Acc train: 0.5460000 | Acc validation: 0.4900000
# f1_score is 0.34224598930481287 0.14492753623188404
# roc_auc_score is 0.508 0.41000000000000003
# Iter:   106 | Cost: 0.9444341 | Acc train: 0.5080000 | Acc validation: 0.4100000
# f1_score is 0.301521438450899 0.11940298507462688
# roc_auc_score is 0.495 0.41000000000000003
# Iter:   107 | Cost: 0.9446517 | Acc train: 0.4950000 | Acc validation: 0.4100000
# f1_score is 0.2453102453102453 0.09523809523809523
# roc_auc_score is 0.477 0.43000000000000005
# Iter:   108 | Cost: 0.9449536 | Acc train: 0.4770000 | Acc validation: 0.4300000
# f1_score is 0.26173541963015645 0.12121212121212122
# roc_auc_score is 0.481 0.42000000000000004
# Iter:   109 | Cost: 0.9447914 | Acc train: 0.4810000 | Acc validation: 0.4200000
# f1_score is 0.43532338308457713 0.3333333333333333
# roc_auc_score is 0.546 0.4799999999999999
# Iter:   110 | Cost: 0.9439272 | Acc train: 0.5460000 | Acc validation: 0.4800000
# f1_score is 0.6530612244897959 0.5684210526315789
# roc_auc_score is 0.66 0.5900000000000001
# Iter:   111 | Cost: 0.9434566 | Acc train: 0.6600000 | Acc validation: 0.5900000
# f1_score is 0.7317073170731707 0.6728971962616822
# roc_auc_score is 0.714 0.6500000000000001
# Iter:   112 | Cost: 0.9435593 | Acc train: 0.7140000 | Acc validation: 0.6500000
# f1_score is 0.7965957446808511 0.7666666666666667
# roc_auc_score is 0.7610000000000001 0.72
# Iter:   113 | Cost: 0.9443140 | Acc train: 0.7610000 | Acc validation: 0.7200000
# f1_score is 0.7933227344992051 0.7777777777777777
# roc_auc_score is 0.74 0.72
# Iter:   114 | Cost: 0.9462042 | Acc train: 0.7400000 | Acc validation: 0.7200000
# f1_score is 0.7818608287724785 0.7812500000000001
# roc_auc_score is 0.721 0.72
# Iter:   115 | Cost: 0.9472687 | Acc train: 0.7210000 | Acc validation: 0.7200000
# f1_score is 0.7800312012480499 0.7812500000000001
# roc_auc_score is 0.718 0.72
# Iter:   116 | Cost: 0.9475814 | Acc train: 0.7180000 | Acc validation: 0.7200000
# f1_score is 0.7800312012480499 0.7812500000000001
# roc_auc_score is 0.718 0.72
# Iter:   117 | Cost: 0.9474695 | Acc train: 0.7180000 | Acc validation: 0.7200000
# f1_score is 0.7800312012480499 0.7812500000000001
# roc_auc_score is 0.718 0.72
# Iter:   118 | Cost: 0.9473279 | Acc train: 0.7180000 | Acc validation: 0.7200000
# f1_score is 0.7686395080707148 0.7692307692307693
# roc_auc_score is 0.6990000000000001 0.7
# Iter:   119 | Cost: 0.9487227 | Acc train: 0.6990000 | Acc validation: 0.7000000
# f1_score is 0.7558578987150416 0.7633587786259541
# roc_auc_score is 0.677 0.69
# Iter:   120 | Cost: 0.9505366 | Acc train: 0.6770000 | Acc validation: 0.6900000
# 0.1
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     1 | Cost: 1.0378699 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     2 | Cost: 1.0368658 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     3 | Cost: 1.0338375 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     4 | Cost: 1.0296854 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     5 | Cost: 1.0259995 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     6 | Cost: 1.0206326 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     7 | Cost: 1.0154230 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     8 | Cost: 1.0092501 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:     9 | Cost: 1.0038425 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    10 | Cost: 0.9989951 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    11 | Cost: 0.9942987 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    12 | Cost: 0.9904797 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.66711140760507 0.6666666666666666
# roc_auc_score is 0.501 0.5
# Iter:    13 | Cost: 0.9869952 | Acc train: 0.5010000 | Acc validation: 0.5000000
# f1_score is 0.6675621222296844 0.6756756756756758
# roc_auc_score is 0.505 0.52
# Iter:    14 | Cost: 0.9845620 | Acc train: 0.5050000 | Acc validation: 0.5200000
# f1_score is 0.6831333803810867 0.704225352112676
# roc_auc_score is 0.5509999999999999 0.5800000000000001
# Iter:    15 | Cost: 0.9830437 | Acc train: 0.5510000 | Acc validation: 0.5800000
# f1_score is 0.6882793017456359 0.7258064516129032
# roc_auc_score is 0.625 0.66
# Iter:    16 | Cost: 0.9821532 | Acc train: 0.6250000 | Acc validation: 0.6600000
# f1_score is 0.6162790697674418 0.7272727272727272
# roc_auc_score is 0.67 0.73
# Iter:    17 | Cost: 0.9819886 | Acc train: 0.6700000 | Acc validation: 0.7300000
# f1_score is 0.4036697247706423 0.4411764705882353
# roc_auc_score is 0.61 0.62
# Iter:    18 | Cost: 0.9822985 | Acc train: 0.6100000 | Acc validation: 0.6200000
# f1_score is 0.26804123711340205 0.24561403508771928
# roc_auc_score is 0.574 0.5700000000000001
# Iter:    19 | Cost: 0.9824613 | Acc train: 0.5740000 | Acc validation: 0.5700000
# f1_score is 0.20430107526881722 0.21428571428571425
# roc_auc_score is 0.556 0.56
# Iter:    20 | Cost: 0.9822620 | Acc train: 0.5560000 | Acc validation: 0.5600000
# f1_score is 0.1580882352941176 0.14814814814814814
# roc_auc_score is 0.542 0.54
# Iter:    21 | Cost: 0.9821654 | Acc train: 0.5420000 | Acc validation: 0.5400000
# f1_score is 0.14126394052044608 0.0392156862745098
# roc_auc_score is 0.538 0.51
# Iter:    22 | Cost: 0.9818819 | Acc train: 0.5380000 | Acc validation: 0.5100000
# f1_score is 0.10246679316888045 0.0392156862745098
# roc_auc_score is 0.527 0.51
# Iter:    23 | Cost: 0.9816555 | Acc train: 0.5270000 | Acc validation: 0.5100000
# f1_score is 0.10246679316888045 0.0392156862745098
# roc_auc_score is 0.527 0.51
# Iter:    24 | Cost: 0.9811151 | Acc train: 0.5270000 | Acc validation: 0.5100000
# f1_score is 0.08795411089866156 0.0392156862745098
# roc_auc_score is 0.523 0.51
# Iter:    25 | Cost: 0.9808978 | Acc train: 0.5230000 | Acc validation: 0.5100000
# f1_score is 0.07692307692307693 0.0392156862745098
# roc_auc_score is 0.52 0.51
# Iter:    26 | Cost: 0.9807412 | Acc train: 0.5200000 | Acc validation: 0.5100000
# f1_score is 0.058252427184466014 0.0392156862745098
# roc_auc_score is 0.515 0.51
# Iter:    27 | Cost: 0.9808863 | Acc train: 0.5150000 | Acc validation: 0.5100000
# f1_score is 0.058252427184466014 0.0392156862745098
# roc_auc_score is 0.515 0.51
# Iter:    28 | Cost: 0.9803456 | Acc train: 0.5150000 | Acc validation: 0.5100000
# f1_score is 0.06949806949806948 0.0392156862745098
# roc_auc_score is 0.518 0.51
# Iter:    29 | Cost: 0.9795499 | Acc train: 0.5180000 | Acc validation: 0.5100000
# f1_score is 0.08795411089866156 0.0392156862745098
# roc_auc_score is 0.523 0.51
# Iter:    30 | Cost: 0.9787530 | Acc train: 0.5230000 | Acc validation: 0.5100000
# f1_score is 0.07321772639691715 0.0392156862745098
# roc_auc_score is 0.519 0.51
# Iter:    31 | Cost: 0.9786592 | Acc train: 0.5190000 | Acc validation: 0.5100000
# f1_score is 0.06576402321083172 0.0392156862745098
# roc_auc_score is 0.517 0.51
# Iter:    32 | Cost: 0.9783679 | Acc train: 0.5170000 | Acc validation: 0.5100000
# f1_score is 0.07677543186180422 0.038461538461538464
# roc_auc_score is 0.519 0.5
# Iter:    33 | Cost: 0.9777208 | Acc train: 0.5190000 | Acc validation: 0.5000000
# f1_score is 0.10227272727272728 0.038461538461538464
# roc_auc_score is 0.526 0.5
# Iter:    34 | Cost: 0.9768477 | Acc train: 0.5260000 | Acc validation: 0.5000000
# f1_score is 0.11257035647279551 0.038461538461538464
# roc_auc_score is 0.527 0.5
# Iter:    35 | Cost: 0.9763363 | Acc train: 0.5270000 | Acc validation: 0.5000000
# f1_score is 0.09829867674858221 0.038461538461538464
# roc_auc_score is 0.523 0.5
# Iter:    36 | Cost: 0.9760366 | Acc train: 0.5230000 | Acc validation: 0.5000000
# f1_score is 0.10169491525423728 0.038461538461538464
# roc_auc_score is 0.523 0.5
# Iter:    37 | Cost: 0.9756250 | Acc train: 0.5230000 | Acc validation: 0.5000000
# f1_score is 0.0945179584120983 0.038461538461538464
# roc_auc_score is 0.521 0.5
# Iter:    38 | Cost: 0.9753269 | Acc train: 0.5210000 | Acc validation: 0.5000000
# f1_score is 0.1080074487895717 0.038461538461538464
# roc_auc_score is 0.521 0.5
# Iter:    39 | Cost: 0.9747842 | Acc train: 0.5210000 | Acc validation: 0.5000000
# f1_score is 0.16696269982238013 0.07142857142857142
# roc_auc_score is 0.531 0.48000000000000004
# Iter:    40 | Cost: 0.9739270 | Acc train: 0.5310000 | Acc validation: 0.4800000
# f1_score is 0.24960505529225907 0.15873015873015872
# roc_auc_score is 0.5249999999999999 0.47000000000000003
# Iter:    41 | Cost: 0.9731732 | Acc train: 0.5250000 | Acc validation: 0.4700000
# f1_score is 0.267071320182094 0.15625
# roc_auc_score is 0.5169999999999999 0.4600000000000001
# Iter:    42 | Cost: 0.9727301 | Acc train: 0.5170000 | Acc validation: 0.4600000
# f1_score is 0.34674063800277394 0.3684210526315789
# roc_auc_score is 0.529 0.52
# Iter:    43 | Cost: 0.9721437 | Acc train: 0.5290000 | Acc validation: 0.5200000
# f1_score is 0.5330243337195828 0.45783132530120485
# roc_auc_score is 0.597 0.5499999999999999
# Iter:    44 | Cost: 0.9715730 | Acc train: 0.5970000 | Acc validation: 0.5500000
# f1_score is 0.6563467492260061 0.6732673267326733
# roc_auc_score is 0.667 0.67
# Iter:    45 | Cost: 0.9711403 | Acc train: 0.6670000 | Acc validation: 0.6700000
# f1_score is 0.7229601518026565 0.6857142857142857
# roc_auc_score is 0.7080000000000001 0.67
# Iter:    46 | Cost: 0.9708152 | Acc train: 0.7080000 | Acc validation: 0.6700000
# f1_score is 0.7479376718606782 0.7207207207207207
# roc_auc_score is 0.725 0.6900000000000002
# Iter:    47 | Cost: 0.9705726 | Acc train: 0.7250000 | Acc validation: 0.6900000
# f1_score is 0.7880851063829787 0.7521367521367521
# roc_auc_score is 0.7510000000000001 0.7100000000000001
# Iter:    48 | Cost: 0.9703822 | Acc train: 0.7510000 | Acc validation: 0.7100000
# f1_score is 0.7937806873977088 0.7580645161290321
# roc_auc_score is 0.748 0.7
# Iter:    49 | Cost: 0.9702579 | Acc train: 0.7480000 | Acc validation: 0.7000000
# f1_score is 0.7851500789889415 0.765625
# roc_auc_score is 0.728 0.7
# Iter:    50 | Cost: 0.9702286 | Acc train: 0.7280000 | Acc validation: 0.7000000
# f1_score is 0.7799530148786219 0.7692307692307693
# roc_auc_score is 0.719 0.7
# Iter:    51 | Cost: 0.9701798 | Acc train: 0.7190000 | Acc validation: 0.7000000
# f1_score is 0.7744945567651633 0.7692307692307693
# roc_auc_score is 0.71 0.7
# ...
# f1_score is 0.6662216288384513 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    23 | Cost: 0.9902384 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6657754010695187 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    24 | Cost: 0.9898739 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6657754010695187 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    25 | Cost: 0.9895979 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6653306613226453 0.6711409395973155
# roc_auc_score is 0.499 0.51
# Iter:    26 | Cost: 0.9893401 | Acc train: 0.4990000 | Acc validation: 0.5100000
# f1_score is 0.6653306613226453 0.6666666666666666
# roc_auc_score is 0.499 0.5
# Iter:    27 | Cost: 0.9891582 | Acc train: 0.4990000 | Acc validation: 0.5000000
# f1_score is 0.6662216288384513 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    28 | Cost: 0.9889602 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6657771847898599 0.6666666666666666
# roc_auc_score is 0.499 0.5
# Iter:    29 | Cost: 0.9887403 | Acc train: 0.4990000 | Acc validation: 0.5000000
# f1_score is 0.6657771847898599 0.6666666666666666
# roc_auc_score is 0.499 0.5
# Iter:    30 | Cost: 0.9885774 | Acc train: 0.4990000 | Acc validation: 0.5000000
# f1_score is 0.6657771847898599 0.6666666666666666
# roc_auc_score is 0.499 0.5
# Iter:    31 | Cost: 0.9883897 | Acc train: 0.4990000 | Acc validation: 0.5000000
# f1_score is 0.6657771847898599 0.6711409395973155
# roc_auc_score is 0.499 0.51
# Iter:    32 | Cost: 0.9882326 | Acc train: 0.4990000 | Acc validation: 0.5100000
# f1_score is 0.6666666666666666 0.6711409395973155
# roc_auc_score is 0.5 0.51
# Iter:    33 | Cost: 0.9881101 | Acc train: 0.5000000 | Acc validation: 0.5100000
# f1_score is 0.6666666666666666 0.6711409395973155
# roc_auc_score is 0.5 0.51
# Iter:    34 | Cost: 0.9879760 | Acc train: 0.5000000 | Acc validation: 0.5100000
# f1_score is 0.6666666666666666 0.6711409395973155
# roc_auc_score is 0.5 0.51
# Iter:    35 | Cost: 0.9878730 | Acc train: 0.5000000 | Acc validation: 0.5100000
# f1_score is 0.6666666666666666 0.6711409395973155
# roc_auc_score is 0.5 0.51
# Iter:    36 | Cost: 0.9877931 | Acc train: 0.5000000 | Acc validation: 0.5100000
# f1_score is 0.6666666666666666 0.6711409395973155
# roc_auc_score is 0.5 0.51
# Iter:    37 | Cost: 0.9877502 | Acc train: 0.5000000 | Acc validation: 0.5100000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    38 | Cost: 0.9877461 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    39 | Cost: 0.9877859 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    40 | Cost: 0.9878174 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    41 | Cost: 0.9878533 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    42 | Cost: 0.9878445 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    43 | Cost: 0.9878855 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    44 | Cost: 0.9879542 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    45 | Cost: 0.9879138 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    46 | Cost: 0.9878299 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    47 | Cost: 0.9877736 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    48 | Cost: 0.9876062 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    49 | Cost: 0.9874210 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    50 | Cost: 0.9872611 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6666666666666666
# roc_auc_score is 0.5 0.5
# Iter:    51 | Cost: 0.9870672 | Acc train: 0.5000000 | Acc validation: 0.5000000
# f1_score is 0.6666666666666666 0.6711409395973155
# roc_auc_score is 0.5 0.51
# Iter:    52 | Cost: 0.9867886 | Acc train: 0.5000000 | Acc validation: 0.5100000
# f1_score is 0.66711140760507 0.6711409395973155
# roc_auc_score is 0.501 0.51
# Iter:    53 | Cost: 0.9865411 | Acc train: 0.5010000 | Acc validation: 0.5100000
# f1_score is 0.6675567423230975 0.6711409395973155
# roc_auc_score is 0.502 0.51
# Iter:    54 | Cost: 0.9863152 | Acc train: 0.5020000 | Acc validation: 0.5100000
# f1_score is 0.6684491978609626 0.6711409395973155
# roc_auc_score is 0.504 0.51
# Iter:    55 | Cost: 0.9861181 | Acc train: 0.5040000 | Acc validation: 0.5100000
# f1_score is 0.6684491978609626 0.6711409395973155
# roc_auc_score is 0.504 0.51
# Iter:    56 | Cost: 0.9859056 | Acc train: 0.5040000 | Acc validation: 0.5100000
# f1_score is 0.6684491978609626 0.6711409395973155
# roc_auc_score is 0.504 0.51
# Iter:    57 | Cost: 0.9857261 | Acc train: 0.5040000 | Acc validation: 0.5100000
# f1_score is 0.6702412868632708 0.6711409395973155
# roc_auc_score is 0.508 0.51
# Iter:    58 | Cost: 0.9855422 | Acc train: 0.5080000 | Acc validation: 0.5100000
# f1_score is 0.6729475100942127 0.6711409395973155
# roc_auc_score is 0.514 0.51
# Iter:    59 | Cost: 0.9853592 | Acc train: 0.5140000 | Acc validation: 0.5100000
# f1_score is 0.6747638326585695 0.6756756756756758
# roc_auc_score is 0.518 0.52
# Iter:    60 | Cost: 0.9852124 | Acc train: 0.5180000 | Acc validation: 0.5200000
# f1_score is 0.6811989100817438 0.6802721088435374
# roc_auc_score is 0.532 0.53
# Iter:    61 | Cost: 0.9850951 | Acc train: 0.5320000 | Acc validation: 0.5300000
# f1_score is 0.6821282401091405 0.684931506849315
# roc_auc_score is 0.534 0.54
# Iter:    62 | Cost: 0.9850065 | Acc train: 0.5340000 | Acc validation: 0.5400000
# f1_score is 0.6868547832071576 0.6896551724137931
# roc_auc_score is 0.5449999999999999 0.55
# Iter:    63 | Cost: 0.9849331 | Acc train: 0.5450000 | Acc validation: 0.5500000
# f1_score is 0.6892265193370165 0.6896551724137931
# roc_auc_score is 0.5499999999999999 0.55
# Iter:    64 | Cost: 0.9848682 | Acc train: 0.5500000 | Acc validation: 0.5500000
# f1_score is 0.6922005571030639 0.6944444444444444
# roc_auc_score is 0.5579999999999999 0.56
# Iter:    65 | Cost: 0.9848011 | Acc train: 0.5580000 | Acc validation: 0.5600000
# f1_score is 0.6926829268292682 0.6944444444444444
# roc_auc_score is 0.5589999999999999 0.56
# Iter:    66 | Cost: 0.9847501 | Acc train: 0.5590000 | Acc validation: 0.5600000
# f1_score is 0.693165969316597 0.6944444444444444
# roc_auc_score is 0.56 0.56
# Iter:    67 | Cost: 0.9846974 | Acc train: 0.5600000 | Acc validation: 0.5600000
# f1_score is 0.6946191474493362 0.6944444444444444
# roc_auc_score is 0.563 0.56
# Iter:    68 | Cost: 0.9846406 | Acc train: 0.5630000 | Acc validation: 0.5600000
# f1_score is 0.6955307262569833 0.6944444444444444
# roc_auc_score is 0.5640000000000001 0.56
# Iter:    69 | Cost: 0.9845902 | Acc train: 0.5640000 | Acc validation: 0.5600000
# f1_score is 0.6955307262569833 0.6944444444444444
# roc_auc_score is 0.5640000000000001 0.56
# Iter:    70 | Cost: 0.9845433 | Acc train: 0.5640000 | Acc validation: 0.5600000
# f1_score is 0.6955307262569833 0.6896551724137931
# roc_auc_score is 0.5640000000000001 0.55
# Iter:    71 | Cost: 0.9844960 | Acc train: 0.5640000 | Acc validation: 0.5500000
# f1_score is 0.6926286509040332 0.6896551724137931
# roc_auc_score is 0.558 0.55
# Iter:    72 | Cost: 0.9844421 | Acc train: 0.5580000 | Acc validation: 0.5500000
# f1_score is 0.693000693000693 0.6896551724137931
# roc_auc_score is 0.5569999999999999 0.55
# Iter:    73 | Cost: 0.9843915 | Acc train: 0.5570000 | Acc validation: 0.5500000
# f1_score is 0.693000693000693 0.6896551724137931
# roc_auc_score is 0.5569999999999999 0.55
# Iter:    74 | Cost: 0.9843348 | Acc train: 0.5570000 | Acc validation: 0.5500000
# f1_score is 0.6934812760055479 0.6896551724137931
# roc_auc_score is 0.558 0.55
# Iter:    75 | Cost: 0.9842833 | Acc train: 0.5580000 | Acc validation: 0.5500000
# f1_score is 0.6939625260235947 0.6896551724137931
# roc_auc_score is 0.5589999999999999 0.55
# Iter:    76 | Cost: 0.9842349 | Acc train: 0.5590000 | Acc validation: 0.5500000
# f1_score is 0.6954102920723227 0.6896551724137931
# roc_auc_score is 0.562 0.55
# Iter:    77 | Cost: 0.9841920 | Acc train: 0.5620000 | Acc validation: 0.5500000
# f1_score is 0.696927374301676 0.6944444444444444
# roc_auc_score is 0.5660000000000001 0.56
# Iter:    78 | Cost: 0.9841517 | Acc train: 0.5660000 | Acc validation: 0.5600000
# f1_score is 0.6949270326615705 0.6896551724137931
# roc_auc_score is 0.5609999999999999 0.55
# Iter:    79 | Cost: 0.9841251 | Acc train: 0.5610000 | Acc validation: 0.5500000
# f1_score is 0.6939625260235947 0.6896551724137931
# roc_auc_score is 0.5589999999999999 0.55
# Iter:    80 | Cost: 0.9840888 | Acc train: 0.5590000 | Acc validation: 0.5500000
# f1_score is 0.693000693000693 0.6896551724137931
# roc_auc_score is 0.5569999999999999 0.55
# Iter:    81 | Cost: 0.9840633 | Acc train: 0.5570000 | Acc validation: 0.5500000
# f1_score is 0.6906077348066298 0.6896551724137931
# roc_auc_score is 0.552 0.55
# Iter:    82 | Cost: 0.9840450 | Acc train: 0.5520000 | Acc validation: 0.5500000
# f1_score is 0.6882312456985548 0.6896551724137931
# roc_auc_score is 0.5469999999999999 0.55
# Iter:    83 | Cost: 0.9840396 | Acc train: 0.5470000 | Acc validation: 0.5500000
# f1_score is 0.6868131868131868 0.684931506849315
# roc_auc_score is 0.544 0.54
# Iter:    84 | Cost: 0.9840323 | Acc train: 0.5440000 | Acc validation: 0.5400000
# f1_score is 0.6863417982155113 0.684931506849315
# roc_auc_score is 0.5429999999999999 0.54
# Iter:    85 | Cost: 0.9840146 | Acc train: 0.5430000 | Acc validation: 0.5400000
# f1_score is 0.687757909215956 0.684931506849315
# roc_auc_score is 0.546 0.54
# Iter:    86 | Cost: 0.9839819 | Acc train: 0.5460000 | Acc validation: 0.5400000
# f1_score is 0.6854009595613434 0.684931506849315
# roc_auc_score is 0.5409999999999999 0.54
# Iter:    87 | Cost: 0.9839683 | Acc train: 0.5410000 | Acc validation: 0.5400000
# f1_score is 0.684931506849315 0.684931506849315
# roc_auc_score is 0.54 0.54
# Iter:    88 | Cost: 0.9839509 | Acc train: 0.5400000 | Acc validation: 0.5400000
# f1_score is 0.684931506849315 0.684931506849315
# roc_auc_score is 0.54 0.54
# Iter:    89 | Cost: 0.9839291 | Acc train: 0.5400000 | Acc validation: 0.5400000
# f1_score is 0.684931506849315 0.684931506849315
# roc_auc_score is 0.54 0.54
# Iter:    90 | Cost: 0.9839082 | Acc train: 0.5400000 | Acc validation: 0.5400000
# f1_score is 0.6830601092896176 0.6802721088435374
# roc_auc_score is 0.536 0.53
# Iter:    91 | Cost: 0.9839058 | Acc train: 0.5360000 | Acc validation: 0.5300000
# f1_score is 0.6802721088435374 0.6802721088435374
# roc_auc_score is 0.53 0.53
# Iter:    92 | Cost: 0.9839074 | Acc train: 0.5300000 | Acc validation: 0.5300000
# f1_score is 0.6793478260869565 0.6756756756756758
# roc_auc_score is 0.528 0.52
# Iter:    93 | Cost: 0.9839174 | Acc train: 0.5280000 | Acc validation: 0.5200000
# f1_score is 0.6775067750677507 0.6711409395973155
# roc_auc_score is 0.524 0.51
# Iter:    94 | Cost: 0.9839645 | Acc train: 0.5240000 | Acc validation: 0.5100000
# f1_score is 0.676132521974307 0.6711409395973155
# roc_auc_score is 0.521 0.51
# Iter:    95 | Cost: 0.9839711 | Acc train: 0.5210000 | Acc validation: 0.5100000
# f1_score is 0.675219446320054 0.6711409395973155
# roc_auc_score is 0.519 0.51
# Iter:    96 | Cost: 0.9839831 | Acc train: 0.5190000 | Acc validation: 0.5100000
# f1_score is 0.675219446320054 0.6711409395973155
# roc_auc_score is 0.519 0.51
# Iter:    97 | Cost: 0.9840056 | Acc train: 0.5190000 | Acc validation: 0.5100000
# f1_score is 0.6743088334457181 0.6711409395973155
# roc_auc_score is 0.517 0.51
# Iter:    98 | Cost: 0.9839907 | Acc train: 0.5170000 | Acc validation: 0.5100000
# f1_score is 0.675219446320054 0.6711409395973155
# roc_auc_score is 0.519 0.51
# Iter:    99 | Cost: 0.9839224 | Acc train: 0.5190000 | Acc validation: 0.5100000
# f1_score is 0.675219446320054 0.6711409395973155
# roc_auc_score is 0.519 0.51
# Iter:   100 | Cost: 0.9838647 | Acc train: 0.5190000 | Acc validation: 0.5100000
# f1_score is 0.6756756756756758 0.6711409395973155
# roc_auc_score is 0.52 0.51
# Iter:   101 | Cost: 0.9837889 | Acc train: 0.5200000 | Acc validation: 0.5100000
# f1_score is 0.676132521974307 0.6711409395973155
# roc_auc_score is 0.521 0.51
# Iter:   102 | Cost: 0.9837038 | Acc train: 0.5210000 | Acc validation: 0.5100000
# f1_score is 0.6779661016949152 0.6711409395973155
# roc_auc_score is 0.525 0.51
# Iter:   103 | Cost: 0.9836111 | Acc train: 0.5250000 | Acc validation: 0.5100000
# f1_score is 0.6807351940095303 0.6756756756756758
# roc_auc_score is 0.531 0.52
# Iter:   104 | Cost: 0.9834629 | Acc train: 0.5310000 | Acc validation: 0.5200000
# f1_score is 0.6863417982155113 0.6802721088435374
# roc_auc_score is 0.5429999999999999 0.53
# Iter:   105 | Cost: 0.9833233 | Acc train: 0.5430000 | Acc validation: 0.5300000
# f1_score is 0.6944444444444444 0.6993006993006993
# roc_auc_score is 0.56 0.5700000000000001
# Iter:   106 | Cost: 0.9831818 | Acc train: 0.5600000 | Acc validation: 0.5700000
# f1_score is 0.7013352073085033 0.704225352112676
# roc_auc_score is 0.575 0.5800000000000001
# Iter:   107 | Cost: 0.9830867 | Acc train: 0.5750000 | Acc validation: 0.5800000
# f1_score is 0.7059659090909092 0.7092198581560284
# roc_auc_score is 0.586 0.5900000000000001
# Iter:   108 | Cost: 0.9830130 | Acc train: 0.5860000 | Acc validation: 0.5900000
# f1_score is 0.7106017191977078 0.7101449275362319
# roc_auc_score is 0.596 0.6
# Iter:   109 | Cost: 0.9829491 | Acc train: 0.5960000 | Acc validation: 0.6000000
# f1_score is 0.7126269956458637 0.7007299270072993
# roc_auc_score is 0.604 0.59
# Iter:   110 | Cost: 0.9828981 | Acc train: 0.6040000 | Acc validation: 0.5900000
# f1_score is 0.7142857142857143 0.7164179104477612
# roc_auc_score is 0.612 0.62
# Iter:   111 | Cost: 0.9828566 | Acc train: 0.6120000 | Acc validation: 0.6200000
# f1_score is 0.7092846270928462 0.671875
# roc_auc_score is 0.6180000000000001 0.5800000000000001
# Iter:   112 | Cost: 0.9828353 | Acc train: 0.6180000 | Acc validation: 0.5800000
# f1_score is 0.6923076923076923 0.6446280991735538
# roc_auc_score is 0.608 0.5700000000000001
# Iter:   113 | Cost: 0.9828310 | Acc train: 0.6080000 | Acc validation: 0.5700000
# f1_score is 0.6699426699426699 0.5614035087719298
# roc_auc_score is 0.597 0.5
# Iter:   114 | Cost: 0.9828604 | Acc train: 0.5970000 | Acc validation: 0.5000000
# f1_score is 0.6547008547008548 0.47169811320754723
# roc_auc_score is 0.5960000000000001 0.44000000000000006
# Iter:   115 | Cost: 0.9829344 | Acc train: 0.5960000 | Acc validation: 0.4400000
# f1_score is 0.6444043321299638 0.4423076923076923
# roc_auc_score is 0.606 0.42
# Iter:   116 | Cost: 0.9830507 | Acc train: 0.6060000 | Acc validation: 0.4200000
# f1_score is 0.6131805157593123 0.4421052631578947
# roc_auc_score is 0.595 0.47
# Iter:   117 | Cost: 0.9831783 | Acc train: 0.5950000 | Acc validation: 0.4700000
# f1_score is 0.6006006006006006 0.4222222222222222
# roc_auc_score is 0.601 0.48
# Iter:   118 | Cost: 0.9833211 | Acc train: 0.6010000 | Acc validation: 0.4800000
# f1_score is 0.6049382716049382 0.4269662921348315
# roc_auc_score is 0.616 0.49
# Iter:   119 | Cost: 0.9834149 | Acc train: 0.6160000 | Acc validation: 0.4900000
# f1_score is 0.6020833333333333 0.37209302325581395
# roc_auc_score is 0.6179999999999999 0.46
# Iter:   120 | Cost: 0.9834620 | Acc train: 0.6180000 | Acc validation: 0.4600000
# 0.3

# %%
plt.plot([i for i in range(120)],his1[0], label = 'noiseless')
plt.plot([i for i in range(120)],his1[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his1[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his1[3], label = 'p=0.3')
plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Bit flip test accuracy')
plt.legend()
plt.savefig('Angle_Encoding_Hardware_efficient_ansatz test accuracy1',dpi=600,bbox_inches='tight')
plt.show()

# %%
plt.plot([i for i in range(120)],his2[0], label = 'noiseless')
plt.plot([i for i in range(120)],his2[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his2[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his2[3], label = 'p=0.3')
plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Bit flip train accuracy')
plt.legend()
plt.savefig('Angle_Encoding_Hardware_efficient_ansatz train accuracy1',dpi=600,bbox_inches='tight')
plt.show()

# %%
plt.plot([i for i in range(120)],his3[0], label = 'noiseless')
plt.plot([i for i in range(120)],his3[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his3[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his3[3], label = 'p=0.3')
#plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Bit flip cost function')
plt.legend()
plt.savefig('Angle_Encoding_Hardware_efficient_ansatz cost function1',dpi=600,bbox_inches='tight')
plt.show()

# %%
print(his1)
print(his2)
print(his3)
# Out:
# [[0.5, 0.5, 0.5, 0.5, 0.5, 0.54, 0.66, 0.64, 0.51, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.52, 0.51, 0.53, 0.55, 0.56, 0.54, 0.52, 0.5, 0.51, 0.5, 0.5, 0.49, 0.49, 0.49, 0.5, 0.5, 0.5, 0.5, 0.5, 0.49, 0.48, 0.48, 0.47, 0.47, 0.52, 0.53, 0.6, 0.66, 0.68, 0.66, 0.67, 0.68, 0.66, 0.64, 0.58, 0.6, 0.52, 0.51, 0.44, 0.45, 0.44, 0.47, 0.49, 0.52, 0.57, 0.7, 0.71, 0.74, 0.75, 0.74, 0.72, 0.72, 0.7, 0.74, 0.74, 0.74, 0.72, 0.76, 0.74, 0.74, 0.73, 0.71, 0.57, 0.58, 0.62, 0.49, 0.46, 0.45, 0.43, 0.45, 0.46, 0.46, 0.44, 0.45, 0.5, 0.72, 0.75, 0.77, 0.74, 0.73, 0.72, 0.67, 0.67, 0.71, 0.76, 0.76, 0.68, 0.48, 0.47, 0.48, 0.48, 0.48, 0.48, 0.48, 0.48, 0.48, 0.48, 0.48, 0.52, 0.53, 0.53, 0.6, 0.82], [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.52, 0.55, 0.63, 0.68, 0.66, 0.63, 0.58, 0.51, 0.52, 0.5, 0.49, 0.49, 0.5, 0.5, 0.49, 0.5, 0.48, 0.47, 0.53, 0.68, 0.69, 0.7, 0.69, 0.7, 0.69, 0.69, 0.67, 0.68, 0.68, 0.68, 0.67, 0.69, 0.71, 0.71, 0.71, 0.71, 0.71, 0.72, 0.7, 0.72, 0.71, 0.71, 0.72, 0.69, 0.61, 0.49, 0.47, 0.47, 0.5, 0.52, 0.52, 0.58, 0.64, 0.71, 0.72, 0.69, 0.69, 0.68, 0.62, 0.59, 0.57, 0.53, 0.54, 0.59, 0.65, 0.69, 0.69, 0.69, 0.69, 0.69, 0.69, 0.7, 0.71, 0.7, 0.55, 0.49, 0.4, 0.41, 0.41, 0.41, 0.43, 0.43, 0.4, 0.41, 0.43, 0.42, 0.43, 0.41, 0.46, 0.48, 0.49, 0.49, 0.49, 0.5, 0.49, 0.49, 0.41, 0.41, 0.43, 0.42, 0.48, 0.59, 0.65, 0.72, 0.72, 0.72, 0.72, 0.72, 0.72, 0.7, 0.69], [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.52, 0.58, 0.66, 0.73, 0.62, 0.57, 0.56, 0.54, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.48, 0.47, 0.46, 0.52, 0.55, 0.67, 0.67, 0.69, 0.71, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.71, 0.71, 0.71, 0.73, 0.67, 0.66, 0.66, 0.67, 0.66, 0.57, 0.63, 0.63, 0.63, 0.52, 0.48, 0.47, 0.52, 0.66, 0.72, 0.72, 0.71, 0.71, 0.69, 0.69, 0.69, 0.69, 0.69, 0.69, 0.69, 0.69, 0.69, 0.69, 0.71, 0.73, 0.67, 0.58, 0.48, 0.45, 0.45, 0.44, 0.45, 0.45, 0.48, 0.6, 0.63, 0.68, 0.68, 0.64, 0.58, 0.44, 0.43, 0.42, 0.43, 0.42, 0.41, 0.43, 0.44, 0.57, 0.67, 0.69, 0.72], [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.51, 0.5, 0.5, 0.5, 0.5, 0.5, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.52, 0.53, 0.54, 0.55, 0.55, 0.56, 0.56, 0.56, 0.56, 0.56, 0.56, 0.55, 0.55, 0.55, 0.55, 0.55, 0.55, 0.55, 0.56, 0.55, 0.55, 0.55, 0.55, 0.55, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.53, 0.53, 0.52, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.52, 0.53, 0.57, 0.58, 0.59, 0.6, 0.59, 0.62, 0.58, 0.57, 0.5, 0.44, 0.42, 0.47, 0.48, 0.49, 0.46]]
# [[0.5, 0.5, 0.5, 0.5, 0.5, 0.533, 0.678, 0.617, 0.531, 0.507, 0.501, 0.501, 0.501, 0.501, 0.501, 0.502, 0.509, 0.519, 0.541, 0.569, 0.613, 0.624, 0.627, 0.614, 0.61, 0.571, 0.536, 0.507, 0.497, 0.497, 0.494, 0.494, 0.496, 0.496, 0.495, 0.493, 0.492, 0.491, 0.489, 0.478, 0.48, 0.511, 0.559, 0.67, 0.685, 0.711, 0.678, 0.69, 0.707, 0.666, 0.654, 0.59, 0.609, 0.544, 0.507, 0.464, 0.456, 0.46, 0.487, 0.514, 0.524, 0.567, 0.709, 0.732, 0.772, 0.782, 0.739, 0.716, 0.703, 0.699, 0.757, 0.781, 0.779, 0.773, 0.781, 0.774, 0.782, 0.77, 0.706, 0.551, 0.57, 0.609, 0.511, 0.48, 0.447, 0.452, 0.454, 0.468, 0.46, 0.455, 0.452, 0.518, 0.722, 0.79, 0.79, 0.769, 0.747, 0.732, 0.685, 0.684, 0.724, 0.778, 0.786, 0.671, 0.501, 0.474, 0.487, 0.487, 0.483, 0.488, 0.486, 0.488, 0.49, 0.489, 0.485, 0.489, 0.494, 0.497, 0.559, 0.683], [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.501, 0.53, 0.628, 0.677, 0.67, 0.643, 0.586, 0.552, 0.546, 0.537, 0.531, 0.522, 0.518, 0.507, 0.506, 0.507, 0.517, 0.519, 0.55, 0.659, 0.723, 0.739, 0.758, 0.757, 0.763, 0.735, 0.691, 0.699, 0.7, 0.701, 0.727, 0.745, 0.763, 0.767, 0.765, 0.761, 0.759, 0.761, 0.764, 0.762, 0.76, 0.759, 0.76, 0.74, 0.645, 0.538, 0.506, 0.516, 0.567, 0.599, 0.615, 0.627, 0.678, 0.747, 0.75, 0.706, 0.679, 0.658, 0.625, 0.586, 0.556, 0.542, 0.549, 0.587, 0.643, 0.666, 0.681, 0.693, 0.686, 0.682, 0.683, 0.713, 0.758, 0.743, 0.632, 0.557, 0.479, 0.466, 0.45, 0.452, 0.461, 0.497, 0.489, 0.471, 0.462, 0.459, 0.463, 0.476, 0.519, 0.531, 0.561, 0.545, 0.544, 0.578, 0.569, 0.546, 0.508, 0.495, 0.477, 0.481, 0.546, 0.66, 0.714, 0.761, 0.74, 0.721, 0.718, 0.718, 0.718, 0.699, 0.677], [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.501, 0.505, 0.551, 0.625, 0.67, 0.61, 0.574, 0.556, 0.542, 0.538, 0.527, 0.527, 0.523, 0.52, 0.515, 0.515, 0.518, 0.523, 0.519, 0.517, 0.519, 0.526, 0.527, 0.523, 0.523, 0.521, 0.521, 0.531, 0.525, 0.517, 0.529, 0.597, 0.667, 0.708, 0.725, 0.751, 0.748, 0.728, 0.719, 0.71, 0.705, 0.712, 0.712, 0.713, 0.734, 0.738, 0.745, 0.761, 0.756, 0.763, 0.748, 0.717, 0.707, 0.708, 0.695, 0.669, 0.627, 0.636, 0.636, 0.633, 0.581, 0.524, 0.511, 0.579, 0.686, 0.741, 0.763, 0.736, 0.717, 0.698, 0.691, 0.679, 0.673, 0.667, 0.665, 0.667, 0.678, 0.693, 0.712, 0.742, 0.767, 0.698, 0.587, 0.532, 0.496, 0.488, 0.486, 0.488, 0.487, 0.533, 0.593, 0.645, 0.684, 0.679, 0.651, 0.572, 0.487, 0.477, 0.468, 0.455, 0.456, 0.452, 0.461, 0.486, 0.551, 0.657, 0.728, 0.76], [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.501, 0.501, 0.501, 0.5, 0.5, 0.5, 0.499, 0.499, 0.5, 0.499, 0.499, 0.499, 0.499, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.501, 0.502, 0.504, 0.504, 0.504, 0.508, 0.514, 0.518, 0.532, 0.534, 0.545, 0.55, 0.558, 0.559, 0.56, 0.563, 0.564, 0.564, 0.564, 0.558, 0.557, 0.557, 0.558, 0.559, 0.562, 0.566, 0.561, 0.559, 0.557, 0.552, 0.547, 0.544, 0.543, 0.546, 0.541, 0.54, 0.54, 0.54, 0.536, 0.53, 0.528, 0.524, 0.521, 0.519, 0.519, 0.517, 0.519, 0.519, 0.52, 0.521, 0.525, 0.531, 0.543, 0.56, 0.575, 0.586, 0.596, 0.604, 0.612, 0.618, 0.608, 0.597, 0.596, 0.606, 0.595, 0.601, 0.616, 0.618]]
# [[1.1512804668429328, 1.1082277904032398, 1.0607640939869747, 1.0194065300883013, 0.9878208620537957, 0.9697340220934906, 0.9629230860109479, 0.9629418122608722, 0.9656090987162661, 0.969209914970821, 0.9720385281579239, 0.9729588377203089, 0.972236188580473, 0.9712603312357864, 0.9695922531248419, 0.9678722526857192, 0.966906119450437, 0.9663479305380559, 0.9660189454697274, 0.9659603523818083, 0.9661231564244599, 0.9650271827809112, 0.9632569563215687, 0.9614771964669118, 0.9599148798506778, 0.9574747999431297, 0.9552232905891089, 0.9531500892725614, 0.9519225698072921, 0.9510279233212177, 0.9501685376955854, 0.9495833732601082, 0.9491045087331961, 0.948494299669662, 0.9476069288118868, 0.9464174720398131, 0.9446002344385231, 0.942758114553869, 0.9407170066132319, 0.9380528824391343, 0.9355884655245409, 0.9342846828808217, 0.9334104810560476, 0.9330501801251703, 0.9319595929518795, 0.9310197877384543, 0.92910355969959, 0.9278848871200692, 0.9269143226503188, 0.9252744327217445, 0.9240335640218875, 0.9228166818123537, 0.9218651005156491, 0.9210160434698801, 0.9206511280507231, 0.9216882920055883, 0.9219694274916459, 0.9208724269320466, 0.9193105149526547, 0.9179054375568855, 0.9171825965318403, 0.9163269504436874, 0.9158720068825552, 0.9157012134316925, 0.9165806970500157, 0.9174749979234582, 0.9216748483226317, 0.9242010997266379, 0.92543595417616, 0.9266854458227735, 0.9188036080510473, 0.915160899003371, 0.9148671378436204, 0.914109224305505, 0.9160774089412972, 0.9164284136321029, 0.9144840035084865, 0.913641388203778, 0.9126146118219437, 0.9130803941099103, 0.9128016894427802, 0.9124056135613695, 0.9136140784806521, 0.9150980317907463, 0.9180287457121928, 0.9193243284262534, 0.9217001979578138, 0.9256232381583748, 0.9219712128685186, 0.9186051159260057, 0.9162840220229362, 0.9110537519125816, 0.9093985645299579, 0.9103943162440332, 0.911664238820376, 0.9141921031250109, 0.9162585178332867, 0.91860154843482, 0.924652746576746, 0.9243983984395518, 0.9187393693245826, 0.9120249903774136, 0.9071412671415761, 0.9059879738329005, 0.9075885591165718, 0.9134727256532996, 0.9209708081618907, 0.9189400503773302, 0.9155041674133854, 0.9159541341413259, 0.9136341973437198, 0.9138497058642507, 0.9136706621878093, 0.910440532323046, 0.9052656458005305, 0.9002695607673126, 0.8984541333389424, 0.8966740297744293, 0.8940128332663232, 0.8916116651084951], [1.085973168624858, 1.0769673714863688, 1.0657887283828982, 1.0559284810479113, 1.0410322033996458, 1.0279014135029667, 1.0151092101469807, 1.0005570822513672, 0.988959735229686, 0.9787633183298057, 0.9724627668873871, 0.9685676903452591, 0.9663692491725459, 0.9653653771009979, 0.9647290986055516, 0.9644559160693627, 0.9644397786681506, 0.9638198948641864, 0.9630406766926661, 0.9624467916877523, 0.9620378850224232, 0.9620161189149049, 0.9624996642503677, 0.9620479077193741, 0.9604099140104462, 0.9586091487681374, 0.9569753249222743, 0.9552788532720007, 0.954591816385381, 0.9543095140055431, 0.9539208915756976, 0.9535829456158574, 0.9534616987871467, 0.9527540965717567, 0.9517647625143634, 0.9509581430811678, 0.9503849966198197, 0.9498301445035314, 0.9493037990105706, 0.9488652246387902, 0.9484144736275518, 0.9483139567315181, 0.9480289753516784, 0.9475913610253596, 0.9473903443069955, 0.9471071551696152, 0.9466154654923638, 0.9460164433287345, 0.9455379854465052, 0.9456327489212338, 0.9455560020755645, 0.9451796254481765, 0.9443566779781445, 0.9444242772982584, 0.9450978627821587, 0.9454446846747063, 0.945325081604133, 0.9448076678004442, 0.944493826763164, 0.9442861950299254, 0.9441700449033608, 0.9438051086781064, 0.9437054271755001, 0.9447033699093877, 0.9470920992867092, 0.9487797242143343, 0.9509348514762749, 0.9544515724806444, 0.9582777560377704, 0.962235038463847, 0.9641048886751212, 0.9629156762061066, 0.9580206705268297, 0.9523700667294837, 0.949612377567399, 0.9481485015201615, 0.9476087198747489, 0.9479027677314469, 0.948142573259382, 0.9480780356381383, 0.9461988075538355, 0 ...

# %%
plt.figure(figsize=(18, 4))
plt.subplot(1, 3, 1)

plt.plot([i for i in range(120)],his1[0], label = 'noiseless')
plt.plot([i for i in range(120)],his1[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his1[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his1[3], label = 'p=0.3')
#plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Bit flip test accuracy')
plt.legend()
#plt.title("plot 1")

plt.subplot(1, 3, 2)

plt.plot([i for i in range(120)],his2[0], label = 'noiseless')
plt.plot([i for i in range(120)],his2[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his2[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his2[3], label = 'p=0.3')
#plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Bit flip train accuracy')
plt.legend()
#plt.title("plot 2")

plt.subplot(1, 3, 3)

plt.plot([i for i in range(120)],his3[0], label = 'noiseless')
plt.plot([i for i in range(120)],his3[1], label = 'p=0.1')
plt.plot([i for i in range(120)],his3[2], label = 'p=0.2')
plt.plot([i for i in range(120)],his3[3], label = 'p=0.3')
#plt.ylim((0, 1.1))
plt.xlabel('Training steps')
plt.ylabel('Bit flip cost function')
plt.legend()
#plt.title("plot 2")

#plt.suptitle("RUNOOB subplot Test")
plt.savefig('Angle_Encoding_Hardware_efficient_ansatz5',dpi=800,bbox_inches='tight')
plt.show()
